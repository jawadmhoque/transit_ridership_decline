# %%
import pandas as pd
import seaborn as sns
import numpy as np
import linearmodels as lm
import matplotlib
import math
import statsmodels.formula.api as smf

from linearmodels.panel import PanelOLS
from linearmodels.panel import RandomEffects
from linearmodels.panel import FirstDifferenceOLS
from linearmodels.panel import compare
from matplotlib import pyplot as plt

from pandas.api.types import is_numeric_dtype

pd.set_option('display.max_columns', 500)

# %matplotlib inline

# %%
# read the main data set
df=pd.read_csv('final_dataset_oct_24.csv',
                    encoding='utf-8')

# %%
# exclude if ridership is zero--missing data
df = df[df['UPT']>0]

# %%
# set the indices
df['ID'] = df['MNAME'] + '-' + df['Mode']
df=df.set_index(['ID','Year'])

# %%
# keep only the numeric columns -- the estimation will give an error otherwise
df = df.select_dtypes(include=[np.number])

# %%
# create a log of all fields
for col in df.columns:
    df[col+'_log'] = np.log(df[col]+1)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:3: RuntimeWarning: invalid value encountered in log
#   app.launch_new_instance()

# %%
# check the data
df.head()
# Out:
#                                   CBSA  NEW_CBSA     UPT     VRM   UPT_ADJ  \
# ID                         Year
# Abilene, TX Metro Area-Bus 2002  10180       NaN  493073  389678  493073.0
#                            2003  10180       NaN  475747  383239  475747.0
#                            2004  10180       NaN  469981  388907  469981.0
#                            2005  10180       NaN  507165  444176  507165.0
#                            2006  10180       NaN  493638  441300  493638.0
#
#                                   VRM_ADJ  VRH_ADJ  FARE_TOTAL  FARE_per_UPT  \
# ID                         Year
# Abilene, TX Metro Area-Bus 2002  389678.0  29016.0    162609.0      0.329787
#                            2003  383239.0  28597.0    173563.0      0.364822
#                            2004  388907.0  29126.0    185046.0      0.393731
#                            2005  444176.0  31147.0    213965.0      0.421884
#                            2006  441300.0  30750.0    201795.0      0.408791
#
#                                  AREALANDPT      Tot_Pop  Tot_Instate_Pop  \
# ID                         Year
# Abilene, TX Metro Area-Bus 2002   141756054  117258.2188      87723.96875
#                            2003   141756054  127098.1250      93677.12500
#                            2004   141756054  137113.5000      99787.50000
#                            2005   141756054  146427.0000     105269.00000
#                            2006   141756054  158548.0000     113266.00000
#
#                                  Tot_Outstate_Pop  Tot_NonUSA_POP  \
# ID                         Year
# Abilene, TX Metro Area-Bus 2002       23752.17188     2987.484375
#                            2003       26964.31250     2834.062500
#                            2004       30227.75000     2648.750000
#                            2005       33286.00000     2591.000000
#                            2006       37165.00000     2023.000000
#
#                                  Total_Median_Income_Individual  \
# ID                         Year
# Abilene, TX Metro Area-Bus 2002                     19756.67188
#                            2003                     19941.31250
#                            2004                     20132.75000
#                            2005                     20297.00000
#                            2006                     20570.00000
#
#                                  Native_Instate_Med_Inc_Indiv  \
# ID                         Year
# Abilene, TX Metro Area-Bus 2002                   22848.10938
#                            2003                   21972.56250
#                            2004                   21085.75000
#                            2005                   20244.00000
#                            2006                   19222.00000
#
#                                  Native_Outstate_Med_Inc_Indiv  \
# ID                         Year
# Abilene, TX Metro Area-Bus 2002                    17091.51563
#                            2003                    18472.93750
#                            2004                    19808.25000
#                            2005                    21328.00000
#                            2006                    22110.00000
#
#                                  Total_Pop_Poverty  Pop_Below100_Poverty  \
# ID                         Year
# Abilene, TX Metro Area-Bus 2002          147631.94                 22.30
#                            2003          147198.25                 20.72
#                            2004          146801.00                 19.13
#                            2005          146258.00                 17.60
#                            2006          146298.00                 15.80
#
#                                  Pop_Below150_Poverty  Pop_Above150_Poverty  \
# ID                         Year
# Abilene, TX Metro Area-Bus 2002                 12.89                 64.82
#                            2003                 12.86                 66.43
#                            2004                 12.88                 68.00
#                            2005                 12.70                 69.70
#                            2006                 13.30                 70.90
#
#                                  Age_under18  Age_18to64  Age_over64  \
# ID                         Year
# Abilene, TX Metro Area-Bus 2002        31.23       54.90       13.87
#                            2003        29.78       56.41       13.81
#                            2004        28.30       57.95       13.75
#                            2005        26.90       59.40       13.70
#                            2006        25.20       61.20       13.60
#
#                                  Total_HH  HH_0Veh   HH_1Veh   HH_2Veh  \
# ID                         Year
# Abilene, TX Metro Area-Bus 2002  61601.69  1195.73  27303.56  21926.16
#                            2003  61229.25  1515.06  25910.75  22846.38
#                            2004  60833.00  1823.75  24514.00  23787.50
#                            2005  60532.00  2175.00  23133.00  24645.00
#                            2006  59850.00  2356.00  21689.00  25837.00
#
#                                  HH_3Veh  HH_4+Veh  PCT_HH_NO_VEH  HH_MED_INC  \
# ID                         Year
# Abilene, TX Metro Area-Bus 2002  8121.36   3054.88           1.94   25775.875
#                            2003  8038.56   2918.50           2.47   29077.500
#                            2004  7942.75   2765.00           3.00   32452.000
#                            2005  7899.00   2680.00           3.59   35535.000
#                            2006  7647.00   2321.00           3.94   39784.000
#
#                                  HH_MEAN_INC  INC_U35  INC_35_100  INC_100P  \
# ID                         Year
# Abilene, TX Metro Area-Bus 2002    30134.875    61.74       34.07      4.19
#                            2003    35373.500    57.54       36.92      5.54
#                            2004    40728.000    53.25       39.83      6.93
#                            2005    45619.000    49.30       42.50      8.20
#                            2006    52364.000    44.00       46.10      9.90
#
#                                  TOT_UNEMP_MSA  TOT_EMP_MSA  TOT_LABOR_MSA  \
# ID                         Year
# Abilene, TX Metro Area-Bus 2002        3945.33     73760.33       77705.67
#                            2003        4222.75     75377.08       79599.83
#                            2004        3712.17     75862.08       79574.25
#                            2005        3375.75     76704.50       80080.25
#                            2006        3242.08     78203.25       81445.33
#
#                                  UNEMP_RATE_PCT  EMP_RATE_PCT  GasPrice  \
# ID                         Year
# Abilene, TX Metro Area-Bus 2002            5.08         94.92      1.32
#                            2003            5.30         94.70      1.50
#                            2004            4.67         95.33      1.79
#                            2005            4.22         95.78      2.23
#                            2006            3.98         96.02      2.52
#
#                                  Area_acre  AVG_SPEED  2018_Dollar_Multiplier  \
# ID                         Year
# Abilene, TX Metro Area-Bus 2002        NaN      13.43                    1.40
#                            2003        NaN      13.40                    1.37
#                            2004        NaN      13.35                    1.33
#                            2005     1216.0      14.26                    1.29
#                            2006     1216.0      14.35                    1.25
#
#                                  TNC_ARRIVAL  TNC_FLAG  YEARS_SINCE_TNC  \
# ID                         Year
# Abilene, TX Metro Area-Bus 2002         2016         0                0
#                            2003         2016         0                0
#                            2004         2016         0                0
#                            2005         2016         0                0
#                            2006         2016         0                0
#
#                                  PROBLEM_FLAG  CBSA_log  NEW_CBSA_log  \
# ID                         Year
# Abilene, TX Metro Area-Bus 2002           NaN  9.228279           NaN
#                            2003           NaN  9.228279           NaN
#                            2004           NaN  9.228279           NaN
#                            2005           NaN  9.228279           NaN
#                            2006           NaN  9.228279           NaN
#
#                                    UPT_log    VRM_log  UPT_ADJ_log  \
# ID                         Year
# Abilene, TX Metro Area-Bus 2002  13.108415  12.873079    13.108415
#                            2003  13.072644  12.856417    13.072644
#                            2004  13.060450  12.871098    13.060450
#                            2005  13.136594  13.003978    13.136594
#                            2006  13.109560  12.997482    13.109560
#
#                                  VRM_ADJ_log  VRH_ADJ_log  FARE_TOTAL_log  \
# ID                         Year
# Abilene, TX Metro Area-Bus 2002    12.873079    10.275637       11.999110
#                            2003    12.856417    10.261092       12.064302
#                            2004    12.871098    10.279421       12.128365
#                            2005    13.003978    10.346505       12.273572
#                            2006    12.997482    10.333678       12.215013
#
#                                  FARE_per_UPT_log  AREALANDPT_log  \
# ID                         Year
# Abilene, TX Metro Area-Bus 2002          0.285019       18.769618
#                            2003          0.311024       18.769618
#                            2004          0.331984       18.769618
#                            2005          0.351983       18.769618
#                            2006          0.342732       18.769618
#
#                                  Tot_Pop_log  Tot_Instate_Pop_log  \
# ID                         Year
# Abilene, TX Metro Area-Bus 2002    11.672142            11.381962
#                            2003    11.752723            11.447620
#                            2004    11.828572            11.510808
#                            2005    11.894289            11.564284
#                            2006    11.973819            11.637503
#
#                                  Tot_Outstate_Pop_log  Tot_NonUSA_POP_log  \
# ID                         Year
# Abilene, TX Metro Area-Bus 2002             10.075471            8.002522
#                            2003             10.202307            7.949819
#                            2004             10.316549            7.882221
#                            2005             10.412922            7.860185
#                            2006             10.523150            7.612831
#
#                                  Total_Median_Income_Individual_log  \
# ID                         Year
# Abilene, TX Metro Area-Bus 2002                            9.891297
#                            2003                            9.900599
#                            2004                            9.910153
#                            2005                            9.918278
#                            2006                            9.931638
#
#                                  Native_Instate_Med_Inc_Indiv_log  \
# ID                         Year
# Abilene, TX Metro Area-Bus 2002                         10.036667
#                            2003                          9.997595
#                            2004                          9.956400
#                            2005                          9.915663
#                            2006                          9.863863
#
#                                  Native_Outstate_Med_Inc_Indiv_log  \
# ID                         Year
# Abilene, TX Metro Area-Bus 2002                           9.746396
#                            2003                           9.824116
#                            2004                           9.893904
#                            2005                           9.967823
#                            2006                          10.003831
#
#                                  Total_Pop_Poverty_log  \
# ID                         Year
# Abilene, TX Metro Area-Bus 2002              11.902484
#                            2003              11.899542
#                            2004              11.896840
#                            2005              11.893134
#                            2006              11.893408
#
#                                  Pop_Below100_Poverty_log  \
# ID                         Year
# Abilene, TX Metro Area-Bus 2002                  3.148453
#                            2003                  3.078233
#                            2004                  3.002211
#                            2005                  2.923162
#                            2006                  2.821379
#
#                                  Pop_Below150_Poverty_log  \
# ID                         Year
# Abilene, TX Metro Area-Bus 2002                  2.631169
#                            2003                  2.629007
#                            2004                  2.630449
#                            2005                  2.617396
#                            2006                  2.660260
#
#                                  Pop_Above150_Poverty_log  Age_under18_log  \
# ID                         Year
# Abilene, TX Metro Area-Bus 2002                  4.186924         3.472898
#                            2003                  4.211090         3.426865
#                            2004                  4.234107         3.377588
#                            2005                  4.258446         3.328627
#                            2006                  4.275276         3.265759
#
#                                  Age_18to64_log  Age_over64_log  Total_HH_log  \
# ID                         Year
# Abilene, TX Metro Area-Bus 2002        4.023564        2.699346     11.028461
#                            2003        4.050219        2.695303     11.022397
#                            2004        4.076690        2.691243     11.015904
#                            2005        4.100989        2.687847     11.010944
#                            2006        4.130355        2.681022     10.999613
#
#                                  HH_0Veh_log  HH_1Veh_log  HH_2Veh_log  \
# ID                         Year
# Abilene, TX Metro Area-Bus 2002     7.087348    10.214809     9.995481
#                            2003     7.323870    10.162452    10.036592
#                            2004     7.509198    10.107040    10.076958
#                            2005     7.685244    10.049059    10.112370
#                            2006     7.765145     9.984607    10.159602
#
#                                  HH_3Veh_log  HH_4+Veh_log  PCT_HH_NO_VEH_log  \
# ID                         Year
# Abilene, TX Metro Area-Bus 2002     9.002376      8.024823           1.078410
#                            2003     8.992130      7.979168           1.244155
#                            2004     8.980141      7.925158           1.386294
#                            2005     8.974618      7.893945           1.523880
#                            2006     8.942199      7.750184           1.597365
#
#                                  HH_MED_INC_log  HH_MEAN_INC_log  INC_U35_log  \
# ID                         Year
# Abilene, TX Metro Area-Bus 2002       10.157233        10.313472     4.138999
#                            2003       10.277754        10.473747     4.069710
#                            2004       10.387548        10.614696     3.993603
#                            2005       10.478302        10.728101     3.918005
#                            2006       10.591245        10.865994     3.806662
#
#                                  INC_35_100_log  INC_100P_log  \
# ID                         Year
# Abilene, TX Metro Area-Bus 2002        3.557346      1.646734
#                            2003        3.635479      1.877937
#                            2004        3.709417      2.070653
#                            2005        3.772761      2.219203
#                            2006        3.852273      2.388763
#
#                                  TOT_UNEMP_MSA_log  TOT_EMP_MSA_log  \
# ID                         Year
# Abilene, TX Metro Area-Bus 2002           8.280541        11.208590
#                            2003           8.348479        11.230272
#                            2004           8.219641        11.236685
#                            2005           8.124669        11.247729
#                            2006           8.084279        11.267079
#
#                                  TOT_LABOR_MSA_log  UNEMP_RATE_PCT_log  \
# ID                         Year
# Abilene, TX Metro Area-Bus 2002          11.260696            1.805005
#                            2003          11.284780            1.840550
#                            2004          11.284458            1.735189
#                            2005          11.290797            1.652497
#                            2006          11.307700            1.605430
#
#                                  EMP_RATE_PCT_log  GasPrice_log  \
# ID                         Year
# Abilene, TX Metro Area-Bus 2002          4.563515      0.841567
#                            2003          4.561218      0.916291
#                            2004          4.567780      1.026042
#                            2005          4.572440      1.172482
#                            2006          4.574917      1.258461
#
#                                  Area_acre_log  AVG_SPEED_log  \
# ID                         Year
# Abilene, TX Metro Area-Bus 2002            NaN       2.669309
#                            2003            NaN       2.667228
#                            2004            NaN       2.663750
#                            2005       7.104144       2.725235
#                            2006       7.104144       2.731115
#
#                                  2018_Dollar_Multiplier_log  TNC_ARRIVAL_log  \
# ID                         Year
# Abilene, TX Metro Area-Bus 2002                    0.875469         7.609367
#                            2003                    0.862890         7.609367
#                            2004                    0.845868         7.609367
#                            2005                    0.828552         7.609367
#                            2006                    0.810930         7.609367
#
#                                  TNC_FLAG_log  YEARS_SINCE_TNC_log  \
# ID                         Year
# Abilene, TX Metro Area-Bus 2002           0.0                  0.0
#                            2003           0.0                  0.0
#                            2004           0.0                  0.0
#                            2005           0.0                  0.0
#                            2006           0.0                  0.0
#
#                                  PROBLEM_FLAG_log
# ID                         Year
# Abilene, TX Metro Area-Bus 2002               NaN
#                            2003               NaN
#                            2004               NaN
#                            2005               NaN
#                            2006               NaN

# %%
# basic log model for bus and rail, all clusters
mod=PanelOLS.from_formula('UPT_ADJ_log \
                    ~ VRM_ADJ_log \
                    + Tot_Pop_log \
                    + TOT_EMP_MSA_log \
                    + GasPrice_log \
                    + EntityEffects \
                    ',data=df)
res=mod.fit()
print(res)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\data.py:39: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   new_df = df.copy().loc[self._full_index]
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\utility.py:476: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   warnings.warn(missing_value_warning_msg, MissingValueWarning)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:            UPT_ADJ_log   R-squared:                        0.1998
# Estimator:                   PanelOLS   R-squared (Between):              0.8893
# No. Observations:                5171   R-squared (Within):               0.1998
# Date:                Fri, Oct 25 2019   R-squared (Overall):              0.8858
# Time:                        13:51:59   Log-likelihood                   -2416.7
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      299.98
# Entities:                         361   P-value                           0.0000
# Avg Obs:                       14.324   Distribution:                  F(4,4806)
# Min Obs:                       1.0000
# Max Obs:                       17.000   F-statistic (robust):             299.98
#                                         P-value                           0.0000
# Time periods:                      17   Distribution:                  F(4,4806)
# Avg Obs:                       304.18
# Min Obs:                       253.00
# Max Obs:                       348.00
#
#                                 Parameter Estimates
# ===================================================================================
#                  Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -----------------------------------------------------------------------------------
# VRM_ADJ_log         0.2470     0.0100     24.690     0.0000      0.2274      0.2666
# Tot_Pop_log         0.0100     0.0112     0.8894     0.3738     -0.0120      0.0320
# TOT_EMP_MSA_log     0.4462     0.1059     4.2128     0.0000      0.2386      0.6539
# GasPrice_log        0.5499     0.0317     17.343     0.0000      0.4877      0.6120
# ===================================================================================
#
# F-test for Poolability: 40.581
# P-value: 0.0000
# Distribution: F(360,4806)
#
# Included effects: Entity

# %%
# basic log model for bus and rail, all clusters
mod=PanelOLS.from_formula('UPT_ADJ_log \
                    ~ VRM_ADJ_log \
                    + Tot_Pop_log \
                    + UNEMP_RATE_PCT_log \
                    + GasPrice_log \
                    + EntityEffects \
                    ',data=df)
res=mod.fit()
print(res)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\data.py:39: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   new_df = df.copy().loc[self._full_index]
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\utility.py:476: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   warnings.warn(missing_value_warning_msg, MissingValueWarning)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:            UPT_ADJ_log   R-squared:                        0.1987
# Estimator:                   PanelOLS   R-squared (Between):              0.5273
# No. Observations:                5171   R-squared (Within):               0.1987
# Date:                Fri, Oct 25 2019   R-squared (Overall):              0.5247
# Time:                        13:52:04   Log-likelihood                   -2420.4
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      297.85
# Entities:                         361   P-value                           0.0000
# Avg Obs:                       14.324   Distribution:                  F(4,4806)
# Min Obs:                       1.0000
# Max Obs:                       17.000   F-statistic (robust):             297.85
#                                         P-value                           0.0000
# Time periods:                      17   Distribution:                  F(4,4806)
# Avg Obs:                       304.18
# Min Obs:                       253.00
# Max Obs:                       348.00
#
#                                  Parameter Estimates
# ======================================================================================
#                     Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# --------------------------------------------------------------------------------------
# VRM_ADJ_log            0.2532     0.0099     25.520     0.0000      0.2337      0.2726
# Tot_Pop_log            0.0110     0.0112     0.9779     0.3282     -0.0110      0.0330
# UNEMP_RATE_PCT_log     0.0788     0.0239     3.2979     0.0010      0.0319      0.1256
# GasPrice_log           0.5416     0.0326     16.590     0.0000      0.4776      0.6056
# ======================================================================================
#
# F-test for Poolability: 46.466
# P-value: 0.0000
# Distribution: F(360,4806)
#
# Included effects: Entity

# %%
# basic log model for bus and rail, all clusters
mod=PanelOLS.from_formula('UPT_ADJ_log \
                    ~ VRM_ADJ_log \
                    + Total_HH_log \
                    + UNEMP_RATE_PCT_log \
                    + GasPrice_log \
                    + EntityEffects \
                    ',data=df)
res=mod.fit()
print(res)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\data.py:39: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   new_df = df.copy().loc[self._full_index]
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\utility.py:476: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   warnings.warn(missing_value_warning_msg, MissingValueWarning)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:            UPT_ADJ_log   R-squared:                        0.1986
# Estimator:                   PanelOLS   R-squared (Between):              0.5239
# No. Observations:                5171   R-squared (Within):               0.1986
# Date:                Fri, Oct 25 2019   R-squared (Overall):              0.5213
# Time:                        13:52:09   Log-likelihood                   -2420.7
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      297.70
# Entities:                         361   P-value                           0.0000
# Avg Obs:                       14.324   Distribution:                  F(4,4806)
# Min Obs:                       1.0000
# Max Obs:                       17.000   F-statistic (robust):             297.70
#                                         P-value                           0.0000
# Time periods:                      17   Distribution:                  F(4,4806)
# Avg Obs:                       304.18
# Min Obs:                       253.00
# Max Obs:                       348.00
#
#                                  Parameter Estimates
# ======================================================================================
#                     Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# --------------------------------------------------------------------------------------
# VRM_ADJ_log            0.2533     0.0099     25.540     0.0000      0.2339      0.2728
# Total_HH_log           0.0084     0.0122     0.6898     0.4903     -0.0154      0.0322
# UNEMP_RATE_PCT_log     0.0790     0.0239     3.3060     0.0010      0.0321      0.1258
# GasPrice_log           0.5438     0.0325     16.718     0.0000      0.4800      0.6075
# ======================================================================================
#
# F-test for Poolability: 45.734
# P-value: 0.0000
# Distribution: F(360,4806)
#
# Included effects: Entity

# %%
# basic log model for bus and rail, all clusters
mod=PanelOLS.from_formula('UPT_ADJ_log \
                    ~ VRM_ADJ_log \
                    + Tot_Pop_log \
                    + UNEMP_RATE_PCT_log \
                    + PCT_HH_NO_VEH_log \
                    + GasPrice_log \
                    + EntityEffects \
                    ',data=df)
res=mod.fit()
print(res)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\data.py:39: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   new_df = df.copy().loc[self._full_index]
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\utility.py:476: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   warnings.warn(missing_value_warning_msg, MissingValueWarning)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:            UPT_ADJ_log   R-squared:                        0.1988
# Estimator:                   PanelOLS   R-squared (Between):              0.5270
# No. Observations:                5166   R-squared (Within):               0.1988
# Date:                Fri, Oct 25 2019   R-squared (Overall):              0.5243
# Time:                        13:52:16   Log-likelihood                   -2416.8
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      238.16
# Entities:                         361   P-value                           0.0000
# Avg Obs:                       14.310   Distribution:                  F(5,4800)
# Min Obs:                       1.0000
# Max Obs:                       17.000   F-statistic (robust):             238.16
#                                         P-value                           0.0000
# Time periods:                      17   Distribution:                  F(5,4800)
# Avg Obs:                       303.88
# Min Obs:                       249.00
# Max Obs:                       348.00
#
#                                  Parameter Estimates
# ======================================================================================
#                     Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# --------------------------------------------------------------------------------------
# VRM_ADJ_log            0.2529     0.0099     25.483     0.0000      0.2335      0.2724
# Tot_Pop_log            0.0151     0.0119     1.2700     0.2041     -0.0082      0.0384
# UNEMP_RATE_PCT_log     0.0814     0.0240     3.3937     0.0007      0.0344      0.1284
# PCT_HH_NO_VEH_log     -0.0314     0.0288    -1.0886     0.2764     -0.0879      0.0251
# GasPrice_log           0.5456     0.0329     16.590     0.0000      0.4811      0.6101
# ======================================================================================
#
# F-test for Poolability: 45.307
# P-value: 0.0000
# Distribution: F(360,4800)
#
# Included effects: Entity

# %%
# basic log model for bus and rail, all clusters
mod=PanelOLS.from_formula('UPT_ADJ_log \
                    ~ VRM_ADJ_log \
                    + FARE_per_UPT_log \
                    + Tot_Pop_log \
                    + UNEMP_RATE_PCT_log \
                    + GasPrice_log \
                    + EntityEffects \
                    ',data=df)
res=mod.fit()
print(res)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\data.py:39: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   new_df = df.copy().loc[self._full_index]
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\utility.py:476: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   warnings.warn(missing_value_warning_msg, MissingValueWarning)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:            UPT_ADJ_log   R-squared:                        0.4749
# Estimator:                   PanelOLS   R-squared (Between):              0.4858
# No. Observations:                5171   R-squared (Within):               0.4749
# Date:                Fri, Oct 25 2019   R-squared (Overall):              0.4831
# Time:                        13:52:25   Log-likelihood                   -1327.4
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      869.17
# Entities:                         361   P-value                           0.0000
# Avg Obs:                       14.324   Distribution:                  F(5,4805)
# Min Obs:                       1.0000
# Max Obs:                       17.000   F-statistic (robust):             869.17
#                                         P-value                           0.0000
# Time periods:                      17   Distribution:                  F(5,4805)
# Avg Obs:                       304.18
# Min Obs:                       253.00
# Max Obs:                       348.00
#
#                                  Parameter Estimates
# ======================================================================================
#                     Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# --------------------------------------------------------------------------------------
# VRM_ADJ_log            0.2378     0.0080     29.592     0.0000      0.2221      0.2536
# FARE_per_UPT_log      -0.7702     0.0153    -50.280     0.0000     -0.8003     -0.7402
# Tot_Pop_log            0.0256     0.0091     2.8105     0.0050      0.0077      0.0434
# UNEMP_RATE_PCT_log     0.0662     0.0193     3.4245     0.0006      0.0283      0.1041
# GasPrice_log           0.5829     0.0264     22.044     0.0000      0.5310      0.6347
# ======================================================================================
#
# F-test for Poolability: 70.883
# P-value: 0.0000
# Distribution: F(360,4805)
#
# Included effects: Entity

# %%
# basic log model for bus and rail, all clusters
mod=PanelOLS.from_formula('UPT_ADJ_log \
                    ~ VRM_ADJ_log \
                    + FARE_per_UPT_log \
                    + Tot_Pop_log \
                    + TOT_EMP_MSA_log \
                    + GasPrice_log \
                    + EntityEffects \
                    ',data=df)
res=mod.fit()
print(res)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\data.py:39: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   new_df = df.copy().loc[self._full_index]
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\utility.py:476: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   warnings.warn(missing_value_warning_msg, MissingValueWarning)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:            UPT_ADJ_log   R-squared:                        0.4801
# Estimator:                   PanelOLS   R-squared (Between):              0.9635
# No. Observations:                5171   R-squared (Within):               0.4801
# Date:                Fri, Oct 25 2019   R-squared (Overall):              0.9613
# Time:                        13:52:46   Log-likelihood                   -1301.7
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      887.46
# Entities:                         361   P-value                           0.0000
# Avg Obs:                       14.324   Distribution:                  F(5,4805)
# Min Obs:                       1.0000
# Max Obs:                       17.000   F-statistic (robust):             887.46
#                                         P-value                           0.0000
# Time periods:                      17   Distribution:                  F(5,4805)
# Avg Obs:                       304.18
# Min Obs:                       253.00
# Max Obs:                       348.00
#
#                                 Parameter Estimates
# ====================================================================================
#                   Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------
# VRM_ADJ_log          0.2289     0.0081     28.356     0.0000      0.2130      0.2447
# FARE_per_UPT_log    -0.7768     0.0153    -50.899     0.0000     -0.8067     -0.7468
# Tot_Pop_log          0.0235     0.0091     2.5908     0.0096      0.0057      0.0412
# TOT_EMP_MSA_log      0.6614     0.0855     7.7365     0.0000      0.4938      0.8290
# GasPrice_log         0.5756     0.0256     22.515     0.0000      0.5254      0.6257
# ====================================================================================
#
# F-test for Poolability: 61.120
# P-value: 0.0000
# Distribution: F(360,4805)
#
# Included effects: Entity

# %%
# basic log model for bus and rail, all clusters
mod=PanelOLS.from_formula('UPT_ADJ_log \
                    ~ VRM_ADJ_log \
                    + FARE_per_UPT_log \
                    + Tot_Pop_log \
                    + TOT_EMP_MSA_log \
                    + GasPrice_log \
                    + TNC_FLAG \
                    + EntityEffects \
                    ',data=df)
res=mod.fit()
print(res)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\data.py:39: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   new_df = df.copy().loc[self._full_index]
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\utility.py:476: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   warnings.warn(missing_value_warning_msg, MissingValueWarning)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:            UPT_ADJ_log   R-squared:                        0.4815
# Estimator:                   PanelOLS   R-squared (Between):              0.8876
# No. Observations:                5171   R-squared (Within):               0.4815
# Date:                Fri, Oct 25 2019   R-squared (Overall):              0.8840
# Time:                        13:52:57   Log-likelihood                   -1294.6
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      743.62
# Entities:                         361   P-value                           0.0000
# Avg Obs:                       14.324   Distribution:                  F(6,4804)
# Min Obs:                       1.0000
# Max Obs:                       17.000   F-statistic (robust):             743.62
#                                         P-value                           0.0000
# Time periods:                      17   Distribution:                  F(6,4804)
# Avg Obs:                       304.18
# Min Obs:                       253.00
# Max Obs:                       348.00
#
#                                 Parameter Estimates
# ====================================================================================
#                   Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------
# VRM_ADJ_log          0.2271     0.0081     28.128     0.0000      0.2113      0.2430
# FARE_per_UPT_log    -0.7807     0.0153    -51.093     0.0000     -0.8106     -0.7507
# Tot_Pop_log          0.0234     0.0090     2.5813     0.0099      0.0056      0.0411
# TOT_EMP_MSA_log      0.4835     0.0985     4.9104     0.0000      0.2904      0.6765
# GasPrice_log         0.5830     0.0256     22.762     0.0000      0.5328      0.6332
# TNC_FLAG             0.0458     0.0126     3.6295     0.0003      0.0211      0.0706
# ====================================================================================
#
# F-test for Poolability: 61.303
# P-value: 0.0000
# Distribution: F(360,4804)
#
# Included effects: Entity

# %%
# basic log model for bus and rail, all clusters
mod=PanelOLS.from_formula('UPT_ADJ_log \
                    ~ VRM_ADJ_log \
                    + FARE_per_UPT_log \
                    + Tot_Pop_log \
                    + TOT_EMP_MSA_log \
                    + GasPrice_log \
                    + YEARS_SINCE_TNC \
                    + EntityEffects \
                    ',data=df)
res=mod.fit()
print(res)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\data.py:39: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   new_df = df.copy().loc[self._full_index]
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\utility.py:476: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   warnings.warn(missing_value_warning_msg, MissingValueWarning)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:            UPT_ADJ_log   R-squared:                        0.4802
# Estimator:                   PanelOLS   R-squared (Between):              0.9766
# No. Observations:                5171   R-squared (Within):               0.4802
# Date:                Fri, Oct 25 2019   R-squared (Overall):              0.9749
# Time:                        13:53:06   Log-likelihood                   -1301.3
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      739.64
# Entities:                         361   P-value                           0.0000
# Avg Obs:                       14.324   Distribution:                  F(6,4804)
# Min Obs:                       1.0000
# Max Obs:                       17.000   F-statistic (robust):             739.64
#                                         P-value                           0.0000
# Time periods:                      17   Distribution:                  F(6,4804)
# Avg Obs:                       304.18
# Min Obs:                       253.00
# Max Obs:                       348.00
#
#                                 Parameter Estimates
# ====================================================================================
#                   Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------
# VRM_ADJ_log          0.2291     0.0081     28.368     0.0000      0.2132      0.2449
# FARE_per_UPT_log    -0.7760     0.0153    -50.778     0.0000     -0.8060     -0.7461
# Tot_Pop_log          0.0234     0.0091     2.5798     0.0099      0.0056      0.0411
# TOT_EMP_MSA_log      0.7112     0.1025     6.9373     0.0000      0.5102      0.9122
# GasPrice_log         0.5725     0.0258     22.197     0.0000      0.5220      0.6231
# YEARS_SINCE_TNC     -0.0042     0.0048    -0.8801     0.3788     -0.0137      0.0052
# ====================================================================================
#
# F-test for Poolability: 61.119
# P-value: 0.0000
# Distribution: F(360,4804)
#
# Included effects: Entity

# %%
# basic log model for bus and rail, all clusters
mod=PanelOLS.from_formula('UPT_ADJ_log \
                    ~ VRM_ADJ_log \
                    + AVG_SPEED_log \
                    + FARE_per_UPT_log \
                    + Tot_Pop_log \
                    + TOT_EMP_MSA_log \
                    + GasPrice_log \
                    + YEARS_SINCE_TNC \
                    + EntityEffects \
                    ',data=df)
res=mod.fit()
print(res)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\data.py:39: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   new_df = df.copy().loc[self._full_index]
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\utility.py:476: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   warnings.warn(missing_value_warning_msg, MissingValueWarning)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:            UPT_ADJ_log   R-squared:                        0.4976
# Estimator:                   PanelOLS   R-squared (Between):              0.9582
# No. Observations:                5171   R-squared (Within):               0.4976
# Date:                Fri, Oct 25 2019   R-squared (Overall):              0.9562
# Time:                        13:53:21   Log-likelihood                   -1213.3
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      679.56
# Entities:                         361   P-value                           0.0000
# Avg Obs:                       14.324   Distribution:                  F(7,4803)
# Min Obs:                       1.0000
# Max Obs:                       17.000   F-statistic (robust):             679.56
#                                         P-value                           0.0000
# Time periods:                      17   Distribution:                  F(7,4803)
# Avg Obs:                       304.18
# Min Obs:                       253.00
# Max Obs:                       348.00
#
#                                 Parameter Estimates
# ====================================================================================
#                   Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------
# VRM_ADJ_log          0.2806     0.0089     31.570     0.0000      0.2632      0.2981
# AVG_SPEED_log       -0.3208     0.0249    -12.897     0.0000     -0.3696     -0.2721
# FARE_per_UPT_log    -0.7756     0.0150    -51.614     0.0000     -0.8051     -0.7461
# Tot_Pop_log          0.0221     0.0089     2.4864     0.0129      0.0047      0.0396
# TOT_EMP_MSA_log      0.6591     0.1009     6.5335     0.0000      0.4613      0.8568
# GasPrice_log         0.5396     0.0255     21.171     0.0000      0.4897      0.5896
# YEARS_SINCE_TNC     -0.0078     0.0047    -1.6571     0.0976     -0.0171      0.0014
# ====================================================================================
#
# F-test for Poolability: 52.692
# P-value: 0.0000
# Distribution: F(360,4803)
#
# Included effects: Entity

# %%
# basic log model for bus and rail, all clusters
mod=PanelOLS.from_formula('UPT_ADJ_log \
                    ~ VRM_ADJ_log \
                    + FARE_per_UPT_log \
                    + Tot_Pop_log \
                    + TOT_EMP_MSA_log \
                    + GasPrice_log \
                    + YEARS_SINCE_TNC \
                    + EntityEffects \
                    ',data=df)
res=mod.fit()
print(res)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\data.py:39: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   new_df = df.copy().loc[self._full_index]
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\utility.py:476: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   warnings.warn(missing_value_warning_msg, MissingValueWarning)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:            UPT_ADJ_log   R-squared:                        0.4802
# Estimator:                   PanelOLS   R-squared (Between):              0.9766
# No. Observations:                5171   R-squared (Within):               0.4802
# Date:                Fri, Oct 25 2019   R-squared (Overall):              0.9749
# Time:                        13:53:32   Log-likelihood                   -1301.3
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      739.64
# Entities:                         361   P-value                           0.0000
# Avg Obs:                       14.324   Distribution:                  F(6,4804)
# Min Obs:                       1.0000
# Max Obs:                       17.000   F-statistic (robust):             739.64
#                                         P-value                           0.0000
# Time periods:                      17   Distribution:                  F(6,4804)
# Avg Obs:                       304.18
# Min Obs:                       253.00
# Max Obs:                       348.00
#
#                                 Parameter Estimates
# ====================================================================================
#                   Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------
# VRM_ADJ_log          0.2291     0.0081     28.368     0.0000      0.2132      0.2449
# FARE_per_UPT_log    -0.7760     0.0153    -50.778     0.0000     -0.8060     -0.7461
# Tot_Pop_log          0.0234     0.0091     2.5798     0.0099      0.0056      0.0411
# TOT_EMP_MSA_log      0.7112     0.1025     6.9373     0.0000      0.5102      0.9122
# GasPrice_log         0.5725     0.0258     22.197     0.0000      0.5220      0.6231
# YEARS_SINCE_TNC     -0.0042     0.0048    -0.8801     0.3788     -0.0137      0.0052
# ====================================================================================
#
# F-test for Poolability: 61.119
# P-value: 0.0000
# Distribution: F(360,4804)
#
# Included effects: Entity

# %%
# basic log model for bus and rail, all clusters
mod=PanelOLS.from_formula('UPT_ADJ_log \
                    ~ VRM_ADJ_log \
                    + FARE_per_UPT_log \
                    + Tot_Pop_log \
                    + TOT_EMP_MSA_log \
                    + GasPrice_log \
                    + PCT_HH_NO_VEH \
                    + YEARS_SINCE_TNC \
                    + EntityEffects \
                    ',data=df)
res=mod.fit()
print(res)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\data.py:39: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   new_df = df.copy().loc[self._full_index]
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\utility.py:476: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   warnings.warn(missing_value_warning_msg, MissingValueWarning)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:            UPT_ADJ_log   R-squared:                        0.4810
# Estimator:                   PanelOLS   R-squared (Between):              0.9825
# No. Observations:                5171   R-squared (Within):               0.4810
# Date:                Fri, Oct 25 2019   R-squared (Overall):              0.9812
# Time:                        13:53:43   Log-likelihood                   -1297.5
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      635.80
# Entities:                         361   P-value                           0.0000
# Avg Obs:                       14.324   Distribution:                  F(7,4803)
# Min Obs:                       1.0000
# Max Obs:                       17.000   F-statistic (robust):             635.80
#                                         P-value                           0.0000
# Time periods:                      17   Distribution:                  F(7,4803)
# Avg Obs:                       304.18
# Min Obs:                       253.00
# Max Obs:                       348.00
#
#                                 Parameter Estimates
# ====================================================================================
#                   Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------
# VRM_ADJ_log          0.2292     0.0081     28.404     0.0000      0.2134      0.2450
# FARE_per_UPT_log    -0.7773     0.0153    -50.868     0.0000     -0.8073     -0.7473
# Tot_Pop_log          0.0188     0.0092     2.0418     0.0412      0.0007      0.0369
# TOT_EMP_MSA_log      0.7380     0.1029     7.1690     0.0000      0.5362      0.9398
# GasPrice_log         0.5653     0.0259     21.810     0.0000      0.5145      0.6161
# PCT_HH_NO_VEH        0.0110     0.0041     2.6661     0.0077      0.0029      0.0190
# YEARS_SINCE_TNC     -0.0036     0.0048    -0.7521     0.4521     -0.0130      0.0058
# ====================================================================================
#
# F-test for Poolability: 56.415
# P-value: 0.0000
# Distribution: F(360,4803)
#
# Included effects: Entity

# %%
# This is our initial core model
mod=PanelOLS.from_formula('UPT_ADJ_log \
                    ~ VRM_ADJ_log \
                    + FARE_per_UPT_log \
                    + Tot_Pop_log \
                    + TOT_EMP_MSA_log \
                    + GasPrice_log \
                    + PCT_HH_NO_VEH \
                    + EntityEffects \
                    ',data=df)
res=mod.fit()
print(res)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\data.py:39: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   new_df = df.copy().loc[self._full_index]
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\utility.py:476: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   warnings.warn(missing_value_warning_msg, MissingValueWarning)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:            UPT_ADJ_log   R-squared:                        0.4809
# Estimator:                   PanelOLS   R-squared (Between):              0.9733
# No. Observations:                5171   R-squared (Within):               0.4809
# Date:                Fri, Oct 25 2019   R-squared (Overall):              0.9715
# Time:                        13:54:08   Log-likelihood                   -1297.8
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      741.74
# Entities:                         361   P-value                           0.0000
# Avg Obs:                       14.324   Distribution:                  F(6,4804)
# Min Obs:                       1.0000
# Max Obs:                       17.000   F-statistic (robust):             741.74
#                                         P-value                           0.0000
# Time periods:                      17   Distribution:                  F(6,4804)
# Avg Obs:                       304.18
# Min Obs:                       253.00
# Max Obs:                       348.00
#
#                                 Parameter Estimates
# ====================================================================================
#                   Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------
# VRM_ADJ_log          0.2290     0.0081     28.395     0.0000      0.2132      0.2449
# FARE_per_UPT_log    -0.7779     0.0153    -50.989     0.0000     -0.8078     -0.7480
# Tot_Pop_log          0.0188     0.0092     2.0443     0.0410      0.0008      0.0369
# TOT_EMP_MSA_log      0.6959     0.0864     8.0562     0.0000      0.5265      0.8652
# GasPrice_log         0.5678     0.0257     22.086     0.0000      0.5174      0.6182
# PCT_HH_NO_VEH        0.0111     0.0041     2.7053     0.0068      0.0031      0.0192
# ====================================================================================
#
# F-test for Poolability: 56.445
# P-value: 0.0000
# Distribution: F(360,4804)
#
# Included effects: Entity

# %%
# This is our initial core model, with time effects
mod=PanelOLS.from_formula('UPT_ADJ_log \
                    ~ VRM_ADJ_log \
                    + FARE_per_UPT_log \
                    + Tot_Pop_log \
                    + TOT_EMP_MSA_log \
                    + GasPrice_log \
                    + PCT_HH_NO_VEH \
                    + EntityEffects \
                    + TimeEffects \
                    ',data=df)
res=mod.fit()
print(res)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\data.py:39: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   new_df = df.copy().loc[self._full_index]
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\utility.py:476: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   warnings.warn(missing_value_warning_msg, MissingValueWarning)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:            UPT_ADJ_log   R-squared:                        0.4386
# Estimator:                   PanelOLS   R-squared (Between):              0.9345
# No. Observations:                5171   R-squared (Within):               0.4629
# Date:                Fri, Oct 25 2019   R-squared (Overall):              0.9317
# Time:                        13:55:37   Log-likelihood                   -1176.9
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      623.46
# Entities:                         361   P-value                           0.0000
# Avg Obs:                       14.324   Distribution:                  F(6,4788)
# Min Obs:                       1.0000
# Max Obs:                       17.000   F-statistic (robust):             623.46
#                                         P-value                           0.0000
# Time periods:                      17   Distribution:                  F(6,4788)
# Avg Obs:                       304.18
# Min Obs:                       253.00
# Max Obs:                       348.00
#
#                                 Parameter Estimates
# ====================================================================================
#                   Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------
# VRM_ADJ_log          0.2138     0.0080     26.785     0.0000      0.1982      0.2295
# FARE_per_UPT_log    -0.7940     0.0150    -52.907     0.0000     -0.8234     -0.7646
# Tot_Pop_log          0.0089     0.0091     0.9853     0.3245     -0.0088      0.0267
# TOT_EMP_MSA_log      0.6411     0.1039     6.1715     0.0000      0.4374      0.8447
# GasPrice_log         0.2738     0.2785     0.9830     0.3257     -0.2722      0.8197
# PCT_HH_NO_VEH        0.0072     0.0041     1.7852     0.0743     -0.0007      0.0152
# ====================================================================================
#
# F-test for Poolability: 57.051
# P-value: 0.0000
# Distribution: F(376,4788)
#
# Included effects: Entity, Time
