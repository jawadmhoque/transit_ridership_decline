# %%
import pandas as pd
import seaborn as sns
import numpy as np
import linearmodels as lm
import matplotlib
import math
import statsmodels.formula.api as smf
import statsmodels.api as sm

from linearmodels.panel import PanelOLS
from linearmodels.panel import RandomEffects
from linearmodels.panel import FirstDifferenceOLS
from linearmodels.panel import compare
from matplotlib import pyplot as plt

from pandas.api.types import is_numeric_dtype

pd.set_option('display.max_columns', 500)

# %matplotlib inline

# %%
# read the main data set
df=pd.read_csv('estimation_file.csv',
                    encoding='utf-8')

# %%
# exclude if ridership is zero--missing data
df = df[df['UPT_ADJ']>0]

# %%
df['BUS_FLAG'] = np.where(df['Mode']=='Bus', 1, 0)
df['RAIL_FLAG'] = np.where(df['Mode']=='Rail', 1, 0)

# %%
# include population + employment
df['POP_EMP'] = df['Tot_Pop'] + df['TOT_EMP_MSA']
df['HH_EMP'] = df['Total_HH'] + df['TOT_EMP_MSA']

# percent of population in transit supportive density
df['TSD_POP_PCT'] = df['POP_CENSUSTRACT'] / df['Tot_Pop']

# %%
# time effects
df['YEARS_SINCE_2002']  = df['Year'] - 2002

df['YEARS_2002_2010']  = df['Year'].apply(lambda x : min(x-2002, 8))
df['YEARS_AFTER_2010'] = df['Year'].apply(lambda x : max(x-2010, 0))

df['YEARS_2002_2014']  = df['Year'].apply(lambda x : min(x-2002, 12))
df['YEARS_AFTER_2014'] = df['Year'].apply(lambda x : max(x-2014, 0))


df['YEARS_SINCE_2002_BUS']  = df['YEARS_SINCE_2002'] * df['BUS_FLAG']
df['YEARS_SINCE_2002_RAIL'] = df['YEARS_SINCE_2002'] * df['RAIL_FLAG']

df['YEARS_2002_2010_BUS']   = df['YEARS_2002_2010'] * df['BUS_FLAG']
df['YEARS_AFTER_2010_BUS']  = df['YEARS_AFTER_2010']* df['BUS_FLAG']
df['YEARS_2002_2010_RAIL']  = df['YEARS_2002_2010'] * df['RAIL_FLAG']
df['YEARS_AFTER_2010_RAIL'] = df['YEARS_AFTER_2010']* df['RAIL_FLAG']

df['YEARS_2002_2014_BUS']   = df['YEARS_2002_2014'] * df['BUS_FLAG']
df['YEARS_AFTER_2014_BUS']  = df['YEARS_AFTER_2014']* df['BUS_FLAG']
df['YEARS_2002_2014_RAIL']  = df['YEARS_2002_2014'] * df['RAIL_FLAG']
df['YEARS_AFTER_2014_RAIL'] = df['YEARS_AFTER_2014']* df['RAIL_FLAG']

# %%
# various bus/rail specifics

df['TNC_FLAG_BUS'] = df['TNC_FLAG'] * df['BUS_FLAG']
df['TNC_FLAG_RAIL'] = df['TNC_FLAG'] * df['RAIL_FLAG']

df['YEARS_SINCE_TNC_BUS'] = df['YEARS_SINCE_TNC'] * df['BUS_FLAG']
df['YEARS_SINCE_TNC_RAIL'] = df['YEARS_SINCE_TNC'] * df['RAIL_FLAG']

df['dockless_flag'] = df['dockCt'].apply(lambda x : min(x,1))
df['scooter_flag']  = df['scooterCt'].apply(lambda x : min(x,1))

df['BIKE_SHARE'] = df['PBS_Flag'] + df['dockless_flag']
df['BIKE_SHARE'] = df['BIKE_SHARE'].apply(lambda x : min(x,1))


df['PBS_Flag_BUS']   = df['PBS_Flag']   * df['BUS_FLAG']
df['dockCt_BUS']     = df['dockCt']     * df['BUS_FLAG']
df['docklessCt_BUS'] = df['docklessCt'] * df['BUS_FLAG']
df['scooterCt_BUS']  = df['scooterCt']  * df['BUS_FLAG']
df['dockless_flag_BUS'] = df['dockless_flag'] * df['BUS_FLAG']
df['scooter_flag_BUS']  = df['scooter_flag']  * df['BUS_FLAG']
df['BIKE_SHARE_BUS']  = df['BIKE_SHARE']  * df['BUS_FLAG']


df['PBS_Flag_RAIL']   = df['PBS_Flag']   * df['RAIL_FLAG']
df['dockCt_RAIL']     = df['dockCt']     * df['RAIL_FLAG']
df['docklessCt_RAIL'] = df['docklessCt'] * df['RAIL_FLAG']
df['scooterCt_RAIL']  = df['scooterCt']  * df['RAIL_FLAG']
df['dockless_flag_RAIL'] = df['dockless_flag'] * df['RAIL_FLAG']
df['scooter_flag_RAIL']  = df['scooter_flag']  * df['RAIL_FLAG']
df['BIKE_SHARE_RAIL']  = df['BIKE_SHARE']  * df['RAIL_FLAG']

# %%
# set the indices
df['ID'] = df['MNAME'] + '-' + df['Mode']
df=df.set_index(['ID','Year'])

# %%
# keep only the numeric columns -- the estimation will give an error otherwise
df = df.select_dtypes(include=[np.number])

# %%
# create a log of all fields
for col in df.columns:
    df[col+'_log'] = np.log(df[col]+1)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:3: RuntimeWarning: invalid value encountered in log
#   app.launch_new_instance()

# %%
# check the data
df.head()
# Out:
#                                Unnamed: 0   CBSA  NEW_CBSA          UPT  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002           0  10420       NaN  5226385.660
#                          2003           1  10420       NaN  5395901.888
#                          2004           2  10420       NaN  5907162.281
#                          2005           3  10420       NaN  6013680.881
#                          2006           4  10420       NaN  6070797.419
#
#                                        VRM      UPT_ADJ      VRM_ADJ  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002  4026372.388  5226385.660  4026372.388
#                          2003  3976568.624  5395901.888  3976568.624
#                          2004  4315392.555  5907162.281  4315392.555
#                          2005  4053011.065  6013680.881  4053011.065
#                          2006  3994786.013  6070797.419  3994786.013
#
#                                    VRH_ADJ  FARE_TOTAL  FARE_per_UPT  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002  270506.6928    660887.0      0.114148
#                          2003  270398.3688   2568502.0      0.429694
#                          2004  597239.8605   2524882.0      0.385839
#                          2005  281367.9792   3022880.0      0.453758
#                          2006  281536.7841   3163036.0      0.470329
#
#                                AREALANDPT      Tot_Pop  Tot_Instate_Pop  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002   744634347  646583.7344      496141.0469
#                          2003   744634347  659397.0625      504631.8125
#                          2004   744634347  672492.7500      513183.7500
#                          2005   744634347  684459.0000      521491.0000
#                          2006   744634347  700943.0000      530777.0000
#
#                                Tot_Outstate_Pop  Tot_NonUSA_POP  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002       137193.6719      -389.53125
#                          2003       137582.3125       753.12500
#                          2004       138058.7500      1942.50000
#                          2005       138184.0000      2945.00000
#                          2006       139714.0000      4695.00000
#
#                                Total_Median_Income_Individual  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                     25405.20313
#                          2003                     25120.18750
#                          2004                     24804.25000
#                          2005                     24612.00000
#                          2006                     23925.00000
#
#                                Native_Instate_Med_Inc_Indiv  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                   26028.32813
#                          2003                   25632.68750
#                          2004                   25208.25000
#                          2005                   24899.00000
#                          2006                   24129.00000
#
#                                Native_Outstate_Med_Inc_Indiv  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                    26651.07813
#                          2003                    25995.68750
#                          2004                    25305.25000
#                          2005                    24755.00000
#                          2006                    23644.00000
#
#                                Total_Pop_Poverty  Pop_Below100_Poverty  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002          682354.11                  7.55
#                          2003          682850.56                  8.81
#                          2004          683397.75                 10.08
#                          2005          683742.00                 11.30
#                          2006          684898.00                 12.70
#
#                                Pop_Below150_Poverty  Pop_Above150_Poverty  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                  8.94                 83.85
#                          2003                  8.66                 82.79
#                          2004                  8.38                 81.73
#                          2005                  8.10                 80.70
#                          2006                  7.80                 79.50
#
#                                Age_under18  Age_18to64  Age_over64   Total_HH  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002        24.64        62.9       12.46  265452.20
#                          2003        24.33        63.0       12.68  269144.19
#                          2004        24.00        63.1       12.90  272892.25
#                          2005        23.70        63.2       13.10  276416.00
#                          2006        23.30        63.3       13.40  280837.00
#
#                                 HH_0Veh   HH_1Veh    HH_2Veh   HH_3Veh  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002  22830.14  58254.52  117083.25  46891.53
#                          2003  22073.44  67400.94  115443.00  44874.88
#                          2004  21266.25  76795.25  113694.00  42855.50
#                          2005  20661.00  85198.00  112380.00  40847.00
#                          2006  19248.00  97567.00  109326.00  38795.00
#
#                                HH_4+Veh  PCT_HH_NO_VEH   HH_MED_INC  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002  20392.77           8.60  43046.82813
#                          2003  19351.94           8.20  43566.68750
#                          2004  18281.25           7.79  44030.25000
#                          2005  17330.00           7.47  44719.00000
#                          2006  15901.00           6.85  44507.00000
#
#                                HH_MEAN_INC  INC_U35  INC_35_100  INC_100P  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002   55300.5625    39.49       46.56     13.95
#                          2003   56379.7500    39.24       46.66     14.10
#                          2004   57390.0000    39.03       46.78     14.20
#                          2005   58676.0000    38.70       46.80     14.50
#                          2006   58859.0000    38.80       47.20     14.00
#
#                                TOT_UNEMP_MSA  TOT_EMP_MSA  TOT_LABOR_MSA  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002       21948.42    346147.17      368095.58
#                          2003       23342.50    348574.17      371916.67
#                          2004       23471.75    351723.75      375195.50
#                          2005       22420.75    358105.92      380526.67
#                          2006       20348.08    365133.33      385481.42
#
#                                UNEMP_RATE_PCT  EMP_RATE_PCT  GasPrice  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002            5.96         94.04      1.36
#                          2003            6.28         93.72      1.55
#                          2004            6.26         93.74      1.83
#                          2005            5.90         94.10      2.25
#                          2006            5.28         94.72      2.54
#
#                                Area_acre  POP_CENSUSTRACT  AVG_SPEED  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002        NaN         119786.0      14.88
#                          2003        NaN         119199.0      14.71
#                          2004        NaN         118612.0       7.23
#                          2005    13644.8         118025.0      14.40
#                          2006    13644.8         117438.0      14.19
#
#                                2018_Dollar_Multiplier  TNC_ARRIVAL  TNC_FLAG  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                    1.40         2014         0
#                          2003                    1.37         2014         0
#                          2004                    1.33         2014         0
#                          2005                    1.29         2014         0
#                          2006                    1.25         2014         0
#
#                                YEARS_SINCE_TNC  dockCt  docklessCt  scooterCt  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                0       0           0          0
#                          2003                0       0           0          0
#                          2004                0       0           0          0
#                          2005                0       0           0          0
#                          2006                0       0           0          0
#
#                                PBS_Start  PBS_End  PBS_Flag  walkscore  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002        NaN      NaN       0.0          0
#                          2003        NaN      NaN       0.0          0
#                          2004        NaN      NaN       0.0          0
#                          2005        NaN      NaN       0.0          0
#                          2006        NaN      NaN       0.0          0
#
#                                transit  bike  FARE_TOTAL_2018  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002        0     0        925241.80
#                          2003        0     0       3518847.74
#                          2004        0     0       3358093.06
#                          2005        0     0       3899515.20
#                          2006        0     0       3953795.00
#
#                                TOTAL_MED_INC_INDIV_2018  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002              35567.284382
#                          2003              34414.656875
#                          2004              32989.652500
#                          2005              31749.480000
#                          2006              29906.250000
#
#                                NATIVE_INSTATE_MED_INC_2018  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                 36439.659382
#                          2003                 35116.781875
#                          2004                 33526.972500
#                          2005                 32119.710000
#                          2006                 30161.250000
#
#                                NATIVE_OUTSTATE_MED_INC_2018  HH_MED_INC_2018  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                  37311.509382     60265.559382
#                          2003                  35614.091875     59686.361875
#                          2004                  33655.982500     58560.232500
#                          2005                  31933.950000     57687.510000
#                          2006                  29555.000000     55633.750000
#
#                                HH_MEAN_INC_2018  GAS_PRICE_2018  BUS_FLAG  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002        77420.7875          1.9040         1
#                          2003        77240.2575          2.1235         1
#                          2004        76328.7000          2.4339         1
#                          2005        75692.0400          2.9025         1
#                          2006        73573.7500          3.1750         1
#
#                                RAIL_FLAG       POP_EMP     HH_EMP  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002          0  9.927309e+05  611599.37
#                          2003          0  1.007971e+06  617718.36
#                          2004          0  1.024216e+06  624616.00
#                          2005          0  1.042565e+06  634521.92
#                          2006          0  1.066076e+06  645970.33
#
#                                POP_EMP_log  HH_EMP_log  YEARS_SINCE_2002  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002    13.808216   13.323834                 0
#                          2003    13.823451   13.333790                 1
#                          2004    13.839439   13.344894                 2
#                          2005    13.857195   13.360629                 3
#                          2006    13.879496   13.378510                 4
#
#                                YEARS_2002_2010  YEARS_AFTER_2010  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                0                 0
#                          2003                1                 0
#                          2004                2                 0
#                          2005                3                 0
#                          2006                4                 0
#
#                                YEARS_2002_2014  YEARS_AFTER_2014  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                0                 0
#                          2003                1                 0
#                          2004                2                 0
#                          2005                3                 0
#                          2006                4                 0
#
#                                YEARS_SINCE_2002_BUS  YEARS_SINCE_2002_RAIL  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                     0                      0
#                          2003                     1                      0
#                          2004                     2                      0
#                          2005                     3                      0
#                          2006                     4                      0
#
#                                YEARS_2002_2010_BUS  YEARS_AFTER_2010_BUS  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                    0                     0
#                          2003                    1                     0
#                          2004                    2                     0
#                          2005                    3                     0
#                          2006                    4                     0
#
#                                YEARS_2002_2010_RAIL  YEARS_AFTER_2010_RAIL  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                     0                      0
#                          2003                     0                      0
#                          2004                     0                      0
#                          2005                     0                      0
#                          2006                     0                      0
#
#                                YEARS_2002_2014_BUS  YEARS_AFTER_2014_BUS  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                    0                     0
#                          2003                    1                     0
#                          2004                    2                     0
#                          2005                    3                     0
#                          2006                    4                     0
#
#                                YEARS_2002_2014_RAIL  YEARS_AFTER_2014_RAIL  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                     0                      0
#                          2003                     0                      0
#                          2004                     0                      0
#                          2005                     0                      0
#                          2006                     0                      0
#
#                                TNC_FLAG_BUS  TNC_FLAG_RAIL  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002             0              0
#                          2003             0              0
#                          2004             0              0
#                          2005             0              0
#                          2006             0              0
#
#                                YEARS_SINCE_TNC_BUS  YEARS_SINCE_TNC_RAIL  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                    0                     0
#                          2003                    0                     0
#                          2004                    0                     0
#                          2005                    0                     0
#                          2006                    0                     0
#
#                                dockless_flag  scooter_flag  BIKE_SHARE  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002              0             0         0.0
#                          2003              0             0         0.0
#                          2004              0             0         0.0
#                          2005              0             0         0.0
#                          2006              0             0         0.0
#
#                                PBS_Flag_BUS  dockCt_BUS  docklessCt_BUS  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002           0.0           0               0
#                          2003           0.0           0               0
#                          2004           0.0           0               0
#                          2005           0.0           0               0
#                          2006           0.0           0               0
#
#                                scooterCt_BUS  dockless_flag_BUS  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002              0                  0
#                          2003              0                  0
#                          2004              0                  0
#                          2005              0                  0
#                          2006              0                  0
#
#                                scooter_flag_BUS  BIKE_SHARE_BUS  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                 0             0.0
#                          2003                 0             0.0
#                          2004                 0             0.0
#                          2005                 0             0.0
#                          2006                 0             0.0
#
#                                PBS_Flag_RAIL  dockCt_RAIL  docklessCt_RAIL  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002            0.0            0                0
#                          2003            0.0            0                0
#                          2004            0.0            0                0
#                          2005            0.0            0                0
#                          2006            0.0            0                0
#
#                                scooterCt_RAIL  dockless_flag_RAIL  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002               0                   0
#                          2003               0                   0
#                          2004               0                   0
#                          2005               0                   0
#                          2006               0                   0
#
#                                scooter_flag_RAIL  BIKE_SHARE_RAIL  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                  0              0.0
#                          2003                  0              0.0
#                          2004                  0              0.0
#                          2005                  0              0.0
#                          2006                  0              0.0
#
#                                Unnamed: 0_log  CBSA_log  NEW_CBSA_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002        0.000000  9.251578           NaN
#                          2003        0.693147  9.251578           NaN
#                          2004        1.098612  9.251578           NaN
#                          2005        1.386294  9.251578           NaN
#                          2006        1.609438  9.251578           NaN
#
#                                  UPT_log    VRM_log  UPT_ADJ_log  VRM_ADJ_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002  15.469231  15.208377    15.469231    15.208377
#                          2003  15.501150  15.195930    15.501150    15.195930
#                          2004  15.591676  15.277699    15.591676    15.277699
#                          2005  15.609548  15.214971    15.609548    15.214971
#                          2006  15.619001  15.200501    15.619001    15.200501
#
#                                VRH_ADJ_log  FARE_TOTAL_log  FARE_per_UPT_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002    12.508056       13.401340          0.108090
#                          2003    12.507655       14.758834          0.357460
#                          2004    13.300076       14.741705          0.326305
#                          2005    12.547422       14.921721          0.374152
#                          2006    12.548022       14.967043          0.385486
#
#                                AREALANDPT_log  Tot_Pop_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002       20.428404    13.379460
#                          2003       20.428404    13.399083
#                          2004       20.428404    13.418748
#                          2005       20.428404    13.436385
#                          2006       20.428404    13.460183
#
#                                Tot_Instate_Pop_log  Tot_Outstate_Pop_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002            13.114618             11.829156
#                          2003            13.131586             11.831985
#                          2004            13.148391             11.835442
#                          2005            13.164449             11.836349
#                          2006            13.182099             11.847360
#
#                                Tot_NonUSA_POP_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                 NaN
#                          2003            6.625558
#                          2004            7.572246
#                          2005            7.988204
#                          2006            8.454466
#
#                                Total_Median_Income_Individual_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                           10.142749
#                          2003                           10.131467
#                          2004                           10.118811
#                          2005                           10.111030
#                          2006                           10.082721
#
#                                Native_Instate_Med_Inc_Indiv_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                         10.166979
#                          2003                         10.151663
#                          2004                         10.134966
#                          2005                         10.122623
#                          2006                         10.091211
#
#                                Native_Outstate_Med_Inc_Indiv_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                          10.190622
#                          2003                          10.165724
#                          2004                          10.138807
#                          2005                          10.116823
#                          2006                          10.070907
#
#                                Total_Pop_Poverty_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002              13.433305
#                          2003              13.434033
#                          2004              13.434834
#                          2005              13.435337
#                          2006              13.437027
#
#                                Pop_Below100_Poverty_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                  2.145931
#                          2003                  2.283402
#                          2004                  2.405142
#                          2005                  2.509599
#                          2006                  2.617396
#
#                                Pop_Below150_Poverty_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                  2.296567
#                          2003                  2.267994
#                          2004                  2.238580
#                          2005                  2.208274
#                          2006                  2.174752
#
#                                Pop_Above150_Poverty_log  Age_under18_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                  4.440885         3.244154
#                          2003                  4.428314         3.231989
#                          2004                  4.415582         3.218876
#                          2005                  4.403054         3.206803
#                          2006                  4.388257         3.190476
#
#                                Age_18to64_log  Age_over64_log  Total_HH_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002        4.157319        2.599722     12.489194
#                          2003        4.158883        2.615935     12.503006
#                          2004        4.160444        2.631889     12.516836
#                          2005        4.162003        2.646175     12.529666
#                          2006        4.163560        2.667228     12.545533
#
#                                HH_0Veh_log  HH_1Veh_log  HH_2Veh_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002    10.035881    10.972594    11.670649
#                          2003    10.002176    11.118429    11.656541
#                          2004     9.964924    11.248911    11.641275
#                          2005     9.936052    11.352745    11.629650
#                          2006     9.865214    11.488305    11.602099
#
#                                HH_3Veh_log  HH_4+Veh_log  PCT_HH_NO_VEH_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002    10.755614      9.922985           2.261763
#                          2003    10.711656      9.870600           2.219203
#                          2004    10.665613      9.813686           2.173615
#                          2005    10.617613      9.760252           2.136531
#                          2006    10.566072      9.674200           2.060514
#
#                                HH_MED_INC_log  HH_MEAN_INC_log  INC_U35_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002       10.670067        10.920556     3.701055
#                          2003       10.682071        10.939883     3.694862
#                          2004       10.692655        10.957643     3.689629
#                          2005       10.708176        10.979803     3.681351
#                          2006       10.703424        10.982917     3.683867
#
#                                INC_35_100_log  INC_100P_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002        3.861992      2.704711
#                          2003        3.864092      2.714695
#                          2004        3.866607      2.721295
#                          2005        3.867026      2.740840
#                          2006        3.875359      2.708050
#
#                                TOT_UNEMP_MSA_log  TOT_EMP_MSA_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002           9.996496        12.754622
#                          2003          10.058074        12.761609
#                          2004          10.063595        12.770604
#                          2005          10.017787        12.788587
#                          2006           9.920791        12.808021
#
#                                TOT_LABOR_MSA_log  UNEMP_RATE_PCT_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002          12.816101            1.940179
#                          2003          12.826428            1.985131
#                          2004          12.835205            1.982380
#                          2005          12.849314            1.931521
#                          2006          12.862251            1.837370
#
#                                EMP_RATE_PCT_log  GasPrice_log  Area_acre_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002          4.554298      0.858662            NaN
#                          2003          4.550925      0.936093            NaN
#                          2004          4.551136      1.040277            NaN
#                          2005          4.554929      1.178655       9.521187
#                          2006          4.561427      1.264127       9.521187
#
#                                POP_CENSUSTRACT_log  AVG_SPEED_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002            11.693470       2.765060
#                          2003            11.688558       2.754297
#                          2004            11.683621       2.107786
#                          2005            11.678660       2.734368
#                          2006            11.673674       2.720637
#
#                                2018_Dollar_Multiplier_log  TNC_ARRIVAL_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                    0.875469         7.608374
#                          2003                    0.862890         7.608374
#                          2004                    0.845868         7.608374
#                          2005                    0.828552         7.608374
#                          2006                    0.810930         7.608374
#
#                                TNC_FLAG_log  YEARS_SINCE_TNC_log  dockCt_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002           0.0                  0.0         0.0
#                          2003           0.0                  0.0         0.0
#                          2004           0.0                  0.0         0.0
#                          2005           0.0                  0.0         0.0
#                          2006           0.0                  0.0         0.0
#
#                                docklessCt_log  scooterCt_log  PBS_Start_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002             0.0            0.0            NaN
#                          2003             0.0            0.0            NaN
#                          2004             0.0            0.0            NaN
#                          2005             0.0            0.0            NaN
#                          2006             0.0            0.0            NaN
#
#                                PBS_End_log  PBS_Flag_log  walkscore_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002          NaN           0.0            0.0
#                          2003          NaN           0.0            0.0
#                          2004          NaN           0.0            0.0
#                          2005          NaN           0.0            0.0
#                          2006          NaN           0.0            0.0
#
#                                transit_log  bike_log  FARE_TOTAL_2018_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002          0.0       0.0            13.737811
#                          2003          0.0       0.0            15.073644
#                          2004          0.0       0.0            15.026884
#                          2005          0.0       0.0            15.176363
#                          2006          0.0       0.0            15.190187
#
#                                TOTAL_MED_INC_INDIV_2018_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                     10.479210
#                          2003                     10.446267
#                          2004                     10.403980
#                          2005                     10.365663
#                          2006                     10.305856
#
#                                NATIVE_INSTATE_MED_INC_2018_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                        10.503440
#                          2003                        10.466463
#                          2004                        10.420135
#                          2005                        10.377256
#                          2006                        10.314346
#
#                                NATIVE_OUTSTATE_MED_INC_2018_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                         10.527084
#                          2003                         10.480525
#                          2004                         10.423976
#                          2005                         10.371456
#                          2006                         10.294042
#
#                                HH_MED_INC_2018_log  HH_MEAN_INC_2018_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002            11.006533             11.257024
#                          2003            10.996876             11.254689
#                          2004            10.977828             11.242817
#                          2005            10.962813             11.234441
#                          2006            10.926563             11.206057
#
#                                GAS_PRICE_2018_log  BUS_FLAG_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002            1.066089      0.693147
#                          2003            1.138954      0.693147
#                          2004            1.233697      0.693147
#                          2005            1.361617      0.693147
#                          2006            1.429114      0.693147
#
#                                RAIL_FLAG_log  POP_EMP_log_log  HH_EMP_log_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002            0.0         2.695182        2.661925
#                          2003            0.0         2.696210        2.662620
#                          2004            0.0         2.697288        2.663394
#                          2005            0.0         2.698484        2.664490
#                          2006            0.0         2.699984        2.665735
#
#                                YEARS_SINCE_2002_log  YEARS_2002_2010_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002              0.000000             0.000000
#                          2003              0.693147             0.693147
#                          2004              1.098612             1.098612
#                          2005              1.386294             1.386294
#                          2006              1.609438             1.609438
#
#                                YEARS_AFTER_2010_log  YEARS_2002_2014_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                   0.0             0.000000
#                          2003                   0.0             0.693147
#                          2004                   0.0             1.098612
#                          2005                   0.0             1.386294
#                          2006                   0.0             1.609438
#
#                                YEARS_AFTER_2014_log  YEARS_SINCE_2002_BUS_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                   0.0                  0.000000
#                          2003                   0.0                  0.693147
#                          2004                   0.0                  1.098612
#                          2005                   0.0                  1.386294
#                          2006                   0.0                  1.609438
#
#                                YEARS_SINCE_2002_RAIL_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                        0.0
#                          2003                        0.0
#                          2004                        0.0
#                          2005                        0.0
#                          2006                        0.0
#
#                                YEARS_2002_2010_BUS_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                 0.000000
#                          2003                 0.693147
#                          2004                 1.098612
#                          2005                 1.386294
#                          2006                 1.609438
#
#                                YEARS_AFTER_2010_BUS_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                       0.0
#                          2003                       0.0
#                          2004                       0.0
#                          2005                       0.0
#                          2006                       0.0
#
#                                YEARS_2002_2010_RAIL_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                       0.0
#                          2003                       0.0
#                          2004                       0.0
#                          2005                       0.0
#                          2006                       0.0
#
#                                YEARS_AFTER_2010_RAIL_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                        0.0
#                          2003                        0.0
#                          2004                        0.0
#                          2005                        0.0
#                          2006                        0.0
#
#                                YEARS_2002_2014_BUS_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                 0.000000
#                          2003                 0.693147
#                          2004                 1.098612
#                          2005                 1.386294
#                          2006                 1.609438
#
#                                YEARS_AFTER_2014_BUS_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                       0.0
#                          2003                       0.0
#                          2004                       0.0
#                          2005                       0.0
#                          2006                       0.0
#
#                                YEARS_2002_2014_RAIL_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                       0.0
#                          2003                       0.0
#                          2004                       0.0
#                          2005                       0.0
#                          2006                       0.0
#
#                                YEARS_AFTER_2014_RAIL_log  TNC_FLAG_BUS_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                        0.0               0.0
#                          2003                        0.0               0.0
#                          2004                        0.0               0.0
#                          2005                        0.0               0.0
#                          2006                        0.0               0.0
#
#                                TNC_FLAG_RAIL_log  YEARS_SINCE_TNC_BUS_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                0.0                      0.0
#                          2003                0.0                      0.0
#                          2004                0.0                      0.0
#                          2005                0.0                      0.0
#                          2006                0.0                      0.0
#
#                                YEARS_SINCE_TNC_RAIL_log  dockless_flag_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                       0.0                0.0
#                          2003                       0.0                0.0
#                          2004                       0.0                0.0
#                          2005                       0.0                0.0
#                          2006                       0.0                0.0
#
#                                scooter_flag_log  BIKE_SHARE_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002               0.0             0.0
#                          2003               0.0             0.0
#                          2004               0.0             0.0
#                          2005               0.0             0.0
#                          2006               0.0             0.0
#
#                                PBS_Flag_BUS_log  dockCt_BUS_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002               0.0             0.0
#                          2003               0.0             0.0
#                          2004               0.0             0.0
#                          2005               0.0             0.0
#                          2006               0.0             0.0
#
#                                docklessCt_BUS_log  scooterCt_BUS_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                 0.0                0.0
#                          2003                 0.0                0.0
#                          2004                 0.0                0.0
#                          2005                 0.0                0.0
#                          2006                 0.0                0.0
#
#                                dockless_flag_BUS_log  scooter_flag_BUS_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                    0.0                   0.0
#                          2003                    0.0                   0.0
#                          2004                    0.0                   0.0
#                          2005                    0.0                   0.0
#                          2006                    0.0                   0.0
#
#                                BIKE_SHARE_BUS_log  PBS_Flag_RAIL_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                 0.0                0.0
#                          2003                 0.0                0.0
#                          2004                 0.0                0.0
#                          2005                 0.0                0.0
#                          2006                 0.0                0.0
#
#                                dockCt_RAIL_log  docklessCt_RAIL_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002              0.0                  0.0
#                          2003              0.0                  0.0
#                          2004              0.0                  0.0
#                          2005              0.0                  0.0
#                          2006              0.0                  0.0
#
#                                scooterCt_RAIL_log  dockless_flag_RAIL_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                 0.0                     0.0
#                          2003                 0.0                     0.0
#                          2004                 0.0                     0.0
#                          2005                 0.0                     0.0
#                          2006                 0.0                     0.0
#
#                                scooter_flag_RAIL_log  BIKE_SHARE_RAIL_log
# ID                       Year
# Akron, OH Metro Area-Bus 2002                    0.0                  0.0
#                          2003                    0.0                  0.0
#                          2004                    0.0                  0.0
#                          2005                    0.0                  0.0
#                          2006                    0.0                  0.0

# %%
df.to_csv('temp.csv')

# %% [markdown]
# ## Base model

# %%
# Start from this base model

mod=PanelOLS.from_formula('UPT_ADJ_log \
                    ~ VRM_ADJ_log \
                    + FARE_per_UPT_log \
                    + POP_EMP_log \
                    + GasPrice_log \
                    + PCT_HH_NO_VEH \
                    + EntityEffects \
                    ',data=df)
res=mod.fit()
print(res)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\data.py:39: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   new_df = df.copy().loc[self._full_index]
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\utility.py:476: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   warnings.warn(missing_value_warning_msg, MissingValueWarning)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:            UPT_ADJ_log   R-squared:                        0.5081
# Estimator:                   PanelOLS   R-squared (Between):              0.9968
# No. Observations:                4595   R-squared (Within):               0.5081
# Date:                Fri, Nov 01 2019   R-squared (Overall):              0.9967
# Time:                        12:02:13   Log-likelihood                   -696.89
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      887.21
# Entities:                         296   P-value                           0.0000
# Avg Obs:                       15.524   Distribution:                  F(5,4294)
# Min Obs:                       1.0000
# Max Obs:                       17.000   F-statistic (robust):             887.21
#                                         P-value                           0.0000
# Time periods:                      17   Distribution:                  F(5,4294)
# Avg Obs:                       270.29
# Min Obs:                       202.00
# Max Obs:                       292.00
#
#                                 Parameter Estimates
# ====================================================================================
#                   Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------
# VRM_ADJ_log          0.3568     0.0104     34.405     0.0000      0.3365      0.3772
# FARE_per_UPT_log    -0.7585     0.0158    -48.096     0.0000     -0.7894     -0.7276
# POP_EMP_log          0.6909     0.0638     10.837     0.0000      0.5659      0.8159
# GasPrice_log         0.4324     0.0270     16.002     0.0000      0.3794      0.4854
# PCT_HH_NO_VEH        0.0142     0.0042     3.3941     0.0007      0.0060      0.0224
# ====================================================================================
#
# F-test for Poolability: 60.226
# P-value: 0.0000
# Distribution: F(295,4294)
#
# Included effects: Entity

# %%
# add average speed

mod=PanelOLS.from_formula('UPT_ADJ_log \
                    ~ VRM_ADJ_log \
                    + AVG_SPEED_log \
                    + FARE_per_UPT_log \
                    + POP_EMP_log \
                    + GasPrice_log \
                    + PCT_HH_NO_VEH \
                    + EntityEffects \
                    ',data=df)
res=mod.fit()
print(res)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\data.py:39: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   new_df = df.copy().loc[self._full_index]
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\utility.py:476: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   warnings.warn(missing_value_warning_msg, MissingValueWarning)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:            UPT_ADJ_log   R-squared:                        0.5246
# Estimator:                   PanelOLS   R-squared (Between):              0.9856
# No. Observations:                4595   R-squared (Within):               0.5246
# Date:                Fri, Nov 01 2019   R-squared (Overall):              0.9850
# Time:                        12:02:14   Log-likelihood                   -618.45
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      789.69
# Entities:                         296   P-value                           0.0000
# Avg Obs:                       15.524   Distribution:                  F(6,4293)
# Min Obs:                       1.0000
# Max Obs:                       17.000   F-statistic (robust):             789.69
#                                         P-value                           0.0000
# Time periods:                      17   Distribution:                  F(6,4293)
# Avg Obs:                       270.29
# Min Obs:                       202.00
# Max Obs:                       292.00
#
#                                 Parameter Estimates
# ====================================================================================
#                   Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------
# VRM_ADJ_log          0.4081     0.0110     37.007     0.0000      0.3865      0.4297
# AVG_SPEED_log       -0.3742     0.0306    -12.211     0.0000     -0.4343     -0.3141
# FARE_per_UPT_log    -0.7498     0.0155    -48.311     0.0000     -0.7803     -0.7194
# POP_EMP_log          0.6072     0.0631     9.6290     0.0000      0.4835      0.7308
# GasPrice_log         0.4080     0.0266     15.313     0.0000      0.3558      0.4602
# PCT_HH_NO_VEH        0.0150     0.0041     3.6577     0.0003      0.0070      0.0231
# ====================================================================================
#
# F-test for Poolability: 51.851
# P-value: 0.0000
# Distribution: F(295,4293)
#
# Included effects: Entity

# %% [markdown]
# ## Explore the effects of new modes

# %%
# TNC Flag

mod=PanelOLS.from_formula('UPT_ADJ_log \
                    ~ VRM_ADJ_log \
                    + FARE_per_UPT_log \
                    + POP_EMP_log \
                    + GasPrice_log \
                    + PCT_HH_NO_VEH \
                    + TNC_FLAG_BUS \
                    + TNC_FLAG_RAIL \
                    + EntityEffects \
                    ',data=df)
res=mod.fit()
print(res)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\data.py:39: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   new_df = df.copy().loc[self._full_index]
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\utility.py:476: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   warnings.warn(missing_value_warning_msg, MissingValueWarning)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:            UPT_ADJ_log   R-squared:                        0.5114
# Estimator:                   PanelOLS   R-squared (Between):              0.9969
# No. Observations:                4595   R-squared (Within):               0.5114
# Date:                Fri, Nov 01 2019   R-squared (Overall):              0.9969
# Time:                        12:02:16   Log-likelihood                   -681.35
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      641.88
# Entities:                         296   P-value                           0.0000
# Avg Obs:                       15.524   Distribution:                  F(7,4292)
# Min Obs:                       1.0000
# Max Obs:                       17.000   F-statistic (robust):             641.88
#                                         P-value                           0.0000
# Time periods:                      17   Distribution:                  F(7,4292)
# Avg Obs:                       270.29
# Min Obs:                       202.00
# Max Obs:                       292.00
#
#                                 Parameter Estimates
# ====================================================================================
#                   Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------
# VRM_ADJ_log          0.3508     0.0104     33.645     0.0000      0.3304      0.3713
# FARE_per_UPT_log    -0.7622     0.0158    -48.350     0.0000     -0.7931     -0.7313
# POP_EMP_log          0.7168     0.0743     9.6449     0.0000      0.5711      0.8625
# GasPrice_log         0.4224     0.0278     15.214     0.0000      0.3680      0.4769
# PCT_HH_NO_VEH        0.0147     0.0042     3.5261     0.0004      0.0065      0.0229
# TNC_FLAG_BUS        -0.0257     0.0125    -2.0541     0.0400     -0.0502     -0.0012
# TNC_FLAG_RAIL        0.1200     0.0254     4.7142     0.0000      0.0701      0.1699
# ====================================================================================
#
# F-test for Poolability: 59.892
# P-value: 0.0000
# Distribution: F(295,4292)
#
# Included effects: Entity

# %%
# Years since TNC

mod=PanelOLS.from_formula('UPT_ADJ_log \
                    ~ VRM_ADJ_log \
                    + FARE_per_UPT_log \
                    + POP_EMP_log \
                    + GasPrice_log \
                    + PCT_HH_NO_VEH \
                    + YEARS_SINCE_TNC_BUS \
                    + YEARS_SINCE_TNC_RAIL \
                    + EntityEffects \
                    ',data=df)
res=mod.fit()
print(res)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\data.py:39: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   new_df = df.copy().loc[self._full_index]
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\utility.py:476: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   warnings.warn(missing_value_warning_msg, MissingValueWarning)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:            UPT_ADJ_log   R-squared:                        0.5162
# Estimator:                   PanelOLS   R-squared (Between):              0.9808
# No. Observations:                4595   R-squared (Within):               0.5162
# Date:                Fri, Nov 01 2019   R-squared (Overall):              0.9820
# Time:                        12:02:17   Log-likelihood                   -658.99
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      654.16
# Entities:                         296   P-value                           0.0000
# Avg Obs:                       15.524   Distribution:                  F(7,4292)
# Min Obs:                       1.0000
# Max Obs:                       17.000   F-statistic (robust):             654.16
#                                         P-value                           0.0000
# Time periods:                      17   Distribution:                  F(7,4292)
# Avg Obs:                       270.29
# Min Obs:                       202.00
# Max Obs:                       292.00
#
#                                   Parameter Estimates
# ========================================================================================
#                       Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ----------------------------------------------------------------------------------------
# VRM_ADJ_log              0.3512     0.0103     33.933     0.0000      0.3309      0.3715
# FARE_per_UPT_log        -0.7604     0.0157    -48.505     0.0000     -0.7911     -0.7297
# POP_EMP_log              0.8559     0.0726     11.793     0.0000      0.7137      0.9982
# GasPrice_log             0.4013     0.0277     14.511     0.0000      0.3471      0.4556
# PCT_HH_NO_VEH            0.0134     0.0042     3.2249     0.0013      0.0053      0.0216
# YEARS_SINCE_TNC_BUS     -0.0324     0.0048    -6.7592     0.0000     -0.0417     -0.0230
# YEARS_SINCE_TNC_RAIL     0.0299     0.0071     4.2224     0.0000      0.0160      0.0438
# ========================================================================================
#
# F-test for Poolability: 60.892
# P-value: 0.0000
# Distribution: F(295,4292)
#
# Included effects: Entity

# %%
# Public bike share

mod=PanelOLS.from_formula('UPT_ADJ_log \
                    ~ VRM_ADJ_log \
                    + FARE_per_UPT_log \
                    + POP_EMP_log \
                    + GasPrice_log \
                    + PCT_HH_NO_VEH \
                    + YEARS_SINCE_TNC_BUS \
                    + YEARS_SINCE_TNC_RAIL \
                    + PBS_Flag_BUS \
                    + PBS_Flag_RAIL \
                    + EntityEffects \
                    ',data=df)
res=mod.fit()
print(res)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\data.py:39: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   new_df = df.copy().loc[self._full_index]
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\utility.py:476: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   warnings.warn(missing_value_warning_msg, MissingValueWarning)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:            UPT_ADJ_log   R-squared:                        0.5401
# Estimator:                   PanelOLS   R-squared (Between):              0.8957
# No. Observations:                4232   R-squared (Within):               0.5401
# Date:                Fri, Nov 01 2019   R-squared (Overall):              0.8989
# Time:                        12:02:18   Log-likelihood                   -449.12
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      515.89
# Entities:                         269   P-value                           0.0000
# Avg Obs:                       15.732   Distribution:                  F(9,3954)
# Min Obs:                       1.0000
# Max Obs:                       17.000   F-statistic (robust):             515.89
#                                         P-value                           0.0000
# Time periods:                      17   Distribution:                  F(9,3954)
# Avg Obs:                       248.94
# Min Obs:                       189.00
# Max Obs:                       269.00
#
#                                   Parameter Estimates
# ========================================================================================
#                       Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ----------------------------------------------------------------------------------------
# VRM_ADJ_log              0.4349     0.0117     37.174     0.0000      0.4120      0.4578
# FARE_per_UPT_log        -0.7504     0.0160    -47.015     0.0000     -0.7817     -0.7191
# POP_EMP_log              0.9877     0.0828     11.923     0.0000      0.8253      1.1501
# GasPrice_log             0.3295     0.0287     11.472     0.0000      0.2732      0.3858
# PCT_HH_NO_VEH            0.0125     0.0042     3.0161     0.0026      0.0044      0.0207
# YEARS_SINCE_TNC_BUS     -0.0344     0.0058    -5.9607     0.0000     -0.0457     -0.0231
# YEARS_SINCE_TNC_RAIL     0.0045     0.0096     0.4693     0.6389     -0.0143      0.0232
# PBS_Flag_BUS            -0.0387     0.0222    -1.7378     0.0823     -0.0823      0.0050
# PBS_Flag_RAIL            0.0773     0.0408     1.8959     0.0580     -0.0026      0.1572
# ========================================================================================
#
# F-test for Poolability: 60.569
# P-value: 0.0000
# Distribution: F(268,3954)
#
# Included effects: Entity

# %%
# Bike share dock count

mod=PanelOLS.from_formula('UPT_ADJ_log \
                    ~ VRM_ADJ_log \
                    + FARE_per_UPT_log \
                    + POP_EMP_log \
                    + GasPrice_log \
                    + PCT_HH_NO_VEH \
                    + YEARS_SINCE_TNC_BUS \
                    + YEARS_SINCE_TNC_RAIL \
                    + dockCt_BUS \
                    + dockCt_RAIL \
                    + EntityEffects \
                    ',data=df)
res=mod.fit()
print(res)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\data.py:39: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   new_df = df.copy().loc[self._full_index]
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\utility.py:476: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   warnings.warn(missing_value_warning_msg, MissingValueWarning)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:            UPT_ADJ_log   R-squared:                        0.5162
# Estimator:                   PanelOLS   R-squared (Between):              0.9812
# No. Observations:                4595   R-squared (Within):               0.5162
# Date:                Fri, Nov 01 2019   R-squared (Overall):              0.9824
# Time:                        12:02:20   Log-likelihood                   -658.90
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      508.59
# Entities:                         296   P-value                           0.0000
# Avg Obs:                       15.524   Distribution:                  F(9,4290)
# Min Obs:                       1.0000
# Max Obs:                       17.000   F-statistic (robust):             508.59
#                                         P-value                           0.0000
# Time periods:                      17   Distribution:                  F(9,4290)
# Avg Obs:                       270.29
# Min Obs:                       202.00
# Max Obs:                       292.00
#
#                                   Parameter Estimates
# ========================================================================================
#                       Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ----------------------------------------------------------------------------------------
# VRM_ADJ_log              0.3510     0.0104     33.881     0.0000      0.3307      0.3714
# FARE_per_UPT_log        -0.7604     0.0157    -48.494     0.0000     -0.7912     -0.7297
# POP_EMP_log              0.8544     0.0727     11.753     0.0000      0.7119      0.9969
# GasPrice_log             0.4015     0.0277     14.512     0.0000      0.3473      0.4558
# PCT_HH_NO_VEH            0.0134     0.0042     3.2244     0.0013      0.0053      0.0216
# YEARS_SINCE_TNC_BUS     -0.0315     0.0052    -6.0506     0.0000     -0.0417     -0.0213
# YEARS_SINCE_TNC_RAIL     0.0304     0.0087     3.5028     0.0005      0.0134      0.0474
# dockCt_BUS           -5.785e-05     0.0001    -0.3954     0.6926     -0.0003      0.0002
# dockCt_RAIL          -1.622e-05     0.0002    -0.0964     0.9232     -0.0003      0.0003
# ========================================================================================
#
# F-test for Poolability: 60.865
# P-value: 0.0000
# Distribution: F(295,4290)
#
# Included effects: Entity

# %%
# docless bike share

mod=PanelOLS.from_formula('UPT_ADJ_log \
                    ~ VRM_ADJ_log \
                    + FARE_per_UPT_log \
                    + POP_EMP_log \
                    + GasPrice_log \
                    + PCT_HH_NO_VEH \
                    + YEARS_SINCE_TNC_BUS \
                    + YEARS_SINCE_TNC_RAIL \
                    + PBS_Flag_BUS \
                    + PBS_Flag_RAIL \
                    + dockless_flag_BUS \
                    + dockless_flag_RAIL \
                    + EntityEffects \
                    ',data=df)
res=mod.fit()
print(res)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\data.py:39: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   new_df = df.copy().loc[self._full_index]
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\utility.py:476: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   warnings.warn(missing_value_warning_msg, MissingValueWarning)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:            UPT_ADJ_log   R-squared:                        0.5402
# Estimator:                   PanelOLS   R-squared (Between):              0.8930
# No. Observations:                4232   R-squared (Within):               0.5402
# Date:                Fri, Nov 01 2019   R-squared (Overall):              0.8962
# Time:                        12:02:23   Log-likelihood                   -448.56
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      422.09
# Entities:                         269   P-value                           0.0000
# Avg Obs:                       15.732   Distribution:                 F(11,3952)
# Min Obs:                       1.0000
# Max Obs:                       17.000   F-statistic (robust):             422.09
#                                         P-value                           0.0000
# Time periods:                      17   Distribution:                 F(11,3952)
# Avg Obs:                       248.94
# Min Obs:                       189.00
# Max Obs:                       269.00
#
#                                   Parameter Estimates
# ========================================================================================
#                       Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ----------------------------------------------------------------------------------------
# VRM_ADJ_log              0.4347     0.0117     37.147     0.0000      0.4118      0.4577
# FARE_per_UPT_log        -0.7506     0.0160    -47.015     0.0000     -0.7819     -0.7193
# POP_EMP_log              0.9928     0.0834     11.901     0.0000      0.8292      1.1563
# GasPrice_log             0.3280     0.0291     11.263     0.0000      0.2709      0.3851
# PCT_HH_NO_VEH            0.0125     0.0042     3.0052     0.0027      0.0043      0.0206
# YEARS_SINCE_TNC_BUS     -0.0331     0.0059    -5.5906     0.0000     -0.0448     -0.0215
# YEARS_SINCE_TNC_RAIL     0.0015     0.0109     0.1354     0.8923     -0.0199      0.0229
# PBS_Flag_BUS            -0.0279     0.0256    -1.0898     0.2759     -0.0780      0.0223
# PBS_Flag_RAIL            0.0661     0.0456     1.4509     0.1469     -0.0232      0.1555
# dockless_flag_BUS       -0.0249     0.0289    -0.8589     0.3905     -0.0816      0.0319
# dockless_flag_RAIL       0.0293     0.0539     0.5428     0.5873     -0.0764      0.1350
# ========================================================================================
#
# F-test for Poolability: 60.552
# P-value: 0.0000
# Distribution: F(268,3952)
#
# Included effects: Entity

# %%
# Any bike share

mod=PanelOLS.from_formula('UPT_ADJ_log \
                    ~ VRM_ADJ_log \
                    + FARE_per_UPT_log \
                    + POP_EMP_log \
                    + GasPrice_log \
                    + PCT_HH_NO_VEH \
                    + YEARS_SINCE_TNC_BUS \
                    + YEARS_SINCE_TNC_RAIL \
                    + BIKE_SHARE_BUS \
                    + BIKE_SHARE_RAIL \
                    + EntityEffects \
                    ',data=df)
res=mod.fit()
print(res)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\data.py:39: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   new_df = df.copy().loc[self._full_index]
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\utility.py:476: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   warnings.warn(missing_value_warning_msg, MissingValueWarning)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:            UPT_ADJ_log   R-squared:                        0.5399
# Estimator:                   PanelOLS   R-squared (Between):              0.8952
# No. Observations:                4232   R-squared (Within):               0.5399
# Date:                Fri, Nov 01 2019   R-squared (Overall):              0.8984
# Time:                        12:03:02   Log-likelihood                   -449.71
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      515.63
# Entities:                         269   P-value                           0.0000
# Avg Obs:                       15.732   Distribution:                  F(9,3954)
# Min Obs:                       1.0000
# Max Obs:                       17.000   F-statistic (robust):             515.63
#                                         P-value                           0.0000
# Time periods:                      17   Distribution:                  F(9,3954)
# Avg Obs:                       248.94
# Min Obs:                       189.00
# Max Obs:                       269.00
#
#                                   Parameter Estimates
# ========================================================================================
#                       Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ----------------------------------------------------------------------------------------
# VRM_ADJ_log              0.4349     0.0117     37.178     0.0000      0.4120      0.4579
# FARE_per_UPT_log        -0.7504     0.0160    -47.003     0.0000     -0.7817     -0.7191
# POP_EMP_log              0.9888     0.0832     11.886     0.0000      0.8257      1.1518
# GasPrice_log             0.3282     0.0287     11.425     0.0000      0.2719      0.3845
# PCT_HH_NO_VEH            0.0125     0.0042     3.0130     0.0026      0.0044      0.0207
# YEARS_SINCE_TNC_BUS     -0.0356     0.0058    -6.1229     0.0000     -0.0470     -0.0242
# YEARS_SINCE_TNC_RAIL     0.0030     0.0099     0.3005     0.7638     -0.0164      0.0224
# BIKE_SHARE_BUS          -0.0278     0.0217    -1.2783     0.2012     -0.0703      0.0148
# BIKE_SHARE_RAIL          0.0813     0.0412     1.9709     0.0488      0.0004      0.1621
# ========================================================================================
#
# F-test for Poolability: 60.474
# P-value: 0.0000
# Distribution: F(268,3954)
#
# Included effects: Entity

# %%
# scooters

mod=PanelOLS.from_formula('UPT_ADJ_log \
                    ~ VRM_ADJ_log \
                    + FARE_per_UPT_log \
                    + POP_EMP_log \
                    + GasPrice_log \
                    + PCT_HH_NO_VEH \
                    + YEARS_SINCE_TNC_BUS \
                    + YEARS_SINCE_TNC_RAIL \
                    + BIKE_SHARE_BUS \
                    + BIKE_SHARE_RAIL \
                    + scooter_flag_BUS \
                    + scooter_flag_RAIL \
                    + EntityEffects \
                    ',data=df)
res=mod.fit()
print(res)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\data.py:39: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   new_df = df.copy().loc[self._full_index]
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\utility.py:476: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   warnings.warn(missing_value_warning_msg, MissingValueWarning)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:            UPT_ADJ_log   R-squared:                        0.5406
# Estimator:                   PanelOLS   R-squared (Between):              0.8987
# No. Observations:                4232   R-squared (Within):               0.5406
# Date:                Fri, Nov 01 2019   R-squared (Overall):              0.9018
# Time:                        12:03:23   Log-likelihood                   -446.71
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      422.77
# Entities:                         269   P-value                           0.0000
# Avg Obs:                       15.732   Distribution:                 F(11,3952)
# Min Obs:                       1.0000
# Max Obs:                       17.000   F-statistic (robust):             422.77
#                                         P-value                           0.0000
# Time periods:                      17   Distribution:                 F(11,3952)
# Avg Obs:                       248.94
# Min Obs:                       189.00
# Max Obs:                       269.00
#
#                                   Parameter Estimates
# ========================================================================================
#                       Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ----------------------------------------------------------------------------------------
# VRM_ADJ_log              0.4350     0.0117     37.198     0.0000      0.4120      0.4579
# FARE_per_UPT_log        -0.7510     0.0160    -47.056     0.0000     -0.7823     -0.7197
# POP_EMP_log              0.9823     0.0832     11.804     0.0000      0.8192      1.1455
# GasPrice_log             0.3322     0.0288     11.539     0.0000      0.2757      0.3886
# PCT_HH_NO_VEH            0.0123     0.0042     2.9582     0.0031      0.0041      0.0204
# YEARS_SINCE_TNC_BUS     -0.0336     0.0061    -5.5271     0.0000     -0.0456     -0.0217
# YEARS_SINCE_TNC_RAIL     0.0131     0.0110     1.1910     0.2337     -0.0084      0.0345
# BIKE_SHARE_BUS          -0.0272     0.0217    -1.2549     0.2096     -0.0698      0.0153
# BIKE_SHARE_RAIL          0.0719     0.0415     1.7340     0.0830     -0.0094      0.1532
# scooter_flag_BUS        -0.0493     0.0471    -1.0481     0.2947     -0.1416      0.0430
# scooter_flag_RAIL       -0.1496     0.0704    -2.1245     0.0337     -0.2877     -0.0115
# ========================================================================================
#
# F-test for Poolability: 60.524
# P-value: 0.0000
# Distribution: F(268,3952)
#
# Included effects: Entity

# %% [markdown]
# ## add the time trends back in

# %%
# individual time effects

mod=PanelOLS.from_formula('UPT_ADJ_log \
                    ~ VRM_ADJ_log \
                    + FARE_per_UPT_log \
                    + POP_EMP_log \
                    + GasPrice_log \
                    + PCT_HH_NO_VEH \
                    + YEARS_SINCE_TNC_BUS \
                    + YEARS_SINCE_TNC_RAIL \
                    + BIKE_SHARE_BUS \
                    + BIKE_SHARE_RAIL \
                    + scooter_flag_BUS \
                    + scooter_flag_RAIL \
                    + EntityEffects \
                    + TimeEffects \
                    ',data=df)
res=mod.fit()
print(res)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\data.py:39: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   new_df = df.copy().loc[self._full_index]
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\utility.py:476: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   warnings.warn(missing_value_warning_msg, MissingValueWarning)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:            UPT_ADJ_log   R-squared:                        0.4932
# Estimator:                   PanelOLS   R-squared (Between):              0.9905
# No. Observations:                4232   R-squared (Within):               0.5386
# Date:                Fri, Nov 01 2019   R-squared (Overall):              0.9911
# Time:                        12:04:18   Log-likelihood                   -412.23
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      348.24
# Entities:                         269   P-value                           0.0000
# Avg Obs:                       15.732   Distribution:                 F(11,3936)
# Min Obs:                       1.0000
# Max Obs:                       17.000   F-statistic (robust):             348.24
#                                         P-value                           0.0000
# Time periods:                      17   Distribution:                 F(11,3936)
# Avg Obs:                       248.94
# Min Obs:                       189.00
# Max Obs:                       269.00
#
#                                   Parameter Estimates
# ========================================================================================
#                       Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ----------------------------------------------------------------------------------------
# VRM_ADJ_log              0.4279     0.0117     36.541     0.0000      0.4050      0.4509
# FARE_per_UPT_log        -0.7562     0.0159    -47.575     0.0000     -0.7874     -0.7250
# POP_EMP_log              0.7329     0.0945     7.7537     0.0000      0.5476      0.9182
# GasPrice_log             0.3637     0.2619     1.3890     0.1649     -0.1497      0.8771
# PCT_HH_NO_VEH            0.0093     0.0042     2.2261     0.0261      0.0011      0.0175
# YEARS_SINCE_TNC_BUS     -0.0314     0.0089    -3.5306     0.0004     -0.0489     -0.0140
# YEARS_SINCE_TNC_RAIL     0.0134     0.0117     1.1473     0.2513     -0.0095      0.0363
# BIKE_SHARE_BUS          -0.0355     0.0219    -1.6227     0.1047     -0.0783      0.0074
# BIKE_SHARE_RAIL          0.0586     0.0414     1.4165     0.1567     -0.0225      0.1398
# scooter_flag_BUS        -0.0046     0.0490    -0.0929     0.9260     -0.1007      0.0916
# scooter_flag_RAIL       -0.0900     0.0727    -1.2379     0.2158     -0.2327      0.0526
# ========================================================================================
#
# F-test for Poolability: 58.045
# P-value: 0.0000
# Distribution: F(284,3936)
#
# Included effects: Entity, Time

# %%
# years since 2002

mod=PanelOLS.from_formula('UPT_ADJ_log \
                    ~ VRM_ADJ_log \
                    + FARE_per_UPT_log \
                    + POP_EMP_log \
                    + GasPrice_log \
                    + PCT_HH_NO_VEH \
                    + YEARS_SINCE_TNC_BUS \
                    + YEARS_SINCE_TNC_RAIL \
                    + BIKE_SHARE_BUS \
                    + BIKE_SHARE_RAIL \
                    + scooter_flag_BUS \
                    + scooter_flag_RAIL \
                    + YEARS_SINCE_2002_BUS \
                    + YEARS_SINCE_2002_RAIL \
                    + EntityEffects \
                    ',data=df)
res=mod.fit()
print(res)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\data.py:39: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   new_df = df.copy().loc[self._full_index]
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\utility.py:476: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   warnings.warn(missing_value_warning_msg, MissingValueWarning)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:            UPT_ADJ_log   R-squared:                        0.5441
# Estimator:                   PanelOLS   R-squared (Between):              0.9824
# No. Observations:                4232   R-squared (Within):               0.5441
# Date:                Fri, Nov 01 2019   R-squared (Overall):              0.9833
# Time:                        12:05:26   Log-likelihood                   -430.55
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      362.62
# Entities:                         269   P-value                           0.0000
# Avg Obs:                       15.732   Distribution:                 F(13,3950)
# Min Obs:                       1.0000
# Max Obs:                       17.000   F-statistic (robust):             362.62
#                                         P-value                           0.0000
# Time periods:                      17   Distribution:                 F(13,3950)
# Avg Obs:                       248.94
# Min Obs:                       189.00
# Max Obs:                       269.00
#
#                                    Parameter Estimates
# =========================================================================================
#                        Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -----------------------------------------------------------------------------------------
# VRM_ADJ_log               0.4322     0.0118     36.636     0.0000      0.4091      0.4554
# FARE_per_UPT_log         -0.7547     0.0159    -47.405     0.0000     -0.7859     -0.7235
# POP_EMP_log               0.7768     0.0911     8.5309     0.0000      0.5983      0.9553
# GasPrice_log              0.2568     0.0328     7.8361     0.0000      0.1926      0.3211
# PCT_HH_NO_VEH             0.0106     0.0042     2.5562     0.0106      0.0025      0.0187
# YEARS_SINCE_TNC_BUS      -0.0540     0.0071    -7.5803     0.0000     -0.0680     -0.0400
# YEARS_SINCE_TNC_RAIL      0.0106     0.0129     0.8275     0.4080     -0.0146      0.0358
# BIKE_SHARE_BUS           -0.0389     0.0217    -1.7906     0.0734     -0.0815      0.0037
# BIKE_SHARE_RAIL           0.0783     0.0433     1.8069     0.0709     -0.0067      0.1632
# scooter_flag_BUS         -0.0148     0.0473    -0.3117     0.7553     -0.1076      0.0781
# scooter_flag_RAIL        -0.1388     0.0706    -1.9666     0.0493     -0.2772     -0.0004
# YEARS_SINCE_2002_BUS      0.0100     0.0018     5.4580     0.0000      0.0064      0.0136
# YEARS_SINCE_2002_RAIL     0.0030     0.0043     0.6950     0.4871     -0.0055      0.0115
# =========================================================================================
#
# F-test for Poolability: 58.786
# P-value: 0.0000
# Distribution: F(268,3950)
#
# Included effects: Entity

# %%
# breakpoint at 2010

mod=PanelOLS.from_formula('UPT_ADJ_log \
                    ~ VRM_ADJ_log \
                    + FARE_per_UPT_log \
                    + POP_EMP_log \
                    + GasPrice_log \
                    + PCT_HH_NO_VEH \
                    + YEARS_SINCE_TNC_BUS \
                    + YEARS_SINCE_TNC_RAIL \
                    + BIKE_SHARE_BUS \
                    + BIKE_SHARE_RAIL \
                    + scooter_flag_BUS \
                    + scooter_flag_RAIL \
                    + YEARS_2002_2010_BUS \
                    + YEARS_AFTER_2010_BUS \
                    + YEARS_2002_2010_RAIL \
                    + YEARS_AFTER_2010_RAIL \
                    + EntityEffects \
                    ',data=df)
res=mod.fit()
print(res)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\data.py:39: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   new_df = df.copy().loc[self._full_index]
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\utility.py:476: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   warnings.warn(missing_value_warning_msg, MissingValueWarning)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:            UPT_ADJ_log   R-squared:                        0.5469
# Estimator:                   PanelOLS   R-squared (Between):              0.9928
# No. Observations:                4232   R-squared (Within):               0.5469
# Date:                Fri, Nov 01 2019   R-squared (Overall):              0.9932
# Time:                        12:05:47   Log-likelihood                   -417.60
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      317.66
# Entities:                         269   P-value                           0.0000
# Avg Obs:                       15.732   Distribution:                 F(15,3948)
# Min Obs:                       1.0000
# Max Obs:                       17.000   F-statistic (robust):             317.66
#                                         P-value                           0.0000
# Time periods:                      17   Distribution:                 F(15,3948)
# Avg Obs:                       248.94
# Min Obs:                       189.00
# Max Obs:                       269.00
#
#                                    Parameter Estimates
# =========================================================================================
#                        Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -----------------------------------------------------------------------------------------
# VRM_ADJ_log               0.4301     0.0118     36.520     0.0000      0.4070      0.4532
# FARE_per_UPT_log         -0.7567     0.0159    -47.646     0.0000     -0.7879     -0.7256
# POP_EMP_log               0.7257     0.0915     7.9328     0.0000      0.5463      0.9051
# GasPrice_log              0.1366     0.0422     3.2361     0.0012      0.0539      0.2194
# PCT_HH_NO_VEH             0.0098     0.0041     2.3537     0.0186      0.0016      0.0179
# YEARS_SINCE_TNC_BUS      -0.0449     0.0076    -5.8875     0.0000     -0.0598     -0.0299
# YEARS_SINCE_TNC_RAIL      0.0386     0.0165     2.3369     0.0195      0.0062      0.0709
# BIKE_SHARE_BUS           -0.0370     0.0217    -1.7079     0.0877     -0.0796      0.0055
# BIKE_SHARE_RAIL           0.1003     0.0440     2.2800     0.0227      0.0140      0.1865
# scooter_flag_BUS         -0.0072     0.0472    -0.1532     0.8782     -0.0999      0.0854
# scooter_flag_RAIL        -0.1251     0.0705    -1.7745     0.0761     -0.2634      0.0131
# YEARS_2002_2010_BUS       0.0243     0.0039     6.2194     0.0000      0.0166      0.0320
# YEARS_AFTER_2010_BUS     -0.0003     0.0033    -0.0825     0.9343     -0.0068      0.0062
# YEARS_2002_2010_RAIL      0.0243     0.0066     3.6897     0.0002      0.0114      0.0373
# YEARS_AFTER_2010_RAIL    -0.0273     0.0109    -2.5157     0.0119     -0.0486     -0.0060
# =========================================================================================
#
# F-test for Poolability: 58.685
# P-value: 0.0000
# Distribution: F(268,3948)
#
# Included effects: Entity

# %%
# breakpoint at 2014

mod=PanelOLS.from_formula('UPT_ADJ_log \
                    ~ VRM_ADJ_log \
                    + FARE_per_UPT_log \
                    + POP_EMP_log \
                    + GasPrice_log \
                    + PCT_HH_NO_VEH \
                    + YEARS_SINCE_TNC_BUS \
                    + YEARS_SINCE_TNC_RAIL \
                    + BIKE_SHARE_BUS \
                    + BIKE_SHARE_RAIL \
                    + scooter_flag_BUS \
                    + scooter_flag_RAIL \
                    + YEARS_2002_2014_BUS \
                    + YEARS_AFTER_2014_BUS \
                    + YEARS_2002_2014_RAIL \
                    + YEARS_AFTER_2014_RAIL \
                    + EntityEffects \
                    ',data=df)
res=mod.fit()
print(res)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\data.py:39: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   new_df = df.copy().loc[self._full_index]
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\utility.py:476: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   warnings.warn(missing_value_warning_msg, MissingValueWarning)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:            UPT_ADJ_log   R-squared:                        0.5462
# Estimator:                   PanelOLS   R-squared (Between):              0.9884
# No. Observations:                4232   R-squared (Within):               0.5462
# Date:                Fri, Nov 01 2019   R-squared (Overall):              0.9890
# Time:                        12:06:16   Log-likelihood                   -420.61
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      316.83
# Entities:                         269   P-value                           0.0000
# Avg Obs:                       15.732   Distribution:                 F(15,3948)
# Min Obs:                       1.0000
# Max Obs:                       17.000   F-statistic (robust):             316.83
#                                         P-value                           0.0000
# Time periods:                      17   Distribution:                 F(15,3948)
# Avg Obs:                       248.94
# Min Obs:                       189.00
# Max Obs:                       269.00
#
#                                    Parameter Estimates
# =========================================================================================
#                        Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -----------------------------------------------------------------------------------------
# VRM_ADJ_log               0.4324     0.0118     36.727     0.0000      0.4093      0.4555
# FARE_per_UPT_log         -0.7563     0.0159    -47.584     0.0000     -0.7875     -0.7251
# POP_EMP_log               0.7524     0.0910     8.2637     0.0000      0.5739      0.9309
# GasPrice_log              0.1817     0.0382     4.7511     0.0000      0.1067      0.2567
# PCT_HH_NO_VEH             0.0088     0.0042     2.1144     0.0345      0.0006      0.0170
# YEARS_SINCE_TNC_BUS      -0.0369     0.0091    -4.0524     0.0001     -0.0548     -0.0191
# YEARS_SINCE_TNC_RAIL      0.0476     0.0186     2.5589     0.0105      0.0111      0.0841
# BIKE_SHARE_BUS           -0.0421     0.0217    -1.9385     0.0526     -0.0846      0.0005
# BIKE_SHARE_RAIL           0.0809     0.0433     1.8691     0.0617     -0.0040      0.1658
# scooter_flag_BUS         -0.0022     0.0474    -0.0456     0.9637     -0.0950      0.0907
# scooter_flag_RAIL        -0.0736     0.0728    -1.0109     0.3121     -0.2162      0.0691
# YEARS_2002_2014_BUS       0.0150     0.0023     6.5256     0.0000      0.0105      0.0195
# YEARS_AFTER_2014_BUS     -0.0168     0.0086    -1.9506     0.0512     -0.0337   8.616e-05
# YEARS_2002_2014_RAIL      0.0078     0.0045     1.7495     0.0803     -0.0009      0.0165
# YEARS_AFTER_2014_RAIL    -0.0674     0.0237    -2.8466     0.0044     -0.1139     -0.0210
# =========================================================================================
#
# F-test for Poolability: 59.048
# P-value: 0.0000
# Distribution: F(268,3948)
#
# Included effects: Entity

# %% [markdown]
# ## Run some analytics

# %%
sns.distplot(res.resids)

# %%
sm.graphics.qqplot(res.resids,line = 'q')

# %% [markdown]
# ## Calculate FAC
