# %%
import pandas as pd
import seaborn as sns
import numpy as np
import linearmodels as lm
import matplotlib
import math
import statsmodels.formula.api as smf
import statsmodels.api as sm

from linearmodels.panel import PanelOLS
from linearmodels.panel import RandomEffects
from linearmodels.panel import FirstDifferenceOLS
from linearmodels.panel import compare
from matplotlib import pyplot as plt

from pandas.api.types import is_numeric_dtype

pd.set_option('display.max_columns', 500)

# %matplotlib inline

# %%
# read the main data set
df=pd.read_csv('estimation_file.csv',
                    encoding='utf-8')

# %%
# exclude if ridership is zero--missing data
df = df[df['UPT_ADJ']>0]

# %%
df['BUS_FLAG'] = np.where(df['Mode']=='Bus', 1, 0)
df['RAIL_FLAG'] = np.where(df['Mode']=='Rail', 1, 0)

# %%
# include population + employment
df['POP_EMP'] = df['Tot_Pop'] + df['TOT_EMP_MSA']
df['HH_EMP'] = df['Total_HH'] + df['TOT_EMP_MSA']

# percent of population in transit supportive density
df['TSD_POP_PCT'] = df['POP_CENSUSTRACT'] / df['Tot_Pop']

# %%
# time effects
df['YEARS_SINCE_2002']  = df['Year'] - 2002

df['YEARS_2002_2010']  = df['Year'].apply(lambda x : min(x-2002, 8))
df['YEARS_AFTER_2010'] = df['Year'].apply(lambda x : max(x-2010, 0))

df['YEARS_2002_2014']  = df['Year'].apply(lambda x : min(x-2002, 12))
df['YEARS_AFTER_2014'] = df['Year'].apply(lambda x : max(x-2014, 0))


df['YEARS_SINCE_2002_BUS']  = df['YEARS_SINCE_2002'] * df['BUS_FLAG']
df['YEARS_SINCE_2002_RAIL'] = df['YEARS_SINCE_2002'] * df['RAIL_FLAG']

df['YEARS_2002_2010_BUS']   = df['YEARS_2002_2010'] * df['BUS_FLAG']
df['YEARS_AFTER_2010_BUS']  = df['YEARS_AFTER_2010']* df['BUS_FLAG']
df['YEARS_2002_2010_RAIL']  = df['YEARS_2002_2010'] * df['RAIL_FLAG']
df['YEARS_AFTER_2010_RAIL'] = df['YEARS_AFTER_2010']* df['RAIL_FLAG']

df['YEARS_2002_2014_BUS']   = df['YEARS_2002_2014'] * df['BUS_FLAG']
df['YEARS_AFTER_2014_BUS']  = df['YEARS_AFTER_2014']* df['BUS_FLAG']
df['YEARS_2002_2014_RAIL']  = df['YEARS_2002_2014'] * df['RAIL_FLAG']
df['YEARS_AFTER_2014_RAIL'] = df['YEARS_AFTER_2014']* df['RAIL_FLAG']

# %%
# various bus/rail specifics

df['TNC_FLAG_BUS'] = df['TNC_FLAG'] * df['BUS_FLAG']
df['TNC_FLAG_RAIL'] = df['TNC_FLAG'] * df['RAIL_FLAG']

df['YEARS_SINCE_TNC_BUS'] = df['YEARS_SINCE_TNC'] * df['BUS_FLAG']
df['YEARS_SINCE_TNC_RAIL'] = df['YEARS_SINCE_TNC'] * df['RAIL_FLAG']

df['dockless_flag'] = df['dockCt'].apply(lambda x : min(x,1))
df['scooter_flag']  = df['scooterCt'].apply(lambda x : min(x,1))

df['BIKE_SHARE'] = df['PBS_Flag'] + df['dockless_flag']
df['BIKE_SHARE'] = df['BIKE_SHARE'].apply(lambda x : min(x,1))


df['PBS_Flag_BUS']   = df['PBS_Flag']   * df['BUS_FLAG']
df['dockCt_BUS']     = df['dockCt']     * df['BUS_FLAG']
df['docklessCt_BUS'] = df['docklessCt'] * df['BUS_FLAG']
df['scooterCt_BUS']  = df['scooterCt']  * df['BUS_FLAG']
df['dockless_flag_BUS'] = df['dockless_flag'] * df['BUS_FLAG']
df['scooter_flag_BUS']  = df['scooter_flag']  * df['BUS_FLAG']
df['BIKE_SHARE_BUS']  = df['BIKE_SHARE']  * df['BUS_FLAG']


df['PBS_Flag_RAIL']   = df['PBS_Flag']   * df['RAIL_FLAG']
df['dockCt_RAIL']     = df['dockCt']     * df['RAIL_FLAG']
df['docklessCt_RAIL'] = df['docklessCt'] * df['RAIL_FLAG']
df['scooterCt_RAIL']  = df['scooterCt']  * df['RAIL_FLAG']
df['dockless_flag_RAIL'] = df['dockless_flag'] * df['RAIL_FLAG']
df['scooter_flag_RAIL']  = df['scooter_flag']  * df['RAIL_FLAG']
df['BIKE_SHARE_RAIL']  = df['BIKE_SHARE']  * df['RAIL_FLAG']

# %%
# set the indices
df['ID'] = df['MNAME'] + '-' + df['Mode']
df=df.set_index(['ID','Year'])

# %%
# keep only the numeric columns -- the estimation will give an error otherwise
df = df.select_dtypes(include=[np.number])

# %%
# create a log of all fields
for col in df.columns:
    df[col+'_log'] = np.log(df[col]+1)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:3: RuntimeWarning: invalid value encountered in log
#   app.launch_new_instance()

# %%
# check the data
df.head()
# Out:
#                                Unnamed: 0   CBSA  NEW_CBSA          UPT  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002           0  10420       NaN  5226385.660
#                          2003           1  10420       NaN  5395901.888
#                          2004           2  10420       NaN  5907162.281
#                          2005           3  10420       NaN  6013680.881
#                          2006           4  10420       NaN  6070797.419
#
#                                        VRM      UPT_ADJ      VRM_ADJ  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002  4026372.388  5226385.660  4026372.388
#                          2003  3976568.624  5395901.888  3976568.624
#                          2004  4315392.555  5907162.281  4315392.555
#                          2005  4053011.065  6013680.881  4053011.065
#                          2006  3994786.013  6070797.419  3994786.013
#
#                                    VRH_ADJ  FARE_TOTAL  FARE_per_UPT  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002  270506.6928    660887.0      0.114148
#                          2003  270398.3688   2568502.0      0.429694
#                          2004  597239.8605   2524882.0      0.385839
#                          2005  281367.9792   3022880.0      0.453758
#                          2006  281536.7841   3163036.0      0.470329
#
#                                AREALANDPT      Tot_Pop  Tot_Instate_Pop  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002   744634347  646583.7344      496141.0469
#                          2003   744634347  659397.0625      504631.8125
#                          2004   744634347  672492.7500      513183.7500
#                          2005   744634347  684459.0000      521491.0000
#                          2006   744634347  700943.0000      530777.0000
#
#                                Tot_Outstate_Pop  Tot_NonUSA_POP  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002       137193.6719      -389.53125
#                          2003       137582.3125       753.12500
#                          2004       138058.7500      1942.50000
#                          2005       138184.0000      2945.00000
#                          2006       139714.0000      4695.00000
#
#                                Total_Median_Income_Individual  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                     25405.20313
#                          2003                     25120.18750
#                          2004                     24804.25000
#                          2005                     24612.00000
#                          2006                     23925.00000
#
#                                Native_Instate_Med_Inc_Indiv  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                   26028.32813
#                          2003                   25632.68750
#                          2004                   25208.25000
#                          2005                   24899.00000
#                          2006                   24129.00000
#
#                                Native_Outstate_Med_Inc_Indiv  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                    26651.07813
#                          2003                    25995.68750
#                          2004                    25305.25000
#                          2005                    24755.00000
#                          2006                    23644.00000
#
#                                Total_Pop_Poverty  Pop_Below100_Poverty  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002          682354.11                  7.55
#                          2003          682850.56                  8.81
#                          2004          683397.75                 10.08
#                          2005          683742.00                 11.30
#                          2006          684898.00                 12.70
#
#                                Pop_Below150_Poverty  Pop_Above150_Poverty  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                  8.94                 83.85
#                          2003                  8.66                 82.79
#                          2004                  8.38                 81.73
#                          2005                  8.10                 80.70
#                          2006                  7.80                 79.50
#
#                                Age_under18  Age_18to64  Age_over64   Total_HH  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002        24.64        62.9       12.46  265452.20
#                          2003        24.33        63.0       12.68  269144.19
#                          2004        24.00        63.1       12.90  272892.25
#                          2005        23.70        63.2       13.10  276416.00
#                          2006        23.30        63.3       13.40  280837.00
#
#                                 HH_0Veh   HH_1Veh    HH_2Veh   HH_3Veh  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002  22830.14  58254.52  117083.25  46891.53
#                          2003  22073.44  67400.94  115443.00  44874.88
#                          2004  21266.25  76795.25  113694.00  42855.50
#                          2005  20661.00  85198.00  112380.00  40847.00
#                          2006  19248.00  97567.00  109326.00  38795.00
#
#                                HH_4+Veh  PCT_HH_NO_VEH   HH_MED_INC  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002  20392.77           8.60  43046.82813
#                          2003  19351.94           8.20  43566.68750
#                          2004  18281.25           7.79  44030.25000
#                          2005  17330.00           7.47  44719.00000
#                          2006  15901.00           6.85  44507.00000
#
#                                HH_MEAN_INC  INC_U35  INC_35_100  INC_100P  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002   55300.5625    39.49       46.56     13.95
#                          2003   56379.7500    39.24       46.66     14.10
#                          2004   57390.0000    39.03       46.78     14.20
#                          2005   58676.0000    38.70       46.80     14.50
#                          2006   58859.0000    38.80       47.20     14.00
#
#                                TOT_UNEMP_MSA  TOT_EMP_MSA  TOT_LABOR_MSA  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002       21948.42    346147.17      368095.58
#                          2003       23342.50    348574.17      371916.67
#                          2004       23471.75    351723.75      375195.50
#                          2005       22420.75    358105.92      380526.67
#                          2006       20348.08    365133.33      385481.42
#
#                                UNEMP_RATE_PCT  EMP_RATE_PCT  GasPrice  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002            5.96         94.04      1.36
#                          2003            6.28         93.72      1.55
#                          2004            6.26         93.74      1.83
#                          2005            5.90         94.10      2.25
#                          2006            5.28         94.72      2.54
#
#                                Area_acre  POP_CENSUSTRACT  AVG_SPEED  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002        NaN         119786.0      14.88
#                          2003        NaN         119199.0      14.71
#                          2004        NaN         118612.0       7.23
#                          2005    13644.8         118025.0      14.40
#                          2006    13644.8         117438.0      14.19
#
#                                2018_Dollar_Multiplier  TNC_ARRIVAL  TNC_FLAG  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                    1.40         2014         0
#                          2003                    1.37         2014         0
#                          2004                    1.33         2014         0
#                          2005                    1.29         2014         0
#                          2006                    1.25         2014         0
#
#                                YEARS_SINCE_TNC  dockCt  docklessCt  scooterCt  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                0       0           0          0
#                          2003                0       0           0          0
#                          2004                0       0           0          0
#                          2005                0       0           0          0
#                          2006                0       0           0          0
#
#                                PBS_Start  PBS_End  PBS_Flag  walkscore  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002        NaN      NaN       0.0          0
#                          2003        NaN      NaN       0.0          0
#                          2004        NaN      NaN       0.0          0
#                          2005        NaN      NaN       0.0          0
#                          2006        NaN      NaN       0.0          0
#
#                                transit  bike  FARE_TOTAL_2018  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002        0     0        925241.80
#                          2003        0     0       3518847.74
#                          2004        0     0       3358093.06
#                          2005        0     0       3899515.20
#                          2006        0     0       3953795.00
#
#                                TOTAL_MED_INC_INDIV_2018  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002              35567.284382
#                          2003              34414.656875
#                          2004              32989.652500
#                          2005              31749.480000
#                          2006              29906.250000
#
#                                NATIVE_INSTATE_MED_INC_2018  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                 36439.659382
#                          2003                 35116.781875
#                          2004                 33526.972500
#                          2005                 32119.710000
#                          2006                 30161.250000
#
#                                NATIVE_OUTSTATE_MED_INC_2018  HH_MED_INC_2018  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                  37311.509382     60265.559382
#                          2003                  35614.091875     59686.361875
#                          2004                  33655.982500     58560.232500
#                          2005                  31933.950000     57687.510000
#                          2006                  29555.000000     55633.750000
#
#                                HH_MEAN_INC_2018  GAS_PRICE_2018  BUS_FLAG  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002        77420.7875          1.9040         1
#                          2003        77240.2575          2.1235         1
#                          2004        76328.7000          2.4339         1
#                          2005        75692.0400          2.9025         1
#                          2006        73573.7500          3.1750         1
#
#                                RAIL_FLAG       POP_EMP     HH_EMP  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002          0  9.927309e+05  611599.37
#                          2003          0  1.007971e+06  617718.36
#                          2004          0  1.024216e+06  624616.00
#                          2005          0  1.042565e+06  634521.92
#                          2006          0  1.066076e+06  645970.33
#
#                                TSD_POP_PCT  YEARS_SINCE_2002  YEARS_2002_2010  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002     0.185260                 0                0
#                          2003     0.180770                 1                1
#                          2004     0.176377                 2                2
#                          2005     0.172435                 3                3
#                          2006     0.167543                 4                4
#
#                                YEARS_AFTER_2010  YEARS_2002_2014  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                 0                0
#                          2003                 0                1
#                          2004                 0                2
#                          2005                 0                3
#                          2006                 0                4
#
#                                YEARS_AFTER_2014  YEARS_SINCE_2002_BUS  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                 0                     0
#                          2003                 0                     1
#                          2004                 0                     2
#                          2005                 0                     3
#                          2006                 0                     4
#
#                                YEARS_SINCE_2002_RAIL  YEARS_2002_2010_BUS  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                      0                    0
#                          2003                      0                    1
#                          2004                      0                    2
#                          2005                      0                    3
#                          2006                      0                    4
#
#                                YEARS_AFTER_2010_BUS  YEARS_2002_2010_RAIL  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                     0                     0
#                          2003                     0                     0
#                          2004                     0                     0
#                          2005                     0                     0
#                          2006                     0                     0
#
#                                YEARS_AFTER_2010_RAIL  YEARS_2002_2014_BUS  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                      0                    0
#                          2003                      0                    1
#                          2004                      0                    2
#                          2005                      0                    3
#                          2006                      0                    4
#
#                                YEARS_AFTER_2014_BUS  YEARS_2002_2014_RAIL  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                     0                     0
#                          2003                     0                     0
#                          2004                     0                     0
#                          2005                     0                     0
#                          2006                     0                     0
#
#                                YEARS_AFTER_2014_RAIL  TNC_FLAG_BUS  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                      0             0
#                          2003                      0             0
#                          2004                      0             0
#                          2005                      0             0
#                          2006                      0             0
#
#                                TNC_FLAG_RAIL  YEARS_SINCE_TNC_BUS  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002              0                    0
#                          2003              0                    0
#                          2004              0                    0
#                          2005              0                    0
#                          2006              0                    0
#
#                                YEARS_SINCE_TNC_RAIL  dockless_flag  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                     0              0
#                          2003                     0              0
#                          2004                     0              0
#                          2005                     0              0
#                          2006                     0              0
#
#                                scooter_flag  BIKE_SHARE  PBS_Flag_BUS  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002             0         0.0           0.0
#                          2003             0         0.0           0.0
#                          2004             0         0.0           0.0
#                          2005             0         0.0           0.0
#                          2006             0         0.0           0.0
#
#                                dockCt_BUS  docklessCt_BUS  scooterCt_BUS  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002           0               0              0
#                          2003           0               0              0
#                          2004           0               0              0
#                          2005           0               0              0
#                          2006           0               0              0
#
#                                dockless_flag_BUS  scooter_flag_BUS  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                  0                 0
#                          2003                  0                 0
#                          2004                  0                 0
#                          2005                  0                 0
#                          2006                  0                 0
#
#                                BIKE_SHARE_BUS  PBS_Flag_RAIL  dockCt_RAIL  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002             0.0            0.0            0
#                          2003             0.0            0.0            0
#                          2004             0.0            0.0            0
#                          2005             0.0            0.0            0
#                          2006             0.0            0.0            0
#
#                                docklessCt_RAIL  scooterCt_RAIL  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                0               0
#                          2003                0               0
#                          2004                0               0
#                          2005                0               0
#                          2006                0               0
#
#                                dockless_flag_RAIL  scooter_flag_RAIL  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                   0                  0
#                          2003                   0                  0
#                          2004                   0                  0
#                          2005                   0                  0
#                          2006                   0                  0
#
#                                BIKE_SHARE_RAIL  Unnamed: 0_log  CBSA_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002              0.0        0.000000  9.251578
#                          2003              0.0        0.693147  9.251578
#                          2004              0.0        1.098612  9.251578
#                          2005              0.0        1.386294  9.251578
#                          2006              0.0        1.609438  9.251578
#
#                                NEW_CBSA_log    UPT_log    VRM_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002           NaN  15.469231  15.208377
#                          2003           NaN  15.501150  15.195930
#                          2004           NaN  15.591676  15.277699
#                          2005           NaN  15.609548  15.214971
#                          2006           NaN  15.619001  15.200501
#
#                                UPT_ADJ_log  VRM_ADJ_log  VRH_ADJ_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002    15.469231    15.208377    12.508056
#                          2003    15.501150    15.195930    12.507655
#                          2004    15.591676    15.277699    13.300076
#                          2005    15.609548    15.214971    12.547422
#                          2006    15.619001    15.200501    12.548022
#
#                                FARE_TOTAL_log  FARE_per_UPT_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002       13.401340          0.108090
#                          2003       14.758834          0.357460
#                          2004       14.741705          0.326305
#                          2005       14.921721          0.374152
#                          2006       14.967043          0.385486
#
#                                AREALANDPT_log  Tot_Pop_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002       20.428404    13.379460
#                          2003       20.428404    13.399083
#                          2004       20.428404    13.418748
#                          2005       20.428404    13.436385
#                          2006       20.428404    13.460183
#
#                                Tot_Instate_Pop_log  Tot_Outstate_Pop_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002            13.114618             11.829156
#                          2003            13.131586             11.831985
#                          2004            13.148391             11.835442
#                          2005            13.164449             11.836349
#                          2006            13.182099             11.847360
#
#                                Tot_NonUSA_POP_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                 NaN
#                          2003            6.625558
#                          2004            7.572246
#                          2005            7.988204
#                          2006            8.454466
#
#                                Total_Median_Income_Individual_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                           10.142749
#                          2003                           10.131467
#                          2004                           10.118811
#                          2005                           10.111030
#                          2006                           10.082721
#
#                                Native_Instate_Med_Inc_Indiv_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                         10.166979
#                          2003                         10.151663
#                          2004                         10.134966
#                          2005                         10.122623
#                          2006                         10.091211
#
#                                Native_Outstate_Med_Inc_Indiv_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                          10.190622
#                          2003                          10.165724
#                          2004                          10.138807
#                          2005                          10.116823
#                          2006                          10.070907
#
#                                Total_Pop_Poverty_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002              13.433305
#                          2003              13.434033
#                          2004              13.434834
#                          2005              13.435337
#                          2006              13.437027
#
#                                Pop_Below100_Poverty_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                  2.145931
#                          2003                  2.283402
#                          2004                  2.405142
#                          2005                  2.509599
#                          2006                  2.617396
#
#                                Pop_Below150_Poverty_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                  2.296567
#                          2003                  2.267994
#                          2004                  2.238580
#                          2005                  2.208274
#                          2006                  2.174752
#
#                                Pop_Above150_Poverty_log  Age_under18_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                  4.440885         3.244154
#                          2003                  4.428314         3.231989
#                          2004                  4.415582         3.218876
#                          2005                  4.403054         3.206803
#                          2006                  4.388257         3.190476
#
#                                Age_18to64_log  Age_over64_log  Total_HH_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002        4.157319        2.599722     12.489194
#                          2003        4.158883        2.615935     12.503006
#                          2004        4.160444        2.631889     12.516836
#                          2005        4.162003        2.646175     12.529666
#                          2006        4.163560        2.667228     12.545533
#
#                                HH_0Veh_log  HH_1Veh_log  HH_2Veh_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002    10.035881    10.972594    11.670649
#                          2003    10.002176    11.118429    11.656541
#                          2004     9.964924    11.248911    11.641275
#                          2005     9.936052    11.352745    11.629650
#                          2006     9.865214    11.488305    11.602099
#
#                                HH_3Veh_log  HH_4+Veh_log  PCT_HH_NO_VEH_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002    10.755614      9.922985           2.261763
#                          2003    10.711656      9.870600           2.219203
#                          2004    10.665613      9.813686           2.173615
#                          2005    10.617613      9.760252           2.136531
#                          2006    10.566072      9.674200           2.060514
#
#                                HH_MED_INC_log  HH_MEAN_INC_log  INC_U35_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002       10.670067        10.920556     3.701055
#                          2003       10.682071        10.939883     3.694862
#                          2004       10.692655        10.957643     3.689629
#                          2005       10.708176        10.979803     3.681351
#                          2006       10.703424        10.982917     3.683867
#
#                                INC_35_100_log  INC_100P_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002        3.861992      2.704711
#                          2003        3.864092      2.714695
#                          2004        3.866607      2.721295
#                          2005        3.867026      2.740840
#                          2006        3.875359      2.708050
#
#                                TOT_UNEMP_MSA_log  TOT_EMP_MSA_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002           9.996496        12.754622
#                          2003          10.058074        12.761609
#                          2004          10.063595        12.770604
#                          2005          10.017787        12.788587
#                          2006           9.920791        12.808021
#
#                                TOT_LABOR_MSA_log  UNEMP_RATE_PCT_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002          12.816101            1.940179
#                          2003          12.826428            1.985131
#                          2004          12.835205            1.982380
#                          2005          12.849314            1.931521
#                          2006          12.862251            1.837370
#
#                                EMP_RATE_PCT_log  GasPrice_log  Area_acre_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002          4.554298      0.858662            NaN
#                          2003          4.550925      0.936093            NaN
#                          2004          4.551136      1.040277            NaN
#                          2005          4.554929      1.178655       9.521187
#                          2006          4.561427      1.264127       9.521187
#
#                                POP_CENSUSTRACT_log  AVG_SPEED_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002            11.693470       2.765060
#                          2003            11.688558       2.754297
#                          2004            11.683621       2.107786
#                          2005            11.678660       2.734368
#                          2006            11.673674       2.720637
#
#                                2018_Dollar_Multiplier_log  TNC_ARRIVAL_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                    0.875469         7.608374
#                          2003                    0.862890         7.608374
#                          2004                    0.845868         7.608374
#                          2005                    0.828552         7.608374
#                          2006                    0.810930         7.608374
#
#                                TNC_FLAG_log  YEARS_SINCE_TNC_log  dockCt_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002           0.0                  0.0         0.0
#                          2003           0.0                  0.0         0.0
#                          2004           0.0                  0.0         0.0
#                          2005           0.0                  0.0         0.0
#                          2006           0.0                  0.0         0.0
#
#                                docklessCt_log  scooterCt_log  PBS_Start_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002             0.0            0.0            NaN
#                          2003             0.0            0.0            NaN
#                          2004             0.0            0.0            NaN
#                          2005             0.0            0.0            NaN
#                          2006             0.0            0.0            NaN
#
#                                PBS_End_log  PBS_Flag_log  walkscore_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002          NaN           0.0            0.0
#                          2003          NaN           0.0            0.0
#                          2004          NaN           0.0            0.0
#                          2005          NaN           0.0            0.0
#                          2006          NaN           0.0            0.0
#
#                                transit_log  bike_log  FARE_TOTAL_2018_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002          0.0       0.0            13.737811
#                          2003          0.0       0.0            15.073644
#                          2004          0.0       0.0            15.026884
#                          2005          0.0       0.0            15.176363
#                          2006          0.0       0.0            15.190187
#
#                                TOTAL_MED_INC_INDIV_2018_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                     10.479210
#                          2003                     10.446267
#                          2004                     10.403980
#                          2005                     10.365663
#                          2006                     10.305856
#
#                                NATIVE_INSTATE_MED_INC_2018_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                        10.503440
#                          2003                        10.466463
#                          2004                        10.420135
#                          2005                        10.377256
#                          2006                        10.314346
#
#                                NATIVE_OUTSTATE_MED_INC_2018_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                         10.527084
#                          2003                         10.480525
#                          2004                         10.423976
#                          2005                         10.371456
#                          2006                         10.294042
#
#                                HH_MED_INC_2018_log  HH_MEAN_INC_2018_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002            11.006533             11.257024
#                          2003            10.996876             11.254689
#                          2004            10.977828             11.242817
#                          2005            10.962813             11.234441
#                          2006            10.926563             11.206057
#
#                                GAS_PRICE_2018_log  BUS_FLAG_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002            1.066089      0.693147
#                          2003            1.138954      0.693147
#                          2004            1.233697      0.693147
#                          2005            1.361617      0.693147
#                          2006            1.429114      0.693147
#
#                                RAIL_FLAG_log  POP_EMP_log  HH_EMP_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002            0.0    13.808216   13.323834
#                          2003            0.0    13.823451   13.333790
#                          2004            0.0    13.839439   13.344894
#                          2005            0.0    13.857195   13.360629
#                          2006            0.0    13.879496   13.378510
#
#                                TSD_POP_PCT_log  YEARS_SINCE_2002_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002         0.169962              0.000000
#                          2003         0.166167              0.693147
#                          2004         0.162439              1.098612
#                          2005         0.159083              1.386294
#                          2006         0.154901              1.609438
#
#                                YEARS_2002_2010_log  YEARS_AFTER_2010_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002             0.000000                   0.0
#                          2003             0.693147                   0.0
#                          2004             1.098612                   0.0
#                          2005             1.386294                   0.0
#                          2006             1.609438                   0.0
#
#                                YEARS_2002_2014_log  YEARS_AFTER_2014_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002             0.000000                   0.0
#                          2003             0.693147                   0.0
#                          2004             1.098612                   0.0
#                          2005             1.386294                   0.0
#                          2006             1.609438                   0.0
#
#                                YEARS_SINCE_2002_BUS_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                  0.000000
#                          2003                  0.693147
#                          2004                  1.098612
#                          2005                  1.386294
#                          2006                  1.609438
#
#                                YEARS_SINCE_2002_RAIL_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                        0.0
#                          2003                        0.0
#                          2004                        0.0
#                          2005                        0.0
#                          2006                        0.0
#
#                                YEARS_2002_2010_BUS_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                 0.000000
#                          2003                 0.693147
#                          2004                 1.098612
#                          2005                 1.386294
#                          2006                 1.609438
#
#                                YEARS_AFTER_2010_BUS_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                       0.0
#                          2003                       0.0
#                          2004                       0.0
#                          2005                       0.0
#                          2006                       0.0
#
#                                YEARS_2002_2010_RAIL_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                       0.0
#                          2003                       0.0
#                          2004                       0.0
#                          2005                       0.0
#                          2006                       0.0
#
#                                YEARS_AFTER_2010_RAIL_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                        0.0
#                          2003                        0.0
#                          2004                        0.0
#                          2005                        0.0
#                          2006                        0.0
#
#                                YEARS_2002_2014_BUS_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                 0.000000
#                          2003                 0.693147
#                          2004                 1.098612
#                          2005                 1.386294
#                          2006                 1.609438
#
#                                YEARS_AFTER_2014_BUS_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                       0.0
#                          2003                       0.0
#                          2004                       0.0
#                          2005                       0.0
#                          2006                       0.0
#
#                                YEARS_2002_2014_RAIL_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                       0.0
#                          2003                       0.0
#                          2004                       0.0
#                          2005                       0.0
#                          2006                       0.0
#
#                                YEARS_AFTER_2014_RAIL_log  TNC_FLAG_BUS_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                        0.0               0.0
#                          2003                        0.0               0.0
#                          2004                        0.0               0.0
#                          2005                        0.0               0.0
#                          2006                        0.0               0.0
#
#                                TNC_FLAG_RAIL_log  YEARS_SINCE_TNC_BUS_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                0.0                      0.0
#                          2003                0.0                      0.0
#                          2004                0.0                      0.0
#                          2005                0.0                      0.0
#                          2006                0.0                      0.0
#
#                                YEARS_SINCE_TNC_RAIL_log  dockless_flag_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                       0.0                0.0
#                          2003                       0.0                0.0
#                          2004                       0.0                0.0
#                          2005                       0.0                0.0
#                          2006                       0.0                0.0
#
#                                scooter_flag_log  BIKE_SHARE_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002               0.0             0.0
#                          2003               0.0             0.0
#                          2004               0.0             0.0
#                          2005               0.0             0.0
#                          2006               0.0             0.0
#
#                                PBS_Flag_BUS_log  dockCt_BUS_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002               0.0             0.0
#                          2003               0.0             0.0
#                          2004               0.0             0.0
#                          2005               0.0             0.0
#                          2006               0.0             0.0
#
#                                docklessCt_BUS_log  scooterCt_BUS_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                 0.0                0.0
#                          2003                 0.0                0.0
#                          2004                 0.0                0.0
#                          2005                 0.0                0.0
#                          2006                 0.0                0.0
#
#                                dockless_flag_BUS_log  scooter_flag_BUS_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                    0.0                   0.0
#                          2003                    0.0                   0.0
#                          2004                    0.0                   0.0
#                          2005                    0.0                   0.0
#                          2006                    0.0                   0.0
#
#                                BIKE_SHARE_BUS_log  PBS_Flag_RAIL_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                 0.0                0.0
#                          2003                 0.0                0.0
#                          2004                 0.0                0.0
#                          2005                 0.0                0.0
#                          2006                 0.0                0.0
#
#                                dockCt_RAIL_log  docklessCt_RAIL_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002              0.0                  0.0
#                          2003              0.0                  0.0
#                          2004              0.0                  0.0
#                          2005              0.0                  0.0
#                          2006              0.0                  0.0
#
#                                scooterCt_RAIL_log  dockless_flag_RAIL_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                 0.0                     0.0
#                          2003                 0.0                     0.0
#                          2004                 0.0                     0.0
#                          2005                 0.0                     0.0
#                          2006                 0.0                     0.0
#
#                                scooter_flag_RAIL_log  BIKE_SHARE_RAIL_log
# ID                       Year
# Akron, OH Metro Area-Bus 2002                    0.0                  0.0
#                          2003                    0.0                  0.0
#                          2004                    0.0                  0.0
#                          2005                    0.0                  0.0
#                          2006                    0.0                  0.0

# %%
df.to_csv('temp.csv')

# %% [markdown]
# ## Base model

# %%
# Start from this base model

mod=PanelOLS.from_formula('UPT_ADJ_log \
                    ~ VRM_ADJ_log \
                    + FARE_per_UPT_log \
                    + POP_EMP_log \
                    + GasPrice_log \
                    + PCT_HH_NO_VEH \
                    + TSD_POP_PCT \
                    + EntityEffects \
                    ',data=df)
res=mod.fit()
print(res)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\data.py:39: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   new_df = df.copy().loc[self._full_index]
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\utility.py:476: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   warnings.warn(missing_value_warning_msg, MissingValueWarning)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:            UPT_ADJ_log   R-squared:                        0.5053
# Estimator:                   PanelOLS   R-squared (Between):              0.9918
# No. Observations:                4288   R-squared (Within):               0.5053
# Date:                Fri, Nov 01 2019   R-squared (Overall):              0.9924
# Time:                        12:23:23   Log-likelihood                   -662.18
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      682.14
# Entities:                         275   P-value                           0.0000
# Avg Obs:                       15.593   Distribution:                  F(6,4007)
# Min Obs:                       1.0000
# Max Obs:                       17.000   F-statistic (robust):             682.14
#                                         P-value                           0.0000
# Time periods:                      17   Distribution:                  F(6,4007)
# Avg Obs:                       252.24
# Min Obs:                       188.00
# Max Obs:                       273.00
#
#                                 Parameter Estimates
# ====================================================================================
#                   Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------
# VRM_ADJ_log          0.3391     0.0106     32.109     0.0000      0.3184      0.3598
# FARE_per_UPT_log    -0.7666     0.0162    -47.265     0.0000     -0.7984     -0.7348
# POP_EMP_log          0.7993     0.0793     10.083     0.0000      0.6439      0.9548
# GasPrice_log         0.4459     0.0301     14.824     0.0000      0.3869      0.5049
# PCT_HH_NO_VEH        0.0156     0.0044     3.5555     0.0004      0.0070      0.0242
# TSD_POP_PCT          0.5266     0.2263     2.3275     0.0200      0.0830      0.9702
# ====================================================================================
#
# F-test for Poolability: 51.993
# P-value: 0.0000
# Distribution: F(274,4007)
#
# Included effects: Entity

# %% [markdown]
# ## Explore the effects of new modes

# %%
# TNC Flag

mod=PanelOLS.from_formula('UPT_ADJ_log \
                    ~ VRM_ADJ_log \
                    + FARE_per_UPT_log \
                    + POP_EMP_log \
                    + GasPrice_log \
                    + PCT_HH_NO_VEH \
                    + TSD_POP_PCT \
                    + TNC_FLAG_BUS \
                    + TNC_FLAG_RAIL \
                    + EntityEffects \
                    ',data=df)
res=mod.fit()
print(res)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\data.py:39: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   new_df = df.copy().loc[self._full_index]
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\utility.py:476: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   warnings.warn(missing_value_warning_msg, MissingValueWarning)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:            UPT_ADJ_log   R-squared:                        0.5094
# Estimator:                   PanelOLS   R-squared (Between):              0.9878
# No. Observations:                4288   R-squared (Within):               0.5094
# Date:                Fri, Nov 01 2019   R-squared (Overall):              0.9887
# Time:                        12:23:40   Log-likelihood                   -644.21
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      519.87
# Entities:                         275   P-value                           0.0000
# Avg Obs:                       15.593   Distribution:                  F(8,4005)
# Min Obs:                       1.0000
# Max Obs:                       17.000   F-statistic (robust):             519.87
#                                         P-value                           0.0000
# Time periods:                      17   Distribution:                  F(8,4005)
# Avg Obs:                       252.24
# Min Obs:                       188.00
# Max Obs:                       273.00
#
#                                 Parameter Estimates
# ====================================================================================
#                   Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------
# VRM_ADJ_log          0.3323     0.0106     31.332     0.0000      0.3115      0.3531
# FARE_per_UPT_log    -0.7705     0.0162    -47.561     0.0000     -0.8023     -0.7387
# POP_EMP_log          0.8306     0.0875     9.4905     0.0000      0.6590      1.0021
# GasPrice_log         0.4408     0.0312     14.125     0.0000      0.3796      0.5020
# PCT_HH_NO_VEH        0.0162     0.0044     3.7087     0.0002      0.0076      0.0248
# TSD_POP_PCT          0.6077     0.2275     2.6712     0.0076      0.1617      1.0537
# TNC_FLAG_BUS        -0.0246     0.0132    -1.8649     0.0623     -0.0505      0.0013
# TNC_FLAG_RAIL        0.1354     0.0261     5.1883     0.0000      0.0843      0.1866
# ====================================================================================
#
# F-test for Poolability: 52.127
# P-value: 0.0000
# Distribution: F(274,4005)
#
# Included effects: Entity

# %%
# Years since TNC

mod=PanelOLS.from_formula('UPT_ADJ_log \
                    ~ VRM_ADJ_log \
                    + FARE_per_UPT_log \
                    + POP_EMP_log \
                    + GasPrice_log \
                    + PCT_HH_NO_VEH \
                    + TSD_POP_PCT \
                    + YEARS_SINCE_TNC_BUS \
                    + YEARS_SINCE_TNC_RAIL \
                    + EntityEffects \
                    ',data=df)
res=mod.fit()
print(res)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\data.py:39: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   new_df = df.copy().loc[self._full_index]
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\utility.py:476: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   warnings.warn(missing_value_warning_msg, MissingValueWarning)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:            UPT_ADJ_log   R-squared:                        0.5136
# Estimator:                   PanelOLS   R-squared (Between):              0.9555
# No. Observations:                4288   R-squared (Within):               0.5136
# Date:                Fri, Nov 01 2019   R-squared (Overall):              0.9577
# Time:                        12:23:50   Log-likelihood                   -625.72
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      528.71
# Entities:                         275   P-value                           0.0000
# Avg Obs:                       15.593   Distribution:                  F(8,4005)
# Min Obs:                       1.0000
# Max Obs:                       17.000   F-statistic (robust):             528.71
#                                         P-value                           0.0000
# Time periods:                      17   Distribution:                  F(8,4005)
# Avg Obs:                       252.24
# Min Obs:                       188.00
# Max Obs:                       273.00
#
#                                   Parameter Estimates
# ========================================================================================
#                       Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ----------------------------------------------------------------------------------------
# VRM_ADJ_log              0.3327     0.0105     31.584     0.0000      0.3120      0.3533
# FARE_per_UPT_log        -0.7683     0.0161    -47.666     0.0000     -0.7999     -0.7367
# POP_EMP_log              0.9533     0.0860     11.078     0.0000      0.7846      1.1220
# GasPrice_log             0.4160     0.0311     13.396     0.0000      0.3551      0.4769
# PCT_HH_NO_VEH            0.0151     0.0044     3.4598     0.0005      0.0065      0.0236
# TSD_POP_PCT              0.5218     0.2257     2.3119     0.0208      0.0793      0.9643
# YEARS_SINCE_TNC_BUS     -0.0309     0.0050    -6.2037     0.0000     -0.0407     -0.0211
# YEARS_SINCE_TNC_RAIL     0.0335     0.0073     4.6051     0.0000      0.0192      0.0478
# ========================================================================================
#
# F-test for Poolability: 52.828
# P-value: 0.0000
# Distribution: F(274,4005)
#
# Included effects: Entity

# %%
# Public bike share

mod=PanelOLS.from_formula('UPT_ADJ_log \
                    ~ VRM_ADJ_log \
                    + FARE_per_UPT_log \
                    + POP_EMP_log \
                    + GasPrice_log \
                    + PCT_HH_NO_VEH \
                    + TSD_POP_PCT \
                    + YEARS_SINCE_TNC_BUS \
                    + YEARS_SINCE_TNC_RAIL \
                    + PBS_Flag_BUS \
                    + PBS_Flag_RAIL \
                    + EntityEffects \
                    ',data=df)
res=mod.fit()
print(res)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\data.py:39: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   new_df = df.copy().loc[self._full_index]
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\utility.py:476: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   warnings.warn(missing_value_warning_msg, MissingValueWarning)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:            UPT_ADJ_log   R-squared:                        0.5331
# Estimator:                   PanelOLS   R-squared (Between):              0.8364
# No. Observations:                4042   R-squared (Within):               0.5331
# Date:                Fri, Nov 01 2019   R-squared (Overall):              0.8407
# Time:                        12:24:04   Log-likelihood                   -426.64
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      430.95
# Entities:                         257   P-value                           0.0000
# Avg Obs:                       15.728   Distribution:                 F(10,3775)
# Min Obs:                       1.0000
# Max Obs:                       17.000   F-statistic (robust):             430.95
#                                         P-value                           0.0000
# Time periods:                      17   Distribution:                 F(10,3775)
# Avg Obs:                       237.76
# Min Obs:                       180.00
# Max Obs:                       257.00
#
#                                   Parameter Estimates
# ========================================================================================
#                       Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ----------------------------------------------------------------------------------------
# VRM_ADJ_log              0.4175     0.0119     35.067     0.0000      0.3941      0.4408
# FARE_per_UPT_log        -0.7522     0.0163    -46.272     0.0000     -0.7841     -0.7203
# POP_EMP_log              1.0882     0.0966     11.261     0.0000      0.8987      1.2776
# GasPrice_log             0.3542     0.0312     11.357     0.0000      0.2930      0.4153
# PCT_HH_NO_VEH            0.0139     0.0043     3.2291     0.0013      0.0054      0.0223
# TSD_POP_PCT              0.6690     0.2242     2.9838     0.0029      0.2294      1.1086
# YEARS_SINCE_TNC_BUS     -0.0329     0.0059    -5.6085     0.0000     -0.0444     -0.0214
# YEARS_SINCE_TNC_RAIL     0.0078     0.0096     0.8094     0.4183     -0.0110      0.0265
# PBS_Flag_BUS            -0.0350     0.0225    -1.5532     0.1204     -0.0791      0.0092
# PBS_Flag_RAIL            0.0832     0.0408     2.0413     0.0413      0.0033      0.1631
# ========================================================================================
#
# F-test for Poolability: 50.625
# P-value: 0.0000
# Distribution: F(256,3775)
#
# Included effects: Entity

# %%
# Bike share dock count

mod=PanelOLS.from_formula('UPT_ADJ_log \
                    ~ VRM_ADJ_log \
                    + FARE_per_UPT_log \
                    + POP_EMP_log \
                    + GasPrice_log \
                    + PCT_HH_NO_VEH \
                    + TSD_POP_PCT \
                    + YEARS_SINCE_TNC_BUS \
                    + YEARS_SINCE_TNC_RAIL \
                    + dockCt_BUS \
                    + dockCt_RAIL \
                    + EntityEffects \
                    ',data=df)
res=mod.fit()
print(res)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\data.py:39: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   new_df = df.copy().loc[self._full_index]
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\utility.py:476: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   warnings.warn(missing_value_warning_msg, MissingValueWarning)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:            UPT_ADJ_log   R-squared:                        0.5137
# Estimator:                   PanelOLS   R-squared (Between):              0.9565
# No. Observations:                4288   R-squared (Within):               0.5137
# Date:                Fri, Nov 01 2019   R-squared (Overall):              0.9587
# Time:                        12:24:15   Log-likelihood                   -625.64
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      422.79
# Entities:                         275   P-value                           0.0000
# Avg Obs:                       15.593   Distribution:                 F(10,4003)
# Min Obs:                       1.0000
# Max Obs:                       17.000   F-statistic (robust):             422.79
#                                         P-value                           0.0000
# Time periods:                      17   Distribution:                 F(10,4003)
# Avg Obs:                       252.24
# Min Obs:                       188.00
# Max Obs:                       273.00
#
#                                   Parameter Estimates
# ========================================================================================
#                       Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ----------------------------------------------------------------------------------------
# VRM_ADJ_log              0.3325     0.0105     31.531     0.0000      0.3118      0.3532
# FARE_per_UPT_log        -0.7683     0.0161    -47.652     0.0000     -0.8000     -0.7367
# POP_EMP_log              0.9508     0.0863     11.016     0.0000      0.7816      1.1201
# GasPrice_log             0.4160     0.0311     13.394     0.0000      0.3551      0.4769
# PCT_HH_NO_VEH            0.0151     0.0044     3.4597     0.0005      0.0065      0.0236
# TSD_POP_PCT              0.5179     0.2260     2.2918     0.0220      0.0749      0.9609
# YEARS_SINCE_TNC_BUS     -0.0301     0.0054    -5.5425     0.0000     -0.0408     -0.0195
# YEARS_SINCE_TNC_RAIL     0.0344     0.0090     3.8231     0.0001      0.0168      0.0520
# dockCt_BUS           -5.083e-05     0.0001    -0.3444     0.7306     -0.0003      0.0002
# dockCt_RAIL          -2.705e-05     0.0002    -0.1588     0.8739     -0.0004      0.0003
# ========================================================================================
#
# F-test for Poolability: 52.792
# P-value: 0.0000
# Distribution: F(274,4003)
#
# Included effects: Entity

# %%
# docless bike share

mod=PanelOLS.from_formula('UPT_ADJ_log \
                    ~ VRM_ADJ_log \
                    + FARE_per_UPT_log \
                    + POP_EMP_log \
                    + GasPrice_log \
                    + PCT_HH_NO_VEH \
                    + TSD_POP_PCT \
                    + YEARS_SINCE_TNC_BUS \
                    + YEARS_SINCE_TNC_RAIL \
                    + PBS_Flag_BUS \
                    + PBS_Flag_RAIL \
                    + dockless_flag_BUS \
                    + dockless_flag_RAIL \
                    + EntityEffects \
                    ',data=df)
res=mod.fit()
print(res)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\data.py:39: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   new_df = df.copy().loc[self._full_index]
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\utility.py:476: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   warnings.warn(missing_value_warning_msg, MissingValueWarning)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:            UPT_ADJ_log   R-squared:                        0.5332
# Estimator:                   PanelOLS   R-squared (Between):              0.8336
# No. Observations:                4042   R-squared (Within):               0.5332
# Date:                Fri, Nov 01 2019   R-squared (Overall):              0.8379
# Time:                        12:24:26   Log-likelihood                   -426.16
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      359.09
# Entities:                         257   P-value                           0.0000
# Avg Obs:                       15.728   Distribution:                 F(12,3773)
# Min Obs:                       1.0000
# Max Obs:                       17.000   F-statistic (robust):             359.09
#                                         P-value                           0.0000
# Time periods:                      17   Distribution:                 F(12,3773)
# Avg Obs:                       237.76
# Min Obs:                       180.00
# Max Obs:                       257.00
#
#                                   Parameter Estimates
# ========================================================================================
#                       Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ----------------------------------------------------------------------------------------
# VRM_ADJ_log              0.4173     0.0119     35.040     0.0000      0.3939      0.4406
# FARE_per_UPT_log        -0.7524     0.0163    -46.271     0.0000     -0.7843     -0.7205
# POP_EMP_log              1.0925     0.0972     11.244     0.0000      0.9020      1.2830
# GasPrice_log             0.3523     0.0316     11.142     0.0000      0.2903      0.4143
# PCT_HH_NO_VEH            0.0138     0.0043     3.2194     0.0013      0.0054      0.0222
# TSD_POP_PCT              0.6640     0.2243     2.9603     0.0031      0.2242      1.1038
# YEARS_SINCE_TNC_BUS     -0.0317     0.0060    -5.2521     0.0000     -0.0435     -0.0198
# YEARS_SINCE_TNC_RAIL     0.0051     0.0109     0.4652     0.6418     -0.0163      0.0265
# PBS_Flag_BUS            -0.0248     0.0258    -0.9632     0.3355     -0.0753      0.0257
# PBS_Flag_RAIL            0.0734     0.0456     1.6107     0.1073     -0.0159      0.1627
# dockless_flag_BUS       -0.0237     0.0292    -0.8125     0.4165     -0.0810      0.0335
# dockless_flag_RAIL       0.0257     0.0539     0.4760     0.6341     -0.0800      0.1314
# ========================================================================================
#
# F-test for Poolability: 50.600
# P-value: 0.0000
# Distribution: F(256,3773)
#
# Included effects: Entity

# %%
# Any bike share

mod=PanelOLS.from_formula('UPT_ADJ_log \
                    ~ VRM_ADJ_log \
                    + FARE_per_UPT_log \
                    + POP_EMP_log \
                    + GasPrice_log \
                    + PCT_HH_NO_VEH \
                    + TSD_POP_PCT \
                    + YEARS_SINCE_TNC_BUS \
                    + YEARS_SINCE_TNC_RAIL \
                    + BIKE_SHARE_BUS \
                    + BIKE_SHARE_RAIL \
                    + EntityEffects \
                    ',data=df)
res=mod.fit()
print(res)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\data.py:39: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   new_df = df.copy().loc[self._full_index]
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\utility.py:476: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   warnings.warn(missing_value_warning_msg, MissingValueWarning)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:            UPT_ADJ_log   R-squared:                        0.5330
# Estimator:                   PanelOLS   R-squared (Between):              0.8356
# No. Observations:                4042   R-squared (Within):               0.5330
# Date:                Fri, Nov 01 2019   R-squared (Overall):              0.8400
# Time:                        12:24:37   Log-likelihood                   -427.08
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      430.77
# Entities:                         257   P-value                           0.0000
# Avg Obs:                       15.728   Distribution:                 F(10,3775)
# Min Obs:                       1.0000
# Max Obs:                       17.000   F-statistic (robust):             430.77
#                                         P-value                           0.0000
# Time periods:                      17   Distribution:                 F(10,3775)
# Avg Obs:                       237.76
# Min Obs:                       180.00
# Max Obs:                       257.00
#
#                                   Parameter Estimates
# ========================================================================================
#                       Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ----------------------------------------------------------------------------------------
# VRM_ADJ_log              0.4175     0.0119     35.071     0.0000      0.3941      0.4408
# FARE_per_UPT_log        -0.7521     0.0163    -46.263     0.0000     -0.7840     -0.7203
# POP_EMP_log              1.0892     0.0969     11.239     0.0000      0.8992      1.2792
# GasPrice_log             0.3534     0.0312     11.326     0.0000      0.2922      0.4146
# PCT_HH_NO_VEH            0.0139     0.0043     3.2274     0.0013      0.0054      0.0223
# TSD_POP_PCT              0.6757     0.2243     3.0131     0.0026      0.2360      1.1154
# YEARS_SINCE_TNC_BUS     -0.0342     0.0059    -5.7911     0.0000     -0.0458     -0.0226
# YEARS_SINCE_TNC_RAIL     0.0060     0.0099     0.6022     0.5471     -0.0135      0.0254
# BIKE_SHARE_BUS          -0.0233     0.0220    -1.0583     0.2900     -0.0664      0.0198
# BIKE_SHARE_RAIL          0.0887     0.0412     2.1519     0.0315      0.0079      0.1695
# ========================================================================================
#
# F-test for Poolability: 50.490
# P-value: 0.0000
# Distribution: F(256,3775)
#
# Included effects: Entity

# %%
# scooters

mod=PanelOLS.from_formula('UPT_ADJ_log \
                    ~ VRM_ADJ_log \
                    + FARE_per_UPT_log \
                    + POP_EMP_log \
                    + GasPrice_log \
                    + PCT_HH_NO_VEH \
                    + TSD_POP_PCT \
                    + YEARS_SINCE_TNC_BUS \
                    + YEARS_SINCE_TNC_RAIL \
                    + BIKE_SHARE_BUS \
                    + BIKE_SHARE_RAIL \
                    + scooter_flag_BUS \
                    + scooter_flag_RAIL \
                    + EntityEffects \
                    ',data=df)
res=mod.fit()
print(res)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\data.py:39: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   new_df = df.copy().loc[self._full_index]
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\utility.py:476: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   warnings.warn(missing_value_warning_msg, MissingValueWarning)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:            UPT_ADJ_log   R-squared:                        0.5338
# Estimator:                   PanelOLS   R-squared (Between):              0.8347
# No. Observations:                4042   R-squared (Within):               0.5338
# Date:                Fri, Nov 01 2019   R-squared (Overall):              0.8390
# Time:                        12:24:58   Log-likelihood                   -423.59
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      359.95
# Entities:                         257   P-value                           0.0000
# Avg Obs:                       15.728   Distribution:                 F(12,3773)
# Min Obs:                       1.0000
# Max Obs:                       17.000   F-statistic (robust):             359.95
#                                         P-value                           0.0000
# Time periods:                      17   Distribution:                 F(12,3773)
# Avg Obs:                       237.76
# Min Obs:                       180.00
# Max Obs:                       257.00
#
#                                   Parameter Estimates
# ========================================================================================
#                       Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ----------------------------------------------------------------------------------------
# VRM_ADJ_log              0.4175     0.0119     35.096     0.0000      0.3942      0.4409
# FARE_per_UPT_log        -0.7528     0.0163    -46.323     0.0000     -0.7846     -0.7209
# POP_EMP_log              1.0894     0.0969     11.248     0.0000      0.8995      1.2793
# GasPrice_log             0.3598     0.0313     11.489     0.0000      0.2984      0.4212
# PCT_HH_NO_VEH            0.0136     0.0043     3.1648     0.0016      0.0052      0.0220
# TSD_POP_PCT              0.7144     0.2247     3.1794     0.0015      0.2739      1.1550
# YEARS_SINCE_TNC_BUS     -0.0319     0.0062    -5.1390     0.0000     -0.0440     -0.0197
# YEARS_SINCE_TNC_RAIL     0.0168     0.0110     1.5275     0.1267     -0.0048      0.0383
# BIKE_SHARE_BUS          -0.0227     0.0220    -1.0314     0.3024     -0.0657      0.0204
# BIKE_SHARE_RAIL          0.0788     0.0414     1.9016     0.0573     -0.0024      0.1600
# scooter_flag_BUS        -0.0571     0.0472    -1.2076     0.2273     -0.1497      0.0356
# scooter_flag_RAIL       -0.1591     0.0705    -2.2582     0.0240     -0.2973     -0.0210
# ========================================================================================
#
# F-test for Poolability: 50.567
# P-value: 0.0000
# Distribution: F(256,3773)
#
# Included effects: Entity

# %% [markdown]
# ## add the time trends back in

# %%
# individual time effects

mod=PanelOLS.from_formula('UPT_ADJ_log \
                    ~ VRM_ADJ_log \
                    + FARE_per_UPT_log \
                    + POP_EMP_log \
                    + GasPrice_log \
                    + PCT_HH_NO_VEH \
                    + TSD_POP_PCT \
                    + YEARS_SINCE_TNC_BUS \
                    + YEARS_SINCE_TNC_RAIL \
                    + BIKE_SHARE_BUS \
                    + BIKE_SHARE_RAIL \
                    + scooter_flag_BUS \
                    + scooter_flag_RAIL \
                    + EntityEffects \
                    + TimeEffects \
                    ',data=df)
res=mod.fit()
print(res)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\data.py:39: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   new_df = df.copy().loc[self._full_index]
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\utility.py:476: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   warnings.warn(missing_value_warning_msg, MissingValueWarning)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:            UPT_ADJ_log   R-squared:                        0.4894
# Estimator:                   PanelOLS   R-squared (Between):              0.9502
# No. Observations:                4042   R-squared (Within):               0.5310
# Date:                Fri, Nov 01 2019   R-squared (Overall):              0.9520
# Time:                        12:25:16   Log-likelihood                   -383.42
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      300.12
# Entities:                         257   P-value                           0.0000
# Avg Obs:                       15.728   Distribution:                 F(12,3757)
# Min Obs:                       1.0000
# Max Obs:                       17.000   F-statistic (robust):             300.12
#                                         P-value                           0.0000
# Time periods:                      17   Distribution:                 F(12,3757)
# Avg Obs:                       237.76
# Min Obs:                       180.00
# Max Obs:                       257.00
#
#                                   Parameter Estimates
# ========================================================================================
#                       Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ----------------------------------------------------------------------------------------
# VRM_ADJ_log              0.4099     0.0119     34.451     0.0000      0.3866      0.4332
# FARE_per_UPT_log        -0.7576     0.0162    -46.900     0.0000     -0.7893     -0.7259
# POP_EMP_log              0.8818     0.1046     8.4296     0.0000      0.6767      1.0869
# GasPrice_log             0.4239     0.2645     1.6026     0.1091     -0.0947      0.9424
# PCT_HH_NO_VEH            0.0101     0.0043     2.3390     0.0194      0.0016      0.0185
# TSD_POP_PCT              1.1075     0.2304     4.8076     0.0000      0.6559      1.5592
# YEARS_SINCE_TNC_BUS     -0.0272     0.0091    -2.9919     0.0028     -0.0451     -0.0094
# YEARS_SINCE_TNC_RAIL     0.0194     0.0118     1.6512     0.0988     -0.0036      0.0425
# BIKE_SHARE_BUS          -0.0296     0.0221    -1.3406     0.1801     -0.0730      0.0137
# BIKE_SHARE_RAIL          0.0654     0.0413     1.5826     0.1136     -0.0156      0.1464
# scooter_flag_BUS        -0.0114     0.0492    -0.2309     0.8174     -0.1079      0.0851
# scooter_flag_RAIL       -0.0966     0.0727    -1.3278     0.1843     -0.2392      0.0460
# ========================================================================================
#
# F-test for Poolability: 48.619
# P-value: 0.0000
# Distribution: F(272,3757)
#
# Included effects: Entity, Time

# %%
# years since 2002

mod=PanelOLS.from_formula('UPT_ADJ_log \
                    ~ VRM_ADJ_log \
                    + FARE_per_UPT_log \
                    + POP_EMP_log \
                    + GasPrice_log \
                    + PCT_HH_NO_VEH \
                    + TSD_POP_PCT \
                    + YEARS_SINCE_TNC_BUS \
                    + YEARS_SINCE_TNC_RAIL \
                    + BIKE_SHARE_BUS \
                    + BIKE_SHARE_RAIL \
                    + scooter_flag_BUS \
                    + scooter_flag_RAIL \
                    + YEARS_SINCE_2002_BUS \
                    + YEARS_SINCE_2002_RAIL \
                    + EntityEffects \
                    ',data=df)
res=mod.fit()
print(res)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\data.py:39: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   new_df = df.copy().loc[self._full_index]
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\utility.py:476: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   warnings.warn(missing_value_warning_msg, MissingValueWarning)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:            UPT_ADJ_log   R-squared:                        0.5375
# Estimator:                   PanelOLS   R-squared (Between):              0.9476
# No. Observations:                4042   R-squared (Within):               0.5375
# Date:                Fri, Nov 01 2019   R-squared (Overall):              0.9496
# Time:                        12:25:31   Log-likelihood                   -407.44
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      313.00
# Entities:                         257   P-value                           0.0000
# Avg Obs:                       15.728   Distribution:                 F(14,3771)
# Min Obs:                       1.0000
# Max Obs:                       17.000   F-statistic (robust):             313.00
#                                         P-value                           0.0000
# Time periods:                      17   Distribution:                 F(14,3771)
# Avg Obs:                       237.76
# Min Obs:                       180.00
# Max Obs:                       257.00
#
#                                    Parameter Estimates
# =========================================================================================
#                        Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -----------------------------------------------------------------------------------------
# VRM_ADJ_log               0.4133     0.0120     34.396     0.0000      0.3897      0.4368
# FARE_per_UPT_log         -0.7565     0.0162    -46.683     0.0000     -0.7882     -0.7247
# POP_EMP_log               0.8967     0.1028     8.7200     0.0000      0.6951      1.0984
# GasPrice_log              0.2802     0.0348     8.0504     0.0000      0.2120      0.3485
# PCT_HH_NO_VEH             0.0117     0.0043     2.7382     0.0062      0.0033      0.0202
# TSD_POP_PCT               0.8108     0.2258     3.5908     0.0003      0.3681      1.2535
# YEARS_SINCE_TNC_BUS      -0.0530     0.0073    -7.2837     0.0000     -0.0672     -0.0387
# YEARS_SINCE_TNC_RAIL      0.0088     0.0129     0.6836     0.4943     -0.0164      0.0340
# BIKE_SHARE_BUS           -0.0349     0.0220    -1.5840     0.1133     -0.0780      0.0083
# BIKE_SHARE_RAIL           0.0743     0.0433     1.7166     0.0861     -0.0106      0.1593
# scooter_flag_BUS         -0.0224     0.0475    -0.4727     0.6365     -0.1155      0.0707
# scooter_flag_RAIL        -0.1433     0.0706    -2.0304     0.0424     -0.2817     -0.0049
# YEARS_SINCE_2002_BUS      0.0105     0.0019     5.4992     0.0000      0.0067      0.0142
# YEARS_SINCE_2002_RAIL     0.0067     0.0044     1.5303     0.1260     -0.0019      0.0152
# =========================================================================================
#
# F-test for Poolability: 50.379
# P-value: 0.0000
# Distribution: F(256,3771)
#
# Included effects: Entity

# %%
# breakpoint at 2010

mod=PanelOLS.from_formula('UPT_ADJ_log \
                    ~ VRM_ADJ_log \
                    + FARE_per_UPT_log \
                    + POP_EMP_log \
                    + GasPrice_log \
                    + PCT_HH_NO_VEH \
                    + TSD_POP_PCT \
                    + YEARS_SINCE_TNC_BUS \
                    + YEARS_SINCE_TNC_RAIL \
                    + BIKE_SHARE_BUS \
                    + BIKE_SHARE_RAIL \
                    + scooter_flag_BUS \
                    + scooter_flag_RAIL \
                    + YEARS_2002_2010_BUS \
                    + YEARS_AFTER_2010_BUS \
                    + YEARS_2002_2010_RAIL \
                    + YEARS_AFTER_2010_RAIL \
                    + EntityEffects \
                    ',data=df)
res=mod.fit()
print(res)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\data.py:39: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   new_df = df.copy().loc[self._full_index]
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\utility.py:476: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   warnings.warn(missing_value_warning_msg, MissingValueWarning)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:            UPT_ADJ_log   R-squared:                        0.5415
# Estimator:                   PanelOLS   R-squared (Between):              0.9527
# No. Observations:                4042   R-squared (Within):               0.5415
# Date:                Fri, Nov 01 2019   R-squared (Overall):              0.9545
# Time:                        12:25:49   Log-likelihood                   -389.65
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      278.23
# Entities:                         257   P-value                           0.0000
# Avg Obs:                       15.728   Distribution:                 F(16,3769)
# Min Obs:                       1.0000
# Max Obs:                       17.000   F-statistic (robust):             278.23
#                                         P-value                           0.0000
# Time periods:                      17   Distribution:                 F(16,3769)
# Avg Obs:                       237.76
# Min Obs:                       180.00
# Max Obs:                       257.00
#
#                                    Parameter Estimates
# =========================================================================================
#                        Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -----------------------------------------------------------------------------------------
# VRM_ADJ_log               0.4106     0.0120     34.287     0.0000      0.3871      0.4341
# FARE_per_UPT_log         -0.7584     0.0161    -46.982     0.0000     -0.7900     -0.7267
# POP_EMP_log               0.8890     0.1025     8.6693     0.0000      0.6879      1.0900
# GasPrice_log              0.1465     0.0433     3.3826     0.0007      0.0616      0.2315
# PCT_HH_NO_VEH             0.0105     0.0043     2.4627     0.0138      0.0021      0.0189
# TSD_POP_PCT               1.1035     0.2305     4.7872     0.0000      0.6515      1.5554
# YEARS_SINCE_TNC_BUS      -0.0423     0.0078    -5.4379     0.0000     -0.0576     -0.0271
# YEARS_SINCE_TNC_RAIL      0.0440     0.0165     2.6629     0.0078      0.0116      0.0764
# BIKE_SHARE_BUS           -0.0320     0.0219    -1.4589     0.1447     -0.0750      0.0110
# BIKE_SHARE_RAIL           0.1006     0.0439     2.2926     0.0219      0.0146      0.1867
# scooter_flag_BUS         -0.0157     0.0473    -0.3320     0.7399     -0.1085      0.0770
# scooter_flag_RAIL        -0.1303     0.0704    -1.8501     0.0644     -0.2683      0.0078
# YEARS_2002_2010_BUS       0.0278     0.0041     6.8112     0.0000      0.0198      0.0358
# YEARS_AFTER_2010_BUS     -0.0016     0.0034    -0.4576     0.6473     -0.0083      0.0051
# YEARS_2002_2010_RAIL      0.0338     0.0068     4.9656     0.0000      0.0204      0.0471
# YEARS_AFTER_2010_RAIL    -0.0309     0.0109    -2.8363     0.0046     -0.0522     -0.0095
# =========================================================================================
#
# F-test for Poolability: 50.485
# P-value: 0.0000
# Distribution: F(256,3769)
#
# Included effects: Entity

# %%
# breakpoint at 2014

mod=PanelOLS.from_formula('UPT_ADJ_log \
                    ~ VRM_ADJ_log \
                    + FARE_per_UPT_log \
                    + POP_EMP_log \
                    + GasPrice_log \
                    + PCT_HH_NO_VEH \
                    + TSD_POP_PCT \
                    + YEARS_SINCE_TNC_BUS \
                    + YEARS_SINCE_TNC_RAIL \
                    + BIKE_SHARE_BUS \
                    + BIKE_SHARE_RAIL \
                    + scooter_flag_BUS \
                    + scooter_flag_RAIL \
                    + YEARS_2002_2014_BUS \
                    + YEARS_AFTER_2014_BUS \
                    + YEARS_2002_2014_RAIL \
                    + YEARS_AFTER_2014_RAIL \
                    + EntityEffects \
                    ',data=df)
res=mod.fit()
print(res)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\data.py:39: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   new_df = df.copy().loc[self._full_index]
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\utility.py:476: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   warnings.warn(missing_value_warning_msg, MissingValueWarning)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:            UPT_ADJ_log   R-squared:                        0.5402
# Estimator:                   PanelOLS   R-squared (Between):              0.9509
# No. Observations:                4042   R-squared (Within):               0.5402
# Date:                Fri, Nov 01 2019   R-squared (Overall):              0.9527
# Time:                        12:26:01   Log-likelihood                   -395.54
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      276.74
# Entities:                         257   P-value                           0.0000
# Avg Obs:                       15.728   Distribution:                 F(16,3769)
# Min Obs:                       1.0000
# Max Obs:                       17.000   F-statistic (robust):             276.74
#                                         P-value                           0.0000
# Time periods:                      17   Distribution:                 F(16,3769)
# Avg Obs:                       237.76
# Min Obs:                       180.00
# Max Obs:                       257.00
#
#                                    Parameter Estimates
# =========================================================================================
#                        Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -----------------------------------------------------------------------------------------
# VRM_ADJ_log               0.4136     0.0120     34.515     0.0000      0.3901      0.4371
# FARE_per_UPT_log         -0.7583     0.0162    -46.903     0.0000     -0.7900     -0.7266
# POP_EMP_log               0.8922     0.1026     8.6971     0.0000      0.6911      1.0934
# GasPrice_log              0.2028     0.0397     5.1087     0.0000      0.1250      0.2806
# PCT_HH_NO_VEH             0.0097     0.0043     2.2596     0.0239      0.0013      0.0181
# TSD_POP_PCT               0.9359     0.2268     4.1272     0.0000      0.4913      1.3805
# YEARS_SINCE_TNC_BUS      -0.0344     0.0093    -3.6809     0.0002     -0.0527     -0.0161
# YEARS_SINCE_TNC_RAIL      0.0513     0.0186     2.7544     0.0059      0.0148      0.0878
# BIKE_SHARE_BUS           -0.0377     0.0220    -1.7155     0.0863     -0.0807      0.0054
# BIKE_SHARE_RAIL           0.0770     0.0433     1.7799     0.0752     -0.0078      0.1619
# scooter_flag_BUS         -0.0091     0.0475    -0.1916     0.8481     -0.1022      0.0840
# scooter_flag_RAIL        -0.0707     0.0727    -0.9729     0.3307     -0.2133      0.0718
# YEARS_2002_2014_BUS       0.0160     0.0024     6.7378     0.0000      0.0114      0.0207
# YEARS_AFTER_2014_BUS     -0.0189     0.0090    -2.1134     0.0346     -0.0365     -0.0014
# YEARS_2002_2014_RAIL      0.0123     0.0045     2.7143     0.0067      0.0034      0.0211
# YEARS_AFTER_2014_RAIL    -0.0737     0.0237    -3.1050     0.0019     -0.1202     -0.0272
# =========================================================================================
#
# F-test for Poolability: 50.557
# P-value: 0.0000
# Distribution: F(256,3769)
#
# Included effects: Entity

# %% [markdown]
# ## Run some analytics

# %%
sns.distplot(res.resids)

# %%
sm.graphics.qqplot(res.resids,line = 'q')

# %% [markdown]
# ## Calculate FAC
