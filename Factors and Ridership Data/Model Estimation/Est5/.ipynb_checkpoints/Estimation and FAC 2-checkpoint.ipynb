# %%
import pandas as pd
import seaborn as sns
import numpy as np
import linearmodels as lm
import matplotlib
import math
import statsmodels.formula.api as smf
import statsmodels.api as sm

from linearmodels.panel import PanelOLS
from linearmodels.panel import RandomEffects
from linearmodels.panel import FirstDifferenceOLS
from linearmodels.panel import compare
from matplotlib import pyplot as plt

from pandas.api.types import is_numeric_dtype

pd.set_option('display.max_columns', 500)

# %matplotlib inline

# %%
# read the main data set
df=pd.read_csv('estimation_file.csv',
                    encoding='utf-8')
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (5,144) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# read in and join the maintenance and restructure data
mr=pd.read_csv('maintenance_restructure.csv',
                    encoding='utf-8')
mr = mr[['CBSA', 'Mode', 'Year', 'MAINTENANCE', 'MAINTENANCE_NYC', 'MAINTENANCE_WMATA', 'RESTRUCTURE']]

df = df.merge(mr, on=['CBSA', 'Mode', 'Year'], how='left')

# %%
# exclude if ridership is zero--missing data
df = df[df['UPT_ADJ']>0]

# %%
# exclude problematic data
old_len = len(df)
df = df[df['VRM_ADJ']>0]
new_len = len(df)
print('Excluding ' + str(old_len-new_len) + ' records with missing VRM') 

# exclude problematic data
old_len = len(df)
df = df[df['FARE_per_UPT_2018']>0]
new_len = len(df)
print('Excluding ' + str(old_len-new_len) + ' records with zero or negative fare') 

# exclude problematic data
old_len = len(df)
df = df[df['FARE_per_UPT_2018']<20]
new_len = len(df)
print('Excluding ' + str(old_len-new_len) + ' records with fare greater than $20') 

# exclude problematic data
old_len = len(df)
df = df[df['HH_0Veh']>0]
new_len = len(df)
print('Excluding ' + str(old_len-new_len) + ' records with negative 0 veh HH')
# Out:
# Excluding 3 records with missing VRM
# Excluding 78 records with zero or negative fare
# Excluding 11 records with fare greater than $20
# Excluding 30 records with negative 0 veh HH

# %%
# exclude discontinuous data
df = df.sort_values(by=['CBSA', 'Mode', 'Year'])

excluded_records = 100
while excluded_records > 0: 
    old_len = len(df)
    df['YearDiff'] = df['Year'].shift(-1) - df['Year']
    df = df[(df['YearDiff']==1) | (df['Year']==2018)]
    excluded_records = old_len - len(df)
    print('Excluding ' + str(excluded_records) + ' records with discontinuities in year.')
# Out:
# Excluding 20 records with discontinuities in year.
# Excluding 15 records with discontinuities in year.
# Excluding 13 records with discontinuities in year.
# Excluding 13 records with discontinuities in year.
# Excluding 11 records with discontinuities in year.
# Excluding 11 records with discontinuities in year.
# Excluding 9 records with discontinuities in year.
# Excluding 9 records with discontinuities in year.
# Excluding 9 records with discontinuities in year.
# Excluding 7 records with discontinuities in year.
# Excluding 6 records with discontinuities in year.
# Excluding 5 records with discontinuities in year.
# Excluding 5 records with discontinuities in year.
# Excluding 4 records with discontinuities in year.
# Excluding 4 records with discontinuities in year.
# Excluding 2 records with discontinuities in year.
# Excluding 0 records with discontinuities in year.

# %%
df['BUS_FLAG'] = np.where(df['Mode']=='Bus', 1, 0)
df['RAIL_FLAG'] = np.where(df['Mode']=='Rail', 1, 0)

# %%
# include population + employment
df['POP_EMP'] = df['Tot_Pop'] + df['TOT_EMP_MSA']
df['HH_EMP'] = df['Total_HH'] + df['TOT_EMP_MSA']

# percent of population in transit supportive density
df['TSD_POP_PCT'] = df['POP_CENSUSTRACT'] / df['Tot_Pop']

# percent of pop born outside USA
df['Tot_NonUSA_POP_pct'] = df['Tot_NonUSA_POP'] / df['Tot_Pop'] * 100

# %%
# mode specific effects

df['Bus_VRM_ADJ_RAIL']  = df['Bus_VRM_ADJ'] * df['RAIL_FLAG']
df['Rail_VRM_ADJ_BUS'] = df['Rail_VRM_ADJ']  * df['BUS_FLAG']

df['Bus_VRM_ADJ_RAIL_log'] = np.log(1+df['Bus_VRM_ADJ_RAIL'])
df['Rail_VRM_ADJ_BUS_log'] = np.log(1+df['Rail_VRM_ADJ_BUS'])

# %%
# time effects
df['YEARS_SINCE_2002']  = df['Year'] - 2002

df['YEARS_2002_2010']  = df['Year'].apply(lambda x : min(x-2002, 8))
df['YEARS_AFTER_2010'] = df['Year'].apply(lambda x : max(x-2010, 0))

df['YEARS_2002_2014']  = df['Year'].apply(lambda x : min(x-2002, 12))
df['YEARS_AFTER_2014'] = df['Year'].apply(lambda x : max(x-2014, 0))


df['YEARS_SINCE_2002_BUS']  = df['YEARS_SINCE_2002'] * df['BUS_FLAG']
df['YEARS_SINCE_2002_RAIL'] = df['YEARS_SINCE_2002'] * df['RAIL_FLAG']

df['YEARS_2002_2010_BUS']   = df['YEARS_2002_2010'] * df['BUS_FLAG']
df['YEARS_AFTER_2010_BUS']  = df['YEARS_AFTER_2010']* df['BUS_FLAG']
df['YEARS_2002_2010_RAIL']  = df['YEARS_2002_2010'] * df['RAIL_FLAG']
df['YEARS_AFTER_2010_RAIL'] = df['YEARS_AFTER_2010']* df['RAIL_FLAG']

df['YEARS_2002_2014_BUS']   = df['YEARS_2002_2014'] * df['BUS_FLAG']
df['YEARS_AFTER_2014_BUS']  = df['YEARS_AFTER_2014']* df['BUS_FLAG']
df['YEARS_2002_2014_RAIL']  = df['YEARS_2002_2014'] * df['RAIL_FLAG']
df['YEARS_AFTER_2014_RAIL'] = df['YEARS_AFTER_2014']* df['RAIL_FLAG']

# %%
# calculate bus vs rail stuff

# various bus/rail specifics

df['TNC_FLAG_BUS'] = df['TNC_FLAG'] * df['BUS_FLAG']
df['TNC_FLAG_RAIL'] = df['TNC_FLAG'] * df['RAIL_FLAG']

df['YEARS_SINCE_TNC_BUS'] = df['YEARS_SINCE_TNC'] * df['BUS_FLAG']
df['YEARS_SINCE_TNC_RAIL'] = df['YEARS_SINCE_TNC'] * df['RAIL_FLAG']

df['dockless_flag'] = df['dockCt'].apply(lambda x : min(x,1))
df['scooter_flag']  = df['scooterCt'].apply(lambda x : min(x,1))

df['BIKE_SHARE'] = df['PBS_Flag'] + df['dockless_flag']
df['BIKE_SHARE'] = df['BIKE_SHARE'].apply(lambda x : min(x,1))


df['PBS_Flag_BUS']   = df['PBS_Flag']   * df['BUS_FLAG']
df['dockCt_BUS']     = df['dockCt']     * df['BUS_FLAG']
df['docklessCt_BUS'] = df['docklessCt'] * df['BUS_FLAG']
df['scooterCt_BUS']  = df['scooterCt']  * df['BUS_FLAG']
df['dockless_flag_BUS'] = df['dockless_flag'] * df['BUS_FLAG']
df['scooter_flag_BUS']  = df['scooter_flag']  * df['BUS_FLAG']
df['BIKE_SHARE_BUS']  = df['BIKE_SHARE']  * df['BUS_FLAG']


df['PBS_Flag_RAIL']   = df['PBS_Flag']   * df['RAIL_FLAG']
df['dockCt_RAIL']     = df['dockCt']     * df['RAIL_FLAG']
df['docklessCt_RAIL'] = df['docklessCt'] * df['RAIL_FLAG']
df['scooterCt_RAIL']  = df['scooterCt']  * df['RAIL_FLAG']
df['dockless_flag_RAIL'] = df['dockless_flag'] * df['RAIL_FLAG']
df['scooter_flag_RAIL']  = df['scooter_flag']  * df['RAIL_FLAG']
df['BIKE_SHARE_RAIL']  = df['BIKE_SHARE']  * df['RAIL_FLAG']

# %%
# set the indices
df['ID'] = df['MNAME'] + '-' + df['Mode']
df=df.set_index(['ID','Year'])

# %%
# keep only the numeric columns -- the estimation will give an error otherwise
df = df.select_dtypes(include=[np.number])

# %%
# create a log of all fields
for col in df.columns:
    df[col+'_log'] = np.log(df[col]+1)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:3: RuntimeWarning: invalid value encountered in log
#   app.launch_new_instance()
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:3: RuntimeWarning: divide by zero encountered in log
#   app.launch_new_instance()

# %% [markdown]
# ## Some core model specification tests -- looking at traditional factors

# %%
# no time trends

mod=PanelOLS.from_formula('UPT_ADJ_log \
                    ~ VRM_ADJ_log \
                    + FARE_per_UPT_log \
                    + POP_EMP_log \
                    + GasPrice_log \
                    + PCT_HH_NO_VEH \
                    + TSD_POP_PCT \
                    + EntityEffects \
                    ',data=df)
res=mod.fit()
print(res)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\data.py:39: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   new_df = df.copy().loc[self._full_index]
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\utility.py:476: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   warnings.warn(missing_value_warning_msg, MissingValueWarning)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:            UPT_ADJ_log   R-squared:                        0.4916
# Estimator:                   PanelOLS   R-squared (Between):              0.9951
# No. Observations:                4054   R-squared (Within):               0.4916
# Date:                Fri, Nov 22 2019   R-squared (Overall):              0.9948
# Time:                        16:21:10   Log-likelihood                    937.52
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      610.20
# Entities:                         261   P-value                           0.0000
# Avg Obs:                       15.533   Distribution:                  F(6,3787)
# Min Obs:                       3.0000
# Max Obs:                       17.000   F-statistic (robust):             610.20
#                                         P-value                           0.0000
# Time periods:                      17   Distribution:                  F(6,3787)
# Avg Obs:                       238.47
# Min Obs:                       170.00
# Max Obs:                       261.00
#
#                                 Parameter Estimates
# ====================================================================================
#                   Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------
# VRM_ADJ_log          0.6266     0.0140     44.850     0.0000      0.5992      0.6539
# FARE_per_UPT_log    -0.4215     0.0175    -24.064     0.0000     -0.4559     -0.3872
# POP_EMP_log          0.3447     0.0565     6.0974     0.0000      0.2338      0.4555
# GasPrice_log         0.3401     0.0211     16.122     0.0000      0.2987      0.3814
# PCT_HH_NO_VEH        0.0134     0.0032     4.1171     0.0000      0.0070      0.0197
# TSD_POP_PCT          0.5305     0.1592     3.3325     0.0009      0.2184      0.8427
# ====================================================================================
#
# F-test for Poolability: 98.736
# P-value: 0.0000
# Distribution: F(260,3787)
#
# Included effects: Entity

# %%
# with inflation adjusted prices

mod=PanelOLS.from_formula('UPT_ADJ_log \
                    ~ VRM_ADJ_log \
                    + FARE_per_UPT_2018_log \
                    + POP_EMP_log \
                    + GAS_PRICE_2018_log \
                    + PCT_HH_NO_VEH \
                    + TSD_POP_PCT \
                    + EntityEffects \
                    ',data=df)
res=mod.fit()
print(res)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\data.py:39: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   new_df = df.copy().loc[self._full_index]
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\utility.py:476: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   warnings.warn(missing_value_warning_msg, MissingValueWarning)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:            UPT_ADJ_log   R-squared:                        0.5567
# Estimator:                   PanelOLS   R-squared (Between):              0.9959
# No. Observations:                4054   R-squared (Within):               0.5567
# Date:                Fri, Nov 22 2019   R-squared (Overall):              0.9961
# Time:                        16:21:13   Log-likelihood                    1215.5
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      792.63
# Entities:                         261   P-value                           0.0000
# Avg Obs:                       15.533   Distribution:                  F(6,3787)
# Min Obs:                       3.0000
# Max Obs:                       17.000   F-statistic (robust):             792.63
#                                         P-value                           0.0000
# Time periods:                      17   Distribution:                  F(6,3787)
# Avg Obs:                       238.47
# Min Obs:                       170.00
# Max Obs:                       261.00
#
#                                    Parameter Estimates
# =========================================================================================
#                        Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -----------------------------------------------------------------------------------------
# VRM_ADJ_log               0.5786     0.0131     44.057     0.0000      0.5529      0.6044
# FARE_per_UPT_2018_log    -0.6933     0.0201    -34.533     0.0000     -0.7326     -0.6539
# POP_EMP_log               0.5378     0.0523     10.285     0.0000      0.4353      0.6403
# GAS_PRICE_2018_log        0.2958     0.0206     14.375     0.0000      0.2554      0.3361
# PCT_HH_NO_VEH             0.0141     0.0030     4.6532     0.0000      0.0081      0.0200
# TSD_POP_PCT               0.3481     0.1457     2.3890     0.0169      0.0624      0.6337
# =========================================================================================
#
# F-test for Poolability: 109.74
# P-value: 0.0000
# Distribution: F(260,3787)
#
# Included effects: Entity

# %%
# separate pop and emp


mod=PanelOLS.from_formula('UPT_ADJ_log \
                    ~ VRM_ADJ_log \
                    + FARE_per_UPT_2018_log \
                    + Tot_Pop_log \
                    + TOT_EMP_MSA_log \
                    + GAS_PRICE_2018_log \
                    + PCT_HH_NO_VEH \
                    + TSD_POP_PCT \
                    + EntityEffects \
                    ',data=df)
res=mod.fit()
print(res)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\data.py:39: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   new_df = df.copy().loc[self._full_index]
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\utility.py:476: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   warnings.warn(missing_value_warning_msg, MissingValueWarning)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:            UPT_ADJ_log   R-squared:                        0.5608
# Estimator:                   PanelOLS   R-squared (Between):              0.9936
# No. Observations:                4054   R-squared (Within):               0.5608
# Date:                Fri, Nov 22 2019   R-squared (Overall):              0.9933
# Time:                        16:21:16   Log-likelihood                    1234.4
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      690.67
# Entities:                         261   P-value                           0.0000
# Avg Obs:                       15.533   Distribution:                  F(7,3786)
# Min Obs:                       3.0000
# Max Obs:                       17.000   F-statistic (robust):             690.67
#                                         P-value                           0.0000
# Time periods:                      17   Distribution:                  F(7,3786)
# Avg Obs:                       238.47
# Min Obs:                       170.00
# Max Obs:                       261.00
#
#                                    Parameter Estimates
# =========================================================================================
#                        Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -----------------------------------------------------------------------------------------
# VRM_ADJ_log               0.5791     0.0131     44.064     0.0000      0.5533      0.6049
# FARE_per_UPT_2018_log    -0.6944     0.0200    -34.703     0.0000     -0.7336     -0.6552
# Tot_Pop_log               0.5363     0.0470     11.421     0.0000      0.4442      0.6283
# TOT_EMP_MSA_log          -0.1231     0.0705    -1.7455     0.0810     -0.2613      0.0152
# GAS_PRICE_2018_log        0.2715     0.0211     12.895     0.0000      0.2302      0.3128
# PCT_HH_NO_VEH             0.0124     0.0030     4.0682     0.0000      0.0064      0.0183
# TSD_POP_PCT               0.4063     0.1467     2.7699     0.0056      0.1187      0.6939
# =========================================================================================
#
# F-test for Poolability: 99.377
# P-value: 0.0000
# Distribution: F(260,3786)
#
# Included effects: Entity

# %%
# add average speed

mod=PanelOLS.from_formula('UPT_ADJ_log \
                    ~ VRM_ADJ_log \
                    + AVG_SPEED_log \
                    + FARE_per_UPT_2018_log \
                    + POP_EMP_log \
                    + GAS_PRICE_2018_log \
                    + PCT_HH_NO_VEH \
                    + TSD_POP_PCT \
                    + EntityEffects \
                    ',data=df)
res=mod.fit()
print(res)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\data.py:39: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   new_df = df.copy().loc[self._full_index]
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\utility.py:476: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   warnings.warn(missing_value_warning_msg, MissingValueWarning)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:            UPT_ADJ_log   R-squared:                        0.5626
# Estimator:                   PanelOLS   R-squared (Between):              0.9982
# No. Observations:                4054   R-squared (Within):               0.5626
# Date:                Fri, Nov 22 2019   R-squared (Overall):              0.9982
# Time:                        16:21:22   Log-likelihood                    1242.5
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      695.60
# Entities:                         261   P-value                           0.0000
# Avg Obs:                       15.533   Distribution:                  F(7,3786)
# Min Obs:                       3.0000
# Max Obs:                       17.000   F-statistic (robust):             695.60
#                                         P-value                           0.0000
# Time periods:                      17   Distribution:                  F(7,3786)
# Avg Obs:                       238.47
# Min Obs:                       170.00
# Max Obs:                       261.00
#
#                                    Parameter Estimates
# =========================================================================================
#                        Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -----------------------------------------------------------------------------------------
# VRM_ADJ_log               0.5895     0.0131     44.873     0.0000      0.5637      0.6153
# AVG_SPEED_log            -0.1544     0.0217    -7.1287     0.0000     -0.1968     -0.1119
# FARE_per_UPT_2018_log    -0.6808     0.0200    -34.003     0.0000     -0.7200     -0.6415
# POP_EMP_log               0.5195     0.0520     9.9874     0.0000      0.4175      0.6214
# GAS_PRICE_2018_log        0.2931     0.0204     14.336     0.0000      0.2530      0.3332
# PCT_HH_NO_VEH             0.0143     0.0030     4.7534     0.0000      0.0084      0.0202
# TSD_POP_PCT               0.4136     0.1450     2.8519     0.0044      0.1293      0.6980
# =========================================================================================
#
# F-test for Poolability: 92.091
# P-value: 0.0000
# Distribution: F(260,3786)
#
# Included effects: Entity

# %%
# add average speed

mod=PanelOLS.from_formula('UPT_ADJ_log \
                    ~ VRM_ADJ_log \
                    + AVG_SPEED \
                    + FARE_per_UPT_2018_log \
                    + POP_EMP_log \
                    + GAS_PRICE_2018_log \
                    + PCT_HH_NO_VEH \
                    + TSD_POP_PCT \
                    + EntityEffects \
                    ',data=df)
res=mod.fit()
print(res)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\data.py:39: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   new_df = df.copy().loc[self._full_index]
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\utility.py:476: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   warnings.warn(missing_value_warning_msg, MissingValueWarning)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:            UPT_ADJ_log   R-squared:                        0.5569
# Estimator:                   PanelOLS   R-squared (Between):              0.9960
# No. Observations:                4054   R-squared (Within):               0.5569
# Date:                Fri, Nov 22 2019   R-squared (Overall):              0.9963
# Time:                        16:21:25   Log-likelihood                    1216.2
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      679.64
# Entities:                         261   P-value                           0.0000
# Avg Obs:                       15.533   Distribution:                  F(7,3786)
# Min Obs:                       3.0000
# Max Obs:                       17.000   F-statistic (robust):             679.64
#                                         P-value                           0.0000
# Time periods:                      17   Distribution:                  F(7,3786)
# Avg Obs:                       238.47
# Min Obs:                       170.00
# Max Obs:                       261.00
#
#                                    Parameter Estimates
# =========================================================================================
#                        Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -----------------------------------------------------------------------------------------
# VRM_ADJ_log               0.5791     0.0131     44.073     0.0000      0.5533      0.6048
# AVG_SPEED                -0.0004     0.0004    -1.1454     0.2521     -0.0012      0.0003
# FARE_per_UPT_2018_log    -0.6923     0.0201    -34.452     0.0000     -0.7317     -0.6529
# POP_EMP_log               0.5361     0.0523     10.249     0.0000      0.4336      0.6387
# GAS_PRICE_2018_log        0.2949     0.0206     14.325     0.0000      0.2546      0.3353
# PCT_HH_NO_VEH             0.0141     0.0030     4.6627     0.0000      0.0082      0.0200
# TSD_POP_PCT               0.3538     0.1458     2.4267     0.0153      0.0679      0.6396
# =========================================================================================
#
# F-test for Poolability: 105.75
# P-value: 0.0000
# Distribution: F(260,3786)
#
# Included effects: Entity

# %%
# VRH and VRM

mod=PanelOLS.from_formula('UPT_ADJ_log \
                    ~ VRM_ADJ_log \
                    + VRH_ADJ_log \
                    + FARE_per_UPT_2018_log \
                    + POP_EMP_log \
                    + GAS_PRICE_2018_log \
                    + PCT_HH_NO_VEH \
                    + TSD_POP_PCT \
                    + EntityEffects \
                    ',data=df)
res=mod.fit()
print(res)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\data.py:39: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   new_df = df.copy().loc[self._full_index]
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\utility.py:476: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   warnings.warn(missing_value_warning_msg, MissingValueWarning)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:            UPT_ADJ_log   R-squared:                        0.5596
# Estimator:                   PanelOLS   R-squared (Between):              0.9971
# No. Observations:                4054   R-squared (Within):               0.5596
# Date:                Fri, Nov 22 2019   R-squared (Overall):              0.9972
# Time:                        16:21:27   Log-likelihood                    1228.9
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      687.31
# Entities:                         261   P-value                           0.0000
# Avg Obs:                       15.533   Distribution:                  F(7,3786)
# Min Obs:                       3.0000
# Max Obs:                       17.000   F-statistic (robust):             687.31
#                                         P-value                           0.0000
# Time periods:                      17   Distribution:                  F(7,3786)
# Avg Obs:                       238.47
# Min Obs:                       170.00
# Max Obs:                       261.00
#
#                                    Parameter Estimates
# =========================================================================================
#                        Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -----------------------------------------------------------------------------------------
# VRM_ADJ_log               0.5167     0.0180     28.693     0.0000      0.4814      0.5520
# VRH_ADJ_log               0.0682     0.0136     5.0121     0.0000      0.0416      0.0949
# FARE_per_UPT_2018_log    -0.6887     0.0200    -34.382     0.0000     -0.7280     -0.6495
# POP_EMP_log               0.5288     0.0522     10.140     0.0000      0.4266      0.6311
# GAS_PRICE_2018_log        0.2952     0.0205     14.393     0.0000      0.2550      0.3354
# PCT_HH_NO_VEH             0.0139     0.0030     4.6300     0.0000      0.0080      0.0199
# TSD_POP_PCT               0.3851     0.1454     2.6480     0.0081      0.1000      0.6702
# =========================================================================================
#
# F-test for Poolability: 95.382
# P-value: 0.0000
# Distribution: F(260,3786)
#
# Included effects: Entity

# %%
# VRH and VRM

mod=PanelOLS.from_formula('UPT_ADJ_log \
                    ~ VRH_ADJ_log \
                    + FARE_per_UPT_2018_log \
                    + POP_EMP_log \
                    + GAS_PRICE_2018_log \
                    + PCT_HH_NO_VEH \
                    + TSD_POP_PCT \
                    + EntityEffects \
                    ',data=df)
res=mod.fit()
print(res)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\data.py:39: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   new_df = df.copy().loc[self._full_index]
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\utility.py:476: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   warnings.warn(missing_value_warning_msg, MissingValueWarning)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:            UPT_ADJ_log   R-squared:                        0.4639
# Estimator:                   PanelOLS   R-squared (Between):              0.9968
# No. Observations:                4054   R-squared (Within):               0.4639
# Date:                Fri, Nov 22 2019   R-squared (Overall):              0.9967
# Time:                        16:21:33   Log-likelihood                    830.02
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      546.08
# Entities:                         261   P-value                           0.0000
# Avg Obs:                       15.533   Distribution:                  F(6,3787)
# Min Obs:                       3.0000
# Max Obs:                       17.000   F-statistic (robust):             546.08
#                                         P-value                           0.0000
# Time periods:                      17   Distribution:                  F(6,3787)
# Avg Obs:                       238.47
# Min Obs:                       170.00
# Max Obs:                       261.00
#
#                                    Parameter Estimates
# =========================================================================================
#                        Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -----------------------------------------------------------------------------------------
# VRH_ADJ_log               0.3365     0.0109     30.807     0.0000      0.3151      0.3579
# FARE_per_UPT_2018_log    -0.7220     0.0221    -32.724     0.0000     -0.7653     -0.6787
# POP_EMP_log               0.7759     0.0567     13.673     0.0000      0.6647      0.8872
# GAS_PRICE_2018_log        0.2845     0.0226     12.573     0.0000      0.2401      0.3288
# PCT_HH_NO_VEH             0.0153     0.0033     4.5909     0.0000      0.0087      0.0218
# TSD_POP_PCT               0.2940     0.1604     1.8326     0.0669     -0.0205      0.6084
# =========================================================================================
#
# F-test for Poolability: 78.687
# P-value: 0.0000
# Distribution: F(260,3787)
#
# Included effects: Entity

# %% [markdown]
# ## look at lagging the VRM and the Fares

# %%
# base model

mod=PanelOLS.from_formula('UPT_ADJ_log \
                    ~ VRM_ADJ_log \
                    + FARE_per_UPT_2018_log \
                    + POP_EMP_log \
                    + GAS_PRICE_2018_log \
                    + PCT_HH_NO_VEH \
                    + TSD_POP_PCT \
                    + EntityEffects \
                    ',data=df)
res=mod.fit()
print(res)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\data.py:39: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   new_df = df.copy().loc[self._full_index]
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\utility.py:476: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   warnings.warn(missing_value_warning_msg, MissingValueWarning)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:            UPT_ADJ_log   R-squared:                        0.5567
# Estimator:                   PanelOLS   R-squared (Between):              0.9959
# No. Observations:                4054   R-squared (Within):               0.5567
# Date:                Fri, Nov 22 2019   R-squared (Overall):              0.9961
# Time:                        16:21:36   Log-likelihood                    1215.5
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      792.63
# Entities:                         261   P-value                           0.0000
# Avg Obs:                       15.533   Distribution:                  F(6,3787)
# Min Obs:                       3.0000
# Max Obs:                       17.000   F-statistic (robust):             792.63
#                                         P-value                           0.0000
# Time periods:                      17   Distribution:                  F(6,3787)
# Avg Obs:                       238.47
# Min Obs:                       170.00
# Max Obs:                       261.00
#
#                                    Parameter Estimates
# =========================================================================================
#                        Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -----------------------------------------------------------------------------------------
# VRM_ADJ_log               0.5786     0.0131     44.057     0.0000      0.5529      0.6044
# FARE_per_UPT_2018_log    -0.6933     0.0201    -34.533     0.0000     -0.7326     -0.6539
# POP_EMP_log               0.5378     0.0523     10.285     0.0000      0.4353      0.6403
# GAS_PRICE_2018_log        0.2958     0.0206     14.375     0.0000      0.2554      0.3361
# PCT_HH_NO_VEH             0.0141     0.0030     4.6532     0.0000      0.0081      0.0200
# TSD_POP_PCT               0.3481     0.1457     2.3890     0.0169      0.0624      0.6337
# =========================================================================================
#
# F-test for Poolability: 109.74
# P-value: 0.0000
# Distribution: F(260,3787)
#
# Included effects: Entity

# %% [markdown]
# ## Look at demographics

# %%
# base model

mod=PanelOLS.from_formula('UPT_ADJ_log \
                    ~ VRM_ADJ_log \
                    + FARE_per_UPT_2018_log \
                    + POP_EMP_log \
                    + GAS_PRICE_2018_log \
                    + PCT_HH_NO_VEH \
                    + TSD_POP_PCT \
                    + EntityEffects \
                    ',data=df)
res=mod.fit()
print(res)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\data.py:39: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   new_df = df.copy().loc[self._full_index]
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\utility.py:476: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   warnings.warn(missing_value_warning_msg, MissingValueWarning)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:            UPT_ADJ_log   R-squared:                        0.5567
# Estimator:                   PanelOLS   R-squared (Between):              0.9959
# No. Observations:                4054   R-squared (Within):               0.5567
# Date:                Fri, Nov 22 2019   R-squared (Overall):              0.9961
# Time:                        16:21:41   Log-likelihood                    1215.5
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      792.63
# Entities:                         261   P-value                           0.0000
# Avg Obs:                       15.533   Distribution:                  F(6,3787)
# Min Obs:                       3.0000
# Max Obs:                       17.000   F-statistic (robust):             792.63
#                                         P-value                           0.0000
# Time periods:                      17   Distribution:                  F(6,3787)
# Avg Obs:                       238.47
# Min Obs:                       170.00
# Max Obs:                       261.00
#
#                                    Parameter Estimates
# =========================================================================================
#                        Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -----------------------------------------------------------------------------------------
# VRM_ADJ_log               0.5786     0.0131     44.057     0.0000      0.5529      0.6044
# FARE_per_UPT_2018_log    -0.6933     0.0201    -34.533     0.0000     -0.7326     -0.6539
# POP_EMP_log               0.5378     0.0523     10.285     0.0000      0.4353      0.6403
# GAS_PRICE_2018_log        0.2958     0.0206     14.375     0.0000      0.2554      0.3361
# PCT_HH_NO_VEH             0.0141     0.0030     4.6532     0.0000      0.0081      0.0200
# TSD_POP_PCT               0.3481     0.1457     2.3890     0.0169      0.0624      0.6337
# =========================================================================================
#
# F-test for Poolability: 109.74
# P-value: 0.0000
# Distribution: F(260,3787)
#
# Included effects: Entity

# %%
# income percentages

mod=PanelOLS.from_formula('UPT_ADJ_log \
                    ~ VRM_ADJ_log \
                    + FARE_per_UPT_2018_log \
                    + POP_EMP_log \
                    + GAS_PRICE_2018_log \
                    + PCT_HH_NO_VEH \
                    + INC_U35 \
                    + TSD_POP_PCT \
                    + EntityEffects \
                    ',data=df)
res=mod.fit()
print(res)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\data.py:39: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   new_df = df.copy().loc[self._full_index]
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\utility.py:476: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   warnings.warn(missing_value_warning_msg, MissingValueWarning)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:            UPT_ADJ_log   R-squared:                        0.5570
# Estimator:                   PanelOLS   R-squared (Between):              0.9984
# No. Observations:                4054   R-squared (Within):               0.5570
# Date:                Fri, Nov 22 2019   R-squared (Overall):              0.9984
# Time:                        16:21:45   Log-likelihood                    1216.9
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      680.08
# Entities:                         261   P-value                           0.0000
# Avg Obs:                       15.533   Distribution:                  F(7,3786)
# Min Obs:                       3.0000
# Max Obs:                       17.000   F-statistic (robust):             680.08
#                                         P-value                           0.0000
# Time periods:                      17   Distribution:                  F(7,3786)
# Avg Obs:                       238.47
# Min Obs:                       170.00
# Max Obs:                       261.00
#
#                                    Parameter Estimates
# =========================================================================================
#                        Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -----------------------------------------------------------------------------------------
# VRM_ADJ_log               0.5760     0.0132     43.526     0.0000      0.5500      0.6019
# FARE_per_UPT_2018_log    -0.6956     0.0201    -34.569     0.0000     -0.7351     -0.6562
# POP_EMP_log               0.4913     0.0595     8.2573     0.0000      0.3747      0.6080
# GAS_PRICE_2018_log        0.2949     0.0206     14.333     0.0000      0.2546      0.3353
# PCT_HH_NO_VEH             0.0149     0.0031     4.8627     0.0000      0.0089      0.0209
# INC_U35                  -0.0016     0.0010    -1.6355     0.1020     -0.0035      0.0003
# TSD_POP_PCT               0.3846     0.1474     2.6098     0.0091      0.0957      0.6735
# =========================================================================================
#
# F-test for Poolability: 109.40
# P-value: 0.0000
# Distribution: F(260,3786)
#
# Included effects: Entity

# %%
# income percentages

mod=PanelOLS.from_formula('UPT_ADJ_log \
                    ~ VRM_ADJ_log \
                    + FARE_per_UPT_2018_log \
                    + POP_EMP_log \
                    + GAS_PRICE_2018_log \
                    + PCT_HH_NO_VEH \
                    + INC_100P \
                    + TSD_POP_PCT \
                    + EntityEffects \
                    ',data=df)
res=mod.fit()
print(res)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\data.py:39: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   new_df = df.copy().loc[self._full_index]
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\utility.py:476: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   warnings.warn(missing_value_warning_msg, MissingValueWarning)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:            UPT_ADJ_log   R-squared:                        0.5567
# Estimator:                   PanelOLS   R-squared (Between):              0.9962
# No. Observations:                4054   R-squared (Within):               0.5567
# Date:                Fri, Nov 22 2019   R-squared (Overall):              0.9964
# Time:                        16:21:52   Log-likelihood                    1215.5
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      679.22
# Entities:                         261   P-value                           0.0000
# Avg Obs:                       15.533   Distribution:                  F(7,3786)
# Min Obs:                       3.0000
# Max Obs:                       17.000   F-statistic (robust):             679.22
#                                         P-value                           0.0000
# Time periods:                      17   Distribution:                  F(7,3786)
# Avg Obs:                       238.47
# Min Obs:                       170.00
# Max Obs:                       261.00
#
#                                    Parameter Estimates
# =========================================================================================
#                        Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -----------------------------------------------------------------------------------------
# VRM_ADJ_log               0.5783     0.0133     43.457     0.0000      0.5523      0.6044
# FARE_per_UPT_2018_log    -0.6936     0.0202    -34.293     0.0000     -0.7333     -0.6540
# POP_EMP_log               0.5339     0.0594     8.9926     0.0000      0.4175      0.6503
# GAS_PRICE_2018_log        0.2960     0.0206     14.347     0.0000      0.2555      0.3364
# PCT_HH_NO_VEH             0.0141     0.0030     4.6546     0.0000      0.0081      0.0200
# INC_100P                  0.0001     0.0010     0.1399     0.8888     -0.0017      0.0020
# TSD_POP_PCT               0.3545     0.1529     2.3194     0.0204      0.0548      0.6542
# =========================================================================================
#
# F-test for Poolability: 108.64
# P-value: 0.0000
# Distribution: F(260,3786)
#
# Included effects: Entity

# %%
# median income


mod=PanelOLS.from_formula('UPT_ADJ_log \
                    ~ VRM_ADJ_log \
                    + FARE_per_UPT_2018_log \
                    + POP_EMP_log \
                    + GAS_PRICE_2018_log \
                    + PCT_HH_NO_VEH \
                    + HH_MED_INC_2018 \
                    + TSD_POP_PCT \
                    + EntityEffects \
                    ',data=df)
res=mod.fit()
print(res)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\data.py:39: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   new_df = df.copy().loc[self._full_index]
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\utility.py:476: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   warnings.warn(missing_value_warning_msg, MissingValueWarning)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:            UPT_ADJ_log   R-squared:                        0.5570
# Estimator:                   PanelOLS   R-squared (Between):              0.9953
# No. Observations:                4054   R-squared (Within):               0.5570
# Date:                Fri, Nov 22 2019   R-squared (Overall):              0.9956
# Time:                        16:21:52   Log-likelihood                    1217.0
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      680.14
# Entities:                         261   P-value                           0.0000
# Avg Obs:                       15.533   Distribution:                  F(7,3786)
# Min Obs:                       3.0000
# Max Obs:                       17.000   F-statistic (robust):             680.14
#                                         P-value                           0.0000
# Time periods:                      17   Distribution:                  F(7,3786)
# Avg Obs:                       238.47
# Min Obs:                       170.00
# Max Obs:                       261.00
#
#                                    Parameter Estimates
# =========================================================================================
#                        Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -----------------------------------------------------------------------------------------
# VRM_ADJ_log               0.5791     0.0131     44.091     0.0000      0.5533      0.6048
# FARE_per_UPT_2018_log    -0.6936     0.0201    -34.556     0.0000     -0.7330     -0.6543
# POP_EMP_log               0.5509     0.0528     10.424     0.0000      0.4473      0.6545
# GAS_PRICE_2018_log        0.2897     0.0209     13.866     0.0000      0.2487      0.3306
# PCT_HH_NO_VEH             0.0130     0.0031     4.2133     0.0000      0.0070      0.0191
# HH_MED_INC_2018       -1.438e-06  8.529e-07    -1.6865     0.0918  -3.111e-06   2.338e-07
# TSD_POP_PCT               0.3251     0.1463     2.2224     0.0263      0.0383      0.6119
# =========================================================================================
#
# F-test for Poolability: 108.79
# P-value: 0.0000
# Distribution: F(260,3786)
#
# Included effects: Entity

# %%
# median income -- log


mod=PanelOLS.from_formula('UPT_ADJ_log \
                    ~ VRM_ADJ_log \
                    + FARE_per_UPT_2018_log \
                    + POP_EMP_log \
                    + GAS_PRICE_2018_log \
                    + PCT_HH_NO_VEH \
                    + HH_MED_INC_2018_log \
                    + TSD_POP_PCT \
                    + EntityEffects \
                    ',data=df)
res=mod.fit()
print(res)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\data.py:39: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   new_df = df.copy().loc[self._full_index]
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\utility.py:476: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   warnings.warn(missing_value_warning_msg, MissingValueWarning)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:            UPT_ADJ_log   R-squared:                        0.5571
# Estimator:                   PanelOLS   R-squared (Between):              0.9984
# No. Observations:                4054   R-squared (Within):               0.5571
# Date:                Fri, Nov 22 2019   R-squared (Overall):              0.9983
# Time:                        16:21:54   Log-likelihood                    1217.5
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      680.45
# Entities:                         261   P-value                           0.0000
# Avg Obs:                       15.533   Distribution:                  F(7,3786)
# Min Obs:                       3.0000
# Max Obs:                       17.000   F-statistic (robust):             680.45
#                                         P-value                           0.0000
# Time periods:                      17   Distribution:                  F(7,3786)
# Avg Obs:                       238.47
# Min Obs:                       170.00
# Max Obs:                       261.00
#
#                                    Parameter Estimates
# =========================================================================================
#                        Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -----------------------------------------------------------------------------------------
# VRM_ADJ_log               0.5791     0.0131     44.100     0.0000      0.5533      0.6048
# FARE_per_UPT_2018_log    -0.6937     0.0201    -34.567     0.0000     -0.7331     -0.6544
# POP_EMP_log               0.5525     0.0528     10.463     0.0000      0.4490      0.6561
# GAS_PRICE_2018_log        0.2896     0.0208     13.919     0.0000      0.2488      0.3304
# PCT_HH_NO_VEH             0.0127     0.0031     4.0855     0.0000      0.0066      0.0188
# HH_MED_INC_2018_log      -0.0978     0.0500    -1.9545     0.0507     -0.1959      0.0003
# TSD_POP_PCT               0.3259     0.1461     2.2309     0.0257      0.0395      0.6123
# =========================================================================================
#
# F-test for Poolability: 108.69
# P-value: 0.0000
# Distribution: F(260,3786)
#
# Included effects: Entity

# %%
# mean income


mod=PanelOLS.from_formula('UPT_ADJ_log \
                    ~ VRM_ADJ_log \
                    + FARE_per_UPT_2018_log \
                    + POP_EMP_log \
                    + GAS_PRICE_2018_log \
                    + PCT_HH_NO_VEH \
                    + HH_MEAN_INC_2018 \
                    + TSD_POP_PCT \
                    + EntityEffects \
                    ',data=df)
res=mod.fit()
print(res)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\data.py:39: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   new_df = df.copy().loc[self._full_index]
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\utility.py:476: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   warnings.warn(missing_value_warning_msg, MissingValueWarning)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:            UPT_ADJ_log   R-squared:                        0.5588
# Estimator:                   PanelOLS   R-squared (Between):              0.9921
# No. Observations:                4054   R-squared (Within):               0.5588
# Date:                Fri, Nov 22 2019   R-squared (Overall):              0.9925
# Time:                        16:21:55   Log-likelihood                    1225.2
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      685.09
# Entities:                         261   P-value                           0.0000
# Avg Obs:                       15.533   Distribution:                  F(7,3786)
# Min Obs:                       3.0000
# Max Obs:                       17.000   F-statistic (robust):             685.09
#                                         P-value                           0.0000
# Time periods:                      17   Distribution:                  F(7,3786)
# Avg Obs:                       238.47
# Min Obs:                       170.00
# Max Obs:                       261.00
#
#                                    Parameter Estimates
# =========================================================================================
#                        Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -----------------------------------------------------------------------------------------
# VRM_ADJ_log               0.5807     0.0131     44.283     0.0000      0.5550      0.6064
# FARE_per_UPT_2018_log    -0.6929     0.0200    -34.592     0.0000     -0.7322     -0.6536
# POP_EMP_log               0.5900     0.0536     11.011     0.0000      0.4850      0.6951
# GAS_PRICE_2018_log        0.2783     0.0209     13.293     0.0000      0.2372      0.3193
# PCT_HH_NO_VEH             0.0113     0.0031     3.6721     0.0002      0.0053      0.0174
# HH_MEAN_INC_2018      -3.129e-06  7.332e-07    -4.2678     0.0000  -4.567e-06  -1.692e-06
# TSD_POP_PCT               0.2468     0.1473     1.6756     0.0939     -0.0420      0.5356
# =========================================================================================
#
# F-test for Poolability: 109.19
# P-value: 0.0000
# Distribution: F(260,3786)
#
# Included effects: Entity

# %%
# mean income - log


mod=PanelOLS.from_formula('UPT_ADJ_log \
                    ~ VRM_ADJ_log \
                    + FARE_per_UPT_2018_log \
                    + POP_EMP_log \
                    + GAS_PRICE_2018_log \
                    + PCT_HH_NO_VEH \
                    + HH_MEAN_INC_2018_log \
                    + TSD_POP_PCT \
                    + EntityEffects \
                    ',data=df)
res=mod.fit()
print(res)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\data.py:39: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   new_df = df.copy().loc[self._full_index]
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\utility.py:476: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   warnings.warn(missing_value_warning_msg, MissingValueWarning)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:            UPT_ADJ_log   R-squared:                        0.5592
# Estimator:                   PanelOLS   R-squared (Between):              0.9884
# No. Observations:                4054   R-squared (Within):               0.5592
# Date:                Fri, Nov 22 2019   R-squared (Overall):              0.9881
# Time:                        16:21:56   Log-likelihood                    1227.1
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      686.25
# Entities:                         261   P-value                           0.0000
# Avg Obs:                       15.533   Distribution:                  F(7,3786)
# Min Obs:                       3.0000
# Max Obs:                       17.000   F-statistic (robust):             686.25
#                                         P-value                           0.0000
# Time periods:                      17   Distribution:                  F(7,3786)
# Avg Obs:                       238.47
# Min Obs:                       170.00
# Max Obs:                       261.00
#
#                                    Parameter Estimates
# =========================================================================================
#                        Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -----------------------------------------------------------------------------------------
# VRM_ADJ_log               0.5804     0.0131     44.295     0.0000      0.5547      0.6061
# FARE_per_UPT_2018_log    -0.6932     0.0200    -34.623     0.0000     -0.7324     -0.6539
# POP_EMP_log               0.5961     0.0536     11.118     0.0000      0.4910      0.7013
# GAS_PRICE_2018_log        0.2779     0.0209     13.315     0.0000      0.2370      0.3189
# PCT_HH_NO_VEH             0.0108     0.0031     3.4851     0.0005      0.0047      0.0169
# HH_MEAN_INC_2018_log     -0.2721     0.0583    -4.6715     0.0000     -0.3863     -0.1579
# TSD_POP_PCT               0.2576     0.1466     1.7576     0.0789     -0.0297      0.5450
# =========================================================================================
#
# F-test for Poolability: 109.06
# P-value: 0.0000
# Distribution: F(260,3786)
#
# Included effects: Entity

# %%
# median personal income

mod=PanelOLS.from_formula('UPT_ADJ_log \
                    ~ VRM_ADJ_log \
                    + FARE_per_UPT_2018_log \
                    + POP_EMP_log \
                    + GAS_PRICE_2018_log \
                    + PCT_HH_NO_VEH \
                    + TOTAL_MED_INC_INDIV_2018 \
                    + TSD_POP_PCT \
                    + EntityEffects \
                    ',data=df)
res=mod.fit()
print(res)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\data.py:39: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   new_df = df.copy().loc[self._full_index]
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\utility.py:476: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   warnings.warn(missing_value_warning_msg, MissingValueWarning)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:            UPT_ADJ_log   R-squared:                        0.5608
# Estimator:                   PanelOLS   R-squared (Between):              0.9983
# No. Observations:                4054   R-squared (Within):               0.5608
# Date:                Fri, Nov 22 2019   R-squared (Overall):              0.9983
# Time:                        16:21:57   Log-likelihood                    1234.1
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      690.48
# Entities:                         261   P-value                           0.0000
# Avg Obs:                       15.533   Distribution:                  F(7,3786)
# Min Obs:                       3.0000
# Max Obs:                       17.000   F-statistic (robust):             690.48
#                                         P-value                           0.0000
# Time periods:                      17   Distribution:                  F(7,3786)
# Avg Obs:                       238.47
# Min Obs:                       170.00
# Max Obs:                       261.00
#
#                                     Parameter Estimates
# ============================================================================================
#                           Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# --------------------------------------------------------------------------------------------
# VRM_ADJ_log                  0.5776     0.0131     44.171     0.0000      0.5520      0.6032
# FARE_per_UPT_2018_log       -0.6962     0.0200    -34.823     0.0000     -0.7354     -0.6570
# POP_EMP_log                  0.5045     0.0524     9.6357     0.0000      0.4019      0.6072
# GAS_PRICE_2018_log           0.2295     0.0233     9.8310     0.0000      0.1838      0.2753
# PCT_HH_NO_VEH                0.0095     0.0031     3.0430     0.0024      0.0034      0.0156
# TOTAL_MED_INC_INDIV_2018 -1.031e-05  1.743e-06    -5.9126     0.0000  -1.372e-05  -6.889e-06
# TSD_POP_PCT                  0.5758     0.1501     3.8366     0.0001      0.2815      0.8700
# ============================================================================================
#
# F-test for Poolability: 109.94
# P-value: 0.0000
# Distribution: F(260,3786)
#
# Included effects: Entity

# %%
# median personal income - log

mod=PanelOLS.from_formula('UPT_ADJ_log \
                    ~ VRM_ADJ_log \
                    + FARE_per_UPT_2018_log \
                    + POP_EMP_log \
                    + GAS_PRICE_2018_log \
                    + TOTAL_MED_INC_INDIV_2018_log \
                    + PCT_HH_NO_VEH \
                    + TSD_POP_PCT \
                    + EntityEffects \
                    ',data=df)
res=mod.fit()
print(res)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\data.py:39: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   new_df = df.copy().loc[self._full_index]
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\utility.py:476: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   warnings.warn(missing_value_warning_msg, MissingValueWarning)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:            UPT_ADJ_log   R-squared:                        0.5626
# Estimator:                   PanelOLS   R-squared (Between):              0.9332
# No. Observations:                4054   R-squared (Within):               0.5626
# Date:                Fri, Nov 22 2019   R-squared (Overall):              0.9330
# Time:                        16:21:58   Log-likelihood                    1242.5
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      695.63
# Entities:                         261   P-value                           0.0000
# Avg Obs:                       15.533   Distribution:                  F(7,3786)
# Min Obs:                       3.0000
# Max Obs:                       17.000   F-statistic (robust):             695.63
#                                         P-value                           0.0000
# Time periods:                      17   Distribution:                  F(7,3786)
# Avg Obs:                       238.47
# Min Obs:                       170.00
# Max Obs:                       261.00
#
#                                       Parameter Estimates
# ================================================================================================
#                               Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------------------
# VRM_ADJ_log                      0.5770     0.0131     44.216     0.0000      0.5514      0.6026
# FARE_per_UPT_2018_log           -0.6975     0.0200    -34.957     0.0000     -0.7366     -0.6584
# POP_EMP_log                      0.4936     0.0523     9.4353     0.0000      0.3910      0.5962
# GAS_PRICE_2018_log               0.2162     0.0233     9.2821     0.0000      0.1705      0.2618
# TOTAL_MED_INC_INDIV_2018_log    -0.3820     0.0535    -7.1367     0.0000     -0.4870     -0.2771
# PCT_HH_NO_VEH                    0.0084     0.0031     2.7004     0.0070      0.0023      0.0145
# TSD_POP_PCT                      0.5609     0.1478     3.7956     0.0001      0.2712      0.8507
# ================================================================================================
#
# F-test for Poolability: 110.65
# P-value: 0.0000
# Distribution: F(260,3786)
#
# Included effects: Entity

# %%
# immigrant population

mod=PanelOLS.from_formula('UPT_ADJ_log \
                    ~ VRM_ADJ_log \
                    + FARE_per_UPT_2018_log \
                    + POP_EMP_log \
                    + GAS_PRICE_2018_log \
                    + TOTAL_MED_INC_INDIV_2018_log \
                    + Tot_NonUSA_POP \
                    + PCT_HH_NO_VEH \
                    + TSD_POP_PCT \
                    + EntityEffects \
                    ',data=df)
res=mod.fit()
print(res)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\data.py:39: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   new_df = df.copy().loc[self._full_index]
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\utility.py:476: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   warnings.warn(missing_value_warning_msg, MissingValueWarning)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:            UPT_ADJ_log   R-squared:                        0.5631
# Estimator:                   PanelOLS   R-squared (Between):              0.9414
# No. Observations:                4054   R-squared (Within):               0.5631
# Date:                Fri, Nov 22 2019   R-squared (Overall):              0.9411
# Time:                        16:22:06   Log-likelihood                    1245.1
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      609.88
# Entities:                         261   P-value                           0.0000
# Avg Obs:                       15.533   Distribution:                  F(8,3785)
# Min Obs:                       3.0000
# Max Obs:                       17.000   F-statistic (robust):             609.88
#                                         P-value                           0.0000
# Time periods:                      17   Distribution:                  F(8,3785)
# Avg Obs:                       238.47
# Min Obs:                       170.00
# Max Obs:                       261.00
#
#                                       Parameter Estimates
# ================================================================================================
#                               Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------------------
# VRM_ADJ_log                      0.5776     0.0130     44.274     0.0000      0.5520      0.6032
# FARE_per_UPT_2018_log           -0.6951     0.0200    -34.801     0.0000     -0.7343     -0.6559
# POP_EMP_log                      0.5200     0.0537     9.6901     0.0000      0.4148      0.6252
# GAS_PRICE_2018_log               0.2114     0.0234     9.0426     0.0000      0.1656      0.2572
# TOTAL_MED_INC_INDIV_2018_log    -0.3890     0.0536    -7.2583     0.0000     -0.4941     -0.2839
# Tot_NonUSA_POP                -1.06e-06  4.847e-07    -2.1872     0.0288   -2.01e-06  -1.098e-07
# PCT_HH_NO_VEH                    0.0081     0.0031     2.6127     0.0090      0.0020      0.0142
# TSD_POP_PCT                      0.5021     0.1501     3.3440     0.0008      0.2077      0.7965
# ================================================================================================
#
# F-test for Poolability: 108.77
# P-value: 0.0000
# Distribution: F(260,3785)
#
# Included effects: Entity

# %%
# immigrant population - log

mod=PanelOLS.from_formula('UPT_ADJ_log \
                    ~ VRM_ADJ_log \
                    + FARE_per_UPT_2018_log \
                    + POP_EMP_log \
                    + GAS_PRICE_2018_log \
                    + TOTAL_MED_INC_INDIV_2018_log \
                    + Tot_NonUSA_POP_log \
                    + PCT_HH_NO_VEH \
                    + TSD_POP_PCT \
                    + EntityEffects \
                    ',data=df)
res=mod.fit()
print(res)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\data.py:39: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   new_df = df.copy().loc[self._full_index]
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\utility.py:476: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   warnings.warn(missing_value_warning_msg, MissingValueWarning)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:            UPT_ADJ_log   R-squared:                        0.5610
# Estimator:                   PanelOLS   R-squared (Between):              0.9630
# No. Observations:                4009   R-squared (Within):               0.5610
# Date:                Fri, Nov 22 2019   R-squared (Overall):              0.9628
# Time:                        16:22:07   Log-likelihood                    1356.3
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      597.44
# Entities:                         261   P-value                           0.0000
# Avg Obs:                       15.360   Distribution:                  F(8,3740)
# Min Obs:                       3.0000
# Max Obs:                       17.000   F-statistic (robust):             597.44
#                                         P-value                           0.0000
# Time periods:                      17   Distribution:                  F(8,3740)
# Avg Obs:                       235.82
# Min Obs:                       144.00
# Max Obs:                       261.00
#
#                                       Parameter Estimates
# ================================================================================================
#                               Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------------------
# VRM_ADJ_log                      0.5845     0.0128     45.672     0.0000      0.5594      0.6096
# FARE_per_UPT_2018_log           -0.6540     0.0202    -32.454     0.0000     -0.6935     -0.6145
# POP_EMP_log                      0.5054     0.0537     9.4045     0.0000      0.4001      0.6108
# GAS_PRICE_2018_log               0.2308     0.0228     10.121     0.0000      0.1861      0.2755
# TOTAL_MED_INC_INDIV_2018_log    -0.3276     0.0528    -6.2050     0.0000     -0.4312     -0.2241
# Tot_NonUSA_POP_log               0.0028     0.0080     0.3471     0.7285     -0.0129      0.0185
# PCT_HH_NO_VEH                    0.0148     0.0031     4.7381     0.0000      0.0087      0.0209
# TSD_POP_PCT                      0.8917     0.1485     6.0054     0.0000      0.6006      1.1829
# ================================================================================================
#
# F-test for Poolability: 115.55
# P-value: 0.0000
# Distribution: F(260,3740)
#
# Included effects: Entity

# %%
# immigrant population percentage
df['Tot_NonUSA_POP_pct'] = df['Tot_NonUSA_POP'] / df['Tot_Pop'] * 100


mod=PanelOLS.from_formula('UPT_ADJ_log \
                    ~ VRM_ADJ_log \
                    + FARE_per_UPT_2018_log \
                    + POP_EMP_log \
                    + GAS_PRICE_2018_log \
                    + TOTAL_MED_INC_INDIV_2018_log \
                    + Tot_NonUSA_POP_pct \
                    + PCT_HH_NO_VEH \
                    + TSD_POP_PCT \
                    + EntityEffects \
                    ',data=df)
res=mod.fit()
print(res)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\data.py:39: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   new_df = df.copy().loc[self._full_index]
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\utility.py:476: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   warnings.warn(missing_value_warning_msg, MissingValueWarning)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:            UPT_ADJ_log   R-squared:                        0.5639
# Estimator:                   PanelOLS   R-squared (Between):              0.9211
# No. Observations:                4054   R-squared (Within):               0.5639
# Date:                Fri, Nov 22 2019   R-squared (Overall):              0.9208
# Time:                        16:22:08   Log-likelihood                    1248.7
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      611.81
# Entities:                         261   P-value                           0.0000
# Avg Obs:                       15.533   Distribution:                  F(8,3785)
# Min Obs:                       3.0000
# Max Obs:                       17.000   F-statistic (robust):             611.81
#                                         P-value                           0.0000
# Time periods:                      17   Distribution:                  F(8,3785)
# Avg Obs:                       238.47
# Min Obs:                       170.00
# Max Obs:                       261.00
#
#                                       Parameter Estimates
# ================================================================================================
#                               Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------------------
# VRM_ADJ_log                      0.5756     0.0130     44.146     0.0000      0.5500      0.6012
# FARE_per_UPT_2018_log           -0.6989     0.0199    -35.066     0.0000     -0.7379     -0.6598
# POP_EMP_log                      0.4580     0.0533     8.5961     0.0000      0.3536      0.5625
# GAS_PRICE_2018_log               0.2189     0.0233     9.4054     0.0000      0.1732      0.2645
# TOTAL_MED_INC_INDIV_2018_log    -0.3706     0.0536    -6.9196     0.0000     -0.4756     -0.2656
# Tot_NonUSA_POP_pct               0.0294     0.0087     3.3969     0.0007      0.0124      0.0464
# PCT_HH_NO_VEH                    0.0083     0.0031     2.6735     0.0075      0.0022      0.0144
# TSD_POP_PCT                      0.5864     0.1478     3.9681     0.0001      0.2967      0.8761
# ================================================================================================
#
# F-test for Poolability: 109.68
# P-value: 0.0000
# Distribution: F(260,3785)
#
# Included effects: Entity

# %% [markdown]
# ## bus vs rail competion

# %%
# base model

mod=PanelOLS.from_formula('UPT_ADJ_log \
                    ~ VRM_ADJ_log \
                    + FARE_per_UPT_2018_log \
                    + POP_EMP_log \
                    + GAS_PRICE_2018_log \
                    + TOTAL_MED_INC_INDIV_2018_log \
                    + Tot_NonUSA_POP_pct \
                    + PCT_HH_NO_VEH \
                    + TSD_POP_PCT \
                    + EntityEffects \
                    ',data=df)
res=mod.fit()
print(res)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\data.py:39: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   new_df = df.copy().loc[self._full_index]
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\utility.py:476: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   warnings.warn(missing_value_warning_msg, MissingValueWarning)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:            UPT_ADJ_log   R-squared:                        0.5639
# Estimator:                   PanelOLS   R-squared (Between):              0.9211
# No. Observations:                4054   R-squared (Within):               0.5639
# Date:                Fri, Nov 22 2019   R-squared (Overall):              0.9208
# Time:                        16:22:11   Log-likelihood                    1248.7
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      611.81
# Entities:                         261   P-value                           0.0000
# Avg Obs:                       15.533   Distribution:                  F(8,3785)
# Min Obs:                       3.0000
# Max Obs:                       17.000   F-statistic (robust):             611.81
#                                         P-value                           0.0000
# Time periods:                      17   Distribution:                  F(8,3785)
# Avg Obs:                       238.47
# Min Obs:                       170.00
# Max Obs:                       261.00
#
#                                       Parameter Estimates
# ================================================================================================
#                               Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------------------
# VRM_ADJ_log                      0.5756     0.0130     44.146     0.0000      0.5500      0.6012
# FARE_per_UPT_2018_log           -0.6989     0.0199    -35.066     0.0000     -0.7379     -0.6598
# POP_EMP_log                      0.4580     0.0533     8.5961     0.0000      0.3536      0.5625
# GAS_PRICE_2018_log               0.2189     0.0233     9.4054     0.0000      0.1732      0.2645
# TOTAL_MED_INC_INDIV_2018_log    -0.3706     0.0536    -6.9196     0.0000     -0.4756     -0.2656
# Tot_NonUSA_POP_pct               0.0294     0.0087     3.3969     0.0007      0.0124      0.0464
# PCT_HH_NO_VEH                    0.0083     0.0031     2.6735     0.0075      0.0022      0.0144
# TSD_POP_PCT                      0.5864     0.1478     3.9681     0.0001      0.2967      0.8761
# ================================================================================================
#
# F-test for Poolability: 109.68
# P-value: 0.0000
# Distribution: F(260,3785)
#
# Included effects: Entity

# %%
# include VRM on competing modes
# base model

mod=PanelOLS.from_formula('UPT_ADJ_log \
                    ~ VRM_ADJ_log \
                    + Bus_VRM_ADJ_RAIL \
                    + Rail_VRM_ADJ_BUS \
                    + FARE_per_UPT_2018_log \
                    + POP_EMP_log \
                    + GAS_PRICE_2018_log \
                    + TOTAL_MED_INC_INDIV_2018_log \
                    + Tot_NonUSA_POP_pct \
                    + PCT_HH_NO_VEH \
                    + TSD_POP_PCT \
                    + EntityEffects \
                    ',data=df)
res=mod.fit()
print(res)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\data.py:39: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   new_df = df.copy().loc[self._full_index]
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\utility.py:476: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   warnings.warn(missing_value_warning_msg, MissingValueWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-42-0c142a70be42> in <module>()
#       2 # base model
#       3
# ----> 4 mod=PanelOLS.from_formula('UPT_ADJ_log                     ~ VRM_ADJ_log                     + Bus_VRM_ADJ_RAIL                     + Rail_VRM_ADJ_BUS                     + FARE_per_UPT_2018_log                     + POP_EMP_log                     + GAS_PRICE_2018_log                     + TOTAL_MED_INC_INDIV_2018_log                     + Tot_NonUSA_POP_pct                     + PCT_HH_NO_VEH                     + TSD_POP_PCT                     + EntityEffects                     ',data=df)
#       5 res=mod.fit()
#       6 print(res)
#
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\model.py in from_formula(cls, formula, data, weights, other_effects)
#     734                                     return_type='dataframe', NA_action=na_action)
#     735         mod = cls(dependent, exog, entity_effects=entity_effect,
# --> 736                   time_effects=time_effect, weights=weights, other_effects=other_effects)
#     737         mod.formula = formula
#     738         return mod
#
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\model.py in __init__(self, dependent, exog, weights, entity_effects, time_effects, other_effects)
#     598     def __init__(self, dependent, exog, *, weights=None, entity_effects=False, time_effects=False,
#     599                  other_effects=None):
# --> 600         super(PanelOLS, self).__init__(dependent, exog, weights=weights)
#     601
#     602         self._entity_effects = entity_effects
#
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\model.py in __init__(self, dependent, exog, weights)
#      86                                                  DriscollKraay, ACCovariance)
#      87
# ---> 88         self._validate_data()
#      89
#      90     def __str__(self):
#
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\model.py in _validate_data(self)
#     207
#     208         if matrix_rank(x) < x.shape[1]:
# --> 209             raise ValueError('exog does not have full column rank.')
#     210         self._constant, self._constant_index = has_constant(x)
#     211
#
# ValueError: exog does not have full column rank.

# %% [markdown]
# ## TNCs, bikes, scooters

# %%
# base model

mod=PanelOLS.from_formula('UPT_ADJ_log \
                    ~ VRM_ADJ_log \
                    + FARE_per_UPT_2018_log \
                    + POP_EMP_log \
                    + GAS_PRICE_2018_log \
                    + TOTAL_MED_INC_INDIV_2018_log \
                    + Tot_NonUSA_POP_pct \
                    + PCT_HH_NO_VEH \
                    + TSD_POP_PCT \
                    + EntityEffects \
                    ',data=df)
res=mod.fit()
print(res)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\data.py:39: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   new_df = df.copy().loc[self._full_index]
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\utility.py:476: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   warnings.warn(missing_value_warning_msg, MissingValueWarning)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:            UPT_ADJ_log   R-squared:                        0.5639
# Estimator:                   PanelOLS   R-squared (Between):              0.9211
# No. Observations:                4054   R-squared (Within):               0.5639
# Date:                Fri, Nov 22 2019   R-squared (Overall):              0.9208
# Time:                        16:22:15   Log-likelihood                    1248.7
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      611.81
# Entities:                         261   P-value                           0.0000
# Avg Obs:                       15.533   Distribution:                  F(8,3785)
# Min Obs:                       3.0000
# Max Obs:                       17.000   F-statistic (robust):             611.81
#                                         P-value                           0.0000
# Time periods:                      17   Distribution:                  F(8,3785)
# Avg Obs:                       238.47
# Min Obs:                       170.00
# Max Obs:                       261.00
#
#                                       Parameter Estimates
# ================================================================================================
#                               Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------------------
# VRM_ADJ_log                      0.5756     0.0130     44.146     0.0000      0.5500      0.6012
# FARE_per_UPT_2018_log           -0.6989     0.0199    -35.066     0.0000     -0.7379     -0.6598
# POP_EMP_log                      0.4580     0.0533     8.5961     0.0000      0.3536      0.5625
# GAS_PRICE_2018_log               0.2189     0.0233     9.4054     0.0000      0.1732      0.2645
# TOTAL_MED_INC_INDIV_2018_log    -0.3706     0.0536    -6.9196     0.0000     -0.4756     -0.2656
# Tot_NonUSA_POP_pct               0.0294     0.0087     3.3969     0.0007      0.0124      0.0464
# PCT_HH_NO_VEH                    0.0083     0.0031     2.6735     0.0075      0.0022      0.0144
# TSD_POP_PCT                      0.5864     0.1478     3.9681     0.0001      0.2967      0.8761
# ================================================================================================
#
# F-test for Poolability: 109.68
# P-value: 0.0000
# Distribution: F(260,3785)
#
# Included effects: Entity

# %%
# add TNC flag

mod=PanelOLS.from_formula('UPT_ADJ_log \
                    ~ VRM_ADJ_log \
                    + FARE_per_UPT_2018_log \
                    + POP_EMP_log \
                    + GAS_PRICE_2018_log \
                    + TOTAL_MED_INC_INDIV_2018_log \
                    + Tot_NonUSA_POP_pct \
                    + PCT_HH_NO_VEH \
                    + TSD_POP_PCT \
                    + TNC_FLAG_BUS \
                    + TNC_FLAG_RAIL \
                    + EntityEffects \
                    ',data=df)
res=mod.fit()
print(res)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\data.py:39: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   new_df = df.copy().loc[self._full_index]
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\utility.py:476: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   warnings.warn(missing_value_warning_msg, MissingValueWarning)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:            UPT_ADJ_log   R-squared:                        0.5645
# Estimator:                   PanelOLS   R-squared (Between):              0.9340
# No. Observations:                4054   R-squared (Within):               0.5645
# Date:                Fri, Nov 22 2019   R-squared (Overall):              0.9337
# Time:                        16:22:19   Log-likelihood                    1251.3
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      490.32
# Entities:                         261   P-value                           0.0000
# Avg Obs:                       15.533   Distribution:                 F(10,3783)
# Min Obs:                       3.0000
# Max Obs:                       17.000   F-statistic (robust):             490.32
#                                         P-value                           0.0000
# Time periods:                      17   Distribution:                 F(10,3783)
# Avg Obs:                       238.47
# Min Obs:                       170.00
# Max Obs:                       261.00
#
#                                       Parameter Estimates
# ================================================================================================
#                               Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------------------
# VRM_ADJ_log                      0.5736     0.0134     42.946     0.0000      0.5474      0.5998
# FARE_per_UPT_2018_log           -0.6978     0.0201    -34.790     0.0000     -0.7371     -0.6585
# POP_EMP_log                      0.4983     0.0572     8.7080     0.0000      0.3861      0.6105
# GAS_PRICE_2018_log               0.1976     0.0265     7.4621     0.0000      0.1457      0.2495
# TOTAL_MED_INC_INDIV_2018_log    -0.3820     0.0540    -7.0726     0.0000     -0.4879     -0.2761
# Tot_NonUSA_POP_pct               0.0318     0.0088     3.6231     0.0003      0.0146      0.0490
# PCT_HH_NO_VEH                    0.0083     0.0031     2.6680     0.0077      0.0022      0.0144
# TSD_POP_PCT                      0.5662     0.1498     3.7807     0.0002      0.2726      0.8599
# TNC_FLAG_BUS                    -0.0185     0.0095    -1.9509     0.0511     -0.0371   9.148e-05
# TNC_FLAG_RAIL                    0.0110     0.0178     0.6152     0.5385     -0.0240      0.0459
# ================================================================================================
#
# F-test for Poolability: 108.86
# P-value: 0.0000
# Distribution: F(260,3783)
#
# Included effects: Entity

# %%
# add TNC flag

mod=PanelOLS.from_formula('UPT_ADJ_log \
                    ~ VRM_ADJ_log \
                    + FARE_per_UPT_2018_log \
                    + POP_EMP_log \
                    + GAS_PRICE_2018_log \
                    + TOTAL_MED_INC_INDIV_2018_log \
                    + Tot_NonUSA_POP_pct \
                    + PCT_HH_NO_VEH \
                    + TSD_POP_PCT \
                    + YEARS_SINCE_TNC_BUS \
                    + YEARS_SINCE_TNC_RAIL \
                    + EntityEffects \
                    ',data=df)
res=mod.fit()
print(res)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\data.py:39: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   new_df = df.copy().loc[self._full_index]
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\utility.py:476: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   warnings.warn(missing_value_warning_msg, MissingValueWarning)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:            UPT_ADJ_log   R-squared:                        0.5694
# Estimator:                   PanelOLS   R-squared (Between):              0.9646
# No. Observations:                4054   R-squared (Within):               0.5694
# Date:                Fri, Nov 22 2019   R-squared (Overall):              0.9642
# Time:                        16:22:20   Log-likelihood                    1274.2
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      500.16
# Entities:                         261   P-value                           0.0000
# Avg Obs:                       15.533   Distribution:                 F(10,3783)
# Min Obs:                       3.0000
# Max Obs:                       17.000   F-statistic (robust):             500.16
#                                         P-value                           0.0000
# Time periods:                      17   Distribution:                 F(10,3783)
# Avg Obs:                       238.47
# Min Obs:                       170.00
# Max Obs:                       261.00
#
#                                       Parameter Estimates
# ================================================================================================
#                               Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------------------
# VRM_ADJ_log                      0.5693     0.0132     43.199     0.0000      0.5434      0.5951
# FARE_per_UPT_2018_log           -0.6965     0.0199    -35.049     0.0000     -0.7355     -0.6575
# POP_EMP_log                      0.5736     0.0565     10.159     0.0000      0.4629      0.6843
# GAS_PRICE_2018_log               0.1685     0.0251     6.7139     0.0000      0.1193      0.2177
# TOTAL_MED_INC_INDIV_2018_log    -0.3674     0.0533    -6.8986     0.0000     -0.4718     -0.2630
# Tot_NonUSA_POP_pct               0.0367     0.0087     4.2109     0.0000      0.0196      0.0538
# PCT_HH_NO_VEH                    0.0076     0.0031     2.4735     0.0134      0.0016      0.0137
# TSD_POP_PCT                      0.5135     0.1485     3.4588     0.0005      0.2224      0.8046
# YEARS_SINCE_TNC_BUS             -0.0219     0.0034    -6.3836     0.0000     -0.0286     -0.0152
# YEARS_SINCE_TNC_RAIL             0.0066     0.0048     1.3759     0.1689     -0.0028      0.0161
# ================================================================================================
#
# F-test for Poolability: 110.64
# P-value: 0.0000
# Distribution: F(260,3783)
#
# Included effects: Entity

# %%
# add BIKE SHARE

mod=PanelOLS.from_formula('UPT_ADJ_log \
                    ~ VRM_ADJ_log \
                    + FARE_per_UPT_2018_log \
                    + POP_EMP_log \
                    + GAS_PRICE_2018_log \
                    + TOTAL_MED_INC_INDIV_2018_log \
                    + Tot_NonUSA_POP_pct \
                    + PCT_HH_NO_VEH \
                    + TSD_POP_PCT \
                    + YEARS_SINCE_TNC_BUS \
                    + YEARS_SINCE_TNC_RAIL \
                    + BIKE_SHARE_BUS \
                    + BIKE_SHARE_RAIL \
                    + EntityEffects \
                    ',data=df)
res=mod.fit()
print(res)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\data.py:39: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   new_df = df.copy().loc[self._full_index]
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\utility.py:476: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   warnings.warn(missing_value_warning_msg, MissingValueWarning)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:            UPT_ADJ_log   R-squared:                        0.5693
# Estimator:                   PanelOLS   R-squared (Between):              0.9983
# No. Observations:                3861   R-squared (Within):               0.5693
# Date:                Fri, Nov 22 2019   R-squared (Overall):              0.9983
# Time:                        16:22:24   Log-likelihood                    1247.8
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      396.90
# Entities:                         246   P-value                           0.0000
# Avg Obs:                       15.695   Distribution:                 F(12,3603)
# Min Obs:                       3.0000
# Max Obs:                       17.000   F-statistic (robust):             396.90
#                                         P-value                           0.0000
# Time periods:                      17   Distribution:                 F(12,3603)
# Avg Obs:                       227.12
# Min Obs:                       164.00
# Max Obs:                       246.00
#
#                                       Parameter Estimates
# ================================================================================================
#                               Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------------------
# VRM_ADJ_log                      0.5698     0.0139     40.896     0.0000      0.5425      0.5971
# FARE_per_UPT_2018_log           -0.7116     0.0205    -34.783     0.0000     -0.7518     -0.6715
# POP_EMP_log                      0.7584     0.0663     11.433     0.0000      0.6283      0.8885
# GAS_PRICE_2018_log               0.1505     0.0256     5.8670     0.0000      0.1002      0.2008
# TOTAL_MED_INC_INDIV_2018_log    -0.3500     0.0543    -6.4467     0.0000     -0.4565     -0.2436
# Tot_NonUSA_POP_pct               0.0326     0.0088     3.7025     0.0002      0.0153      0.0499
# PCT_HH_NO_VEH                    0.0077     0.0031     2.4494     0.0144      0.0015      0.0138
# TSD_POP_PCT                      0.6622     0.1512     4.3803     0.0000      0.3658      0.9586
# YEARS_SINCE_TNC_BUS             -0.0226     0.0041    -5.4974     0.0000     -0.0306     -0.0145
# YEARS_SINCE_TNC_RAIL             0.0023     0.0067     0.3487     0.7273     -0.0107      0.0154
# BIKE_SHARE_BUS                  -0.0272     0.0146    -1.8583     0.0632     -0.0559      0.0015
# BIKE_SHARE_RAIL                 -0.0058     0.0274    -0.2101     0.8336     -0.0596      0.0480
# ================================================================================================
#
# F-test for Poolability: 106.11
# P-value: 0.0000
# Distribution: F(245,3603)
#
# Included effects: Entity

# %%
# add SCOOTERS

mod=PanelOLS.from_formula('UPT_ADJ_log \
                    ~ VRM_ADJ_log \
                    + FARE_per_UPT_2018_log \
                    + POP_EMP_log \
                    + GAS_PRICE_2018_log \
                    + TOTAL_MED_INC_INDIV_2018_log \
                    + Tot_NonUSA_POP_pct \
                    + PCT_HH_NO_VEH \
                    + TSD_POP_PCT \
                    + YEARS_SINCE_TNC_BUS \
                    + YEARS_SINCE_TNC_RAIL \
                    + BIKE_SHARE_BUS \
                    + BIKE_SHARE_RAIL \
                    + scooter_flag_BUS \
                    + scooter_flag_RAIL \
                    + EntityEffects \
                    ',data=df)
res=mod.fit()
print(res)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\data.py:39: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   new_df = df.copy().loc[self._full_index]
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\utility.py:476: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   warnings.warn(missing_value_warning_msg, MissingValueWarning)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:            UPT_ADJ_log   R-squared:                        0.5697
# Estimator:                   PanelOLS   R-squared (Between):              0.9984
# No. Observations:                3861   R-squared (Within):               0.5697
# Date:                Fri, Nov 22 2019   R-squared (Overall):              0.9984
# Time:                        16:22:25   Log-likelihood                    1249.6
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      340.59
# Entities:                         246   P-value                           0.0000
# Avg Obs:                       15.695   Distribution:                 F(14,3601)
# Min Obs:                       3.0000
# Max Obs:                       17.000   F-statistic (robust):             340.59
#                                         P-value                           0.0000
# Time periods:                      17   Distribution:                 F(14,3601)
# Avg Obs:                       227.12
# Min Obs:                       164.00
# Max Obs:                       246.00
#
#                                       Parameter Estimates
# ================================================================================================
#                               Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------------------
# VRM_ADJ_log                      0.5696     0.0139     40.885     0.0000      0.5422      0.5969
# FARE_per_UPT_2018_log           -0.7127     0.0205    -34.828     0.0000     -0.7528     -0.6726
# POP_EMP_log                      0.7608     0.0663     11.468     0.0000      0.6307      0.8909
# GAS_PRICE_2018_log               0.1574     0.0259     6.0747     0.0000      0.1066      0.2082
# TOTAL_MED_INC_INDIV_2018_log    -0.3421     0.0545    -6.2825     0.0000     -0.4489     -0.2354
# Tot_NonUSA_POP_pct               0.0322     0.0088     3.6534     0.0003      0.0149      0.0495
# PCT_HH_NO_VEH                    0.0076     0.0031     2.4355     0.0149      0.0015      0.0138
# TSD_POP_PCT                      0.6808     0.1515     4.4942     0.0000      0.3838      0.9778
# YEARS_SINCE_TNC_BUS             -0.0204     0.0043    -4.7157     0.0000     -0.0288     -0.0119
# YEARS_SINCE_TNC_RAIL             0.0056     0.0074     0.7613     0.4465     -0.0088      0.0200
# BIKE_SHARE_BUS                  -0.0266     0.0146    -1.8161     0.0694     -0.0553      0.0021
# BIKE_SHARE_RAIL                 -0.0078     0.0275    -0.2817     0.7782     -0.0618      0.0462
# scooter_flag_BUS                -0.0489     0.0310    -1.5768     0.1149     -0.1097      0.0119
# scooter_flag_RAIL               -0.0478     0.0480    -0.9968     0.3189     -0.1419      0.0462
# ================================================================================================
#
# F-test for Poolability: 106.15
# P-value: 0.0000
# Distribution: F(245,3601)
#
# Included effects: Entity

# %%
# add dock count

mod=PanelOLS.from_formula('UPT_ADJ_log \
                    ~ VRM_ADJ_log \
                    + FARE_per_UPT_2018_log \
                    + POP_EMP_log \
                    + GAS_PRICE_2018_log \
                    + TOTAL_MED_INC_INDIV_2018_log \
                    + Tot_NonUSA_POP_pct \
                    + PCT_HH_NO_VEH \
                    + TSD_POP_PCT \
                    + YEARS_SINCE_TNC_BUS \
                    + YEARS_SINCE_TNC_RAIL \
                    + dockCt_BUS \
                    + dockCt_RAIL \
                    + scooter_flag_BUS \
                    + scooter_flag_RAIL \
                    + EntityEffects \
                    ',data=df)
res=mod.fit()
print(res)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\data.py:39: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   new_df = df.copy().loc[self._full_index]
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\utility.py:476: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   warnings.warn(missing_value_warning_msg, MissingValueWarning)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:            UPT_ADJ_log   R-squared:                        0.5698
# Estimator:                   PanelOLS   R-squared (Between):              0.9679
# No. Observations:                4054   R-squared (Within):               0.5698
# Date:                Fri, Nov 22 2019   R-squared (Overall):              0.9675
# Time:                        16:22:27   Log-likelihood                    1276.3
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      357.53
# Entities:                         261   P-value                           0.0000
# Avg Obs:                       15.533   Distribution:                 F(14,3779)
# Min Obs:                       3.0000
# Max Obs:                       17.000   F-statistic (robust):             357.53
#                                         P-value                           0.0000
# Time periods:                      17   Distribution:                 F(14,3779)
# Avg Obs:                       238.47
# Min Obs:                       170.00
# Max Obs:                       261.00
#
#                                       Parameter Estimates
# ================================================================================================
#                               Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------------------
# VRM_ADJ_log                      0.5696     0.0132     43.080     0.0000      0.5437      0.5955
# FARE_per_UPT_2018_log           -0.6973     0.0199    -35.070     0.0000     -0.7363     -0.6583
# POP_EMP_log                      0.5758     0.0566     10.175     0.0000      0.4648      0.6867
# GAS_PRICE_2018_log               0.1756     0.0254     6.9218     0.0000      0.1259      0.2253
# TOTAL_MED_INC_INDIV_2018_log    -0.3586     0.0535    -6.7079     0.0000     -0.4634     -0.2538
# Tot_NonUSA_POP_pct               0.0364     0.0087     4.1769     0.0000      0.0193      0.0535
# PCT_HH_NO_VEH                    0.0076     0.0031     2.4594     0.0140      0.0015      0.0137
# TSD_POP_PCT                      0.5321     0.1489     3.5733     0.0004      0.2402      0.8241
# YEARS_SINCE_TNC_BUS             -0.0197     0.0039    -5.0039     0.0000     -0.0275     -0.0120
# YEARS_SINCE_TNC_RAIL             0.0070     0.0066     1.0533     0.2923     -0.0060      0.0199
# dockCt_BUS                    6.449e-06  9.377e-05     0.0688     0.9452     -0.0002      0.0002
# dockCt_RAIL                   7.751e-05     0.0001     0.7115     0.4768     -0.0001      0.0003
# scooter_flag_BUS                -0.0487     0.0310    -1.5709     0.1163     -0.1095      0.0121
# scooter_flag_RAIL               -0.0460     0.0472    -0.9748     0.3297     -0.1386      0.0466
# ================================================================================================
#
# F-test for Poolability: 110.57
# P-value: 0.0000
# Distribution: F(260,3779)
#
# Included effects: Entity

# %%
# current favorite

mod=PanelOLS.from_formula('UPT_ADJ_log \
                    ~ VRM_ADJ_log \
                    + FARE_per_UPT_2018_log \
                    + POP_EMP_log \
                    + GAS_PRICE_2018_log \
                    + TOTAL_MED_INC_INDIV_2018_log \
                    + Tot_NonUSA_POP_pct \
                    + PCT_HH_NO_VEH \
                    + TSD_POP_PCT \
                    + YEARS_SINCE_TNC_BUS \
                    + YEARS_SINCE_TNC_RAIL \
                    + BIKE_SHARE_BUS \
                    + BIKE_SHARE_RAIL \
                    + scooter_flag_BUS \
                    + scooter_flag_RAIL \
                    + EntityEffects \
                    ',data=df)
res=mod.fit()
print(res)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\data.py:39: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   new_df = df.copy().loc[self._full_index]
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\utility.py:476: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   warnings.warn(missing_value_warning_msg, MissingValueWarning)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:            UPT_ADJ_log   R-squared:                        0.5697
# Estimator:                   PanelOLS   R-squared (Between):              0.9984
# No. Observations:                3861   R-squared (Within):               0.5697
# Date:                Fri, Nov 22 2019   R-squared (Overall):              0.9984
# Time:                        16:22:29   Log-likelihood                    1249.6
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      340.59
# Entities:                         246   P-value                           0.0000
# Avg Obs:                       15.695   Distribution:                 F(14,3601)
# Min Obs:                       3.0000
# Max Obs:                       17.000   F-statistic (robust):             340.59
#                                         P-value                           0.0000
# Time periods:                      17   Distribution:                 F(14,3601)
# Avg Obs:                       227.12
# Min Obs:                       164.00
# Max Obs:                       246.00
#
#                                       Parameter Estimates
# ================================================================================================
#                               Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------------------
# VRM_ADJ_log                      0.5696     0.0139     40.885     0.0000      0.5422      0.5969
# FARE_per_UPT_2018_log           -0.7127     0.0205    -34.828     0.0000     -0.7528     -0.6726
# POP_EMP_log                      0.7608     0.0663     11.468     0.0000      0.6307      0.8909
# GAS_PRICE_2018_log               0.1574     0.0259     6.0747     0.0000      0.1066      0.2082
# TOTAL_MED_INC_INDIV_2018_log    -0.3421     0.0545    -6.2825     0.0000     -0.4489     -0.2354
# Tot_NonUSA_POP_pct               0.0322     0.0088     3.6534     0.0003      0.0149      0.0495
# PCT_HH_NO_VEH                    0.0076     0.0031     2.4355     0.0149      0.0015      0.0138
# TSD_POP_PCT                      0.6808     0.1515     4.4942     0.0000      0.3838      0.9778
# YEARS_SINCE_TNC_BUS             -0.0204     0.0043    -4.7157     0.0000     -0.0288     -0.0119
# YEARS_SINCE_TNC_RAIL             0.0056     0.0074     0.7613     0.4465     -0.0088      0.0200
# BIKE_SHARE_BUS                  -0.0266     0.0146    -1.8161     0.0694     -0.0553      0.0021
# BIKE_SHARE_RAIL                 -0.0078     0.0275    -0.2817     0.7782     -0.0618      0.0462
# scooter_flag_BUS                -0.0489     0.0310    -1.5768     0.1149     -0.1097      0.0119
# scooter_flag_RAIL               -0.0478     0.0480    -0.9968     0.3189     -0.1419      0.0462
# ================================================================================================
#
# F-test for Poolability: 106.15
# P-value: 0.0000
# Distribution: F(245,3601)
#
# Included effects: Entity

# %%
# bike share plus scooters for rail
df['BIKE_SCOOTER_RAIL'] = df['BIKE_SHARE_RAIL'] + df['scooter_flag_RAIL']

mod=PanelOLS.from_formula('UPT_ADJ_log \
                    ~ VRM_ADJ_log \
                    + FARE_per_UPT_2018_log \
                    + POP_EMP_log \
                    + GAS_PRICE_2018_log \
                    + TOTAL_MED_INC_INDIV_2018_log \
                    + Tot_NonUSA_POP_pct \
                    + PCT_HH_NO_VEH \
                    + TSD_POP_PCT \
                    + YEARS_SINCE_TNC_BUS \
                    + YEARS_SINCE_TNC_RAIL \
                    + BIKE_SHARE_BUS \
                    + scooter_flag_BUS \
                    + BIKE_SCOOTER_RAIL \
                    + EntityEffects \
                    ',data=df)
res=mod.fit()
print(res)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\data.py:39: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   new_df = df.copy().loc[self._full_index]
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\utility.py:476: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   warnings.warn(missing_value_warning_msg, MissingValueWarning)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:            UPT_ADJ_log   R-squared:                        0.5697
# Estimator:                   PanelOLS   R-squared (Between):              0.9984
# No. Observations:                3861   R-squared (Within):               0.5697
# Date:                Fri, Nov 22 2019   R-squared (Overall):              0.9984
# Time:                        16:22:31   Log-likelihood                    1249.3
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      366.78
# Entities:                         246   P-value                           0.0000
# Avg Obs:                       15.695   Distribution:                 F(13,3602)
# Min Obs:                       3.0000
# Max Obs:                       17.000   F-statistic (robust):             366.78
#                                         P-value                           0.0000
# Time periods:                      17   Distribution:                 F(13,3602)
# Avg Obs:                       227.12
# Min Obs:                       164.00
# Max Obs:                       246.00
#
#                                       Parameter Estimates
# ================================================================================================
#                               Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------------------
# VRM_ADJ_log                      0.5700     0.0139     40.957     0.0000      0.5427      0.5973
# FARE_per_UPT_2018_log           -0.7122     0.0205    -34.824     0.0000     -0.7523     -0.6721
# POP_EMP_log                      0.7606     0.0663     11.465     0.0000      0.6305      0.8906
# GAS_PRICE_2018_log               0.1557     0.0258     6.0322     0.0000      0.1051      0.2063
# TOTAL_MED_INC_INDIV_2018_log    -0.3447     0.0543    -6.3440     0.0000     -0.4513     -0.2382
# Tot_NonUSA_POP_pct               0.0323     0.0088     3.6710     0.0002      0.0151      0.0496
# PCT_HH_NO_VEH                    0.0076     0.0031     2.4266     0.0153      0.0015      0.0138
# TSD_POP_PCT                      0.6761     0.1513     4.4674     0.0000      0.3794      0.9728
# YEARS_SINCE_TNC_BUS             -0.0205     0.0043    -4.7471     0.0000     -0.0290     -0.0120
# YEARS_SINCE_TNC_RAIL             0.0053     0.0073     0.7236     0.4694     -0.0091      0.0197
# BIKE_SHARE_BUS                  -0.0267     0.0146    -1.8230     0.0684     -0.0554      0.0020
# scooter_flag_BUS                -0.0486     0.0310    -1.5660     0.1174     -0.1094      0.0122
# BIKE_SCOOTER_RAIL               -0.0169     0.0247    -0.6820     0.4953     -0.0654      0.0316
# ================================================================================================
#
# F-test for Poolability: 106.55
# P-value: 0.0000
# Distribution: F(245,3602)
#
# Included effects: Entity

# %%
# different spec of bike and scooter
df['BIKE_SCOOTER_SCOOTER_RAIL'] = df['BIKE_SHARE_RAIL'] + df['scooter_flag_RAIL'] + df['scooter_flag_RAIL']

mod=PanelOLS.from_formula('UPT_ADJ_log \
                    ~ VRM_ADJ_log \
                    + FARE_per_UPT_2018_log \
                    + POP_EMP_log \
                    + GAS_PRICE_2018_log \
                    + TOTAL_MED_INC_INDIV_2018_log \
                    + Tot_NonUSA_POP_pct \
                    + PCT_HH_NO_VEH \
                    + TSD_POP_PCT \
                    + YEARS_SINCE_TNC_BUS \
                    + YEARS_SINCE_TNC_RAIL \
                    + BIKE_SHARE_BUS \
                    + scooter_flag_BUS \
                    + BIKE_SCOOTER_SCOOTER_RAIL \
                    + EntityEffects \
                    ',data=df)
res=mod.fit()
print(res)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\data.py:39: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   new_df = df.copy().loc[self._full_index]
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\utility.py:476: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   warnings.warn(missing_value_warning_msg, MissingValueWarning)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:            UPT_ADJ_log   R-squared:                        0.5697
# Estimator:                   PanelOLS   R-squared (Between):              0.9984
# No. Observations:                3861   R-squared (Within):               0.5697
# Date:                Fri, Nov 22 2019   R-squared (Overall):              0.9984
# Time:                        16:22:36   Log-likelihood                    1249.5
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      366.85
# Entities:                         246   P-value                           0.0000
# Avg Obs:                       15.695   Distribution:                 F(13,3602)
# Min Obs:                       3.0000
# Max Obs:                       17.000   F-statistic (robust):             366.85
#                                         P-value                           0.0000
# Time periods:                      17   Distribution:                 F(13,3602)
# Avg Obs:                       227.12
# Min Obs:                       164.00
# Max Obs:                       246.00
#
#                                       Parameter Estimates
# ================================================================================================
#                               Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------------------
# VRM_ADJ_log                      0.5700     0.0139     40.999     0.0000      0.5427      0.5972
# FARE_per_UPT_2018_log           -0.7123     0.0204    -34.846     0.0000     -0.7523     -0.6722
# POP_EMP_log                      0.7611     0.0663     11.474     0.0000      0.6310      0.8911
# GAS_PRICE_2018_log               0.1564     0.0258     6.0579     0.0000      0.1058      0.2071
# TOTAL_MED_INC_INDIV_2018_log    -0.3437     0.0543    -6.3233     0.0000     -0.4502     -0.2371
# Tot_NonUSA_POP_pct               0.0323     0.0088     3.6667     0.0002      0.0150      0.0496
# PCT_HH_NO_VEH                    0.0076     0.0031     2.4277     0.0152      0.0015      0.0138
# TSD_POP_PCT                      0.6785     0.1514     4.4819     0.0000      0.3817      0.9753
# YEARS_SINCE_TNC_BUS             -0.0205     0.0043    -4.7405     0.0000     -0.0289     -0.0120
# YEARS_SINCE_TNC_RAIL             0.0063     0.0072     0.8797     0.3791     -0.0078      0.0204
# BIKE_SHARE_BUS                  -0.0267     0.0146    -1.8215     0.0686     -0.0553      0.0020
# scooter_flag_BUS                -0.0487     0.0310    -1.5704     0.1164     -0.1095      0.0121
# BIKE_SCOOTER_SCOOTER_RAIL       -0.0170     0.0188    -0.9045     0.3658     -0.0540      0.0199
# ================================================================================================
#
# F-test for Poolability: 107.06
# P-value: 0.0000
# Distribution: F(245,3602)
#
# Included effects: Entity

# %% [markdown]
# ## Maintenance and restructures

# %%
# base model

mod=PanelOLS.from_formula('UPT_ADJ_log \
                    ~ VRM_ADJ_log \
                    + FARE_per_UPT_2018_log \
                    + POP_EMP_log \
                    + GAS_PRICE_2018_log \
                    + TOTAL_MED_INC_INDIV_2018_log \
                    + Tot_NonUSA_POP_pct \
                    + PCT_HH_NO_VEH \
                    + TSD_POP_PCT \
                    + YEARS_SINCE_TNC_BUS \
                    + YEARS_SINCE_TNC_RAIL \
                    + BIKE_SHARE_BUS \
                    + scooter_flag_BUS \
                    + BIKE_SCOOTER_SCOOTER_RAIL \
                    + EntityEffects \
                    ',data=df)
res=mod.fit()
print(res)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\data.py:39: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   new_df = df.copy().loc[self._full_index]
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\utility.py:476: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   warnings.warn(missing_value_warning_msg, MissingValueWarning)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:            UPT_ADJ_log   R-squared:                        0.5697
# Estimator:                   PanelOLS   R-squared (Between):              0.9984
# No. Observations:                3861   R-squared (Within):               0.5697
# Date:                Fri, Nov 22 2019   R-squared (Overall):              0.9984
# Time:                        16:22:40   Log-likelihood                    1249.5
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      366.85
# Entities:                         246   P-value                           0.0000
# Avg Obs:                       15.695   Distribution:                 F(13,3602)
# Min Obs:                       3.0000
# Max Obs:                       17.000   F-statistic (robust):             366.85
#                                         P-value                           0.0000
# Time periods:                      17   Distribution:                 F(13,3602)
# Avg Obs:                       227.12
# Min Obs:                       164.00
# Max Obs:                       246.00
#
#                                       Parameter Estimates
# ================================================================================================
#                               Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------------------
# VRM_ADJ_log                      0.5700     0.0139     40.999     0.0000      0.5427      0.5972
# FARE_per_UPT_2018_log           -0.7123     0.0204    -34.846     0.0000     -0.7523     -0.6722
# POP_EMP_log                      0.7611     0.0663     11.474     0.0000      0.6310      0.8911
# GAS_PRICE_2018_log               0.1564     0.0258     6.0579     0.0000      0.1058      0.2071
# TOTAL_MED_INC_INDIV_2018_log    -0.3437     0.0543    -6.3233     0.0000     -0.4502     -0.2371
# Tot_NonUSA_POP_pct               0.0323     0.0088     3.6667     0.0002      0.0150      0.0496
# PCT_HH_NO_VEH                    0.0076     0.0031     2.4277     0.0152      0.0015      0.0138
# TSD_POP_PCT                      0.6785     0.1514     4.4819     0.0000      0.3817      0.9753
# YEARS_SINCE_TNC_BUS             -0.0205     0.0043    -4.7405     0.0000     -0.0289     -0.0120
# YEARS_SINCE_TNC_RAIL             0.0063     0.0072     0.8797     0.3791     -0.0078      0.0204
# BIKE_SHARE_BUS                  -0.0267     0.0146    -1.8215     0.0686     -0.0553      0.0020
# scooter_flag_BUS                -0.0487     0.0310    -1.5704     0.1164     -0.1095      0.0121
# BIKE_SCOOTER_SCOOTER_RAIL       -0.0170     0.0188    -0.9045     0.3658     -0.0540      0.0199
# ================================================================================================
#
# F-test for Poolability: 107.06
# P-value: 0.0000
# Distribution: F(245,3602)
#
# Included effects: Entity

# %%
# add bus restructures

mod=PanelOLS.from_formula('UPT_ADJ_log \
                    ~ VRM_ADJ_log \
                    + FARE_per_UPT_2018_log \
                    + POP_EMP_log \
                    + GAS_PRICE_2018_log \
                    + TOTAL_MED_INC_INDIV_2018_log \
                    + Tot_NonUSA_POP_pct \
                    + PCT_HH_NO_VEH \
                    + TSD_POP_PCT \
                    + YEARS_SINCE_TNC_BUS \
                    + YEARS_SINCE_TNC_RAIL \
                    + BIKE_SHARE_BUS \
                    + scooter_flag_BUS \
                    + BIKE_SCOOTER_SCOOTER_RAIL \
                    + RESTRUCTURE \
                    + EntityEffects \
                    ',data=df)
res=mod.fit()
print(res)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\data.py:39: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   new_df = df.copy().loc[self._full_index]
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\utility.py:476: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   warnings.warn(missing_value_warning_msg, MissingValueWarning)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:            UPT_ADJ_log   R-squared:                        0.5701
# Estimator:                   PanelOLS   R-squared (Between):              0.9984
# No. Observations:                3861   R-squared (Within):               0.5701
# Date:                Fri, Nov 22 2019   R-squared (Overall):              0.9984
# Time:                        16:22:43   Log-likelihood                    1251.1
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      341.04
# Entities:                         246   P-value                           0.0000
# Avg Obs:                       15.695   Distribution:                 F(14,3601)
# Min Obs:                       3.0000
# Max Obs:                       17.000   F-statistic (robust):             341.04
#                                         P-value                           0.0000
# Time periods:                      17   Distribution:                 F(14,3601)
# Avg Obs:                       227.12
# Min Obs:                       164.00
# Max Obs:                       246.00
#
#                                       Parameter Estimates
# ================================================================================================
#                               Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------------------
# VRM_ADJ_log                      0.5698     0.0139     40.999     0.0000      0.5426      0.5971
# FARE_per_UPT_2018_log           -0.7121     0.0204    -34.846     0.0000     -0.7521     -0.6720
# POP_EMP_log                      0.7664     0.0664     11.545     0.0000      0.6362      0.8966
# GAS_PRICE_2018_log               0.1551     0.0258     6.0035     0.0000      0.1044      0.2057
# TOTAL_MED_INC_INDIV_2018_log    -0.3485     0.0544    -6.4052     0.0000     -0.4552     -0.2418
# Tot_NonUSA_POP_pct               0.0327     0.0088     3.7090     0.0002      0.0154      0.0499
# PCT_HH_NO_VEH                    0.0075     0.0031     2.3951     0.0167      0.0014      0.0137
# TSD_POP_PCT                      0.6892     0.1515     4.5500     0.0000      0.3922      0.9862
# YEARS_SINCE_TNC_BUS             -0.0202     0.0043    -4.6702     0.0000     -0.0286     -0.0117
# YEARS_SINCE_TNC_RAIL             0.0062     0.0072     0.8676     0.3857     -0.0079      0.0203
# BIKE_SHARE_BUS                  -0.0261     0.0146    -1.7836     0.0746     -0.0548      0.0026
# scooter_flag_BUS                -0.0466     0.0310    -1.5028     0.1330     -0.1075      0.0142
# BIKE_SCOOTER_SCOOTER_RAIL       -0.0171     0.0188    -0.9087     0.3635     -0.0541      0.0198
# RESTRUCTURE                     -0.0944     0.0551    -1.7143     0.0866     -0.2024      0.0136
# ================================================================================================
#
# F-test for Poolability: 107.08
# P-value: 0.0000
# Distribution: F(245,3601)
#
# Included effects: Entity

# %%
# add maintenance issues

mod=PanelOLS.from_formula('UPT_ADJ_log \
                    ~ VRM_ADJ_log \
                    + FARE_per_UPT_2018_log \
                    + POP_EMP_log \
                    + GAS_PRICE_2018_log \
                    + TOTAL_MED_INC_INDIV_2018_log \
                    + Tot_NonUSA_POP_pct \
                    + PCT_HH_NO_VEH \
                    + TSD_POP_PCT \
                    + YEARS_SINCE_TNC_BUS \
                    + YEARS_SINCE_TNC_RAIL \
                    + BIKE_SHARE_BUS \
                    + scooter_flag_BUS \
                    + BIKE_SCOOTER_SCOOTER_RAIL \
                    + MAINTENANCE \
                    + EntityEffects \
                    ',data=df)
res=mod.fit()
print(res)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\data.py:39: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   new_df = df.copy().loc[self._full_index]
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\utility.py:476: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   warnings.warn(missing_value_warning_msg, MissingValueWarning)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:            UPT_ADJ_log   R-squared:                        0.5706
# Estimator:                   PanelOLS   R-squared (Between):              0.9984
# No. Observations:                3861   R-squared (Within):               0.5706
# Date:                Fri, Nov 22 2019   R-squared (Overall):              0.9984
# Time:                        16:22:47   Log-likelihood                    1253.6
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      341.83
# Entities:                         246   P-value                           0.0000
# Avg Obs:                       15.695   Distribution:                 F(14,3601)
# Min Obs:                       3.0000
# Max Obs:                       17.000   F-statistic (robust):             341.83
#                                         P-value                           0.0000
# Time periods:                      17   Distribution:                 F(14,3601)
# Avg Obs:                       227.12
# Min Obs:                       164.00
# Max Obs:                       246.00
#
#                                       Parameter Estimates
# ================================================================================================
#                               Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------------------
# VRM_ADJ_log                      0.5689     0.0139     40.946     0.0000      0.5417      0.5961
# FARE_per_UPT_2018_log           -0.7114     0.0204    -34.832     0.0000     -0.7514     -0.6714
# POP_EMP_log                      0.7634     0.0663     11.519     0.0000      0.6334      0.8933
# GAS_PRICE_2018_log               0.1552     0.0258     6.0165     0.0000      0.1047      0.2058
# TOTAL_MED_INC_INDIV_2018_log    -0.3426     0.0543    -6.3098     0.0000     -0.4491     -0.2362
# Tot_NonUSA_POP_pct               0.0331     0.0088     3.7609     0.0002      0.0159      0.0504
# PCT_HH_NO_VEH                    0.0076     0.0031     2.4264     0.0153      0.0015      0.0138
# TSD_POP_PCT                      0.6697     0.1513     4.4274     0.0000      0.3732      0.9663
# YEARS_SINCE_TNC_BUS             -0.0206     0.0043    -4.7693     0.0000     -0.0290     -0.0121
# YEARS_SINCE_TNC_RAIL             0.0097     0.0073     1.3295     0.1838     -0.0046      0.0240
# BIKE_SHARE_BUS                  -0.0271     0.0146    -1.8529     0.0640     -0.0558      0.0016
# scooter_flag_BUS                -0.0487     0.0310    -1.5712     0.1162     -0.1094      0.0121
# BIKE_SCOOTER_SCOOTER_RAIL       -0.0218     0.0189    -1.1553     0.2481     -0.0589      0.0152
# MAINTENANCE                     -0.2931     0.1054    -2.7801     0.0055     -0.4998     -0.0864
# ================================================================================================
#
# F-test for Poolability: 107.26
# P-value: 0.0000
# Distribution: F(245,3601)
#
# Included effects: Entity

# %%
# restructure and maintenance


mod=PanelOLS.from_formula('UPT_ADJ_log \
                    ~ VRM_ADJ_log \
                    + FARE_per_UPT_2018_log \
                    + POP_EMP_log \
                    + GAS_PRICE_2018_log \
                    + TOTAL_MED_INC_INDIV_2018_log \
                    + Tot_NonUSA_POP_pct \
                    + PCT_HH_NO_VEH \
                    + TSD_POP_PCT \
                    + YEARS_SINCE_TNC_BUS \
                    + YEARS_SINCE_TNC_RAIL \
                    + BIKE_SHARE_BUS \
                    + scooter_flag_BUS \
                    + BIKE_SCOOTER_SCOOTER_RAIL \
                    + MAINTENANCE \
                    + RESTRUCTURE \
                    + EntityEffects \
                    ',data=df)
res=mod.fit()
print(res)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\data.py:39: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   new_df = df.copy().loc[self._full_index]
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\utility.py:476: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   warnings.warn(missing_value_warning_msg, MissingValueWarning)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:            UPT_ADJ_log   R-squared:                        0.5710
# Estimator:                   PanelOLS   R-squared (Between):              0.9984
# No. Observations:                3861   R-squared (Within):               0.5710
# Date:                Fri, Nov 22 2019   R-squared (Overall):              0.9984
# Time:                        16:22:50   Log-likelihood                    1255.2
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      319.42
# Entities:                         246   P-value                           0.0000
# Avg Obs:                       15.695   Distribution:                 F(15,3600)
# Min Obs:                       3.0000
# Max Obs:                       17.000   F-statistic (robust):             319.42
#                                         P-value                           0.0000
# Time periods:                      17   Distribution:                 F(15,3600)
# Avg Obs:                       227.12
# Min Obs:                       164.00
# Max Obs:                       246.00
#
#                                       Parameter Estimates
# ================================================================================================
#                               Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------------------
# VRM_ADJ_log                      0.5688     0.0139     40.946     0.0000      0.5415      0.5960
# FARE_per_UPT_2018_log           -0.7112     0.0204    -34.832     0.0000     -0.7512     -0.6712
# POP_EMP_log                      0.7687     0.0663     11.590     0.0000      0.6387      0.8988
# GAS_PRICE_2018_log               0.1539     0.0258     5.9619     0.0000      0.1033      0.2045
# TOTAL_MED_INC_INDIV_2018_log    -0.3475     0.0544    -6.3921     0.0000     -0.4540     -0.2409
# Tot_NonUSA_POP_pct               0.0335     0.0088     3.8036     0.0001      0.0162      0.0508
# PCT_HH_NO_VEH                    0.0075     0.0031     2.3937     0.0167      0.0014      0.0136
# TSD_POP_PCT                      0.6805     0.1514     4.4958     0.0000      0.3837      0.9773
# YEARS_SINCE_TNC_BUS             -0.0203     0.0043    -4.6988     0.0000     -0.0287     -0.0118
# YEARS_SINCE_TNC_RAIL             0.0096     0.0073     1.3183     0.1875     -0.0047      0.0239
# BIKE_SHARE_BUS                  -0.0265     0.0146    -1.8149     0.0696     -0.0552      0.0021
# scooter_flag_BUS                -0.0466     0.0310    -1.5033     0.1329     -0.1074      0.0142
# BIKE_SCOOTER_SCOOTER_RAIL       -0.0219     0.0189    -1.1599     0.2462     -0.0590      0.0151
# MAINTENANCE                     -0.2935     0.1054    -2.7849     0.0054     -0.5001     -0.0869
# RESTRUCTURE                     -0.0948     0.0550    -1.7225     0.0851     -0.2027      0.0131
# ================================================================================================
#
# F-test for Poolability: 107.29
# P-value: 0.0000
# Distribution: F(245,3600)
#
# Included effects: Entity

# %%
# Split NYC from WMATA on maintenance
# NYC is prefectly correlated with something?

mod=PanelOLS.from_formula('UPT_ADJ_log \
                    ~ VRM_ADJ_log \
                    + FARE_per_UPT_2018_log \
                    + POP_EMP_log \
                    + GAS_PRICE_2018_log \
                    + TOTAL_MED_INC_INDIV_2018_log \
                    + Tot_NonUSA_POP_pct \
                    + PCT_HH_NO_VEH \
                    + TSD_POP_PCT \
                    + YEARS_SINCE_TNC_BUS \
                    + YEARS_SINCE_TNC_RAIL \
                    + BIKE_SHARE_BUS \
                    + scooter_flag_BUS \
                    + BIKE_SCOOTER_SCOOTER_RAIL \
                    + MAINTENANCE_WMATA \
                    + MAINTENANCE_NYC \
                    + EntityEffects \
                    ',data=df)
res=mod.fit()
print(res)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\data.py:39: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   new_df = df.copy().loc[self._full_index]
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\utility.py:476: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   warnings.warn(missing_value_warning_msg, MissingValueWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-56-e90a7bc64791> in <module>()
#       2 # NYC is prefectly correlated with something?
#       3
# ----> 4 mod=PanelOLS.from_formula('UPT_ADJ_log                     ~ VRM_ADJ_log                     + FARE_per_UPT_2018_log                     + POP_EMP_log                     + GAS_PRICE_2018_log                     + TOTAL_MED_INC_INDIV_2018_log                     + Tot_NonUSA_POP_pct                     + PCT_HH_NO_VEH                     + TSD_POP_PCT                     + YEARS_SINCE_TNC_BUS                     + YEARS_SINCE_TNC_RAIL                     + BIKE_SHARE_BUS                     + scooter_flag_BUS                     + BIKE_SCOOTER_SCOOTER_RAIL                     + MAINTENANCE_WMATA                     + MAINTENANCE_NYC                     + EntityEffects                     ',data=df)
#       5 res=mod.fit()
#       6 print(res)
#
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\model.py in from_formula(cls, formula, data, weights, other_effects)
#     734                                     return_type='dataframe', NA_action=na_action)
#     735         mod = cls(dependent, exog, entity_effects=entity_effect,
# --> 736                   time_effects=time_effect, weights=weights, other_effects=other_effects)
#     737         mod.formula = formula
#     738         return mod
#
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\model.py in __init__(self, dependent, exog, weights, entity_effects, time_effects, other_effects)
#     598     def __init__(self, dependent, exog, *, weights=None, entity_effects=False, time_effects=False,
#     599                  other_effects=None):
# --> 600         super(PanelOLS, self).__init__(dependent, exog, weights=weights)
#     601
#     602         self._entity_effects = entity_effects
#
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\model.py in __init__(self, dependent, exog, weights)
#      86                                                  DriscollKraay, ACCovariance)
#      87
# ---> 88         self._validate_data()
#      89
#      90     def __str__(self):
#
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\model.py in _validate_data(self)
#     207
#     208         if matrix_rank(x) < x.shape[1]:
# --> 209             raise ValueError('exog does not have full column rank.')
#     210         self._constant, self._constant_index = has_constant(x)
#     211
#
# ValueError: exog does not have full column rank.

# %%
# Maintenance with just WMATA

mod=PanelOLS.from_formula('UPT_ADJ_log \
                    ~ VRM_ADJ_log \
                    + FARE_per_UPT_2018_log \
                    + POP_EMP_log \
                    + GAS_PRICE_2018_log \
                    + TOTAL_MED_INC_INDIV_2018_log \
                    + Tot_NonUSA_POP_pct \
                    + PCT_HH_NO_VEH \
                    + TSD_POP_PCT \
                    + YEARS_SINCE_TNC_BUS \
                    + YEARS_SINCE_TNC_RAIL \
                    + BIKE_SHARE_BUS \
                    + scooter_flag_BUS \
                    + BIKE_SCOOTER_SCOOTER_RAIL \
                    + MAINTENANCE_WMATA \
                    + EntityEffects \
                    ',data=df)
res=mod.fit()
print(res)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\data.py:39: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   new_df = df.copy().loc[self._full_index]
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\utility.py:476: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   warnings.warn(missing_value_warning_msg, MissingValueWarning)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:            UPT_ADJ_log   R-squared:                        0.5702
# Estimator:                   PanelOLS   R-squared (Between):              0.9984
# No. Observations:                3861   R-squared (Within):               0.5702
# Date:                Fri, Nov 22 2019   R-squared (Overall):              0.9984
# Time:                        16:22:56   Log-likelihood                    1251.7
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      341.24
# Entities:                         246   P-value                           0.0000
# Avg Obs:                       15.695   Distribution:                 F(14,3601)
# Min Obs:                       3.0000
# Max Obs:                       17.000   F-statistic (robust):             341.24
#                                         P-value                           0.0000
# Time periods:                      17   Distribution:                 F(14,3601)
# Avg Obs:                       227.12
# Min Obs:                       164.00
# Max Obs:                       246.00
#
#                                       Parameter Estimates
# ================================================================================================
#                               Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------------------
# VRM_ADJ_log                      0.5692     0.0139     40.947     0.0000      0.5419      0.5965
# FARE_per_UPT_2018_log           -0.7118     0.0204    -34.838     0.0000     -0.7519     -0.6718
# POP_EMP_log                      0.7610     0.0663     11.477     0.0000      0.6310      0.8910
# GAS_PRICE_2018_log               0.1556     0.0258     6.0265     0.0000      0.1050      0.2062
# TOTAL_MED_INC_INDIV_2018_log    -0.3447     0.0543    -6.3456     0.0000     -0.4513     -0.2382
# Tot_NonUSA_POP_pct               0.0323     0.0088     3.6640     0.0003      0.0150      0.0495
# PCT_HH_NO_VEH                    0.0076     0.0031     2.4357     0.0149      0.0015      0.0138
# TSD_POP_PCT                      0.6707     0.1514     4.4311     0.0000      0.3739      0.9675
# YEARS_SINCE_TNC_BUS             -0.0205     0.0043    -4.7554     0.0000     -0.0290     -0.0121
# YEARS_SINCE_TNC_RAIL             0.0095     0.0074     1.2964     0.1949     -0.0049      0.0240
# BIKE_SHARE_BUS                  -0.0267     0.0146    -1.8277     0.0677     -0.0554      0.0019
# scooter_flag_BUS                -0.0485     0.0310    -1.5647     0.1177     -0.1093      0.0123
# BIKE_SCOOTER_SCOOTER_RAIL       -0.0214     0.0190    -1.1310     0.2581     -0.0586      0.0157
# MAINTENANCE_WMATA               -0.2720     0.1329    -2.0461     0.0408     -0.5326     -0.0114
# ================================================================================================
#
# F-test for Poolability: 107.14
# P-value: 0.0000
# Distribution: F(245,3601)
#
# Included effects: Entity

# %% [markdown]
# ## try time effects

# %%
# no time effects

mod=PanelOLS.from_formula('UPT_ADJ_log \
                    ~ VRM_ADJ_log \
                    + FARE_per_UPT_2018_log \
                    + POP_EMP_log \
                    + GAS_PRICE_2018_log \
                    + TOTAL_MED_INC_INDIV_2018_log \
                    + Tot_NonUSA_POP_pct \
                    + PCT_HH_NO_VEH \
                    + TSD_POP_PCT \
                    + YEARS_SINCE_TNC_BUS \
                    + YEARS_SINCE_TNC_RAIL \
                    + BIKE_SHARE_BUS \
                    + scooter_flag_BUS \
                    + BIKE_SCOOTER_SCOOTER_RAIL \
                    + MAINTENANCE \
                    + EntityEffects \
                    ',data=df)
res=mod.fit()
print(res)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\data.py:39: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   new_df = df.copy().loc[self._full_index]
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\utility.py:476: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   warnings.warn(missing_value_warning_msg, MissingValueWarning)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:            UPT_ADJ_log   R-squared:                        0.5706
# Estimator:                   PanelOLS   R-squared (Between):              0.9984
# No. Observations:                3861   R-squared (Within):               0.5706
# Date:                Fri, Nov 22 2019   R-squared (Overall):              0.9984
# Time:                        16:23:00   Log-likelihood                    1253.6
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      341.83
# Entities:                         246   P-value                           0.0000
# Avg Obs:                       15.695   Distribution:                 F(14,3601)
# Min Obs:                       3.0000
# Max Obs:                       17.000   F-statistic (robust):             341.83
#                                         P-value                           0.0000
# Time periods:                      17   Distribution:                 F(14,3601)
# Avg Obs:                       227.12
# Min Obs:                       164.00
# Max Obs:                       246.00
#
#                                       Parameter Estimates
# ================================================================================================
#                               Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------------------
# VRM_ADJ_log                      0.5689     0.0139     40.946     0.0000      0.5417      0.5961
# FARE_per_UPT_2018_log           -0.7114     0.0204    -34.832     0.0000     -0.7514     -0.6714
# POP_EMP_log                      0.7634     0.0663     11.519     0.0000      0.6334      0.8933
# GAS_PRICE_2018_log               0.1552     0.0258     6.0165     0.0000      0.1047      0.2058
# TOTAL_MED_INC_INDIV_2018_log    -0.3426     0.0543    -6.3098     0.0000     -0.4491     -0.2362
# Tot_NonUSA_POP_pct               0.0331     0.0088     3.7609     0.0002      0.0159      0.0504
# PCT_HH_NO_VEH                    0.0076     0.0031     2.4264     0.0153      0.0015      0.0138
# TSD_POP_PCT                      0.6697     0.1513     4.4274     0.0000      0.3732      0.9663
# YEARS_SINCE_TNC_BUS             -0.0206     0.0043    -4.7693     0.0000     -0.0290     -0.0121
# YEARS_SINCE_TNC_RAIL             0.0097     0.0073     1.3295     0.1838     -0.0046      0.0240
# BIKE_SHARE_BUS                  -0.0271     0.0146    -1.8529     0.0640     -0.0558      0.0016
# scooter_flag_BUS                -0.0487     0.0310    -1.5712     0.1162     -0.1094      0.0121
# BIKE_SCOOTER_SCOOTER_RAIL       -0.0218     0.0189    -1.1553     0.2481     -0.0589      0.0152
# MAINTENANCE                     -0.2931     0.1054    -2.7801     0.0055     -0.4998     -0.0864
# ================================================================================================
#
# F-test for Poolability: 107.26
# P-value: 0.0000
# Distribution: F(245,3601)
#
# Included effects: Entity

# %%
# full time effects

mod=PanelOLS.from_formula('UPT_ADJ_log \
                    ~ VRM_ADJ_log \
                    + FARE_per_UPT_2018_log \
                    + POP_EMP_log \
                    + GAS_PRICE_2018_log \
                    + TOTAL_MED_INC_INDIV_2018_log \
                    + Tot_NonUSA_POP_pct \
                    + PCT_HH_NO_VEH \
                    + TSD_POP_PCT \
                    + YEARS_SINCE_TNC_BUS \
                    + YEARS_SINCE_TNC_RAIL \
                    + BIKE_SHARE_BUS \
                    + scooter_flag_BUS \
                    + BIKE_SCOOTER_SCOOTER_RAIL \
                    + MAINTENANCE \
                    + EntityEffects \
                    + TimeEffects \
                    ',data=df)
res=mod.fit()
print(res)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\data.py:39: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   new_df = df.copy().loc[self._full_index]
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\utility.py:476: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   warnings.warn(missing_value_warning_msg, MissingValueWarning)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:            UPT_ADJ_log   R-squared:                        0.5096
# Estimator:                   PanelOLS   R-squared (Between):              0.9927
# No. Observations:                3861   R-squared (Within):               0.5638
# Date:                Fri, Nov 22 2019   R-squared (Overall):              0.9930
# Time:                        16:23:03   Log-likelihood                    1307.4
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      266.10
# Entities:                         246   P-value                           0.0000
# Avg Obs:                       15.695   Distribution:                 F(14,3585)
# Min Obs:                       3.0000
# Max Obs:                       17.000   F-statistic (robust):             266.10
#                                         P-value                           0.0000
# Time periods:                      17   Distribution:                 F(14,3585)
# Avg Obs:                       227.12
# Min Obs:                       164.00
# Max Obs:                       246.00
#
#                                       Parameter Estimates
# ================================================================================================
#                               Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------------------
# VRM_ADJ_log                      0.5596     0.0140     40.074     0.0000      0.5322      0.5870
# FARE_per_UPT_2018_log           -0.7391     0.0205    -36.093     0.0000     -0.7793     -0.6990
# POP_EMP_log                      0.6970     0.0708     9.8515     0.0000      0.5583      0.8357
# GAS_PRICE_2018_log               0.2001     0.1759     1.1371     0.2556     -0.1449      0.5450
# TOTAL_MED_INC_INDIV_2018_log    -0.1356     0.0646    -2.1002     0.0358     -0.2621     -0.0090
# Tot_NonUSA_POP_pct               0.0278     0.0088     3.1417     0.0017      0.0104      0.0451
# PCT_HH_NO_VEH                    0.0060     0.0031     1.9088     0.0564     -0.0002      0.0121
# TSD_POP_PCT                      0.8548     0.1542     5.5437     0.0000      0.5525      1.1572
# YEARS_SINCE_TNC_BUS             -0.0052     0.0060    -0.8633     0.3880     -0.0170      0.0066
# YEARS_SINCE_TNC_RAIL             0.0180     0.0077     2.3452     0.0191      0.0029      0.0330
# BIKE_SHARE_BUS                  -0.0348     0.0146    -2.3753     0.0176     -0.0635     -0.0061
# scooter_flag_BUS                -0.0322     0.0320    -1.0066     0.3142     -0.0949      0.0305
# BIKE_SCOOTER_SCOOTER_RAIL       -0.0156     0.0191    -0.8191     0.4128     -0.0530      0.0218
# MAINTENANCE                     -0.2717     0.1043    -2.6050     0.0092     -0.4761     -0.0672
# ================================================================================================
#
# F-test for Poolability: 103.46
# P-value: 0.0000
# Distribution: F(261,3585)
#
# Included effects: Entity, Time

# %%
# trends

mod=PanelOLS.from_formula('UPT_ADJ_log \
                    ~ VRM_ADJ_log \
                    + FARE_per_UPT_2018_log \
                    + POP_EMP_log \
                    + GAS_PRICE_2018_log \
                    + TOTAL_MED_INC_INDIV_2018_log \
                    + Tot_NonUSA_POP_pct \
                    + PCT_HH_NO_VEH \
                    + TSD_POP_PCT \
                    + YEARS_SINCE_TNC_BUS \
                    + YEARS_SINCE_TNC_RAIL \
                    + BIKE_SHARE_BUS \
                    + scooter_flag_BUS \
                    + BIKE_SCOOTER_SCOOTER_RAIL \
                    + MAINTENANCE \
                    + YEARS_SINCE_2002_BUS \
                    + YEARS_SINCE_2002_RAIL \
                    + EntityEffects \
                    ',data=df)
res=mod.fit()
print(res)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\data.py:39: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   new_df = df.copy().loc[self._full_index]
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\utility.py:476: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   warnings.warn(missing_value_warning_msg, MissingValueWarning)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:            UPT_ADJ_log   R-squared:                        0.5754
# Estimator:                   PanelOLS   R-squared (Between):              0.9952
# No. Observations:                3861   R-squared (Within):               0.5754
# Date:                Fri, Nov 22 2019   R-squared (Overall):              0.9951
# Time:                        16:23:08   Log-likelihood                    1275.2
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      304.83
# Entities:                         246   P-value                           0.0000
# Avg Obs:                       15.695   Distribution:                 F(16,3599)
# Min Obs:                       3.0000
# Max Obs:                       17.000   F-statistic (robust):             304.83
#                                         P-value                           0.0000
# Time periods:                      17   Distribution:                 F(16,3599)
# Avg Obs:                       227.12
# Min Obs:                       164.00
# Max Obs:                       246.00
#
#                                       Parameter Estimates
# ================================================================================================
#                               Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------------------
# VRM_ADJ_log                      0.5719     0.0142     40.136     0.0000      0.5440      0.5998
# FARE_per_UPT_2018_log           -0.7155     0.0205    -34.959     0.0000     -0.7556     -0.6754
# POP_EMP_log                      0.6223     0.0699     8.8965     0.0000      0.4851      0.7594
# GAS_PRICE_2018_log               0.1591     0.0257     6.1892     0.0000      0.1087      0.2095
# TOTAL_MED_INC_INDIV_2018_log    -0.2483     0.0585    -4.2481     0.0000     -0.3629     -0.1337
# Tot_NonUSA_POP_pct               0.0260     0.0089     2.9199     0.0035      0.0085      0.0434
# PCT_HH_NO_VEH                    0.0074     0.0031     2.3649     0.0181      0.0013      0.0135
# TSD_POP_PCT                      0.6741     0.1526     4.4170     0.0000      0.3749      0.9733
# YEARS_SINCE_TNC_BUS             -0.0330     0.0049    -6.7435     0.0000     -0.0426     -0.0234
# YEARS_SINCE_TNC_RAIL             0.0228     0.0087     2.6290     0.0086      0.0058      0.0397
# BIKE_SHARE_BUS                  -0.0346     0.0146    -2.3699     0.0178     -0.0632     -0.0060
# scooter_flag_BUS                -0.0334     0.0309    -1.0792     0.2806     -0.0941      0.0273
# BIKE_SCOOTER_SCOOTER_RAIL       -0.0127     0.0190    -0.6719     0.5017     -0.0499      0.0244
# MAINTENANCE                     -0.3042     0.1049    -2.8998     0.0038     -0.5098     -0.0985
# YEARS_SINCE_2002_BUS             0.0068     0.0013     5.2717     0.0000      0.0042      0.0093
# YEARS_SINCE_2002_RAIL           -0.0058     0.0029    -2.0040     0.0451     -0.0114     -0.0001
# ================================================================================================
#
# F-test for Poolability: 105.89
# P-value: 0.0000
# Distribution: F(245,3599)
#
# Included effects: Entity

# %%
# split trends

mod=PanelOLS.from_formula('UPT_ADJ_log \
                    ~ VRM_ADJ_log \
                    + FARE_per_UPT_2018_log \
                    + POP_EMP_log \
                    + GAS_PRICE_2018_log \
                    + TOTAL_MED_INC_INDIV_2018_log \
                    + Tot_NonUSA_POP_pct \
                    + PCT_HH_NO_VEH \
                    + TSD_POP_PCT \
                    + YEARS_SINCE_TNC_BUS \
                    + YEARS_SINCE_TNC_RAIL \
                    + BIKE_SHARE_BUS \
                    + scooter_flag_BUS \
                    + BIKE_SCOOTER_SCOOTER_RAIL \
                    + MAINTENANCE \
                    + YEARS_2002_2014_BUS \
                    + YEARS_2002_2014_RAIL \
                    + YEARS_AFTER_2014_BUS \
                    + YEARS_AFTER_2014_RAIL \
                    + EntityEffects \
                    ',data=df)
res=mod.fit()
print(res)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\data.py:39: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   new_df = df.copy().loc[self._full_index]
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\utility.py:476: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   warnings.warn(missing_value_warning_msg, MissingValueWarning)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:            UPT_ADJ_log   R-squared:                        0.5833
# Estimator:                   PanelOLS   R-squared (Between):              0.9985
# No. Observations:                3861   R-squared (Within):               0.5833
# Date:                Fri, Nov 22 2019   R-squared (Overall):              0.9985
# Time:                        16:23:11   Log-likelihood                    1311.4
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      279.70
# Entities:                         246   P-value                           0.0000
# Avg Obs:                       15.695   Distribution:                 F(18,3597)
# Min Obs:                       3.0000
# Max Obs:                       17.000   F-statistic (robust):             279.70
#                                         P-value                           0.0000
# Time periods:                      17   Distribution:                 F(18,3597)
# Avg Obs:                       227.12
# Min Obs:                       164.00
# Max Obs:                       246.00
#
#                                       Parameter Estimates
# ================================================================================================
#                               Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------------------
# VRM_ADJ_log                      0.5728     0.0141     40.552     0.0000      0.5452      0.6005
# FARE_per_UPT_2018_log           -0.7296     0.0204    -35.844     0.0000     -0.7695     -0.6897
# POP_EMP_log                      0.6092     0.0693     8.7855     0.0000      0.4733      0.7452
# GAS_PRICE_2018_log               0.0842     0.0275     3.0577     0.0022      0.0302      0.1381
# TOTAL_MED_INC_INDIV_2018_log    -0.1280     0.0601    -2.1289     0.0333     -0.2460     -0.0101
# Tot_NonUSA_POP_pct               0.0281     0.0088     3.1899     0.0014      0.0108      0.0454
# PCT_HH_NO_VEH                    0.0060     0.0031     1.9291     0.0538   -9.76e-05      0.0120
# TSD_POP_PCT                      0.7969     0.1520     5.2427     0.0000      0.4989      1.0949
# YEARS_SINCE_TNC_BUS             -0.0106     0.0062    -1.7240     0.0848     -0.0227      0.0015
# YEARS_SINCE_TNC_RAIL             0.0651     0.0123     5.3139     0.0000      0.0411      0.0892
# BIKE_SHARE_BUS                  -0.0384     0.0145    -2.6511     0.0081     -0.0668     -0.0100
# scooter_flag_BUS                -0.0186     0.0307    -0.6064     0.5443     -0.0789      0.0416
# BIKE_SCOOTER_SCOOTER_RAIL        0.0121     0.0193     0.6262     0.5312     -0.0257      0.0498
# MAINTENANCE                     -0.3046     0.1044    -2.9174     0.0036     -0.5093     -0.0999
# YEARS_2002_2014_BUS              0.0133     0.0016     8.4751     0.0000      0.0102      0.0164
# YEARS_2002_2014_RAIL            -0.0003     0.0029    -0.0877     0.9301     -0.0060      0.0055
# YEARS_AFTER_2014_BUS            -0.0312     0.0062    -5.0690     0.0000     -0.0433     -0.0192
# YEARS_AFTER_2014_RAIL           -0.0936     0.0158    -5.9174     0.0000     -0.1247     -0.0626
# ================================================================================================
#
# F-test for Poolability: 107.58
# P-value: 0.0000
# Distribution: F(245,3597)
#
# Included effects: Entity

# %%
# it looks best without the time effects

mod=PanelOLS.from_formula('UPT_ADJ_log \
                    ~ VRM_ADJ_log \
                    + FARE_per_UPT_2018_log \
                    + POP_EMP_log \
                    + GAS_PRICE_2018_log \
                    + TOTAL_MED_INC_INDIV_2018_log \
                    + Tot_NonUSA_POP_pct \
                    + PCT_HH_NO_VEH \
                    + TSD_POP_PCT \
                    + YEARS_SINCE_TNC_BUS \
                    + YEARS_SINCE_TNC_RAIL \
                    + BIKE_SHARE_BUS \
                    + scooter_flag_BUS \
                    + BIKE_SCOOTER_SCOOTER_RAIL \
                    + MAINTENANCE \
                    + EntityEffects \
                    ',data=df)
res=mod.fit()
print(res)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\data.py:39: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   new_df = df.copy().loc[self._full_index]
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\utility.py:476: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   warnings.warn(missing_value_warning_msg, MissingValueWarning)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:            UPT_ADJ_log   R-squared:                        0.5706
# Estimator:                   PanelOLS   R-squared (Between):              0.9984
# No. Observations:                3861   R-squared (Within):               0.5706
# Date:                Fri, Nov 22 2019   R-squared (Overall):              0.9984
# Time:                        16:23:14   Log-likelihood                    1253.6
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      341.83
# Entities:                         246   P-value                           0.0000
# Avg Obs:                       15.695   Distribution:                 F(14,3601)
# Min Obs:                       3.0000
# Max Obs:                       17.000   F-statistic (robust):             341.83
#                                         P-value                           0.0000
# Time periods:                      17   Distribution:                 F(14,3601)
# Avg Obs:                       227.12
# Min Obs:                       164.00
# Max Obs:                       246.00
#
#                                       Parameter Estimates
# ================================================================================================
#                               Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------------------
# VRM_ADJ_log                      0.5689     0.0139     40.946     0.0000      0.5417      0.5961
# FARE_per_UPT_2018_log           -0.7114     0.0204    -34.832     0.0000     -0.7514     -0.6714
# POP_EMP_log                      0.7634     0.0663     11.519     0.0000      0.6334      0.8933
# GAS_PRICE_2018_log               0.1552     0.0258     6.0165     0.0000      0.1047      0.2058
# TOTAL_MED_INC_INDIV_2018_log    -0.3426     0.0543    -6.3098     0.0000     -0.4491     -0.2362
# Tot_NonUSA_POP_pct               0.0331     0.0088     3.7609     0.0002      0.0159      0.0504
# PCT_HH_NO_VEH                    0.0076     0.0031     2.4264     0.0153      0.0015      0.0138
# TSD_POP_PCT                      0.6697     0.1513     4.4274     0.0000      0.3732      0.9663
# YEARS_SINCE_TNC_BUS             -0.0206     0.0043    -4.7693     0.0000     -0.0290     -0.0121
# YEARS_SINCE_TNC_RAIL             0.0097     0.0073     1.3295     0.1838     -0.0046      0.0240
# BIKE_SHARE_BUS                  -0.0271     0.0146    -1.8529     0.0640     -0.0558      0.0016
# scooter_flag_BUS                -0.0487     0.0310    -1.5712     0.1162     -0.1094      0.0121
# BIKE_SCOOTER_SCOOTER_RAIL       -0.0218     0.0189    -1.1553     0.2481     -0.0589      0.0152
# MAINTENANCE                     -0.2931     0.1054    -2.7801     0.0055     -0.4998     -0.0864
# ================================================================================================
#
# F-test for Poolability: 107.26
# P-value: 0.0000
# Distribution: F(245,3601)
#
# Included effects: Entity

# %% [markdown]
# ## Run some analytics

# %%
# bike share plus scooters for rail

mod=PanelOLS.from_formula('UPT_ADJ_log \
                    ~ VRM_ADJ_log \
                    + FARE_per_UPT_2018_log \
                    + POP_EMP_log \
                    + GAS_PRICE_2018_log \
                    + TOTAL_MED_INC_INDIV_2018_log \
                    + Tot_NonUSA_POP_pct \
                    + PCT_HH_NO_VEH \
                    + TSD_POP_PCT \
                    + YEARS_SINCE_TNC_BUS \
                    + YEARS_SINCE_TNC_RAIL \
                    + BIKE_SHARE_BUS \
                    + scooter_flag_BUS \
                    + BIKE_SCOOTER_SCOOTER_RAIL \
                    + MAINTENANCE \
                    + EntityEffects \
                    ',data=df)
res=mod.fit()
print(res)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\data.py:39: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   new_df = df.copy().loc[self._full_index]
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\utility.py:476: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   warnings.warn(missing_value_warning_msg, MissingValueWarning)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:            UPT_ADJ_log   R-squared:                        0.5706
# Estimator:                   PanelOLS   R-squared (Between):              0.9984
# No. Observations:                3861   R-squared (Within):               0.5706
# Date:                Fri, Nov 22 2019   R-squared (Overall):              0.9984
# Time:                        16:23:19   Log-likelihood                    1253.6
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      341.83
# Entities:                         246   P-value                           0.0000
# Avg Obs:                       15.695   Distribution:                 F(14,3601)
# Min Obs:                       3.0000
# Max Obs:                       17.000   F-statistic (robust):             341.83
#                                         P-value                           0.0000
# Time periods:                      17   Distribution:                 F(14,3601)
# Avg Obs:                       227.12
# Min Obs:                       164.00
# Max Obs:                       246.00
#
#                                       Parameter Estimates
# ================================================================================================
#                               Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------------------
# VRM_ADJ_log                      0.5689     0.0139     40.946     0.0000      0.5417      0.5961
# FARE_per_UPT_2018_log           -0.7114     0.0204    -34.832     0.0000     -0.7514     -0.6714
# POP_EMP_log                      0.7634     0.0663     11.519     0.0000      0.6334      0.8933
# GAS_PRICE_2018_log               0.1552     0.0258     6.0165     0.0000      0.1047      0.2058
# TOTAL_MED_INC_INDIV_2018_log    -0.3426     0.0543    -6.3098     0.0000     -0.4491     -0.2362
# Tot_NonUSA_POP_pct               0.0331     0.0088     3.7609     0.0002      0.0159      0.0504
# PCT_HH_NO_VEH                    0.0076     0.0031     2.4264     0.0153      0.0015      0.0138
# TSD_POP_PCT                      0.6697     0.1513     4.4274     0.0000      0.3732      0.9663
# YEARS_SINCE_TNC_BUS             -0.0206     0.0043    -4.7693     0.0000     -0.0290     -0.0121
# YEARS_SINCE_TNC_RAIL             0.0097     0.0073     1.3295     0.1838     -0.0046      0.0240
# BIKE_SHARE_BUS                  -0.0271     0.0146    -1.8529     0.0640     -0.0558      0.0016
# scooter_flag_BUS                -0.0487     0.0310    -1.5712     0.1162     -0.1094      0.0121
# BIKE_SCOOTER_SCOOTER_RAIL       -0.0218     0.0189    -1.1553     0.2481     -0.0589      0.0152
# MAINTENANCE                     -0.2931     0.1054    -2.7801     0.0055     -0.4998     -0.0864
# ================================================================================================
#
# F-test for Poolability: 107.26
# P-value: 0.0000
# Distribution: F(245,3601)
#
# Included effects: Entity

# %%
sns.distplot(res.resids)

# %%
sm.graphics.qqplot(res.resids,line = 'q')

# %% [markdown]
# ## Calculate FAC

# %%
# keep the relevant fields in the data set
app_data = pd.concat([df[['RAIL_FLAG', 'CLUSTER_APTA']], 
                      res.model.dependent.dataframe, 
                      res.model.exog.dataframe, 
                      res.estimated_effects, 
                      res.resids], axis=1)

# %%
app_data.head()
# Out:
#                                RAIL_FLAG  CLUSTER_APTA  UPT_ADJ_log  \
# Akron, OH Metro Area-Bus 2002          0          24.0    15.469231
#                          2003          0          24.0    15.501150
#                          2004          0          24.0    15.591676
#                          2005          0          24.0    15.609548
#                          2006          0          24.0    15.619001
#
#                                VRM_ADJ_log  FARE_per_UPT_2018_log  \
# Akron, OH Metro Area-Bus 2002    15.208377               0.162997
#                          2003    15.195930               0.502067
#                          2004    15.277699               0.450106
#                          2005    15.214971               0.499830
#                          2006    15.200501               0.501551
#
#                                POP_EMP_log  GAS_PRICE_2018_log  \
# Akron, OH Metro Area-Bus 2002    13.808216            1.066089
#                          2003    13.823451            1.138954
#                          2004    13.839439            1.233697
#                          2005    13.857195            1.361617
#                          2006    13.879496            1.429114
#
#                                TOTAL_MED_INC_INDIV_2018_log  \
# Akron, OH Metro Area-Bus 2002                     10.479210
#                          2003                     10.446267
#                          2004                     10.403980
#                          2005                     10.365663
#                          2006                     10.305856
#
#                                Tot_NonUSA_POP_pct  PCT_HH_NO_VEH  TSD_POP_PCT  \
# Akron, OH Metro Area-Bus 2002           -0.060245           8.60     0.185260
#                          2003            0.114214           8.20     0.180770
#                          2004            0.288851           7.79     0.176377
#                          2005            0.430267           7.47     0.172435
#                          2006            0.669812           6.85     0.167543
#
#                                YEARS_SINCE_TNC_BUS  YEARS_SINCE_TNC_RAIL  \
# Akron, OH Metro Area-Bus 2002                  0.0                   0.0
#                          2003                  0.0                   0.0
#                          2004                  0.0                   0.0
#                          2005                  0.0                   0.0
#                          2006                  0.0                   0.0
#
#                                BIKE_SHARE_BUS  scooter_flag_BUS  \
# Akron, OH Metro Area-Bus 2002             0.0               0.0
#                          2003             0.0               0.0
#                          2004             0.0               0.0
#                          2005             0.0               0.0
#                          2006             0.0               0.0
#
#                                BIKE_SCOOTER_SCOOTER_RAIL  MAINTENANCE  \
# Akron, OH Metro Area-Bus 2002                        0.0          0.0
#                          2003                        0.0          0.0
#                          2004                        0.0          0.0
#                          2005                        0.0          0.0
#                          2006                        0.0          0.0
#
#                                 effects  residual
# Akron, OH Metro Area-Bus 2002 -0.105589 -0.265001
#                          2003 -0.105589 -0.018743
#                          2004 -0.105589 -0.052825
#                          2005 -0.105589 -0.010045
#                          2006 -0.105589 -0.039069

# %%
# calculate the fitted values
app_data['fitted'] = app_data['effects']
for var in res.params.keys(): 
    app_data['fitted'] = app_data['fitted'] + (res.params[var] * app_data[var])

# and check that we add up correctly
app_data['check_fitted'] = app_data['fitted'] + app_data['residual'] - app_data['UPT_ADJ_log']

# %%
# create the necessary columns

# dependents
app_data['UPT_ADJ']    = np.exp(app_data['UPT_ADJ_log']) - 1
app_data['fitted_exp'] = np.exp(app_data['fitted']) - 1

# linear versions of logged variables
for var in res.params.keys(): 
    if '_log' in var: 
        app_data[var.replace('_log', '')] = np.exp(app_data[var]) - 1              

# ratios and differences
for var in res.params.keys(): 
    if '_log' in var: 
        app_data[var.replace('_log', '_ratio')] = 1
    else: 
        app_data[var+'_diff'] = 0

# FAC multipliers
for var in res.params.keys(): 
    app_data[var+'_FAC_ratio'] = 1

app_data['UPT_ADJ_base'] = 0
app_data['UPT_ADJ_ratio'] = 1
app_data['fitted_exp_ratio'] = 1
app_data['UPT_ADJ_diff'] = 0
app_data['fitted_exp_diff'] = 0

# %%
# calculate the FAC relative to a specific base year
ids = app_data.index.get_level_values(0).unique()

for id in ids: 
    years = app_data.loc[id].index.get_level_values(0)

    for year in years[1:]:       
        base_year = year-1
        
        for var in res.params.keys(): 
            # ratios and differences
            if '_log' in var: 
                out_var = var.replace('_log', '_ratio')
                app_data.loc[(id,year), out_var] = (app_data.loc[(id,year), var] 
                                                 / app_data.loc[(id,base_year), var])
            else: 
                out_var = var+'_diff'                    
                app_data.loc[(id,year), out_var] = (app_data.loc[(id,year), var] 
                                                 - app_data.loc[(id,base_year), var])

            # FAC multipliers
            app_data.loc[(id,year),var+'_FAC_ratio'] = np.exp(res.params[var] * (
                                                    app_data.loc[(id,year), var] 
                                                    - app_data.loc[(id,base_year), var]))

            # estimated effects (if time effects is zero, no change)
            app_data.loc[(id,year),'effects_FAC_ratio'] = np.exp(
                                                    app_data.loc[(id,year), 'effects'] 
                                                    - app_data.loc[(id,base_year), 'effects'])

            # residual
            app_data.loc[(id,year),'residual_FAC_ratio'] = np.exp(
                                                    app_data.loc[(id,year), 'residual'] 
                                                    - app_data.loc[(id,base_year), 'residual'])

        # observed and fitted changes            
        app_data.loc[(id,year),'UPT_ADJ_base'] = app_data.loc[(id,base_year),'UPT_ADJ']
        app_data.loc[(id,year),'UPT_ADJ_ratio'] = (app_data.loc[(id,year),'UPT_ADJ'] 
                                                 / app_data.loc[(id,base_year),'UPT_ADJ'])
        app_data.loc[(id,year),'fitted_exp_ratio'] = (app_data.loc[(id,year),'fitted_exp'] 
                                                 / app_data.loc[(id,base_year),'fitted_exp'])

        app_data.loc[(id,year),'UPT_ADJ_diff'] = (app_data.loc[(id,year),'UPT_ADJ'] 
                                                 - app_data.loc[(id,base_year),'UPT_ADJ'])
        app_data.loc[(id,year),'fitted_exp_diff'] = (app_data.loc[(id,year),'fitted_exp'] 
                                                 - app_data.loc[(id,base_year),'fitted_exp'])

# %%
# calculate the total change ratios

app_data['FAC_ratio'] = 1
for var in res.params.keys(): 
    app_data['FAC_ratio'] = app_data['FAC_ratio'] * app_data[var+'_FAC_ratio']
    
app_data['FAC_ratio'] = app_data['FAC_ratio'] * app_data['effects_FAC_ratio']

# %%
# calculate the FAC
app_data['Total_FAC'] = 0
for var in res.params.keys(): 
    app_data[var+'_FAC'] = (app_data[var+'_FAC_ratio'] - 1) * app_data['UPT_ADJ_base']
    app_data['Total_FAC'] = app_data['Total_FAC'] + app_data[var+'_FAC']
app_data['effects_FAC'] = (app_data['effects_FAC_ratio'] - 1) * app_data['UPT_ADJ_base']
app_data['Total_FAC'] = app_data['Total_FAC'] + app_data['effects_FAC']

# scale the FAC
app_data['FAC_scale'] = app_data['fitted_exp_diff'] / app_data['Total_FAC']
app_data['FAC_scale'] = app_data['FAC_scale'].fillna(1)

app_data['Total_FAC_scaled'] = 0
for var in res.params.keys(): 
    app_data[var+'_FAC_scaled'] = app_data[var+'_FAC'] * app_data['FAC_scale']
    app_data['Total_FAC_scaled'] = app_data['Total_FAC_scaled'] + app_data[var+'_FAC_scaled']
app_data['effects_FAC_scaled'] = app_data[var+'_FAC_scaled'] * app_data['FAC_scale']
app_data['Total_FAC_scaled'] = app_data['Total_FAC_scaled'] + app_data['effects_FAC_scaled']

# %%
# calculate APTA - 4 groups
app_data['CLUSTER_APTA4'] = np.floor(app_data['CLUSTER_APTA']/10)

# %%
# reset the index so I get ID and year
app_data = app_data.reset_index()
app_data = app_data.rename(columns={'level_0' : 'ID', 'level_1' : 'Year'})
app_data.to_csv('FAC.csv')

# %%
# these are the fields we keep
out_fields = ['ID', 'Year', 'RAIL_FLAG', 
              'CLUSTER_APTA', 'CLUTER_APTA4', 
              'UPT_ADJ_base', 'UPT_ADJ', 'UPT_ADJ_diff', 
              'fitted_exp', 'fitted_exp_diff']

# exogenous variables 
for var in res.params.keys(): 
    out_var = var.replace('_log', '')
    out_fields = out_fields + [out_var]
    
# FAC
for var in res.params.keys(): 
    out_fields = out_fields + [var+'_FAC']
out_fields = out_fields + ['Total_FAC']
    
# scaled FAC
for var in res.params.keys(): 
    out_fields = out_fields + [var+'_FAC_scaled']
out_fields = out_fields + ['Total_FAC_scaled']

# keep those fields
summary_data = app_data.reset_index()[out_fields]

# %%
# take weighted average of exogenous variables
for var in res.params.keys(): 
    out_var = var.replace('_log', '')
    summary_data[out_var] = summary_data[out_var] * summary_data['UPT_ADJ_base']

# aggregate to bus/rail totals
summary_data_apta = summary_data.groupby(by=['CLUSTER_APTA', 'RAIL_FLAG', 'Year']).agg('sum')

# divide for weighted averages
for var in res.params.keys(): 
    out_var = var.replace('_log', '')
#    summary_data_gt[out_var] = summary_data_gt[out_var] / summary_data_gt['UPT_ADJ_base']
    summary_data_apta[out_var] = summary_data_apta[out_var] / summary_data_apta['UPT_ADJ_base']
#    summary_data_apta_hml[out_var] = summary_data_apta_hml[out_var] / summary_data_apta_hml['UPT_ADJ_base']

# %%
#summary_data_gt.to_csv('FAC_totals_GT_CLUSTERS.csv')
summary_data_apta.to_csv('FAC_totals_APTA_CLUSTERS.csv')
#summary_data_apta_hml.to_csv('FAC_totals_APTA_HML_CLUSTERS.csv')

# %%
summary_data_apta.head(20)
# Out:
#                              UPT_ADJ_base       UPT_ADJ  UPT_ADJ_diff  \
# CLUSTER_APTA RAIL_FLAG Year
# 10.0         0         2002  0.000000e+00  2.013179e+09          0.00
#                        2003  2.667393e+08  2.013821e+09   12024523.82
#                        2004  2.787638e+08  2.041333e+09    8474727.35
#                        2005  2.872386e+08  2.063005e+09    2153472.79
#                        2006  2.893920e+08  2.071799e+09  -21259282.15
#                        2007  2.681328e+08  2.090532e+09   -4095857.18
#                        2008  2.640369e+08  2.172421e+09   17405510.77
#                        2009  2.814424e+08  2.087737e+09    1112613.15
#                        2010  2.825550e+08  2.019401e+09   -2813381.30
#                        2011  2.797416e+08  2.050938e+09   -5457299.59
#                        2012  2.742843e+08  2.080704e+09  -11268054.75
#                        2013  2.630163e+08  2.076741e+09    1349280.41
#                        2014  2.643656e+08  2.061719e+09   14137930.98
#                        2015  2.785035e+08  2.028750e+09    3762894.15
#                        2016  2.822664e+08  1.944705e+09  -15195686.82
#                        2017  2.670707e+08  1.875434e+09  -12405514.79
#                        2018  2.546652e+08  1.832288e+09  -11523270.00
#              1         2002  0.000000e+00  1.246324e+09          0.00
#                        2003  3.254974e+08  1.241953e+09  -10608802.12
#                        2004  3.148886e+08  1.312022e+09   32604536.25
#
#                                fitted_exp  fitted_exp_diff       VRM_ADJ  \
# CLUSTER_APTA RAIL_FLAG Year
# 10.0         0         2002  1.840098e+09     0.000000e+00           NaN
#                        2003  1.983349e+09     2.298767e+07  2.826832e+07
#                        2004  2.043710e+09     1.048892e+06  2.714501e+07
#                        2005  2.087217e+09     1.053669e+07  2.676103e+07
#                        2006  2.176892e+09     1.516112e+07  2.816483e+07
#                        2007  2.194798e+09     6.319558e+06  3.012858e+07
#                        2008  2.277360e+09     2.528417e+07  3.166796e+07
#                        2009  2.133443e+09    -1.028453e+07  3.164536e+07
#                        2010  2.116622e+09     5.311363e+06  3.116715e+07
#                        2011  2.136279e+09    -2.132196e+06  3.001421e+07
#                        2012  2.111105e+09    -1.404177e+07  2.919962e+07
#                        2013  2.067820e+09    -1.255612e+07  2.904164e+07
#                        2014  2.019809e+09     2.735137e+06  2.842753e+07
#                        2015  1.899215e+09    -1.368375e+07  2.989353e+07
#                        2016  1.829516e+09    -1.655129e+07  2.969291e+07
#                        2017  1.848940e+09    -1.186137e+06  2.976980e+07
#                        2018  1.809739e+09    -1.162714e+07  3.013614e+07
#              1         2002  1.170746e+09     0.000000e+00           NaN
#                        2003  1.256951e+09     1.527450e+07  3.757067e+07
#                        2004  1.309479e+09     2.551756e+07  3.790565e+07
#
#                              FARE_per_UPT_2018       POP_EMP  GAS_PRICE_2018  \
# CLUSTER_APTA RAIL_FLAG Year
# 10.0         0         2002                NaN           NaN             NaN
#                        2003           0.844533  5.570859e+06        2.204544
#                        2004           0.882555  5.738642e+06        2.532280
#                        2005           0.865215  5.966674e+06        2.996941
#                        2006           0.939011  6.189913e+06        3.301906
#                        2007           0.989620  6.317999e+06        3.424988
#                        2008           0.919464  6.290958e+06        3.883720
#                        2009           0.921639  6.311069e+06        2.804807
#                        2010           0.935184  6.217085e+06        3.266035
#                        2011           0.994878  6.248060e+06        4.049726
#                        2012           1.102536  6.359290e+06        4.077173
#                        2013           1.149571  6.514259e+06        3.929063
#                        2014           1.032859  6.564543e+06        3.722682
#                        2015           1.068528  6.628771e+06        2.642807
#                        2016           1.119500  6.719396e+06        2.375526
#                        2017           1.116261  6.793273e+06        2.596538
#                        2018           1.130921  6.948215e+06        2.835784
#              1         2002                NaN           NaN             NaN
#                        2003           1.306967  6.128476e+06        2.210901
#                        2004           1.252843  6.272270e+06        2.534601
#
#                              TOTAL_MED_INC_INDIV_2018  Tot_NonUSA_POP_pct  \
# CLUSTER_APTA RAIL_FLAG Year
# 10.0         0         2002                       NaN                 NaN
#                        2003              42158.707131            1.558338
#                        2004              40661.793855            1.483913
#                        2005              39323.652772            1.431750
#                        2006              37324.498855            1.361385
#                        2007              37608.343082            1.299136
#                        2008              37431.869831            1.476451
#                        2009              36235.033332            1.436220
#                        2010              35403.356888            1.563417
#                        2011              34580.712240            1.680341
#                        2012              34536.932232            1.613035
#                        2013              35319.289684            1.671169
#                        2014              35307.023480            1.704385
#                        2015              36507.722393            1.735857
#                        2016              37494.482828            1.872523
#                        2017              38002.103422            1.844627
#                        2018              38747.856279            1.869437
#              1         2002                       NaN                 NaN
#                        2003              43263.353161            1.710985
#                        2004              41472.262326            1.638417
#
#                              PCT_HH_NO_VEH  TSD_POP_PCT  YEARS_SINCE_TNC_BUS  \
# CLUSTER_APTA RAIL_FLAG Year
# 10.0         0         2002            NaN          NaN                  NaN
#                        2003      10.034945     0.172378             0.000000
#                        2004      10.240992     0.163748             0.000000
#                        2005      10.349189     0.150209             0.000000
#                        2006      10.540401     0.147711             0.000000
#                        2007      10.056656     0.143772             0.000000
#                        2008      10.239129     0.145655             0.000000
#                        2009      10.411902     0.142010             0.000000
#                        2010      10.783812     0.143935             0.000000
#                        2011      10.979204     0.142342             0.000000
#                        2012      10.995704     0.136356             0.000000
#                        2013      10.787889     0.125468             0.725139
#                        2014      10.871383     0.129498             1.713009
#                        2015      11.043426     0.129603             2.709690
#                        2016      10.795372     0.129743             3.711049
#                        2017      10.493558     0.130952             4.705507
#                        2018      10.231591     0.126011             5.718625
#              1         2002            NaN          NaN                  NaN
#                        2003      10.298131     0.070110             0.000000
#                        2004      10.661814     0.067479             0.000000
#
#                              YEARS_SINCE_TNC_RAIL  BIKE_SHARE_BUS  \
# CLUSTER_APTA RAIL_FLAG Year
# 10.0         0         2002                   NaN             NaN
#                        2003                   0.0        0.000000
#                        2004                   0.0        0.000000
#                        2005                   0.0        0.000000
#                        2006                   0.0        0.000000
#                        2007                   0.0        0.000000
#                        2008                   0.0        0.000000
#                        2009                   0.0        0.000000
#                        2010                   0.0        0.000000
#                        2011                   0.0        0.415338
#                        2012                   0.0        0.439945
#                        2013                   0.0        0.468986
#                        2014                   0.0        0.461824
#                        2015                   0.0        0.709690
#                        2016                   0.0        1.000000
#                        2017                   0.0        1.000000
#                        2018                   0.0        1.000000
#              1         2002                   NaN             NaN
#                        2003                   0.0        0.000000
#                        2004                   0.0        0.000000
#
#                              scooter_flag_BUS  BIKE_SCOOTER_SCOOTER_RAIL  \
# CLUSTER_APTA RAIL_FLAG Year
# 10.0         0         2002               NaN                        NaN
#                        2003               0.0                        0.0
#                        2004               0.0                        0.0
#                        2005               0.0                        0.0
#                        2006               0.0                        0.0
#                        2007               0.0                        0.0
#                        2008               0.0                        0.0
#                        2009               0.0                        0.0
#                        2010               0.0                        0.0
#                        2011               0.0                        0.0
#                        2012               0.0                        0.0
#                        2013               0.0                        0.0
#                        2014               0.0                        0.0
#                        2015               0.0                        0.0
#                        2016               0.0                        0.0
#                        2017               0.0                        0.0
#                        2018               1.0                        0.0
#              1         2002               NaN                        NaN
#                        2003               0.0                        0.0
#                        2004               0.0                        0.0
#
#                              MAINTENANCE  VRM_ADJ_log_FAC  \
# CLUSTER_APTA RAIL_FLAG Year
# 10.0         0         2002          NaN     0.000000e+00
#                        2003          0.0     8.171597e+06
#                        2004          0.0    -6.781219e+06
#                        2005          0.0    -2.538980e+06
#                        2006          0.0     8.710278e+06
#                        2007          0.0     1.046231e+07
#                        2008          0.0     8.635562e+06
#                        2009          0.0    -5.349289e+05
#                        2010          0.0    -1.755907e+06
#                        2011          0.0    -5.095168e+06
#                        2012          0.0    -4.861444e+06
#                        2013          0.0    -1.473226e+06
#                        2014          0.0    -3.199022e+06
#                        2015          0.0     8.766475e+06
#                        2016          0.0    -1.444752e+06
#                        2017          0.0     5.906572e+05
#                        2018          0.0     1.604409e+06
#              1         2002          NaN     0.000000e+00
#                        2003          0.0    -1.595350e+06
#                        2004          0.0     1.200206e+06
#
#                              FARE_per_UPT_2018_log_FAC  POP_EMP_log_FAC  \
# CLUSTER_APTA RAIL_FLAG Year
# 10.0         0         2002               0.000000e+00     0.000000e+00
#                        2003               8.023846e+06     5.290047e+06
#                        2004              -3.806252e+06     5.805566e+06
#                        2005               5.714466e+05     6.146268e+06
#                        2006              -7.550023e+06     7.796701e+06
#                        2007              -5.292468e+06     2.642787e+06
#                        2008               7.040616e+06     1.145299e+06
#                        2009              -1.013342e+05    -2.272160e+05
#                        2010              -1.566191e+06    -1.304378e+06
#                        2011              -6.332228e+06     2.124277e+06
#                        2012              -1.003247e+07     2.616818e+06
#                        2013              -4.644802e+06     1.943617e+06
#                        2014               1.108059e+07     2.551647e+06
#                        2015              -3.896994e+06     2.653918e+06
#                        2016              -5.011221e+06     2.281268e+06
#                        2017               2.452684e+05     2.496641e+06
#                        2018              -1.136000e+06     2.720164e+06
#              1         2002               0.000000e+00     0.000000e+00
#                        2003               3.456430e+06     6.440020e+06
#                        2004               8.208856e+06     6.620526e+06
#
#                              GAS_PRICE_2018_log_FAC  \
# CLUSTER_APTA RAIL_FLAG Year
# 10.0         0         2002            0.000000e+00
#                        2003            3.726197e+06
#                        2004            4.446434e+06
#                        2005            5.848163e+06
#                        2006            3.485371e+06
#                        2007            1.249563e+06
#                        2008            4.258147e+06
#                        2009           -1.120810e+07
#                        2010            5.303779e+06
#                        2011            7.769886e+06
#                        2012            2.216892e+05
#                        2013           -1.268117e+06
#                        2014           -1.837049e+06
#                        2015           -1.154815e+07
#                        2016           -3.472575e+06
#                        2017            2.762645e+06
#                        2018            2.702970e+06
#              1         2002            0.000000e+00
#                        2003            4.567723e+06
#                        2004            4.918287e+06
#
#                              TOTAL_MED_INC_INDIV_2018_log_FAC  \
# CLUSTER_APTA RAIL_FLAG Year
# 10.0         0         2002                      0.000000e+00
#                        2003                      2.502730e+06
#                        2004                      3.493907e+06
#                        2005                      3.402309e+06
#                        2006                      5.086681e+06
#                        2007                     -8.640212e+05
#                        2008                      5.674488e+05
#                        2009                      3.197606e+06
#                        2010                      2.521628e+06
#                        2011                      2.577843e+06
#                        2012                      2.500298e+05
#                        2013                     -2.035495e+06
#                        2014                      1.682321e+05
#                        2015                     -2.970170e+06
#                        2016                     -2.592536e+06
#                        2017                     -1.122095e+06
#                        2018                     -1.601231e+06
#              1         2002                      0.000000e+00
#                        2003                      3.794068e+06
#                        2004                      4.623421e+06
#
#                              Tot_NonUSA_POP_pct_FAC  PCT_HH_NO_VEH_FAC  \
# CLUSTER_APTA RAIL_FLAG Year
# 10.0         0         2002            0.000000e+00           0.000000
#                        2003           -6.138651e+05      360388.210805
#                        2004           -5.379181e+05      404803.710071
#                        2005           -4.945244e+05      299862.363601
#                        2006           -4.642823e+05      741794.380271
#                        2007           -4.007688e+05     -946359.167305
#                        2008            1.213232e+06      126337.753887
#                        2009           -2.685072e+05      623903.724307
#                        2010            9.698587e+05      831272.274373
#                        2011            8.152574e+05      172699.252845
#                        2012           -5.973268e+05     -216477.843417
#                        2013            2.645438e+05     -561331.414648
#                        2014            2.558838e+05      169743.054071
#                        2015            1.827572e+05      212307.152993
#                        2016            1.039312e+06     -553310.588951
#                        2017           -1.738751e+05     -709633.343180
#                        2018            1.106513e+05     -607717.730123
#              1         2002            0.000000e+00           0.000000
#                        2003           -6.610025e+05      658249.542564
#                        2004           -4.896103e+05      657247.088724
#
#                              TSD_POP_PCT_FAC  YEARS_SINCE_TNC_BUS_FAC  \
# CLUSTER_APTA RAIL_FLAG Year
# 10.0         0         2002     0.000000e+00             0.000000e+00
#                        2003    -1.296210e+06             0.000000e+00
#                        2004    -1.234650e+06             0.000000e+00
#                        2005    -1.091265e+06             0.000000e+00
#                        2006    -1.232425e+06             0.000000e+00
#                        2007    -4.466950e+05             0.000000e+00
#                        2008    -2.974916e+05             0.000000e+00
#                        2009    -5.136187e+05             0.000000e+00
#                        2010    -2.376005e+05             0.000000e+00
#                        2011    -3.978126e+05             0.000000e+00
#                        2012    -1.771213e+04             0.000000e+00
#                        2013    -8.639302e+03            -4.318184e+06
#                        2014     1.199413e+04            -5.985524e+06
#                        2015     3.723570e+04            -6.305622e+06
#                        2016     4.526788e+04            -6.390819e+06
#                        2017    -1.153425e+05            -6.046772e+06
#                        2018    -6.915370e+04            -5.765897e+06
#              1         2002     0.000000e+00             0.000000e+00
#                        2003    -8.894259e+05             0.000000e+00
#                        2004    -7.486988e+05             0.000000e+00
#
#                              YEARS_SINCE_TNC_RAIL_FAC  BIKE_SHARE_BUS_FAC  \
# CLUSTER_APTA RAIL_FLAG Year
# 10.0         0         2002                       0.0        0.000000e+00
#                        2003                       0.0        0.000000e+00
#                        2004                       0.0        0.000000e+00
#                        2005                       0.0        0.000000e+00
#                        2006                       0.0        0.000000e+00
#                        2007                       0.0        0.000000e+00
#                        2008                       0.0        0.000000e+00
#                        2009                       0.0        0.000000e+00
#                        2010                       0.0        0.000000e+00
#                        2011                       0.0       -2.450383e+06
#                        2012                       0.0        0.000000e+00
#                        2013                       0.0        0.000000e+00
#                        2014                       0.0        0.000000e+00
#                        2015                       0.0       -1.390181e+06
#                        2016                       0.0       -1.720118e+06
#                        2017                       0.0        0.000000e+00
#                        2018                       0.0        0.000000e+00
#              1         2002                       0.0        0.000000e+00
#                        2003                       0.0        0.000000e+00
#                        2004                       0.0        0.000000e+00
#
#                              scooter_flag_BUS_FAC  \
# CLUSTER_APTA RAIL_FLAG Year
# 10.0         0         2002          0.000000e+00
#                        2003          0.000000e+00
#                        2004          0.000000e+00
#                        2005          0.000000e+00
#                        2006          0.000000e+00
#                        2007          0.000000e+00
#                        2008          0.000000e+00
#                        2009          0.000000e+00
#                        2010          0.000000e+00
#                        2011          0.000000e+00
#                        2012          0.000000e+00
#                        2013          0.000000e+00
#                        2014          0.000000e+00
#                        2015          0.000000e+00
#                        2016          0.000000e+00
#                        2017          0.000000e+00
#                        2018         -1.026510e+07
#              1         2002          0.000000e+00
#                        2003          0.000000e+00
#                        2004          0.000000e+00
#
#                              BIKE_SCOOTER_SCOOTER_RAIL_FAC  MAINTENANCE_FAC  \
# CLUSTER_APTA RAIL_FLAG Year
# 10.0         0         2002                            0.0              0.0
#                        2003                            0.0              0.0
#                        2004                            0.0              0.0
#                        2005                            0.0              0.0
#                        2006                            0.0              0.0
#                        2007                            0.0              0.0
#                        2008                            0.0              0.0
#                        2009                            0.0              0.0
#                        2010                            0.0              0.0
#                        2011                            0.0              0.0
#                        2012                            0.0              0.0
#                        2013                            0.0              0.0
#                        2014                            0.0              0.0
#                        2015                            0.0              0.0
#                        2016                            0.0              0.0
#                        2017                            0.0              0.0
#                        2018                            0.0              0.0
#              1         2002                            0.0              0.0
#                        2003                            0.0              0.0
#                        2004                            0.0              0.0
#
#                                 Total_FAC  VRM_ADJ_log_FAC_scaled  \
# CLUSTER_APTA RAIL_FLAG Year
# 10.0         0         2002  0.000000e+00            0.000000e+00
#                        2003  2.616473e+07            6.456459e+06
#                        2004  1.790670e+06           -5.877575e+06
#                        2005  1.214328e+07           -2.169195e+06
#                        2006  1.657410e+07            8.026828e+06
#                        2007  6.404352e+06            1.029972e+07
#                        2008  2.268915e+07            9.714489e+06
#                        2009 -9.032197e+06           -7.195423e+05
#                        2010  4.762462e+06           -2.350334e+06
#                        2011 -8.156282e+05           -6.477022e+06
#                        2012 -1.263689e+07           -5.401978e+06
#                        2013 -1.210163e+07           -1.590922e+06
#                        2014  3.216491e+06           -2.732538e+06
#                        2015 -1.425843e+07            1.701768e+07
#                        2016 -1.781948e+07           -1.286075e+06
#                        2017 -2.072506e+06            8.347285e+05
#                        2018 -1.230690e+07            2.076719e+06
#              1         2002  0.000000e+00            0.000000e+00
#                        2003  1.577071e+07           -1.158354e+06
#                        2004  2.499023e+07            1.379524e+06
#
#                              FARE_per_UPT_2018_log_FAC_scaled  \
# CLUSTER_APTA RAIL_FLAG Year
# 10.0         0         2002                      0.000000e+00
#                        2003                      7.672361e+06
#                        2004                     -3.644854e+06
#                        2005                      3.962632e+05
#                        2006                     -6.909766e+06
#                        2007                     -5.213857e+06
#                        2008                      7.781216e+06
#                        2009                      5.205982e+04
#                        2010                     -1.588723e+06
#                        2011                     -7.593841e+06
#                        2012                     -1.115346e+07
#                        2013                     -4.616372e+06
#                        2014                      8.498758e+06
#                        2015                     -1.963577e+06
#                        2016                     -4.772513e+06
#                        2017                      5.017258e+05
#                        2018                     -1.134046e+06
#              1         2002                      0.000000e+00
#                        2003                      3.588419e+06
#                        2004                      8.023689e+06
#
#                              POP_EMP_log_FAC_scaled  \
# CLUSTER_APTA RAIL_FLAG Year
# 10.0         0         2002            0.000000e+00
#                        2003            4.506138e+06
#                        2004            4.940394e+06
#                        2005            5.323305e+06
#                        2006            7.000179e+06
#                        2007            2.472299e+06
#                        2008            1.306904e+06
#                        2009           -2.141992e+05
#                        2010           -1.822863e+06
#                        2011            2.434582e+06
#                        2012            2.922198e+06
#                        2013            2.087488e+06
#                        2014            2.257558e+06
#                        2015            3.920403e+06
#                        2016            2.028262e+06
#                        2017            2.370099e+06
#                        2018            2.595010e+06
#              1         2002            0.000000e+00
#                        2003            5.748464e+06
#                        2004            6.779677e+06
#
#                              GAS_PRICE_2018_log_FAC_scaled  \
# CLUSTER_APTA RAIL_FLAG Year
# 10.0         0         2002                   0.000000e+00
#                        2003                   3.310784e+06
#                        2004                   3.823640e+06
#                        2005                   5.101226e+06
#                        2006                   3.153318e+06
#                        2007                   1.233142e+06
#                        2008                   4.738786e+06
#                        2009                  -1.274662e+07
#                        2010                   6.071598e+06
#                        2011                   8.881671e+06
#                        2012                   2.435508e+05
#                        2013                  -1.369375e+06
#                        2014                  -1.441353e+06
#                        2015                  -1.749171e+07
#                        2016                  -3.123591e+06
#                        2017                   2.547233e+06
#                        2018                   2.610206e+06
#              1         2002                   0.000000e+00
#                        2003                   4.280358e+06
#                        2004                   5.116064e+06
#
#                              TOTAL_MED_INC_INDIV_2018_log_FAC_scaled  \
# CLUSTER_APTA RAIL_FLAG Year
# 10.0         0         2002                             0.000000e+00
#                        2003                             2.206894e+06
#                        2004                             2.968282e+06
#                        2005                             2.967281e+06
#                        2006                             4.647752e+06
#                        2007                            -7.635629e+05
#                        2008                             6.068028e+05
#                        2009                             3.523941e+06
#                        2010                             3.153114e+06
#                        2011                             2.961844e+06
#                        2012                             2.777465e+05
#                        2013                            -2.208499e+06
#                        2014                            -2.717885e+05
#                        2015                            -4.600393e+06
#                        2016                            -2.325215e+06
#                        2017                            -9.155403e+05
#                        2018                            -1.409471e+06
#              1         2002                             0.000000e+00
#                        2003                             3.447750e+06
#                        2004                             4.756685e+06
#
#                              Tot_NonUSA_POP_pct_FAC_scaled  \
# CLUSTER_APTA RAIL_FLAG Year
# 10.0         0         2002                   0.000000e+00
#                        2003                  -4.430352e+05
#                        2004                  -4.354471e+05
#                        2005                  -4.112580e+05
#                        2006                  -3.876581e+05
#                        2007                  -4.216176e+05
#                        2008                   1.326442e+06
#                        2009                  -2.978423e+05
#                        2010                   1.079035e+06
#                        2011                   9.758734e+05
#                        2012                  -6.658727e+05
#                        2013                   3.163905e+05
#                        2014                   6.055485e+05
#                        2015                   5.747289e+05
#                        2016                   9.108731e+05
#                        2017                  -1.760806e+05
#                        2018                   6.856029e+04
#              1         2002                   0.000000e+00
#                        2003                  -4.760751e+05
#                        2004                  -4.460415e+05
#
#                              PCT_HH_NO_VEH_FAC_scaled  TSD_POP_PCT_FAC_scaled  \
# CLUSTER_APTA RAIL_FLAG Year
# 10.0         0         2002                  0.000000            0.000000e+00
#                        2003             329302.113527           -1.051232e+06
#                        2004             341799.274036           -1.067348e+06
#                        2005             264963.604109           -9.359001e+05
#                        2006             671093.325597           -1.040630e+06
#                        2007            -881604.178412           -4.049581e+05
#                        2008             130030.850787           -3.205034e+05
#                        2009             675086.169797           -5.574062e+05
#                        2010             990613.169827           -2.210779e+05
#                        2011             157074.696624           -4.322865e+05
#                        2012            -245912.788064           -1.803633e+04
#                        2013            -623333.100212           -1.112246e+04
#                        2014             373933.499032            3.081759e+04
#                        2015             700703.695016            7.835552e+04
#                        2016            -544069.694692            4.446685e+04
#                        2017            -659102.292554           -1.109138e+05
#                        2018            -593602.975966           -7.590086e+04
#              1         2002                  0.000000            0.000000e+00
#                        2003             605929.763922           -7.619898e+05
#                        2004             677262.992873           -7.693009e+05
#
#                              YEARS_SINCE_TNC_BUS_FAC_scaled  \
# CLUSTER_APTA RAIL_FLAG Year
# 10.0         0         2002                    0.000000e+00
#                        2003                    0.000000e+00
#                        2004                    0.000000e+00
#                        2005                    0.000000e+00
#                        2006                    0.000000e+00
#                        2007                    0.000000e+00
#                        2008                    0.000000e+00
#                        2009                    0.000000e+00
#                        2010                    0.000000e+00
#                        2011                    0.000000e+00
#                        2012                    0.000000e+00
#                        2013                   -4.540372e+06
#                        2014                   -4.585798e+06
#                        2015                   -9.659488e+06
#                        2016                   -5.753154e+06
#                        2017                   -5.578286e+06
#                        2018                   -5.670090e+06
#              1         2002                    0.000000e+00
#                        2003                    0.000000e+00
#                        2004                    0.000000e+00
#
#                              YEARS_SINCE_TNC_RAIL_FAC_scaled  \
# CLUSTER_APTA RAIL_FLAG Year
# 10.0         0         2002                              0.0
#                        2003                              0.0
#                        2004                              0.0
#                        2005                              0.0
#                        2006                              0.0
#                        2007                              0.0
#                        2008                              0.0
#                        2009                              0.0
#                        2010                              0.0
#                        2011                              0.0
#                        2012                              0.0
#                        2013                              0.0
#                        2014                              0.0
#                        2015                              0.0
#                        2016                              0.0
#                        2017                              0.0
#                        2018                              0.0
#              1         2002                              0.0
#                        2003                              0.0
#                        2004                              0.0
#
#                              BIKE_SHARE_BUS_FAC_scaled  \
# CLUSTER_APTA RAIL_FLAG Year
# 10.0         0         2002               0.000000e+00
#                        2003               0.000000e+00
#                        2004               0.000000e+00
#                        2005               0.000000e+00
#                        2006               0.000000e+00
#                        2007               0.000000e+00
#                        2008               0.000000e+00
#                        2009               0.000000e+00
#                        2010               0.000000e+00
#                        2011              -3.040092e+06
#                        2012               0.000000e+00
#                        2013               0.000000e+00
#                        2014               0.000000e+00
#                        2015              -2.260446e+06
#                        2016              -1.730271e+06
#                        2017               0.000000e+00
#                        2018               0.000000e+00
#              1         2002               0.000000e+00
#                        2003               0.000000e+00
#                        2004               0.000000e+00
#
#                              scooter_flag_BUS_FAC_scaled  \
# CLUSTER_APTA RAIL_FLAG Year
# 10.0         0         2002                 0.000000e+00
#                        2003                 0.000000e+00
#                        2004                 0.000000e+00
#                        2005                 0.000000e+00
#                        2006                 0.000000e+00
#                        2007                 0.000000e+00
#                        2008                 0.000000e+00
#                        2009                 0.000000e+00
#                        2010                 0.000000e+00
#                        2011                 0.000000e+00
#                        2012                 0.000000e+00
#                        2013                 0.000000e+00
#                        2014                 0.000000e+00
#                        2015                 0.000000e+00
#                        2016                 0.000000e+00
#                        2017                 0.000000e+00
#                        2018                -1.009453e+07
#              1         2002                 0.000000e+00
#                        2003                 0.000000e+00
#                        2004                 0.000000e+00
#
#                              BIKE_SCOOTER_SCOOTER_RAIL_FAC_scaled  \
# CLUSTER_APTA RAIL_FLAG Year
# 10.0         0         2002                                   0.0
#                        2003                                   0.0
#                        2004                                   0.0
#                        2005                                   0.0
#                        2006                                   0.0
#                        2007                                   0.0
#                        2008                                   0.0
#                        2009                                   0.0
#                        2010                                   0.0
#                        2011                                   0.0
#                        2012                                   0.0
#                        2013                                   0.0
#                        2014                                   0.0
#                        2015                                   0.0
#                        2016                                   0.0
#                        2017                                   0.0
#                        2018                                   0.0
#              1         2002                                   0.0
#                        2003                                   0.0
#                        2004                                   0.0
#
#                              MAINTENANCE_FAC_scaled  Total_FAC_scaled
# CLUSTER_APTA RAIL_FLAG Year
# 10.0         0         2002                     0.0      0.000000e+00
#                        2003                     0.0      2.298767e+07
#                        2004                     0.0      1.048892e+06
#                        2005                     0.0      1.053669e+07
#                        2006                     0.0      1.516112e+07
#                        2007                     0.0      6.319558e+06
#                        2008                     0.0      2.528417e+07
#                        2009                     0.0     -1.028453e+07
#                        2010                     0.0      5.311363e+06
#                        2011                     0.0     -2.132196e+06
#                        2012                     0.0     -1.404177e+07
#                        2013                     0.0     -1.255612e+07
#                        2014                     0.0      2.735137e+06
#                        2015                     0.0     -1.368375e+07
#                        2016                     0.0     -1.655129e+07
#                        2017                     0.0     -1.186137e+06
#                        2018                     0.0     -1.162714e+07
#              1         2002                     0.0      0.000000e+00
#                        2003                     0.0      1.527450e+07
#                        2004                     0.0      2.551756e+07
