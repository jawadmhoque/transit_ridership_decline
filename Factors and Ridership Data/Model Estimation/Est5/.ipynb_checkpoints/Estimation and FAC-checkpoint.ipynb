# %%
import pandas as pd
import seaborn as sns
import numpy as np
import linearmodels as lm
import matplotlib
import math
import statsmodels.formula.api as smf
import statsmodels.api as sm

from linearmodels.panel import PanelOLS
from linearmodels.panel import RandomEffects
from linearmodels.panel import FirstDifferenceOLS
from linearmodels.panel import compare
from matplotlib import pyplot as plt

from pandas.api.types import is_numeric_dtype

pd.set_option('display.max_columns', 500)

# %matplotlib inline

# %%
# read the main data set
df=pd.read_csv('estimation_file.csv',
                    encoding='utf-8')
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (5,144) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# exclude if ridership is zero--missing data
df = df[df['UPT_ADJ']>0]

# %%
# exclude problematic data
old_len = len(df)
df = df[df['VRM_ADJ']>0]
new_len = len(df)
print('Excluding ' + str(old_len-new_len) + ' records with missing VRM') 

# exclude problematic data
old_len = len(df)
df = df[df['HH_0Veh']>0]
new_len = len(df)
print('Excluding ' + str(old_len-new_len) + ' records with negative 0 veh HH')
# Out:
# Excluding 3 records with missing VRM
# Excluding 30 records with negative 0 veh HH

# %%
df['BUS_FLAG'] = np.where(df['Mode']=='Bus', 1, 0)
df['RAIL_FLAG'] = np.where(df['Mode']=='Rail', 1, 0)

# %%
# include population + employment
df['POP_EMP'] = df['Tot_Pop'] + df['TOT_EMP_MSA']
df['HH_EMP'] = df['Total_HH'] + df['TOT_EMP_MSA']

# percent of population in transit supportive density
df['TSD_POP_PCT'] = df['POP_CENSUSTRACT'] / df['Tot_Pop']

# percent of pop born outside USA
df['Tot_NonUSA_POP_pct'] = df['Tot_NonUSA_POP'] / df['Tot_Pop'] * 100

# %%
# mode specific effects

df['Bus_VRM_ADJ_RAIL']  = df['Bus_VRM_ADJ'] * df['RAIL_FLAG']
df['Rail_VRM_ADJ_BUS'] = df['Rail_VRM_ADJ']  * df['BUS_FLAG']

df['Bus_VRM_ADJ_RAIL_log'] = np.log(1+df['Bus_VRM_ADJ_RAIL'])
df['Rail_VRM_ADJ_BUS_log'] = np.log(1+df['Rail_VRM_ADJ_BUS'])

# %%
# time effects
df['YEARS_SINCE_2002']  = df['Year'] - 2002

df['YEARS_2002_2010']  = df['Year'].apply(lambda x : min(x-2002, 8))
df['YEARS_AFTER_2010'] = df['Year'].apply(lambda x : max(x-2010, 0))

df['YEARS_2002_2014']  = df['Year'].apply(lambda x : min(x-2002, 12))
df['YEARS_AFTER_2014'] = df['Year'].apply(lambda x : max(x-2014, 0))


df['YEARS_SINCE_2002_BUS']  = df['YEARS_SINCE_2002'] * df['BUS_FLAG']
df['YEARS_SINCE_2002_RAIL'] = df['YEARS_SINCE_2002'] * df['RAIL_FLAG']

df['YEARS_2002_2010_BUS']   = df['YEARS_2002_2010'] * df['BUS_FLAG']
df['YEARS_AFTER_2010_BUS']  = df['YEARS_AFTER_2010']* df['BUS_FLAG']
df['YEARS_2002_2010_RAIL']  = df['YEARS_2002_2010'] * df['RAIL_FLAG']
df['YEARS_AFTER_2010_RAIL'] = df['YEARS_AFTER_2010']* df['RAIL_FLAG']

df['YEARS_2002_2014_BUS']   = df['YEARS_2002_2014'] * df['BUS_FLAG']
df['YEARS_AFTER_2014_BUS']  = df['YEARS_AFTER_2014']* df['BUS_FLAG']
df['YEARS_2002_2014_RAIL']  = df['YEARS_2002_2014'] * df['RAIL_FLAG']
df['YEARS_AFTER_2014_RAIL'] = df['YEARS_AFTER_2014']* df['RAIL_FLAG']

# %%
# calculate bus vs rail stuff

# various bus/rail specifics

df['TNC_FLAG_BUS'] = df['TNC_FLAG'] * df['BUS_FLAG']
df['TNC_FLAG_RAIL'] = df['TNC_FLAG'] * df['RAIL_FLAG']

df['YEARS_SINCE_TNC_BUS'] = df['YEARS_SINCE_TNC'] * df['BUS_FLAG']
df['YEARS_SINCE_TNC_RAIL'] = df['YEARS_SINCE_TNC'] * df['RAIL_FLAG']

df['dockless_flag'] = df['dockCt'].apply(lambda x : min(x,1))
df['scooter_flag']  = df['scooterCt'].apply(lambda x : min(x,1))

df['BIKE_SHARE'] = df['PBS_Flag'] + df['dockless_flag']
df['BIKE_SHARE'] = df['BIKE_SHARE'].apply(lambda x : min(x,1))


df['PBS_Flag_BUS']   = df['PBS_Flag']   * df['BUS_FLAG']
df['dockCt_BUS']     = df['dockCt']     * df['BUS_FLAG']
df['docklessCt_BUS'] = df['docklessCt'] * df['BUS_FLAG']
df['scooterCt_BUS']  = df['scooterCt']  * df['BUS_FLAG']
df['dockless_flag_BUS'] = df['dockless_flag'] * df['BUS_FLAG']
df['scooter_flag_BUS']  = df['scooter_flag']  * df['BUS_FLAG']
df['BIKE_SHARE_BUS']  = df['BIKE_SHARE']  * df['BUS_FLAG']


df['PBS_Flag_RAIL']   = df['PBS_Flag']   * df['RAIL_FLAG']
df['dockCt_RAIL']     = df['dockCt']     * df['RAIL_FLAG']
df['docklessCt_RAIL'] = df['docklessCt'] * df['RAIL_FLAG']
df['scooterCt_RAIL']  = df['scooterCt']  * df['RAIL_FLAG']
df['dockless_flag_RAIL'] = df['dockless_flag'] * df['RAIL_FLAG']
df['scooter_flag_RAIL']  = df['scooter_flag']  * df['RAIL_FLAG']
df['BIKE_SHARE_RAIL']  = df['BIKE_SHARE']  * df['RAIL_FLAG']

# %%
# set the indices
df['ID'] = df['MNAME'] + '-' + df['Mode']
df=df.set_index(['ID','Year'])

# %%
# keep only the numeric columns -- the estimation will give an error otherwise
df = df.select_dtypes(include=[np.number])

# %%
# create a log of all fields
for col in df.columns:
    df[col+'_log'] = np.log(df[col]+1)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:3: RuntimeWarning: invalid value encountered in log
#   app.launch_new_instance()
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:3: RuntimeWarning: divide by zero encountered in log
#   app.launch_new_instance()

# %%
# Out:
# Index(['Akron, OH Metro Area-Bus', 'Albany, GA Metro Area-Bus',
#        'Albany-Schenectady-Troy, NY Metro Area-Bus',
#        'Albuquerque, NM Metro Area-Bus', 'Albuquerque, NM Metro Area-Rail',
#        'Allentown-Bethlehem-Easton, PA-NJ Metro Area-Bus',
#        'Altoona, PA Metro Area-Bus', 'Ames, IA Metro Area-Bus',
#        'Anchorage, AK Metro Area-Bus', 'Ann Arbor, MI Metro Area-Bus',
#        ...
#        'Wichita, KS Metro Area-Bus', 'Williamsport, PA Metro Area-Bus',
#        'Wilmington, NC Metro Area-Bus', 'Winston-Salem, NC Metro Area-Bus',
#        'Worcester, MA Metro Area-Bus', 'Yakima, WA Metro Area-Bus',
#        'York-Hanover, PA Metro Area-Bus',
#        'Youngstown-Warren-Boardman, OH-PA Metro Area-Bus',
#        'Yuba City, CA Metro Area-Bus', 'Yuma, AZ Metro Area-Bus'],
#       dtype='object', name='ID', length=291)

# %%
# calculate lags

ids = df.index.get_level_values(0).unique()
for id in ids: 
    df2 = df.loc[id]
    
    for col in df.columns:
        df2[col + '_lag1'] = df2[col].shift(1)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-a42e1c8fd07d> in <module>()
#       6
#       7     for col in df.columns:
# ----> 8         df2[col + '_lag1'] = df2[col].shift(1)
#
# C:\Program Files\Anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3117         else:
#    3118             # set column
# -> 3119             self._set_item(key, value)
#    3120
#    3121     def _setitem_slice(self, key, value):
#
# C:\Program Files\Anaconda3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3199         # value exception to occur first
#    3200         if len(self):
# -> 3201             self._check_setitem_copy()
#    3202
#    3203     def insert(self, loc, column, value, allow_duplicates=False):
#
# C:\Program Files\Anaconda3\lib\site-packages\pandas\core\generic.py in _check_setitem_copy(self, stacklevel, t, force)
#    2672             try:
#    2673                 gc.collect(2)
# -> 2674                 if not gc.get_referents(self._is_copy()):
#    2675                     self._is_copy = None
#    2676                     return
#
# KeyboardInterrupt:

# %%
df[['UPT_ADJ', 'UPT_ADJ_lag1']]
# Out:
#                                         UPT_ADJ  UPT_ADJ_lag1
# ID                           Year
# Akron, OH Metro Area-Bus     2002  5.226386e+06           NaN
#                              2003  5.395902e+06  5.226386e+06
#                              2004  5.907162e+06  5.395902e+06
#                              2005  6.013681e+06  5.907162e+06
#                              2006  6.070797e+06  6.013681e+06
#                              2007  5.868746e+06  6.070797e+06
#                              2008  6.140429e+06  5.868746e+06
#                              2009  5.560854e+06  6.140429e+06
#                              2010  5.616568e+06  5.560854e+06
#                              2011  5.858953e+06  5.616568e+06
#                              2012  5.996224e+06  5.858953e+06
#                              2013  5.976078e+06  5.996224e+06
#                              2014  5.980822e+06  5.976078e+06
#                              2015  5.854275e+06  5.980822e+06
#                              2016  5.500945e+06  5.854275e+06
#                              2017  5.461312e+06  5.500945e+06
#                              2018  5.427486e+06  5.461312e+06
# Albany, GA Metro Area-Bus    2002  6.283240e+05  5.427486e+06
#                              2003  6.709410e+05  6.283240e+05
#                              2004  6.663280e+05  6.709410e+05
#                              2005  6.538760e+05  6.663280e+05
#                              2006  7.628100e+05  6.538760e+05
#                              2007  7.674140e+05  7.628100e+05
#                              2008  8.808640e+05  7.674140e+05
#                              2009  8.711770e+05  8.808640e+05
#                              2010  9.004060e+05  8.711770e+05
#                              2011  9.858630e+05  9.004060e+05
#                              2012  1.017648e+06  9.858630e+05
#                              2013  1.017015e+06  1.017648e+06
#                              2014  8.830940e+05  1.017015e+06
# ...                                         ...           ...
# Yuba City, CA Metro Area-Bus 2004  1.910000e+02  1.730000e+02
#                              2005  2.320000e+02  1.910000e+02
#                              2006  6.997380e+05  2.320000e+02
#                              2007  8.138180e+05  6.997380e+05
#                              2008  9.538040e+05  8.138180e+05
#                              2009  1.000635e+06  9.538040e+05
#                              2010  1.012255e+06  1.000635e+06
#                              2011  1.111268e+06  1.012255e+06
#                              2012  1.129517e+06  1.111268e+06
#                              2013  1.182420e+06  1.129517e+06
#                              2014  1.218984e+06  1.182420e+06
#                              2015  1.184937e+06  1.218984e+06
#                              2016  1.061357e+06  1.184937e+06
#                              2017  9.484240e+05  1.061357e+06
#                              2018  9.033860e+05  9.484240e+05
# Yuma, AZ Metro Area-Bus      2004  3.797404e+04  9.033860e+05
#                              2005  1.479212e+05  3.797404e+04
#                              2006  2.309756e+05  1.479212e+05
#                              2007  2.522965e+05  2.309756e+05
#                              2008  3.077812e+05  2.522965e+05
#                              2009  3.249207e+05  3.077812e+05
#                              2010  2.962890e+05  3.249207e+05
#                              2011  2.513060e+05  2.962890e+05
#                              2012  1.583911e+05  2.513060e+05
#                              2013  4.189104e+05  1.583911e+05
#                              2014  4.703299e+05  4.189104e+05
#                              2015  4.394423e+05  4.703299e+05
#                              2016  4.118686e+05  4.394423e+05
#                              2017  4.176748e+05  4.118686e+05
#                              2018  4.524758e+05  4.176748e+05
#
# [4535 rows x 2 columns]

# %%
df.to_csv('temp.csv')

# %%
# check the data
df.head()
# Out:
#                                Unnamed: 0   CBSA          UPT          VRM  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002           0  10420  5226385.660  4026372.388
#                          2003           1  10420  5395901.888  3976568.624
#                          2004           2  10420  5907162.281  4315392.555
#                          2005           3  10420  6013680.881  4053011.065
#                          2006           4  10420  6070797.419  3994786.013
#
#                                    UPT_ADJ      VRM_ADJ      VRH_ADJ  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002  5226385.660  4026372.388  270506.6928
#                          2003  5395901.888  3976568.624  270398.3688
#                          2004  5907162.281  4315392.555  597239.8605
#                          2005  6013680.881  4053011.065  281367.9792
#                          2006  6070797.419  3994786.013  281536.7841
#
#                                FARE_TOTAL  FARE_per_UPT  AREALANDPT  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002    660887.0      0.114148   744634347
#                          2003   2568502.0      0.429694   744634347
#                          2004   2524882.0      0.385839   744634347
#                          2005   3022880.0      0.453758   744634347
#                          2006   3163036.0      0.470329   744634347
#
#                                    Tot_Pop  Tot_Instate_Pop  Tot_Outstate_Pop  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002  646583.7344      496141.0469       137193.6719
#                          2003  659397.0625      504631.8125       137582.3125
#                          2004  672492.7500      513183.7500       138058.7500
#                          2005  684459.0000      521491.0000       138184.0000
#                          2006  700943.0000      530777.0000       139714.0000
#
#                                Tot_NonUSA_POP  Total_Median_Income_Individual  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002      -389.53125                     25405.20313
#                          2003       753.12500                     25120.18750
#                          2004      1942.50000                     24804.25000
#                          2005      2945.00000                     24612.00000
#                          2006      4695.00000                     23925.00000
#
#                                Native_Instate_Med_Inc_Indiv  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                   26028.32813
#                          2003                   25632.68750
#                          2004                   25208.25000
#                          2005                   24899.00000
#                          2006                   24129.00000
#
#                                Native_Outstate_Med_Inc_Indiv  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                    26651.07813
#                          2003                    25995.68750
#                          2004                    25305.25000
#                          2005                    24755.00000
#                          2006                    23644.00000
#
#                                Total_Pop_Poverty  Pop_Below100_Poverty  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002          682354.11                  7.55
#                          2003          682850.56                  8.81
#                          2004          683397.75                 10.08
#                          2005          683742.00                 11.30
#                          2006          684898.00                 12.70
#
#                                Pop_Below150_Poverty  Pop_Above150_Poverty  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                
2018  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002        77420.7875          1.9040
#                          2003        77240.2575          2.1235
#                          2004        76328.7000          2.4339
#                          2005        75692.0400          2.9025
#                          2006        73573.7500          3.1750
#
#                                FARE_per_UPT_2018  dockCt  docklessCt  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002           0.177033     0.0         0.0
#                          2003           0.652133     0.0         0.0
#                          2004           0.568478     0.0         0.0
#                          2005           0.648441     0.0         0.0
#                          2006           0.651281     0.0         0.0
#
#                                scooterCt  PBS_Start  PBS_End  PBS_Flag  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002        0.0        NaN      NaN       0.0
#                          2003        0.0        NaN      NaN       0.0
#                          2004        0.0        NaN      NaN       0.0
#                          2005        0.0        NaN      NaN       0.0
#                          2006        0.0        NaN      NaN       0.0
#
#                                walkscore  transit  bike  Bus_UPT_ADJ  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002        0.0      0.0   0.0  5226385.660
#                          2003        0.0      0.0   0.0  5395901.888
#                          2004        0.0      0.0   0.0  5907162.281
#                          2005        0.0      0.0   0.0  6013680.881
#                          2006        0.0      0.0   0.0  6070797.419
#
#                                Bus_UPT_ADJ_diff  Bus_UPT_ADJ_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002             0.000        15.469231
#                          2003        169516.228        15.501150
#                          2004        511260.393        15.591676
#                          2005        106518.600        15.609548
#                          2006         57116.538        15.619001
#
#                                PCT_Bus_UPT_ADJ_rel_diff  Bus_UPT_ADJ_scale  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                  0.000000          3480102.0
#                          2003                  3.243470          3480102.0
#                          2004                  9.474976          3480102.0
#                          2005                  1.803211          3480102.0
#                          2006                  0.949777          3480102.0
#
#                                Bus_VRM_ADJ  Bus_VRM_ADJ_diff  Bus_VRM_ADJ_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002  4026372.388             0.000        15.208377
#                          2003  3976568.624        -49803.764        15.195930
#                          2004  4315392.555        338823.931        15.277699
#                          2005  4053011.065       -262381.490        15.214971
#                          2006  3994786.013        -58225.052        15.200501
#
#                                PCT_Bus_VRM_ADJ_rel_diff  Bus_VRM_ADJ_scale  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                  0.000000         -2165039.5
#                          2003                 -1.236939         -2165039.5
#                          2004                  8.520510         -2165039.5
#                          2005                 -6.080130         -2165039.5
#                          2006                 -1.436588         -2165039.5
#
#                                Bus_VRH_ADJ  Bus_VRH_ADJ_diff  Bus_VRH_ADJ_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002  270506.6928            0.0000        12.508056
#                          2003  270398.3688         -108.3240        12.507655
#                          2004  597239.8605       326841.4917        13.300076
#                          2005  281367.9792      -315871.8813        12.547422
#                          2006  281536.7841          168.8049        12.548022
#
#                                PCT_Bus_VRH_ADJ_rel_diff  Bus_VRH_ADJ_scale  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                  0.000000          -60840.25
#                          2003                 -0.040045          -60840.25
#                          2004                120.874062          -60840.25
#                          2005                -52.888613          -60840.25
#                          2006                  0.059994          -60840.25
#
#                                Bus_FARE_TOTAL  Bus_FARE_TOTAL_diff  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002        660887.0                  0.0
#                          2003       2568502.0            1907615.0
#                          2004       2524882.0             -43620.0
#                          2005       3022880.0             497998.0
#                          2006       3163036.0             140156.0
#
#                                Bus_FARE_TOTAL_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002           13.401340
#                          2003           14.758834
#                          2004           14.741705
#                          2005           14.921721
#                          2006           14.967043
#
#                                PCT_Bus_FARE_TOTAL_rel_diff  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                     0.000000
#                          2003                   288.644655
#                          2004                    -1.698266
#                          2005                    19.723615
#                          2006                     4.636506
#
#                                Bus_FARE_TOTAL_scale  Bus_FARE_per_UPT_2018  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002            -4804550.0               0.177033
#                          2003            -4804550.0               0.652133
#                          2004            -4804550.0               0.568478
#                          2005            -4804550.0               0.648441
#                          2006            -4804550.0               0.651281
#
#                                Bus_FARE_per_UPT_2018_diff  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                    0.000000
#                          2003                    0.475101
#                          2004                   -0.083655
#                          2005                    0.079962
#                          2006                    0.002840
#
#                                Bus_FARE_per_UPT_2018_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                   0.162997
#                          2003                   0.502067
#                          2004                   0.450106
#                          2005                   0.499830
#                          2006                   0.501551
#
#                                PCT_Bus_FARE_per_UPT_2018_rel_diff  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                            0.000000
#                          2003                          268.368630
#                          2004                          -12.827923
#                          2005                           14.066053
#                          2006                            0.438026
#
#                                Bus_FARE_per_UPT_2018_scale  Bus_AVG_SPEED  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                   -20.320026          14.88
#                          2003                   -20.320026          14.71
#                          2004                   -20.320026           7.23
#                          2005                   -20.320026          14.40
#                          2006                   -20.320026          14.19
#
#                                Bus_AVG_SPEED_diff  Bus_AVG_SPEED_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                0.00           2.765060
#                          2003               -0.17           2.754297
#                          2004               -7.48           2.107786
#                          2005                7.17           2.734368
#                          2006               -0.21           2.720637
#
#                                PCT_Bus_AVG_SPEED_rel_diff  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                    0.000000
#                          2003                   -1.142473
#                          2004                  -50.849762
#                          2005                   99.170124
#                          2006                   -1.458333
#
#                                Bus_AVG_SPEED_scale  Rail_UPT_ADJ  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                -22.0           0.0
#                          2003                -22.0           0.0
#                          2004                -22.0           0.0
#                          2005                -22.0           0.0
#                          2006                -22.0           0.0
#
#                                Rail_UPT_ADJ_diff  Rail_UPT_ADJ_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                0.0               0.0
#                          2003                0.0               0.0
#                          2004                0.0               0.0
#                          2005                0.0               0.0
#                          2006                0.0               0.0
#
#                                PCT_Rail_UPT_ADJ_rel_diff  Rail_UPT_ADJ_scale  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                        0.0       -1.988719e+08
#                          2003                        0.0       -1.988719e+08
#                          2004                        0.0       -1.988719e+08
#                          2005                        0.0       -1.988719e+08
#                          2006                        0.0       -1.988719e+08
#
#                                Rail_VRM_ADJ  Rail_VRM_ADJ_diff  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002           0.0                0.0
#                          2003           0.0                0.0
#                          2004           0.0                0.0
#                          2005           0.0                0.0
#                          2006           0.0                0.0
#
#                                Rail_VRM_ADJ_log  PCT_Rail_VRM_ADJ_rel_diff  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002               0.0                        0.0
#                          2003               0.0                        0.0
#                          2004               0.0                        0.0
#                          2005               0.0                        0.0
#                          2006               0.0                        0.0
#
#                                Rail_VRM_ADJ_scale  Rail_VRH_ADJ  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002        2.720957e+08           0.0
#                          2003        2.720957e+08           0.0
#                          2004        2.720957e+08           0.0
#                          2005        2.720957e+08           0.0
#                          2006        2.720957e+08           0.0
#
#                                Rail_VRH_ADJ_diff  Rail_VRH_ADJ_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                0.0               0.0
#                          2003                0.0               0.0
#                          2004                0.0               0.0
#                          2005                0.0               0.0
#                          2006                0.0               0.0
#
#                                PCT_Rail_VRH_ADJ_rel_diff  Rail_VRH_ADJ_scale  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                        0.0          20967885.2
#                          2003                        0.0          20967885.2
#                          2004                        0.0          20967885.2
#                          2005                        0.0          20967885.2
#                          2006                        0.0          20967885.2
#
#                                Rail_FARE_TOTAL  Rail_FARE_TOTAL_diff  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002              0.0                   0.0
#                          2003              0.0                   0.0
#                          2004              0.0                   0.0
#                          2005              0.0                   0.0
#                          2006              0.0                   0.0
#
#                                Rail_FARE_TOTAL_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                  0.0
#                          2003                  0.0
#                          2004                  0.0
#                          2005                  0.0
#                          2006                  0.0
#
#                                PCT_Rail_FARE_TOTAL_rel_diff  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                           0.0
#                          2003                           0.0
#                          2004                           0.0
#                          2005                           0.0
#                          2006                           0.0
#
#                                Rail_FARE_TOTAL_scale  Rail_FARE_per_UPT_2018  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002          -4.884542e+09                     0.0
#                          2003          -4.884542e+09                     0.0
#                          2004          -4.884542e+09                     0.0
#                          2005          -4.884542e+09                     0.0
#                          2006          -4.884542e+09                     0.0
#
#                                Rail_FARE_per_UPT_2018_diff  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                          0.0
#                          2003                          0.0
#                          2004                          0.0
#                          2005                          0.0
#                          2006                          0.0
#
#                                Rail_FARE_per_UPT_2018_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                         0.0
#                          2003                         0.0
#                          2004                         0.0
#                          2005                         0.0
#                          2006                         0.0
#
#                                PCT_Rail_FARE_per_UPT_2018_rel_diff  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                                  0.0
#                          2003                                  0.0
#                          2004                                  0.0
#                          2005                                  0.0
#                          2006                                  0.0
#
#                                Rail_FARE_per_UPT_2018_scale  Rail_AVG_SPEED  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                    -23.689697             0.0
#                          2003                    -23.689697             0.0
#                          2004                    -23.689697             0.0
#                          2005                    -23.689697             0.0
#                          2006                    -23.689697             0.0
#
#                                Rail_AVG_SPEED_diff  Rail_AVG_SPEED_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                  0.0                 0.0
#                          2003                  0.0                 0.0
#                          2004                  0.0                 0.0
#                          2005                  0.0                 0.0
#                          2006                  0.0                 0.0
#
#                                PCT_Rail_AVG_SPEED_rel_diff  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                          0.0
#                          2003                          0.0
#                          2004                          0.0
#                          2005                          0.0
#                          2006                          0.0
#
#                                Rail_AVG_SPEED_scale  CLUSTER_GT_NEW_11  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                 -62.0                1.0
#                          2003                 -62.0                1.0
#                          2004                 -62.0                1.0
#                          2005                 -62.0                1.0
#                          2006                 -62.0                1.0
#
#                                CLUSTER_GT_ORIGINAL  CLUSTER_APTA  BUS_FLAG  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                  1.0          24.0         1
#                          2003                  1.0          24.0         1
#                          2004                  1.0          24.0         1
#                          2005                  1.0          24.0         1
#                          2006                  1.0          24.0         1
#
#                                RAIL_FLAG       POP_EMP     HH_EMP  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002          0  9.927309e+05  611599.37
#                          2003          0  1.007971e+06  617718.36
#                          2004          0  1.024216e+06  624616.00
#                          2005          0  1.042565e+06  634521.92
#                          2006          0  1.066076e+06  645970.33
#
#                                TSD_POP_PCT  YEARS_SINCE_2002  YEARS_2002_2010  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002     0.185260                 0                0
#                          2003     0.180770                 1                1
#                          2004     0.176377                 2                2
#                          2005     0.172435                 3                3
#                          2006     0.167543                 4                4
#
#                                YEARS_AFTER_2010  YEARS_2002_2014  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                 0                0
#                          2003                 0                1
#                          2004                 0                2
#                          2005                 0                3
#                          2006                 0                4
#
#                                YEARS_AFTER_2014  YEARS_SINCE_2002_BUS  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                
log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                  2.296567
#                          2003                  2.267994
#                          2004                  2.238580
#                          2005                  2.208274
#                          2006                  2.174752
#
#                                Pop_Above150_Poverty_log  Age_under18_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                  4.440885         3.244154
#                          2003                  4.428314         3.231989
#                          2004                  4.415582         3.218876
#                          2005                  4.403054         3.206803
#                          2006                  4.388257         3.190476
#
#                                Age_18to64_log  Age_over64_log  Total_HH_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002        4.157319        2.599722     12.489194
#                          2003        4.158883        2.615935     12.503006
#                          2004        4.160444        2.631889     12.516836
#                          2005        4.162003        2.646175     12.529666
#                          2006        4.163560        2.667228     12.545533
#
#                                HH_0Veh_log  HH_1Veh_log  HH_2Veh_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002    10.035881    10.972594    11.670649
#                          2003    10.002176    11.118429    11.656541
#                          2004     9.964924    11.248911    11.641275
#                          2005     9.936052    11.352745    11.629650
#                          2006     9.865214    11.488305    11.602099
#
#                                HH_3Veh_log  HH_4+Veh_log  PCT_HH_NO_VEH_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002    10.755614      9.922985           2.261763
#                          2003    10.711656      9.870600           2.219203
#                          2004    10.665613      9.813686           2.173615
#                          2005    10.617613      9.760252           2.136531
#                          2006    10.566072      9.674200           2.060514
#
#                                HH_MED_INC_log  HH_MEAN_INC_log  INC_U35_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002       10.670067        10.920556     3.701055
#                          2003       10.682071        10.939883     3.694862
#                          2004       10.692655        10.957643     3.689629
#                          2005       10.708176        10.979803     3.681351
#                          2006       10.703424        10.982917     3.683867
#
#                                INC_35_100_log  INC_100P_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002        3.861992      2.704711
#                          2003        3.864092      2.714695
#                          2004        3.866607      2.721295
#                          2005        3.867026      2.740840
#                          2006        3.875359      2.708050
#
#                                TOT_UNEMP_MSA_log  TOT_EMP_MSA_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002           9.996496        12.754622
#                          2003          10.058074        12.761609
#                          2004          10.063595        12.770604
#                          2005          10.017787        12.788587
#                          2006           9.920791        12.808021
#
#                                TOT_LABOR_MSA_log  UNEMP_RATE_PCT_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002          12.816101            1.940179
#                          2003          12.826428            1.985131
#                          2004          12.835205            1.982380
#                          2005          12.849314            1.931521
#                          2006          12.862251            1.837370
#
#                                EMP_RATE_PCT_log  GasPrice_log  Area_acre_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002          4.554298      0.858662            NaN
#                          2003          4.550925      0.936093            NaN
#                          2004          4.551136      1.040277            NaN
#                          2005          4.554929      1.178655       9.521187
#                          2006          4.561427      1.264127       9.521187
#
#                                POP_CENSUSTRACT_log  AVG_SPEED_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002            11.693470       2.765060
#                          2003            11.688558       2.754297
#                          2004            11.683621       2.107786
#                          2005            11.678660       2.734368
#                          2006            11.673674       2.720637
#
#                                2018_Dollar_Multiplier_log  TNC_ARRIVAL_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                    0.875469         7.608374
#                          2003                    0.862890         7.608374
#                          2004                    0.845868         7.608374
#                          2005                    0.828552         7.608374
#                          2006                    0.810930         7.608374
#
#                                TNC_FLAG_log  YEARS_SINCE_TNC_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002           0.0                  0.0
#                          2003           0.0                  0.0
#                          2004           0.0                  0.0
#                          2005           0.0                  0.0
#                          2006           0.0                  0.0
#
#                                FARE_TOTAL_2018_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002            13.737811
#                          2003            15.073644
#                          2004            15.026884
#                          2005            15.176363
#                          2006            15.190187
#
#                                TOTAL_MED_INC_INDIV_2018_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                     10.479210
#                          2003                     10.446267
#                          2004                     10.403980
#                          2005                     10.365663
#                          2006                     10.305856
#
#                                NATIVE_INSTATE_MED_INC_2018_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                        10.503440
#                          2003                        10.466463
#                          2004                        10.420135
#                          2005                        10.377256
#                          2006                        10.314346
#
#                                NATIVE_OUTSTATE_MED_INC_2018_log  \
# ...
#
#                                PCT_Rail_UPT_ADJ_rel_diff_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                            0.0
#                          2003                            0.0
#                          2004                            0.0
#                          2005                            0.0
#                          2006                            0.0
#
#                                Rail_UPT_ADJ_scale_log  Rail_VRM_ADJ_diff_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                     NaN                    0.0
#                          2003                     NaN                    0.0
#                          2004                     NaN                    0.0
#                          2005                     NaN                    0.0
#                          2006                     NaN                    0.0
#
#                                Rail_VRM_ADJ_log_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                   0.0
#                          2003                   0.0
#                          2004                   0.0
#                          2005                   0.0
#                          2006                   0.0
#
#                                PCT_Rail_VRM_ADJ_rel_diff_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                            0.0
#                          2003                            0.0
#                          2004                            0.0
#                          2005                            0.0
#                          2006                            0.0
#
#                                Rail_VRM_ADJ_scale_log  Rail_VRH_ADJ_diff_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002               19.421665                    0.0
#                          2003               19.421665                    0.0
#                          2004               19.421665                    0.0
#                          2005               19.421665                    0.0
#                          2006               19.421665                    0.0
#
#                                Rail_VRH_ADJ_log_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                   0.0
#                          2003                   0.0
#                          2004                   0.0
#                          2005                   0.0
#                          2006                   0.0
#
#                                PCT_Rail_VRH_ADJ_rel_diff_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                            0.0
#                          2003                            0.0
#                          2004                            0.0
#                          2005                            0.0
#                          2006                            0.0
#
#                                Rail_VRH_ADJ_scale_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002               16.858503
#                          2003               16.858503
#                          2004               16.858503
#                          2005               16.858503
#                          2006               16.858503
#
#                                Rail_FARE_TOTAL_diff_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                       0.0
#                          2003                       0.0
#                          2004                       0.0
#                          2005                       0.0
#                          2006                       0.0
#
#                                Rail_FARE_TOTAL_log_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                      0.0
#                          2003                      0.0
#                          2004                      0.0
#                          2005                      0.0
#                          2006                      0.0
#
#                                PCT_Rail_FARE_TOTAL_rel_diff_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                               0.0
#                          2003                               0.0
#                          2004                               0.0
#                          2005                               0.0
#                          2006                               0.0
#
#                                Rail_FARE_TOTAL_scale_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                        NaN
#                          2003                        NaN
#                          2004                        NaN
#                          2005                        NaN
#                          2006                        NaN
#
#                                Rail_FARE_per_UPT_2018_diff_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                              0.0
#                          2003                              0.0
#                          2004                              0.0
#                          2005                              0.0
#                          2006                              0.0
#
#                                Rail_FARE_per_UPT_2018_log_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                             0.0
#                          2003                             0.0
#                          2004                             0.0
#                          2005                             0.0
#                          2006                             0.0
#
#                                PCT_Rail_FARE_per_UPT_2018_rel_diff_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                                      0.0
#                          2003                                      0.0
#                          2004                                      0.0
#                          2005                                      0.0
#                          2006                                      0.0
#
#                                Rail_FARE_per_UPT_2018_scale_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                               NaN
#                          2003                               NaN
#                          2004                               NaN
#                          2005                               NaN
#                          2006                               NaN
#
#                                Rail_AVG_SPEED_diff_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                      0.0
#                          2003                      0.0
#                          2004                      0.0
#                          2005                      0.0
#                          2006                      0.0
#
#                                Rail_AVG_SPEED_log_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                     0.0
#                          2003                     0.0
#                          2004                     0.0
#                          2005                     0.0
#                          2006                     0.0
#
#                                PCT_Rail_AVG_SPEED_rel_diff_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                              0.0
#                          2003                              0.0
#                          2004                              0.0
#                          2005                              0.0
#                          2006                              0.0
#
#                                Rail_AVG_SPEED_scale_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                       NaN
#                          2003                       NaN
#                          2004                       NaN
#                          2005                       NaN
#                          2006                       NaN
#
#                                CLUSTER_GT_NEW_11_log  CLUSTER_GT_ORIGINAL_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002               0.693147                 0.693147
#                          2003               0.693147                 0.693147
#                          2004               0.693147                 0.693147
#                          2005               0.693147                 0.693147
#                          2006               0.693147                 0.693147
#
#                                CLUSTER_APTA_log  BUS_FLAG_log  RAIL_FLAG_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002          3.218876      0.693147            0.0
#                          2003          3.218876      0.693147            0.0
#                          2004          3.218876      0.693147            0.0
#                          2005          3.218876      0.693147            0.0
#                          2006          3.218876      0.693147            0.0
#
#                                POP_EMP_log  HH_EMP_log  TSD_POP_PCT_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002    13.808216   13.323834         0.169962
#                          2003    13.823451   13.333790         0.166167
#                          2004    13.839439   13.344894         0.162439
#                          2005    13.857195   13.360629         0.159083
#                          2006    13.879496   13.378510         0.154901
#
#                                YEARS_SINCE_2002_log  YEARS_2002_2010_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002              0.000000             0.000000
#                          2003              0.693147             0.693147
#                          2004              1.098612             1.098612
#                          2005              1.386294             1.386294
#                          2006              1.609438             1.609438
#
#                                YEARS_AFTER_2010_log  YEARS_2002_2014_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                   0.0             0.000000
#                          2003                   0.0             0.693147
#                          2004                   0.0             1.098612
#                          2005                   0.0             1.386294
#                          2006                   0.0             1.609438
#
#                                YEARS_AFTER_2014_log  YEARS_SINCE_2002_BUS_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                   0.0                  0.000000
#                          2003                   0.0                  0.693147
#                          2004                   0.0                  1.098612
#                          2005                   0.0                  1.386294
#                          2006                   0.0                  1.609438
#
#                                YEARS_SINCE_2002_RAIL_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                        0.0
#                          2003                        0.0
#                          2004                        0.0
#                          2005                        0.0
#                          2006                        0.0
#
#                                YEARS_2002_2010_BUS_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                 0.000000
#                          2003                 0.693147
#                          2004                 1.098612
#                          2005                 1.386294
#                          2006                 1.609438
#
#                                YEARS_AFTER_2010_BUS_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                       0.0
#                          2003                       0.0
#                          2004                       0.0
#                          2005                       0.0
#                          2006                       0.0
#
#                                YEARS_2002_2010_RAIL_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                       0.0
#                          2003                       0.0
#                          2004                       0.0
#                          2005                       0.0
#                          2006                       0.0
#
#                                YEARS_AFTER_2010_RAIL_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                        0.0
#                          2003                        0.0
#                          2004                        0.0
#                          2005                        0.0
#                          2006                        0.0
#
#                                YEARS_2002_2014_BUS_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                 0.000000
#                          2003                 0.693147
#                          2004                 1.098612
#                          2005                 1.386294
#                          2006                 1.609438
#
#                                YEARS_AFTER_2014_BUS_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                       0.0
#                          2003                       0.0
#                          2004                       0.0
#                          2005                       0.0
#                          2006                       0.0
#
#                                YEARS_2002_2014_RAIL_log  \
# ID                       Year
# Akron, OH Metro Area-Bus 2002                       0.0
#                          2003                       0.0
#                          2004                       0.0
#                          2005                       0.0
#                          2006                       0.0
#
#                                YEARS_AFTER_2014_RAIL_log
# ID                       Year
# Akron, OH Metro Area-Bus 2002                        0.0
#                          2003                        0.0
#                          2004                        0.0
#                          2005                        0.0
#                          2006                        0.0

# %% [markdown]
# ## Some core model specification tests -- looking at traditional factors

# %%
# no time trends

mod=PanelOLS.from_formula('UPT_ADJ_log \
                    ~ VRM_ADJ_log \
                    + FARE_per_UPT_log \
                    + POP_EMP_log \
                    + GasPrice_log \
                    + PCT_HH_NO_VEH \
                    + TSD_POP_PCT \
                    + EntityEffects \
                    ',data=df)
res=mod.fit()
print(res)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\data.py:39: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   new_df = df.copy().loc[self._full_index]
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\utility.py:476: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   warnings.warn(missing_value_warning_msg, MissingValueWarning)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:            UPT_ADJ_log   R-squared:                        0.4863
# Estimator:                   PanelOLS   R-squared (Between):              0.9913
# No. Observations:                4247   R-squared (Within):               0.4863
# Date:                Thu, Nov 21 2019   R-squared (Overall):              0.9920
# Time:                        11:08:39   Log-likelihood                   -639.15
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      626.21
# Entities:                         272   P-value                           0.0000
# Avg Obs:                       15.614   Distribution:                  F(6,3969)
# Min Obs:                       1.0000
# Max Obs:                       17.000   F-statistic (robust):             626.21
#                                         P-value                           0.0000
# Time periods:                      17   Distribution:                  F(6,3969)
# Avg Obs:                       249.82
# Min Obs:                       180.00
# Max Obs:                       271.00
#
#                                 Parameter Estimates
# ====================================================================================
#                   Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------
# VRM_ADJ_log          0.3365     0.0105     31.939     0.0000      0.3159      0.3572
# FARE_per_UPT_log    -0.7385     0.0167    -44.202     0.0000     -0.7713     -0.7058
# POP_EMP_log          0.8025     0.0791     10.141     0.0000      0.6473      0.9576
# GasPrice_log         0.4427     0.0301     14.704     0.0000      0.3836      0.5017
# PCT_HH_NO_VEH        0.0197     0.0046     4.2995     0.0000      0.0107      0.0287
# TSD_POP_PCT          0.5435     0.2266     2.3983     0.0165      0.0992      0.9877
# ====================================================================================
#
# F-test for Poolability: 51.365
# P-value: 0.0000
# Distribution: F(271,3969)
#
# Included effects: Entity

# %%
# add average speed

mod=PanelOLS.from_formula('UPT_ADJ_log \
                    ~ VRM_ADJ_log \
                    + AVG_SPEED_log \
                    + FARE_per_UPT_log \
                    + POP_EMP_log \
                    + GasPrice_log \
                    + PCT_HH_NO_VEH \
                    + TSD_POP_PCT \
                    + EntityEffects \
                    ',data=df)
res=mod.fit()
print(res)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\data.py:39: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   new_df = df.copy().loc[self._full_index]
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\utility.py:476: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   warnings.warn(missing_value_warning_msg, MissingValueWarning)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:            UPT_ADJ_log   R-squared:                        0.5037
# Estimator:                   PanelOLS   R-squared (Between):              0.9975
# No. Observations:                4247   R-squared (Within):               0.5037
# Date:                Thu, Nov 21 2019   R-squared (Overall):              0.9976
# Time:                        11:13:14   Log-likelihood                   -566.14
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      575.22
# Entities:                         272   P-value                           0.0000
# Avg Obs:                       15.614   Distribution:                  F(7,3968)
# Min Obs:                       1.0000
# Max Obs:                       17.000   F-statistic (robust):             575.22
#                                         P-value                           0.0000
# Time periods:                      17   Distribution:                  F(7,3968)
# Avg Obs:                       249.82
# Min Obs:                       180.00
# Max Obs:                       271.00
#
#                                 Parameter Estimates
# ====================================================================================
#                   Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------
# VRM_ADJ_log          0.3895     0.0113     34.492     0.0000      0.3674      0.4117
# AVG_SPEED_log       -0.3780     0.0321    -11.781     0.0000     -0.4409     -0.3151
# FARE_per_UPT_log    -0.7302     0.0164    -44.414     0.0000     -0.7624     -0.6980
# POP_EMP_log          0.7499     0.0779     9.6240     0.0000      0.5971      0.9026
# GasPrice_log         0.4276     0.0296     14.433     0.0000      0.3695      0.4856
# PCT_HH_NO_VEH        0.0198     0.0045     4.4021     0.0000      0.0110      0.0286
# TSD_POP_PCT          0.7074     0.2232     3.1694     0.0015      0.2698      1.1450
# ====================================================================================
#
# F-test for Poolability: 44.742
# P-value: 0.0000
# Distribution: F(271,3968)
#
# Included effects: Entity

# %%
# add average speed

mod=PanelOLS.from_formula('UPT_ADJ_log \
                    ~ VRM_ADJ_log \
                    + AVG_SPEED \
                    + FARE_per_UPT_log \
                    + POP_EMP_log \
                    + GasPrice_log \
                    + PCT_HH_NO_VEH \
                    + TSD_POP_PCT \
                    + EntityEffects \
                    ',data=df)
res=mod.fit()
print(res)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\data.py:39: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   new_df = df.copy().loc[self._full_index]
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\utility.py:476: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   warnings.warn(missing_value_warning_msg, MissingValueWarning)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:            UPT_ADJ_log   R-squared:                        0.4865
# Estimator:                   PanelOLS   R-squared (Between):              0.9915
# No. Observations:                4247   R-squared (Within):               0.4865
# Date:                Thu, Nov 21 2019   R-squared (Overall):              0.9922
# Time:                        11:13:36   Log-likelihood                   -638.49
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      536.96
# Entities:                         272   P-value                           0.0000
# Avg Obs:                       15.614   Distribution:                  F(7,3968)
# Min Obs:                       1.0000
# Max Obs:                       17.000   F-statistic (robust):             536.96
#                                         P-value                           0.0000
# Time periods:                      17   Distribution:                  F(7,3968)
# Avg Obs:                       249.82
# Min Obs:                       180.00
# Max Obs:                       271.00
#
#                                 Parameter Estimates
# ====================================================================================
#                   Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------
# VRM_ADJ_log          0.3371     0.0106     31.954     0.0000      0.3164      0.3578
# AVG_SPEED           -0.0007     0.0006    -1.1109     0.2667     -0.0019      0.0005
# FARE_per_UPT_log    -0.7382     0.0167    -44.175     0.0000     -0.7709     -0.7054
# POP_EMP_log          0.8011     0.0791     10.124     0.0000      0.6460      0.9563
# GasPrice_log         0.4411     0.0301     14.635     0.0000      0.3820      0.5002
# PCT_HH_NO_VEH        0.0197     0.0046     4.3088     0.0000      0.0108      0.0287
# TSD_POP_PCT          0.5506     0.2267     2.4288     0.0152      0.1061      0.9950
# ====================================================================================
#
# F-test for Poolability: 49.939
# P-value: 0.0000
# Distribution: F(271,3968)
#
# Included effects: Entity

# %%
# VRH and VRM

mod=PanelOLS.from_formula('UPT_ADJ_log \
                    ~ VRM_ADJ_log \
                    + VRH_ADJ_log \
                    + FARE_per_UPT_log \
                    + POP_EMP_log \
                    + GasPrice_log \
                    + PCT_HH_NO_VEH \
                    + TSD_POP_PCT \
                    + EntityEffects \
                    ',data=df)
res=mod.fit()
print(res)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\data.py:39: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   new_df = df.copy().loc[self._full_index]
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\utility.py:476: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   warnings.warn(missing_value_warning_msg, MissingValueWarning)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:            UPT_ADJ_log   R-squared:                        0.5155
# Estimator:                   PanelOLS   R-squared (Between):              0.9951
# No. Observations:                4247   R-squared (Within):               0.5155
# Date:                Thu, Nov 21 2019   R-squared (Overall):              0.9954
# Time:                        11:16:19   Log-likelihood                   -514.73
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      603.20
# Entities:                         272   P-value                           0.0000
# Avg Obs:                       15.614   Distribution:                  F(7,3968)
# Min Obs:                       1.0000
# Max Obs:                       17.000   F-statistic (robust):             603.20
#                                         P-value                           0.0000
# Time periods:                      17   Distribution:                  F(7,3968)
# Avg Obs:                       249.82
# Min Obs:                       180.00
# Max Obs:                       271.00
#
#                                 Parameter Estimates
# ====================================================================================
#                   Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------
# VRM_ADJ_log          0.1808     0.0144     12.594     0.0000      0.1526      0.2089
# VRH_ADJ_log          0.2570     0.0166     15.474     0.0000      0.2245      0.2896
# FARE_per_UPT_log    -0.7320     0.0162    -45.089     0.0000     -0.7638     -0.7001
# POP_EMP_log          0.7150     0.0771     9.2780     0.0000      0.5639      0.8661
# GasPrice_log         0.4314     0.0292     14.750     0.0000      0.3741      0.4888
# PCT_HH_NO_VEH        0.0195     0.0044     4.3765     0.0000      0.0107      0.0282
# TSD_POP_PCT          0.7465     0.2205     3.3856     0.0007      0.3142      1.1787
# ====================================================================================
#
# F-test for Poolability: 44.899
# P-value: 0.0000
# Distribution: F(271,3968)
#
# Included effects: Entity

# %%
# VRH and VRM

mod=PanelOLS.from_formula('UPT_ADJ_log \
                    ~ VRH_ADJ_log \
                    + FARE_per_UPT_log \
                    + POP_EMP_log \
                    + GasPrice_log \
                    + PCT_HH_NO_VEH \
                    + TSD_POP_PCT \
                    + EntityEffects \
                    ',data=df)
res=mod.fit()
print(res)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\data.py:39: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   new_df = df.copy().loc[self._full_index]
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\utility.py:476: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   warnings.warn(missing_value_warning_msg, MissingValueWarning)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:            UPT_ADJ_log   R-squared:                        0.4962
# Estimator:                   PanelOLS   R-squared (Between):              0.9955
# No. Observations:                4247   R-squared (Within):               0.4962
# Date:                Thu, Nov 21 2019   R-squared (Overall):              0.9958
# Time:                        11:17:40   Log-likelihood                   -597.96
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      651.43
# Entities:                         272   P-value                           0.0000
# Avg Obs:                       15.614   Distribution:                  F(6,3969)
# Min Obs:                       1.0000
# Max Obs:                       17.000   F-statistic (robust):             651.43
#                                         P-value                           0.0000
# Time periods:                      17   Distribution:                  F(6,3969)
# Avg Obs:                       249.82
# Min Obs:                       180.00
# Max Obs:                       271.00
#
#                                 Parameter Estimates
# ====================================================================================
#                   Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------
# VRH_ADJ_log          0.4037     0.0121     33.433     0.0000      0.3801      0.4274
# FARE_per_UPT_log    -0.7268     0.0165    -43.920     0.0000     -0.7592     -0.6943
# POP_EMP_log          0.7716     0.0784     9.8359     0.0000      0.6178      0.9253
# GasPrice_log         0.4342     0.0298     14.558     0.0000      0.3757      0.4926
# PCT_HH_NO_VEH        0.0201     0.0045     4.4344     0.0000      0.0112      0.0290
# TSD_POP_PCT          0.8406     0.2247     3.7412     0.0002      0.4001      1.2811
# ====================================================================================
#
# F-test for Poolability: 43.897
# P-value: 0.0000
# Distribution: F(271,3969)
#
# Included effects: Entity

# %% [markdown]
# ## look at lagging the VRM and the Fares

# %%
# base model

mod=PanelOLS.from_formula('UPT_ADJ_log \
                    ~ VRM_ADJ_log \
                    + FARE_per_UPT_log \
                    + POP_EMP_log \
                    + GasPrice_log \
                    + PCT_HH_NO_VEH \
                    + TSD_POP_PCT \
                    + EntityEffects \
                    ',data=df)
res=mod.fit()
print(res)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\data.py:39: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   new_df = df.copy().loc[self._full_index]
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\utility.py:476: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   warnings.warn(missing_value_warning_msg, MissingValueWarning)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:            UPT_ADJ_log   R-squared:                        0.4863
# Estimator:                   PanelOLS   R-squared (Between):              0.9913
# No. Observations:                4247   R-squared (Within):               0.4863
# Date:                Thu, Nov 21 2019   R-squared (Overall):              0.9920
# Time:                        11:20:16   Log-likelihood                   -639.15
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      626.21
# Entities:                         272   P-value                           0.0000
# Avg Obs:                       15.614   Distribution:                  F(6,3969)
# Min Obs:                       1.0000
# Max Obs:                       17.000   F-statistic (robust):             626.21
#                                         P-value                           0.0000
# Time periods:                      17   Distribution:                  F(6,3969)
# Avg Obs:                       249.82
# Min Obs:                       180.00
# Max Obs:                       271.00
#
#                                 Parameter Estimates
# ====================================================================================
#                   Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------
# VRM_ADJ_log          0.3365     0.0105     31.939     0.0000      0.3159      0.3572
# FARE_per_UPT_log    -0.7385     0.0167    -44.202     0.0000     -0.7713     -0.7058
# POP_EMP_log          0.8025     0.0791     10.141     0.0000      0.6473      0.9576
# GasPrice_log         0.4427     0.0301     14.704     0.0000      0.3836      0.5017
# PCT_HH_NO_VEH        0.0197     0.0046     4.2995     0.0000      0.0107      0.0287
# TSD_POP_PCT          0.5435     0.2266     2.3983     0.0165      0.0992      0.9877
# ====================================================================================
#
# F-test for Poolability: 51.365
# P-value: 0.0000
# Distribution: F(271,3969)
#
# Included effects: Entity

# %% [markdown]
# ## Look at demographics

# %%
# base model

mod=PanelOLS.from_formula('UPT_ADJ_log \
                    ~ VRM_ADJ_log \
                    + FARE_per_UPT_log \
                    + POP_EMP_log \
                    + GasPrice_log \
                    + PCT_HH_NO_VEH \
                    + TSD_POP_PCT \
                    + EntityEffects \
                    ',data=df)
res=mod.fit()
print(res)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\data.py:39: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   new_df = df.copy().loc[self._full_index]
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\utility.py:476: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   warnings.warn(missing_value_warning_msg, MissingValueWarning)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:            UPT_ADJ_log   R-squared:                        0.4863
# Estimator:                   PanelOLS   R-squared (Between):              0.9913
# No. Observations:                4247   R-squared (Within):               0.4863
# Date:                Thu, Nov 21 2019   R-squared (Overall):              0.9920
# Time:                        11:46:57   Log-likelihood                   -639.15
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      626.21
# Entities:                         272   P-value                           0.0000
# Avg Obs:                       15.614   Distribution:                  F(6,3969)
# Min Obs:                       1.0000
# Max Obs:                       17.000   F-statistic (robust):             626.21
#                                         P-value                           0.0000
# Time periods:                      17   Distribution:                  F(6,3969)
# Avg Obs:                       249.82
# Min Obs:                       180.00
# Max Obs:                       271.00
#
#                                 Parameter Estimates
# ====================================================================================
#                   Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------
# VRM_ADJ_log          0.3365     0.0105     31.939     0.0000      0.3159      0.3572
# FARE_per_UPT_log    -0.7385     0.0167    -44.202     0.0000     -0.7713     -0.7058
# POP_EMP_log          0.8025     0.0791     10.141     0.0000      0.6473      0.9576
# GasPrice_log         0.4427     0.0301     14.704     0.0000      0.3836      0.5017
# PCT_HH_NO_VEH        0.0197     0.0046     4.2995     0.0000      0.0107      0.0287
# TSD_POP_PCT          0.5435     0.2266     2.3983     0.0165      0.0992      0.9877
# ====================================================================================
#
# F-test for Poolability: 51.365
# P-value: 0.0000
# Distribution: F(271,3969)
#
# Included effects: Entity

# %%
# income percentages

mod=PanelOLS.from_formula('UPT_ADJ_log \
                    ~ VRM_ADJ_log \
                    + FARE_per_UPT_log \
                    + POP_EMP_log \
                    + GasPrice_log \
                    + PCT_HH_NO_VEH \
                    + INC_U35 \
                    + TSD_POP_PCT \
                    + EntityEffects \
                    ',data=df)
res=mod.fit()
print(res)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\data.py:39: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   new_df = df.copy().loc[self._full_index]
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\utility.py:476: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   warnings.warn(missing_value_warning_msg, MissingValueWarning)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:            UPT_ADJ_log   R-squared:                        0.4866
# Estimator:                   PanelOLS   R-squared (Between):              0.9973
# No. Observations:                4247   R-squared (Within):               0.4866
# Date:                Thu, Nov 21 2019   R-squared (Overall):              0.9974
# Time:                        11:48:11   Log-likelihood                   -637.88
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      537.28
# Entities:                         272   P-value                           0.0000
# Avg Obs:                       15.614   Distribution:                  F(7,3968)
# Min Obs:                       1.0000
# Max Obs:                       17.000   F-statistic (robust):             537.28
#                                         P-value                           0.0000
# Time periods:                      17   Distribution:                  F(7,3968)
# Avg Obs:                       249.82
# Min Obs:                       180.00
# Max Obs:                       271.00
#
#                                 Parameter Estimates
# ====================================================================================
#                   Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------
# VRM_ADJ_log          0.3354     0.0106     31.759     0.0000      0.3147      0.3561
# FARE_per_UPT_log    -0.7402     0.0167    -44.218     0.0000     -0.7730     -0.7073
# POP_EMP_log          0.7350     0.0904     8.1334     0.0000      0.5579      0.9122
# GasPrice_log         0.4335     0.0307     14.132     0.0000      0.3734      0.4937
# PCT_HH_NO_VEH        0.0211     0.0047     4.5235     0.0000      0.0120      0.0303
# INC_U35             -0.0024     0.0015    -1.5432     0.1229     -0.0053      0.0006
# TSD_POP_PCT          0.5821     0.2279     2.5537     0.0107      0.1352      1.0290
# ====================================================================================
#
# F-test for Poolability: 51.175
# P-value: 0.0000
# Distribution: F(271,3968)
#
# Included effects: Entity

# %%
# income percentages

mod=PanelOLS.from_formula('UPT_ADJ_log \
                    ~ VRM_ADJ_log \
                    + FARE_per_UPT_log \
                    + POP_EMP_log \
                    + GasPrice_log \
                    + PCT_HH_NO_VEH \
                    + INC_100P \
                    + TSD_POP_PCT \
                    + EntityEffects \
                    ',data=df)
res=mod.fit()
print(res)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\data.py:39: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   new_df = df.copy().loc[self._full_index]
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\utility.py:476: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   warnings.warn(missing_value_warning_msg, MissingValueWarning)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:            UPT_ADJ_log   R-squared:                        0.4865
# Estimator:                   PanelOLS   R-squared (Between):              0.9963
# No. Observations:                4247   R-squared (Within):               0.4865
# Date:                Thu, Nov 21 2019   R-squared (Overall):              0.9965
# Time:                        11:48:49   Log-likelihood                   -638.44
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      536.99
# Entities:                         272   P-value                           0.0000
# Avg Obs:                       15.614   Distribution:                  F(7,3968)
# Min Obs:                       1.0000
# Max Obs:                       17.000   F-statistic (robust):             536.99
#                                         P-value                           0.0000
# Time periods:                      17   Distribution:                  F(7,3968)
# Avg Obs:                       249.82
# Min Obs:                       180.00
# Max Obs:                       271.00
#
#                                 Parameter Estimates
# ====================================================================================
#                   Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------
# VRM_ADJ_log          0.3355     0.0106     31.723     0.0000      0.3147      0.3562
# FARE_per_UPT_log    -0.7402     0.0168    -44.140     0.0000     -0.7731     -0.7073
# POP_EMP_log          0.7517     0.0905     8.3064     0.0000      0.5743      0.9291
# GasPrice_log         0.4371     0.0305     14.340     0.0000      0.3774      0.4969
# PCT_HH_NO_VEH        0.0200     0.0046     4.3596     0.0000      0.0110      0.0290
# INC_100P             0.0017     0.0015     1.1554     0.2480     -0.0012      0.0045
# TSD_POP_PCT          0.6036     0.2325     2.5963     0.0095      0.1478      1.0595
# ====================================================================================
#
# F-test for Poolability: 50.899
# P-value: 0.0000
# Distribution: F(271,3968)
#
# Included effects: Entity

# %%
# median income


mod=PanelOLS.from_formula('UPT_ADJ_log \
                    ~ VRM_ADJ_log \
                    + FARE_per_UPT_log \
                    + POP_EMP_log \
                    + GasPrice_log \
                    + PCT_HH_NO_VEH \
                    + HH_MED_INC_2018 \
                    + TSD_POP_PCT \
                    + EntityEffects \
                    ',data=df)
res=mod.fit()
print(res)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\data.py:39: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   new_df = df.copy().loc[self._full_index]
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\utility.py:476: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   warnings.warn(missing_value_warning_msg, MissingValueWarning)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:            UPT_ADJ_log   R-squared:                        0.4863
# Estimator:                   PanelOLS   R-squared (Between):              0.9916
# No. Observations:                4247   R-squared (Within):               0.4863
# Date:                Thu, Nov 21 2019   R-squared (Overall):              0.9922
# Time:                        11:49:54   Log-likelihood                   -639.12
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      536.64
# Entities:                         272   P-value                           0.0000
# Avg Obs:                       15.614   Distribution:                  F(7,3968)
# Min Obs:                       1.0000
# Max Obs:                       17.000   F-statistic (robust):             536.64
#                                         P-value                           0.0000
# Time periods:                      17   Distribution:                  F(7,3968)
# Avg Obs:                       249.82
# Min Obs:                       180.00
# Max Obs:                       271.00
#
#                                 Parameter Estimates
# ====================================================================================
#                   Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------
# VRM_ADJ_log          0.3365     0.0105     31.934     0.0000      0.3159      0.3572
# FARE_per_UPT_log    -0.7386     0.0167    -44.192     0.0000     -0.7714     -0.7058
# POP_EMP_log          0.7989     0.0805     9.9292     0.0000      0.6412      0.9567
# GasPrice_log         0.4442     0.0307     14.452     0.0000      0.3839      0.5044
# PCT_HH_NO_VEH        0.0199     0.0047     4.2615     0.0000      0.0107      0.0291
# HH_MED_INC_2018   3.197e-07  1.319e-06     0.2424     0.8085  -2.266e-06   2.906e-06
# TSD_POP_PCT          0.5502     0.2283     2.4097     0.0160      0.1026      0.9979
# ====================================================================================
#
# F-test for Poolability: 50.917
# P-value: 0.0000
# Distribution: F(271,3968)
#
# Included effects: Entity

# %%
# median income -- log


mod=PanelOLS.from_formula('UPT_ADJ_log \
                    ~ VRM_ADJ_log \
                    + FARE_per_UPT_log \
                    + POP_EMP_log \
                    + GasPrice_log \
                    + PCT_HH_NO_VEH \
                    + HH_MED_INC_2018_log \
                    + TSD_POP_PCT \
                    + EntityEffects \
                    ',data=df)
res=mod.fit()
print(res)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\data.py:39: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   new_df = df.copy().loc[self._full_index]
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\utility.py:476: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   warnings.warn(missing_value_warning_msg, MissingValueWarning)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:            UPT_ADJ_log   R-squared:                        0.4863
# Estimator:                   PanelOLS   R-squared (Between):              0.9906
# No. Observations:                4247   R-squared (Within):               0.4863
# Date:                Thu, Nov 21 2019   R-squared (Overall):              0.9913
# Time:                        11:53:52   Log-likelihood                   -639.14
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      536.62
# Entities:                         272   P-value                           0.0000
# Avg Obs:                       15.614   Distribution:                  F(7,3968)
# Min Obs:                       1.0000
# Max Obs:                       17.000   F-statistic (robust):             536.62
#                                         P-value                           0.0000
# Time periods:                      17   Distribution:                  F(7,3968)
# Avg Obs:                       249.82
# Min Obs:                       180.00
# Max Obs:                       271.00
#
#                                   Parameter Estimates
# =======================================================================================
#                      Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ---------------------------------------------------------------------------------------
# VRM_ADJ_log             0.3365     0.0105     31.934     0.0000      0.3159      0.3572
# FARE_per_UPT_log       -0.7386     0.0167    -44.190     0.0000     -0.7713     -0.7058
# POP_EMP_log             0.8010     0.0803     9.9710     0.0000      0.6435      0.9585
# GasPrice_log            0.4433     0.0306     14.472     0.0000      0.3832      0.5033
# PCT_HH_NO_VEH           0.0198     0.0047     4.2188     0.0000      0.0106      0.0290
# HH_MED_INC_2018_log     0.0082     0.0766     0.1073     0.9145     -0.1420      0.1585
# TSD_POP_PCT             0.5463     0.2282     2.3942     0.0167      0.0989      0.9937
# =======================================================================================
#
# F-test for Poolability: 50.823
# P-value: 0.0000
# Distribution: F(271,3968)
#
# Included effects: Entity

# %%
# mean income


mod=PanelOLS.from_formula('UPT_ADJ_log \
                    ~ VRM_ADJ_log \
                    + FARE_per_UPT_log \
                    + POP_EMP_log \
                    + GasPrice_log \
                    + PCT_HH_NO_VEH \
                    + HH_MEAN_INC_2018 \
                    + TSD_POP_PCT \
                    + EntityEffects \
                    ',data=df)
res=mod.fit()
print(res)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\data.py:39: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   new_df = df.copy().loc[self._full_index]
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\utility.py:476: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   warnings.warn(missing_value_warning_msg, MissingValueWarning)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:            UPT_ADJ_log   R-squared:                        0.4867
# Estimator:                   PanelOLS   R-squared (Between):              0.9871
# No. Observations:                4247   R-squared (Within):               0.4867
# Date:                Thu, Nov 21 2019   R-squared (Overall):              0.9880
# Time:                        11:51:06   Log-likelihood                   -637.35
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      537.56
# Entities:                         272   P-value                           0.0000
# Avg Obs:                       15.614   Distribution:                  F(7,3968)
# Min Obs:                       1.0000
# Max Obs:                       17.000   F-statistic (robust):             537.56
#                                         P-value                           0.0000
# Time periods:                      17   Distribution:                  F(7,3968)
# Avg Obs:                       249.82
# Min Obs:                       180.00
# Max Obs:                       271.00
#
#                                 Parameter Estimates
# ====================================================================================
#                   Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------
# VRM_ADJ_log          0.3371     0.0105     31.988     0.0000      0.3164      0.3578
# FARE_per_UPT_log    -0.7372     0.0167    -44.090     0.0000     -0.7700     -0.7044
# POP_EMP_log          0.8419     0.0820     10.271     0.0000      0.6812      1.0026
# GasPrice_log         0.4331     0.0305     14.178     0.0000      0.3732      0.4930
# PCT_HH_NO_VEH        0.0180     0.0047     3.8442     0.0001      0.0088      0.0271
# HH_MEAN_INC_2018 -2.067e-06  1.126e-06    -1.8360     0.0664  -4.274e-06   1.403e-07
# TSD_POP_PCT          0.4773     0.2294     2.0807     0.0375      0.0276      0.9270
# ====================================================================================
#
# F-test for Poolability: 50.955
# P-value: 0.0000
# Distribution: F(271,3968)
#
# Included effects: Entity

# %%
# mean income - log


mod=PanelOLS.from_formula('UPT_ADJ_log \
                    ~ VRM_ADJ_log \
                    + FARE_per_UPT_log \
                    + POP_EMP_log \
                    + GasPrice_log \
                    + PCT_HH_NO_VEH \
                    + HH_MEAN_INC_2018_log \
                    + TSD_POP_PCT \
                    + EntityEffects \
                    ',data=df)
res=mod.fit()
print(res)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\data.py:39: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   new_df = df.copy().loc[self._full_index]
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\utility.py:476: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   warnings.warn(missing_value_warning_msg, MissingValueWarning)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:            UPT_ADJ_log   R-squared:                        0.4869
# Estimator:                   PanelOLS   R-squared (Between):              0.9967
# No. Observations:                4247   R-squared (Within):               0.4869
# Date:                Thu, Nov 21 2019   R-squared (Overall):              0.9966
# Time:                        11:54:17   Log-likelihood                   -636.64
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      537.92
# Entities:                         272   P-value                           0.0000
# Avg Obs:                       15.614   Distribution:                  F(7,3968)
# Min Obs:                       1.0000
# Max Obs:                       17.000   F-statistic (robust):             537.92
#                                         P-value                           0.0000
# Time periods:                      17   Distribution:                  F(7,3968)
# Avg Obs:                       249.82
# Min Obs:                       180.00
# Max Obs:                       271.00
#
#                                   Parameter Estimates
# ========================================================================================
#                       Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ----------------------------------------------------------------------------------------
# VRM_ADJ_log              0.3371     0.0105     32.000     0.0000      0.3165      0.3578
# FARE_per_UPT_log        -0.7369     0.0167    -44.083     0.0000     -0.7697     -0.7042
# POP_EMP_log              0.8494     0.0820     10.358     0.0000      0.6886      1.0101
# GasPrice_log             0.4319     0.0305     14.161     0.0000      0.3721      0.4917
# PCT_HH_NO_VEH            0.0175     0.0047     3.7303     0.0002      0.0083      0.0267
# HH_MEAN_INC_2018_log    -0.1934     0.0893    -2.1662     0.0304     -0.3684     -0.0184
# TSD_POP_PCT              0.4775     0.2285     2.0894     0.0367      0.0294      0.9256
# ========================================================================================
#
# F-test for Poolability: 50.864
# P-value: 0.0000
# Distribution: F(271,3968)
#
# Included effects: Entity

# %%
# median personal income

mod=PanelOLS.from_formula('UPT_ADJ_log \
                    ~ VRM_ADJ_log \
                    + FARE_per_UPT_log \
                    + POP_EMP_log \
                    + GasPrice_log \
                    + PCT_HH_NO_VEH \
                    + TOTAL_MED_INC_INDIV_2018 \
                    + TSD_POP_PCT \
                    + EntityEffects \
                    ',data=df)
res=mod.fit()
print(res)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\data.py:39: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   new_df = df.copy().loc[self._full_index]
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\utility.py:476: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   warnings.warn(missing_value_warning_msg, MissingValueWarning)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:            UPT_ADJ_log   R-squared:                        0.4882
# Estimator:                   PanelOLS   R-squared (Between):              0.9951
# No. Observations:                4247   R-squared (Within):               0.4882
# Date:                Thu, Nov 21 2019   R-squared (Overall):              0.9955
# Time:                        11:52:11   Log-likelihood                   -631.32
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      540.70
# Entities:                         272   P-value                           0.0000
# Avg Obs:                       15.614   Distribution:                  F(7,3968)
# Min Obs:                       1.0000
# Max Obs:                       17.000   F-statistic (robust):             540.70
#                                         P-value                           0.0000
# Time periods:                      17   Distribution:                  F(7,3968)
# Avg Obs:                       249.82
# Min Obs:                       180.00
# Max Obs:                       271.00
#
#                                     Parameter Estimates
# ============================================================================================
#                           Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# --------------------------------------------------------------------------------------------
# VRM_ADJ_log                  0.3371     0.0105     32.048     0.0000      0.3165      0.3578
# FARE_per_UPT_log            -0.7382     0.0167    -44.259     0.0000     -0.7709     -0.7055
# POP_EMP_log                  0.7982     0.0790     10.104     0.0000      0.6434      0.9531
# GasPrice_log                 0.3684     0.0358     10.299     0.0000      0.2983      0.4385
# PCT_HH_NO_VEH                0.0157     0.0047     3.3598     0.0008      0.0066      0.0249
# TOTAL_MED_INC_INDIV_2018 -1.059e-05  2.767e-06    -3.8282     0.0001  -1.602e-05  -5.168e-06
# TSD_POP_PCT                  0.7073     0.2302     3.0724     0.0021      0.2560      1.1587
# ============================================================================================
#
# F-test for Poolability: 51.191
# P-value: 0.0000
# Distribution: F(271,3968)
#
# Included effects: Entity

# %%
# median personal income - log

mod=PanelOLS.from_formula('UPT_ADJ_log \
                    ~ VRM_ADJ_log \
                    + FARE_per_UPT_log \
                    + POP_EMP_log \
                    + GasPrice_log \
                    + TOTAL_MED_INC_INDIV_2018_log \
                    + PCT_HH_NO_VEH \
                    + TSD_POP_PCT \
                    + EntityEffects \
                    ',data=df)
res=mod.fit()
print(res)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\data.py:39: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   new_df = df.copy().loc[self._full_index]
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\utility.py:476: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   warnings.warn(missing_value_warning_msg, MissingValueWarning)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:            UPT_ADJ_log   R-squared:                        0.4890
# Estimator:                   PanelOLS   R-squared (Between):              0.9580
# No. Observations:                4247   R-squared (Within):               0.4890
# Date:                Thu, Nov 21 2019   R-squared (Overall):              0.9571
# Time:                        11:55:23   Log-likelihood                   -628.12
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      542.37
# Entities:                         272   P-value                           0.0000
# Avg Obs:                       15.614   Distribution:                  F(7,3968)
# Min Obs:                       1.0000
# Max Obs:                       17.000   F-statistic (robust):             542.37
#                                         P-value                           0.0000
# Time periods:                      17   Distribution:                  F(7,3968)
# Avg Obs:                       249.82
# Min Obs:                       180.00
# Max Obs:                       271.00
#
#                                       Parameter Estimates
# ================================================================================================
#                               Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------------------
# VRM_ADJ_log                      0.3370     0.0105     32.057     0.0000      0.3164      0.3576
# FARE_per_UPT_log                -0.7380     0.0167    -44.275     0.0000     -0.7706     -0.7053
# POP_EMP_log                      0.7937     0.0790     10.053     0.0000      0.6389      0.9485
# GasPrice_log                     0.3552     0.0357     9.9595     0.0000      0.2853      0.4251
# TOTAL_MED_INC_INDIV_2018_log    -0.3860     0.0849    -4.5468     0.0000     -0.5524     -0.2195
# PCT_HH_NO_VEH                    0.0149     0.0047     3.1746     0.0015      0.0057      0.0241
# TSD_POP_PCT                      0.6819     0.2281     2.9897     0.0028      0.2347      1.1291
# ================================================================================================
#
# F-test for Poolability: 51.353
# P-value: 0.0000
# Distribution: F(271,3968)
#
# Included effects: Entity

# %%
# immigrant population

mod=PanelOLS.from_formula('UPT_ADJ_log \
                    ~ VRM_ADJ_log \
                    + FARE_per_UPT_log \
                    + POP_EMP_log \
                    + GasPrice_log \
                    + TOTAL_MED_INC_INDIV_2018_log \
                    + Tot_NonUSA_POP \
                    + PCT_HH_NO_VEH \
                    + TSD_POP_PCT \
                    + EntityEffects \
                    ',data=df)
res=mod.fit()
print(res)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\data.py:39: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   new_df = df.copy().loc[self._full_index]
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\utility.py:476: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   warnings.warn(missing_value_warning_msg, MissingValueWarning)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:            UPT_ADJ_log   R-squared:                        0.4890
# Estimator:                   PanelOLS   R-squared (Between):              0.9586
# No. Observations:                4247   R-squared (Within):               0.4890
# Date:                Thu, Nov 21 2019   R-squared (Overall):              0.9577
# Time:                        11:56:55   Log-likelihood                   -628.11
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      474.46
# Entities:                         272   P-value                           0.0000
# Avg Obs:                       15.614   Distribution:                  F(8,3967)
# Min Obs:                       1.0000
# Max Obs:                       17.000   F-statistic (robust):             474.46
#                                         P-value                           0.0000
# Time periods:                      17   Distribution:                  F(8,3967)
# Avg Obs:                       249.82
# Min Obs:                       180.00
# Max Obs:                       271.00
#
#                                       Parameter Estimates
# ================================================================================================
#                               Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------------------
# VRM_ADJ_log                      0.3370     0.0105     32.054     0.0000      0.3164      0.3576
# FARE_per_UPT_log                -0.7379     0.0167    -44.210     0.0000     -0.7706     -0.7051
# POP_EMP_log                      0.7959     0.0814     9.7726     0.0000      0.6362      0.9556
# GasPrice_log                     0.3551     0.0357     9.9539     0.0000      0.2852      0.4251
# TOTAL_MED_INC_INDIV_2018_log    -0.3863     0.0850    -4.5470     0.0000     -0.5529     -0.2197
# Tot_NonUSA_POP               -8.238e-08  7.511e-07    -0.1097     0.9127  -1.555e-06    1.39e-06
# PCT_HH_NO_VEH                    0.0149     0.0047     3.1658     0.0016      0.0057      0.0241
# TSD_POP_PCT                      0.6781     0.2307     2.9388     0.0033      0.2257      1.1305
# ================================================================================================
#
# F-test for Poolability: 50.749
# P-value: 0.0000
# Distribution: F(271,3967)
#
# Included effects: Entity

# %%
# immigrant population - log

mod=PanelOLS.from_formula('UPT_ADJ_log \
                    ~ VRM_ADJ_log \
                    + FARE_per_UPT_log \
                    + POP_EMP_log \
                    + GasPrice_log \
                    + TOTAL_MED_INC_INDIV_2018_log \
                    + Tot_NonUSA_POP_log \
                    + PCT_HH_NO_VEH \
                    + TSD_POP_PCT \
                    + EntityEffects \
                    ',data=df)
res=mod.fit()
print(res)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\data.py:39: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   new_df = df.copy().loc[self._full_index]
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\utility.py:476: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   warnings.warn(missing_value_warning_msg, MissingValueWarning)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:            UPT_ADJ_log   R-squared:                        0.4869
# Estimator:                   PanelOLS   R-squared (Between):              0.9869
# No. Observations:                4200   R-squared (Within):               0.4869
# Date:                Thu, Nov 21 2019   R-squared (Overall):              0.9864
# Time:                        11:57:13   Log-likelihood                   -580.26
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      464.98
# Entities:                         272   P-value                           0.0000
# Avg Obs:                       15.441   Distribution:                  F(8,3920)
# Min Obs:                       1.0000
# Max Obs:                       17.000   F-statistic (robust):             464.98
#                                         P-value                           0.0000
# Time periods:                      17   Distribution:                  F(8,3920)
# Avg Obs:                       247.06
# Min Obs:                       153.00
# Max Obs:                       271.00
#
#                                       Parameter Estimates
# ================================================================================================
#                               Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------------------
# VRM_ADJ_log                      0.3373     0.0105     32.258     0.0000      0.3168      0.3578
# FARE_per_UPT_log                -0.7267     0.0167    -43.592     0.0000     -0.7593     -0.6940
# POP_EMP_log                      0.8631     0.0828     10.426     0.0000      0.7008      1.0255
# GasPrice_log                     0.3823     0.0360     10.610     0.0000      0.3116      0.4529
# TOTAL_MED_INC_INDIV_2018_log    -0.3375     0.0856    -3.9431     0.0001     -0.5053     -0.1697
# Tot_NonUSA_POP_log              -0.0184     0.0126    -1.4577     0.1450     -0.0432      0.0064
# PCT_HH_NO_VEH                    0.0216     0.0048     4.4666     0.0000      0.0121      0.0311
# TSD_POP_PCT                      1.0167     0.2344     4.3380     0.0000      0.5572      1.4762
# ================================================================================================
#
# F-test for Poolability: 51.059
# P-value: 0.0000
# Distribution: F(271,3920)
#
# Included effects: Entity

# %%
# immigrant population percentage
df['Tot_NonUSA_POP_pct'] = df['Tot_NonUSA_POP'] / df['Tot_Pop'] * 100


mod=PanelOLS.from_formula('UPT_ADJ_log \
                    ~ VRM_ADJ_log \
                    + FARE_per_UPT_log \
                    + POP_EMP_log \
                    + GasPrice_log \
                    + TOTAL_MED_INC_INDIV_2018_log \
                    + Tot_NonUSA_POP_pct \
                    + PCT_HH_NO_VEH \
                    + TSD_POP_PCT \
                    + EntityEffects \
                    ',data=df)
res=mod.fit()
print(res)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\data.py:39: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   new_df = df.copy().loc[self._full_index]
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\utility.py:476: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   warnings.warn(missing_value_warning_msg, MissingValueWarning)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:            UPT_ADJ_log   R-squared:                        0.4893
# Estimator:                   PanelOLS   R-squared (Between):              0.9498
# No. Observations:                4247   R-squared (Within):               0.4893
# Date:                Thu, Nov 21 2019   R-squared (Overall):              0.9489
# Time:                        11:58:41   Log-likelihood                   -626.53
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      475.18
# Entities:                         272   P-value                           0.0000
# Avg Obs:                       15.614   Distribution:                  F(8,3967)
# Min Obs:                       1.0000
# Max Obs:                       17.000   F-statistic (robust):             475.18
#                                         P-value                           0.0000
# Time periods:                      17   Distribution:                  F(8,3967)
# Avg Obs:                       249.82
# Min Obs:                       180.00
# Max Obs:                       271.00
#
#                                       Parameter Estimates
# ================================================================================================
#                               Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------------------
# VRM_ADJ_log                      0.3369     0.0105     32.061     0.0000      0.3163      0.3575
# FARE_per_UPT_log                -0.7392     0.0167    -44.319     0.0000     -0.7719     -0.7065
# POP_EMP_log                      0.7651     0.0807     9.4828     0.0000      0.6069      0.9232
# GasPrice_log                     0.3527     0.0357     9.8852     0.0000      0.2828      0.4227
# TOTAL_MED_INC_INDIV_2018_log    -0.3792     0.0850    -4.4633     0.0000     -0.5458     -0.2126
# Tot_NonUSA_POP_pct               0.0224     0.0131     1.7189     0.0857     -0.0032      0.0480
# PCT_HH_NO_VEH                    0.0150     0.0047     3.2088     0.0013      0.0059      0.0242
# TSD_POP_PCT                      0.6846     0.2280     3.0023     0.0027      0.2376      1.1317
# ================================================================================================
#
# F-test for Poolability: 50.516
# P-value: 0.0000
# Distribution: F(271,3967)
#
# Included effects: Entity

# %% [markdown]
# ## bus vs rail competion

# %%
# base model

mod=PanelOLS.from_formula('UPT_ADJ_log \
                    ~ VRM_ADJ_log \
                    + FARE_per_UPT_log \
                    + POP_EMP_log \
                    + GasPrice_log \
                    + TOTAL_MED_INC_INDIV_2018_log \
                    + Tot_NonUSA_POP_pct \
                    + PCT_HH_NO_VEH \
                    + TSD_POP_PCT \
                    + EntityEffects \
                    ',data=df)
res=mod.fit()
print(res)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\data.py:39: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   new_df = df.copy().loc[self._full_index]
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\utility.py:476: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   warnings.warn(missing_value_warning_msg, MissingValueWarning)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:            UPT_ADJ_log   R-squared:                        0.4893
# Estimator:                   PanelOLS   R-squared (Between):              0.9498
# No. Observations:                4247   R-squared (Within):               0.4893
# Date:                Thu, Nov 21 2019   R-squared (Overall):              0.9489
# Time:                        12:11:33   Log-likelihood                   -626.53
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      475.18
# Entities:                         272   P-value                           0.0000
# Avg Obs:                       15.614   Distribution:                  F(8,3967)
# Min Obs:                       1.0000
# Max Obs:                       17.000   F-statistic (robust):             475.18
#                                         P-value                           0.0000
# Time periods:                      17   Distribution:                  F(8,3967)
# Avg Obs:                       249.82
# Min Obs:                       180.00
# Max Obs:                       271.00
#
#                                       Parameter Estimates
# ================================================================================================
#                               Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------------------
# VRM_ADJ_log                      0.3369     0.0105     32.061     0.0000      0.3163      0.3575
# FARE_per_UPT_log                -0.7392     0.0167    -44.319     0.0000     -0.7719     -0.7065
# POP_EMP_log                      0.7651     0.0807     9.4828     0.0000      0.6069      0.9232
# GasPrice_log                     0.3527     0.0357     9.8852     0.0000      0.2828      0.4227
# TOTAL_MED_INC_INDIV_2018_log    -0.3792     0.0850    -4.4633     0.0000     -0.5458     -0.2126
# Tot_NonUSA_POP_pct               0.0224     0.0131     1.7189     0.0857     -0.0032      0.0480
# PCT_HH_NO_VEH                    0.0150     0.0047     3.2088     0.0013      0.0059      0.0242
# TSD_POP_PCT                      0.6846     0.2280     3.0023     0.0027      0.2376      1.1317
# ================================================================================================
#
# F-test for Poolability: 50.516
# P-value: 0.0000
# Distribution: F(271,3967)
#
# Included effects: Entity

# %%
# include VRM on competing modes
# base model

mod=PanelOLS.from_formula('UPT_ADJ_log \
                    ~ VRM_ADJ_log \
                    + Bus_VRM_ADJ_RAIL \
                    + Rail_VRM_ADJ_BUS \
                    + FARE_per_UPT_log \
                    + POP_EMP_log \
                    + GasPrice_log \
                    + TOTAL_MED_INC_INDIV_2018_log \
                    + Tot_NonUSA_POP_pct \
                    + PCT_HH_NO_VEH \
                    + TSD_POP_PCT \
                    + EntityEffects \
                    ',data=df)
res=mod.fit()
print(res)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\data.py:39: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   new_df = df.copy().loc[self._full_index]
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\utility.py:476: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   warnings.warn(missing_value_warning_msg, MissingValueWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-46-2575fcc7fdd7> in <module>()
#       2 # base model
#       3
# ----> 4 mod=PanelOLS.from_formula('UPT_ADJ_log                     ~ VRM_ADJ_log                     + Rail_VRM_ADJ_BUS                     + FARE_per_UPT_log                     + POP_EMP_log                     + GasPrice_log                     + TOTAL_MED_INC_INDIV_2018_log                     + Tot_NonUSA_POP_pct                     + PCT_HH_NO_VEH                     + TSD_POP_PCT                     + EntityEffects                     ',data=df)
#       5 res=mod.fit()
#       6 print(res)
#
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\model.py in from_formula(cls, formula, data, weights, other_effects)
#     734                                     return_type='dataframe', NA_action=na_action)
#     735         mod = cls(dependent, exog, entity_effects=entity_effect,
# --> 736                   time_effects=time_effect, weights=weights, other_effects=other_effects)
#     737         mod.formula = formula
#     738         return mod
#
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\model.py in __init__(self, dependent, exog, weights, entity_effects, time_effects, other_effects)
#     598     def __init__(self, dependent, exog, *, weights=None, entity_effects=False, time_effects=False,
#     599                  other_effects=None):
# --> 600         super(PanelOLS, self).__init__(dependent, exog, weights=weights)
#     601
#     602         self._entity_effects = entity_effects
#
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\model.py in __init__(self, dependent, exog, weights)
#      86                                                  DriscollKraay, ACCovariance)
#      87
# ---> 88         self._validate_data()
#      89
#      90     def __str__(self):
#
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\model.py in _validate_data(self)
#     207
#     208         if matrix_rank(x) < x.shape[1]:
# --> 209             raise ValueError('exog does not have full column rank.')
#     210         self._constant, self._constant_index = has_constant(x)
#     211
#
# ValueError: exog does not have full column rank.

# %% [markdown]
# ## TNCs, bikes, scooters

# %%
# base model

mod=PanelOLS.from_formula('UPT_ADJ_log \
                    ~ VRM_ADJ_log \
                    + FARE_per_UPT_log \
                    + POP_EMP_log \
                    + GasPrice_log \
                    + TOTAL_MED_INC_INDIV_2018_log \
                    + Tot_NonUSA_POP_pct \
                    + PCT_HH_NO_VEH \
                    + TSD_POP_PCT \
                    + EntityEffects \
                    ',data=df)
res=mod.fit()
print(res)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\data.py:39: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   new_df = df.copy().loc[self._full_index]
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\utility.py:476: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   warnings.warn(missing_value_warning_msg, MissingValueWarning)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:            UPT_ADJ_log   R-squared:                        0.4893
# Estimator:                   PanelOLS   R-squared (Between):              0.9498
# No. Observations:                4247   R-squared (Within):               0.4893
# Date:                Thu, Nov 21 2019   R-squared (Overall):              0.9489
# Time:                        12:26:18   Log-likelihood                   -626.53
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      475.18
# Entities:                         272   P-value                           0.0000
# Avg Obs:                       15.614   Distribution:                  F(8,3967)
# Min Obs:                       1.0000
# Max Obs:                       17.000   F-statistic (robust):             475.18
#                                         P-value                           0.0000
# Time periods:                      17   Distribution:                  F(8,3967)
# Avg Obs:                       249.82
# Min Obs:                       180.00
# Max Obs:                       271.00
#
#                                       Parameter Estimates
# ================================================================================================
#                               Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------------------
# VRM_ADJ_log                      0.3369     0.0105     32.061     0.0000      0.3163      0.3575
# FARE_per_UPT_log                -0.7392     0.0167    -44.319     0.0000     -0.7719     -0.7065
# POP_EMP_log                      0.7651     0.0807     9.4828     0.0000      0.6069      0.9232
# GasPrice_log                     0.3527     0.0357     9.8852     0.0000      0.2828      0.4227
# TOTAL_MED_INC_INDIV_2018_log    -0.3792     0.0850    -4.4633     0.0000     -0.5458     -0.2126
# Tot_NonUSA_POP_pct               0.0224     0.0131     1.7189     0.0857     -0.0032      0.0480
# PCT_HH_NO_VEH                    0.0150     0.0047     3.2088     0.0013      0.0059      0.0242
# TSD_POP_PCT                      0.6846     0.2280     3.0023     0.0027      0.2376      1.1317
# ================================================================================================
#
# F-test for Poolability: 50.516
# P-value: 0.0000
# Distribution: F(271,3967)
#
# Included effects: Entity

# %%
# add TNC flag

mod=PanelOLS.from_formula('UPT_ADJ_log \
                    ~ VRM_ADJ_log \
                    + FARE_per_UPT_log \
                    + POP_EMP_log \
                    + GasPrice_log \
                    + TOTAL_MED_INC_INDIV_2018_log \
                    + Tot_NonUSA_POP_pct \
                    + PCT_HH_NO_VEH \
                    + TSD_POP_PCT \
                    + TNC_FLAG_BUS \
                    + TNC_FLAG_RAIL \
                    + EntityEffects \
                    ',data=df)
res=mod.fit()
print(res)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\data.py:39: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   new_df = df.copy().loc[self._full_index]
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\utility.py:476: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   warnings.warn(missing_value_warning_msg, MissingValueWarning)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:            UPT_ADJ_log   R-squared:                        0.4935
# Estimator:                   PanelOLS   R-squared (Between):              0.9661
# No. Observations:                4247   R-squared (Within):               0.4935
# Date:                Thu, Nov 21 2019   R-squared (Overall):              0.9653
# Time:                        12:28:39   Log-likelihood                   -609.07
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      386.36
# Entities:                         272   P-value                           0.0000
# Avg Obs:                       15.614   Distribution:                 F(10,3965)
# Min Obs:                       1.0000
# Max Obs:                       17.000   F-statistic (robust):             386.36
#                                         P-value                           0.0000
# Time periods:                      17   Distribution:                 F(10,3965)
# Avg Obs:                       249.82
# Min Obs:                       180.00
# Max Obs:                       271.00
#
#                                       Parameter Estimates
# ================================================================================================
#                               Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------------------
# VRM_ADJ_log                      0.3305     0.0106     31.316     0.0000      0.3098      0.3512
# FARE_per_UPT_log                -0.7425     0.0167    -44.591     0.0000     -0.7751     -0.7098
# POP_EMP_log                      0.8150     0.0877     9.2946     0.0000      0.6431      0.9869
# GasPrice_log                     0.3425     0.0369     9.2739     0.0000      0.2701      0.4149
# TOTAL_MED_INC_INDIV_2018_log    -0.3760     0.0847    -4.4387     0.0000     -0.5420     -0.2099
# Tot_NonUSA_POP_pct               0.0246     0.0132     1.8615     0.0627     -0.0013      0.0506
# PCT_HH_NO_VEH                    0.0156     0.0047     3.3372     0.0009      0.0064      0.0247
# TSD_POP_PCT                      0.7461     0.2291     3.2563     0.0011      0.2969      1.1953
# TNC_FLAG_BUS                    -0.0314     0.0134    -2.3538     0.0186     -0.0576     -0.0053
# TNC_FLAG_RAIL                    0.1258     0.0262     4.8042     0.0000      0.0745      0.1772
# ================================================================================================
#
# F-test for Poolability: 50.751
# P-value: 0.0000
# Distribution: F(271,3965)
#
# Included effects: Entity

# %%
# add TNC flag

mod=PanelOLS.from_formula('UPT_ADJ_log \
                    ~ VRM_ADJ_log \
                    + FARE_per_UPT_log \
                    + POP_EMP_log \
                    + GasPrice_log \
                    + TOTAL_MED_INC_INDIV_2018_log \
                    + Tot_NonUSA_POP_pct \
                    + PCT_HH_NO_VEH \
                    + TSD_POP_PCT \
                    + YEARS_SINCE_TNC_BUS \
                    + YEARS_SINCE_TNC_RAIL \
                    + EntityEffects \
                    ',data=df)
res=mod.fit()
print(res)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\data.py:39: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   new_df = df.copy().loc[self._full_index]
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\utility.py:476: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   warnings.warn(missing_value_warning_msg, MissingValueWarning)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:            UPT_ADJ_log   R-squared:                        0.4980
# Estimator:                   PanelOLS   R-squared (Between):              0.9911
# No. Observations:                4247   R-squared (Within):               0.4980
# Date:                Thu, Nov 21 2019   R-squared (Overall):              0.9908
# Time:                        12:29:13   Log-likelihood                   -590.41
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      393.27
# Entities:                         272   P-value                           0.0000
# Avg Obs:                       15.614   Distribution:                 F(10,3965)
# Min Obs:                       1.0000
# Max Obs:                       17.000   F-statistic (robust):             393.27
#                                         P-value                           0.0000
# Time periods:                      17   Distribution:                 F(10,3965)
# Avg Obs:                       249.82
# Min Obs:                       180.00
# Max Obs:                       271.00
#
#                                       Parameter Estimates
# ================================================================================================
#                               Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------------------
# VRM_ADJ_log                      0.3304     0.0105     31.531     0.0000      0.3099      0.3510
# FARE_per_UPT_log                -0.7415     0.0166    -44.753     0.0000     -0.7739     -0.7090
# POP_EMP_log                      0.9078     0.0864     10.502     0.0000      0.7384      1.0773
# GasPrice_log                     0.3275     0.0362     9.0552     0.0000      0.2566      0.3984
# TOTAL_MED_INC_INDIV_2018_log    -0.3501     0.0846    -4.1375     0.0000     -0.5159     -0.1842
# Tot_NonUSA_POP_pct               0.0316     0.0131     2.4028     0.0163      0.0058      0.0573
# PCT_HH_NO_VEH                    0.0148     0.0047     3.1877     0.0014      0.0057      0.0240
# TSD_POP_PCT                      0.6698     0.2277     2.9412     0.0033      0.2233      1.1163
# YEARS_SINCE_TNC_BUS             -0.0308     0.0050    -6.1167     0.0000     -0.0407     -0.0209
# YEARS_SINCE_TNC_RAIL             0.0331     0.0073     4.5614     0.0000      0.0189      0.0474
# ================================================================================================
#
# F-test for Poolability: 51.398
# P-value: 0.0000
# Distribution: F(271,3965)
#
# Included effects: Entity

# %%
# add BIKE SHARE

mod=PanelOLS.from_formula('UPT_ADJ_log \
                    ~ VRM_ADJ_log \
                    + FARE_per_UPT_log \
                    + POP_EMP_log \
                    + GasPrice_log \
                    + TOTAL_MED_INC_INDIV_2018_log \
                    + Tot_NonUSA_POP_pct \
                    + PCT_HH_NO_VEH \
                    + TSD_POP_PCT \
                    + YEARS_SINCE_TNC_BUS \
                    + YEARS_SINCE_TNC_RAIL \
                    + BIKE_SHARE_BUS \
                    + BIKE_SHARE_RAIL \
                    + EntityEffects \
                    ',data=df)
res=mod.fit()
print(res)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\data.py:39: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   new_df = df.copy().loc[self._full_index]
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\utility.py:476: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   warnings.warn(missing_value_warning_msg, MissingValueWarning)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:            UPT_ADJ_log   R-squared:                        0.5363
# Estimator:                   PanelOLS   R-squared (Between):              0.9846
# No. Observations:                4033   R-squared (Within):               0.5363
# Date:                Thu, Nov 21 2019   R-squared (Overall):              0.9855
# Time:                        12:30:40   Log-likelihood                   -410.06
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      362.81
# Entities:                         257   P-value                           0.0000
# Avg Obs:                       15.693   Distribution:                 F(12,3764)
# Min Obs:                       1.0000
# Max Obs:                       17.000   F-statistic (robust):             362.81
#                                         P-value                           0.0000
# Time periods:                      17   Distribution:                 F(12,3764)
# Avg Obs:                       237.24
# Min Obs:                       173.00
# Max Obs:                       257.00
#
#                                       Parameter Estimates
# ================================================================================================
#                               Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------------------
# VRM_ADJ_log                      0.4185     0.0119     35.245     0.0000      0.3952      0.4418
# FARE_per_UPT_log                -0.7514     0.0162    -46.323     0.0000     -0.7832     -0.7196
# POP_EMP_log                      1.0265     0.0982     10.454     0.0000      0.8340      1.2190
# GasPrice_log                     0.2761     0.0361     7.6473     0.0000      0.2053      0.3469
# TOTAL_MED_INC_INDIV_2018_log    -0.3406     0.0843    -4.0429     0.0001     -0.5058     -0.1754
# Tot_NonUSA_POP_pct               0.0267     0.0129     2.0613     0.0393      0.0013      0.0520
# PCT_HH_NO_VEH                    0.0127     0.0046     2.7544     0.0059      0.0036      0.0217
# TSD_POP_PCT                      0.7605     0.2261     3.3636     0.0008      0.3172      1.2037
# YEARS_SINCE_TNC_BUS             -0.0329     0.0060    -5.5213     0.0000     -0.0446     -0.0212
# YEARS_SINCE_TNC_RAIL             0.0077     0.0099     0.7829     0.4337     -0.0117      0.0272
# BIKE_SHARE_BUS                  -0.0273     0.0219    -1.2449     0.2133     -0.0703      0.0157
# BIKE_SHARE_RAIL                  0.0809     0.0411     1.9687     0.0491      0.0003      0.1615
# ================================================================================================
#
# F-test for Poolability: 49.665
# P-value: 0.0000
# Distribution: F(256,3764)
#
# Included effects: Entity

# %%
# add SCOOTERS

mod=PanelOLS.from_formula('UPT_ADJ_log \
                    ~ VRM_ADJ_log \
                    + FARE_per_UPT_log \
                    + POP_EMP_log \
                    + GasPrice_log \
                    + TOTAL_MED_INC_INDIV_2018_log \
                    + Tot_NonUSA_POP_pct \
                    + PCT_HH_NO_VEH \
                    + TSD_POP_PCT \
                    + YEARS_SINCE_TNC_BUS \
                    + YEARS_SINCE_TNC_RAIL \
                    + BIKE_SHARE_BUS \
                    + BIKE_SHARE_RAIL \
                    + scooter_flag_BUS \
                    + scooter_flag_RAIL \
                    + EntityEffects \
                    ',data=df)
res=mod.fit()
print(res)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\data.py:39: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   new_df = df.copy().loc[self._full_index]
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\utility.py:476: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   warnings.warn(missing_value_warning_msg, MissingValueWarning)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:            UPT_ADJ_log   R-squared:                        0.5369
# Estimator:                   PanelOLS   R-squared (Between):              0.9817
# No. Observations:                4033   R-squared (Within):               0.5369
# Date:                Thu, Nov 21 2019   R-squared (Overall):              0.9826
# Time:                        12:32:16   Log-likelihood                   -407.47
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      311.56
# Entities:                         257   P-value                           0.0000
# Avg Obs:                       15.693   Distribution:                 F(14,3762)
# Min Obs:                       1.0000
# Max Obs:                       17.000   F-statistic (robust):             311.56
#                                         P-value                           0.0000
# Time periods:                      17   Distribution:                 F(14,3762)
# Avg Obs:                       237.24
# Min Obs:                       173.00
# Max Obs:                       257.00
#
#                                       Parameter Estimates
# ================================================================================================
#                               Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------------------
# VRM_ADJ_log                      0.4185     0.0119     35.260     0.0000      0.3953      0.4418
# FARE_per_UPT_log                -0.7519     0.0162    -46.366     0.0000     -0.7837     -0.7201
# POP_EMP_log                      1.0290     0.0982     10.482     0.0000      0.8365      1.2214
# GasPrice_log                     0.2845     0.0364     7.8247     0.0000      0.2132      0.3558
# TOTAL_MED_INC_INDIV_2018_log    -0.3274     0.0845    -3.8759     0.0001     -0.4930     -0.1618
# Tot_NonUSA_POP_pct               0.0260     0.0129     2.0092     0.0446      0.0006      0.0514
# PCT_HH_NO_VEH                    0.0126     0.0046     2.7370     0.0062      0.0036      0.0216
# TSD_POP_PCT                      0.7895     0.2265     3.4858     0.0005      0.3454      1.2335
# YEARS_SINCE_TNC_BUS             -0.0312     0.0062    -4.9883     0.0000     -0.0434     -0.0189
# YEARS_SINCE_TNC_RAIL             0.0172     0.0110     1.5748     0.1154     -0.0042      0.0387
# BIKE_SHARE_BUS                  -0.0267     0.0219    -1.2206     0.2223     -0.0697      0.0162
# BIKE_SHARE_RAIL                  0.0724     0.0413     1.7514     0.0800     -0.0086      0.1534
# scooter_flag_BUS                -0.0430     0.0472    -0.9121     0.3618     -0.1355      0.0495
# scooter_flag_RAIL               -0.1413     0.0703    -2.0086     0.0447     -0.2792     -0.0034
# ================================================================================================
#
# F-test for Poolability: 49.706
# P-value: 0.0000
# Distribution: F(256,3762)
#
# Included effects: Entity

# %%
# add dock count

mod=PanelOLS.from_formula('UPT_ADJ_log \
                    ~ VRM_ADJ_log \
                    + FARE_per_UPT_log \
                    + POP_EMP_log \
                    + GasPrice_log \
                    + TOTAL_MED_INC_INDIV_2018_log \
                    + Tot_NonUSA_POP_pct \
                    + PCT_HH_NO_VEH \
                    + TSD_POP_PCT \
                    + YEARS_SINCE_TNC_BUS \
                    + YEARS_SINCE_TNC_RAIL \
                    + dockCt_BUS \
                    + dockCt_RAIL \
                    + scooter_flag_BUS \
                    + scooter_flag_RAIL \
                    + EntityEffects \
                    ',data=df)
res=mod.fit()
print(res)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\data.py:39: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   new_df = df.copy().loc[self._full_index]
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\utility.py:476: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   warnings.warn(missing_value_warning_msg, MissingValueWarning)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:            UPT_ADJ_log   R-squared:                        0.4987
# Estimator:                   PanelOLS   R-squared (Between):              0.9924
# No. Observations:                4247   R-squared (Within):               0.4987
# Date:                Thu, Nov 21 2019   R-squared (Overall):              0.9920
# Time:                        12:33:21   Log-likelihood                   -587.22
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      281.47
# Entities:                         272   P-value                           0.0000
# Avg Obs:                       15.614   Distribution:                 F(14,3961)
# Min Obs:                       1.0000
# Max Obs:                       17.000   F-statistic (robust):             281.47
#                                         P-value                           0.0000
# Time periods:                      17   Distribution:                 F(14,3961)
# Avg Obs:                       249.82
# Min Obs:                       180.00
# Max Obs:                       271.00
#
#                                       Parameter Estimates
# ================================================================================================
#                               Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------------------
# VRM_ADJ_log                      0.3301     0.0105     31.477     0.0000      0.3096      0.3507
# FARE_per_UPT_log                -0.7421     0.0166    -44.792     0.0000     -0.7746     -0.7096
# POP_EMP_log                      0.9061     0.0866     10.457     0.0000      0.7362      1.0759
# GasPrice_log                     0.3365     0.0364     9.2371     0.0000      0.2651      0.4079
# TOTAL_MED_INC_INDIV_2018_log    -0.3367     0.0849    -3.9658     0.0001     -0.5032     -0.1703
# Tot_NonUSA_POP_pct               0.0306     0.0132     2.3285     0.0199      0.0048      0.0564
# PCT_HH_NO_VEH                    0.0148     0.0047     3.1725     0.0015      0.0056      0.0239
# TSD_POP_PCT                      0.6981     0.2283     3.0572     0.0022      0.2504      1.1458
# YEARS_SINCE_TNC_BUS             -0.0280     0.0058    -4.8214     0.0000     -0.0393     -0.0166
# YEARS_SINCE_TNC_RAIL             0.0438     0.0099     4.4174     0.0000      0.0244      0.0633
# dockCt_BUS                   -4.659e-05     0.0001    -0.3167     0.7515     -0.0003      0.0002
# dockCt_RAIL                  -5.442e-05     0.0002    -0.3212     0.7481     -0.0004      0.0003
# scooter_flag_BUS                -0.0485     0.0485    -0.9997     0.3175     -0.1437      0.0466
# scooter_flag_RAIL               -0.1557     0.0712    -2.1859     0.0289     -0.2954     -0.0161
# ================================================================================================
#
# F-test for Poolability: 51.389
# P-value: 0.0000
# Distribution: F(271,3961)
#
# Included effects: Entity

# %%
# current favorite

mod=PanelOLS.from_formula('UPT_ADJ_log \
                    ~ VRM_ADJ_log \
                    + FARE_per_UPT_log \
                    + POP_EMP_log \
                    + GasPrice_log \
                    + TOTAL_MED_INC_INDIV_2018_log \
                    + Tot_NonUSA_POP_pct \
                    + PCT_HH_NO_VEH \
                    + TSD_POP_PCT \
                    + YEARS_SINCE_TNC_BUS \
                    + YEARS_SINCE_TNC_RAIL \
                    + BIKE_SHARE_BUS \
                    + BIKE_SHARE_RAIL \
                    + scooter_flag_BUS \
                    + scooter_flag_RAIL \
                    + EntityEffects \
                    ',data=df)
res=mod.fit()
print(res)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\data.py:39: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   new_df = df.copy().loc[self._full_index]
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\utility.py:476: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   warnings.warn(missing_value_warning_msg, MissingValueWarning)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:            UPT_ADJ_log   R-squared:                        0.5369
# Estimator:                   PanelOLS   R-squared (Between):              0.9817
# No. Observations:                4033   R-squared (Within):               0.5369
# Date:                Thu, Nov 21 2019   R-squared (Overall):              0.9826
# Time:                        12:34:31   Log-likelihood                   -407.47
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      311.56
# Entities:                         257   P-value                           0.0000
# Avg Obs:                       15.693   Distribution:                 F(14,3762)
# Min Obs:                       1.0000
# Max Obs:                       17.000   F-statistic (robust):             311.56
#                                         P-value                           0.0000
# Time periods:                      17   Distribution:                 F(14,3762)
# Avg Obs:                       237.24
# Min Obs:                       173.00
# Max Obs:                       257.00
#
#                                       Parameter Estimates
# ================================================================================================
#                               Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------------------
# VRM_ADJ_log                      0.4185     0.0119     35.260     0.0000      0.3953      0.4418
# FARE_per_UPT_log                -0.7519     0.0162    -46.366     0.0000     -0.7837     -0.7201
# POP_EMP_log                      1.0290     0.0982     10.482     0.0000      0.8365      1.2214
# GasPrice_log                     0.2845     0.0364     7.8247     0.0000      0.2132      0.3558
# TOTAL_MED_INC_INDIV_2018_log    -0.3274     0.0845    -3.8759     0.0001     -0.4930     -0.1618
# Tot_NonUSA_POP_pct               0.0260     0.0129     2.0092     0.0446      0.0006      0.0514
# PCT_HH_NO_VEH                    0.0126     0.0046     2.7370     0.0062      0.0036      0.0216
# TSD_POP_PCT                      0.7895     0.2265     3.4858     0.0005      0.3454      1.2335
# YEARS_SINCE_TNC_BUS             -0.0312     0.0062    -4.9883     0.0000     -0.0434     -0.0189
# YEARS_SINCE_TNC_RAIL             0.0172     0.0110     1.5748     0.1154     -0.0042      0.0387
# BIKE_SHARE_BUS                  -0.0267     0.0219    -1.2206     0.2223     -0.0697      0.0162
# BIKE_SHARE_RAIL                  0.0724     0.0413     1.7514     0.0800     -0.0086      0.1534
# scooter_flag_BUS                -0.0430     0.0472    -0.9121     0.3618     -0.1355      0.0495
# scooter_flag_RAIL               -0.1413     0.0703    -2.0086     0.0447     -0.2792     -0.0034
# ================================================================================================
#
# F-test for Poolability: 49.706
# P-value: 0.0000
# Distribution: F(256,3762)
#
# Included effects: Entity

# %%
# bike share plus scooters for rail
df['BIKE_SCOOTER_RAIL'] = df['BIKE_SHARE_RAIL'] + df['scooter_flag_RAIL']

mod=PanelOLS.from_formula('UPT_ADJ_log \
                    ~ VRM_ADJ_log \
                    + FARE_per_UPT_log \
                    + POP_EMP_log \
                    + GasPrice_log \
                    + TOTAL_MED_INC_INDIV_2018_log \
                    + Tot_NonUSA_POP_pct \
                    + PCT_HH_NO_VEH \
                    + TSD_POP_PCT \
                    + YEARS_SINCE_TNC_BUS \
                    + YEARS_SINCE_TNC_RAIL \
                    + BIKE_SHARE_BUS \
                    + scooter_flag_BUS \
                    + BIKE_SCOOTER_RAIL \
                    + EntityEffects \
                    ',data=df)
res=mod.fit()
print(res)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\data.py:39: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   new_df = df.copy().loc[self._full_index]
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\utility.py:476: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   warnings.warn(missing_value_warning_msg, MissingValueWarning)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:            UPT_ADJ_log   R-squared:                        0.5360
# Estimator:                   PanelOLS   R-squared (Between):              0.9834
# No. Observations:                4033   R-squared (Within):               0.5360
# Date:                Thu, Nov 21 2019   R-squared (Overall):              0.9842
# Time:                        12:40:23   Log-likelihood                   -411.52
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      334.37
# Entities:                         257   P-value                           0.0000
# Avg Obs:                       15.693   Distribution:                 F(13,3763)
# Min Obs:                       1.0000
# Max Obs:                       17.000   F-statistic (robust):             334.37
#                                         P-value                           0.0000
# Time periods:                      17   Distribution:                 F(13,3763)
# Avg Obs:                       237.24
# Min Obs:                       173.00
# Max Obs:                       257.00
#
#                                       Parameter Estimates
# ================================================================================================
#                               Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------------------
# VRM_ADJ_log                      0.4192     0.0119     35.294     0.0000      0.3959      0.4425
# FARE_per_UPT_log                -0.7508     0.0162    -46.273     0.0000     -0.7826     -0.7190
# POP_EMP_log                      1.0327     0.0982     10.512     0.0000      0.8401      1.2253
# GasPrice_log                     0.2769     0.0363     7.6318     0.0000      0.2058      0.3481
# TOTAL_MED_INC_INDIV_2018_log    -0.3419     0.0844    -4.0529     0.0001     -0.5074     -0.1765
# Tot_NonUSA_POP_pct               0.0268     0.0129     2.0705     0.0385      0.0014      0.0522
# PCT_HH_NO_VEH                    0.0125     0.0046     2.7138     0.0067      0.0035      0.0215
# TSD_POP_PCT                      0.7659     0.2265     3.3811     0.0007      0.3218      1.2100
# YEARS_SINCE_TNC_BUS             -0.0315     0.0063    -5.0432     0.0000     -0.0438     -0.0193
# YEARS_SINCE_TNC_RAIL             0.0160     0.0110     1.4649     0.1430     -0.0054      0.0375
# BIKE_SHARE_BUS                  -0.0273     0.0219    -1.2427     0.2141     -0.0703      0.0157
# scooter_flag_BUS                -0.0418     0.0472    -0.8842     0.3766     -0.1343      0.0508
# BIKE_SCOOTER_RAIL                0.0228     0.0372     0.6133     0.5397     -0.0501      0.0958
# ================================================================================================
#
# F-test for Poolability: 49.843
# P-value: 0.0000
# Distribution: F(256,3763)
#
# Included effects: Entity

# %% [markdown]
# ## Run some analytics

# %%
# bike share plus scooters for rail

mod=PanelOLS.from_formula('UPT_ADJ_log \
                    ~ VRM_ADJ_log \
                    + FARE_per_UPT_log \
                    + POP_EMP_log \
                    + GasPrice_log \
                    + TOTAL_MED_INC_INDIV_2018_log \
                    + Tot_NonUSA_POP_pct \
                    + PCT_HH_NO_VEH \
                    + TSD_POP_PCT \
                    + YEARS_SINCE_TNC_BUS \
                    + YEARS_SINCE_TNC_RAIL \
                    + BIKE_SHARE_BUS \
                    + scooter_flag_BUS \
                    + BIKE_SCOOTER_RAIL \
                    + EntityEffects \
                    ',data=df)
res=mod.fit()
print(res)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\panel\data.py:39: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   new_df = df.copy().loc[self._full_index]
# C:\Program Files\Anaconda3\lib\site-packages\linearmodels\utility.py:476: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   warnings.warn(missing_value_warning_msg, MissingValueWarning)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:            UPT_ADJ_log   R-squared:                        0.5360
# Estimator:                   PanelOLS   R-squared (Between):              0.9834
# No. Observations:                4033   R-squared (Within):               0.5360
# Date:                Thu, Nov 21 2019   R-squared (Overall):              0.9842
# Time:                        12:40:42   Log-likelihood                   -411.52
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      334.37
# Entities:                         257   P-value                           0.0000
# Avg Obs:                       15.693   Distribution:                 F(13,3763)
# Min Obs:                       1.0000
# Max Obs:                       17.000   F-statistic (robust):             334.37
#                                         P-value                           0.0000
# Time periods:                      17   Distribution:                 F(13,3763)
# Avg Obs:                       237.24
# Min Obs:                       173.00
# Max Obs:                       257.00
#
#                                       Parameter Estimates
# ================================================================================================
#                               Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------------------
# VRM_ADJ_log                      0.4192     0.0119     35.294     0.0000      0.3959      0.4425
# FARE_per_UPT_log                -0.7508     0.0162    -46.273     0.0000     -0.7826     -0.7190
# POP_EMP_log                      1.0327     0.0982     10.512     0.0000      0.8401      1.2253
# GasPrice_log                     0.2769     0.0363     7.6318     0.0000      0.2058      0.3481
# TOTAL_MED_INC_INDIV_2018_log    -0.3419     0.0844    -4.0529     0.0001     -0.5074     -0.1765
# Tot_NonUSA_POP_pct               0.0268     0.0129     2.0705     0.0385      0.0014      0.0522
# PCT_HH_NO_VEH                    0.0125     0.0046     2.7138     0.0067      0.0035      0.0215
# TSD_POP_PCT                      0.7659     0.2265     3.3811     0.0007      0.3218      1.2100
# YEARS_SINCE_TNC_BUS             -0.0315     0.0063    -5.0432     0.0000     -0.0438     -0.0193
# YEARS_SINCE_TNC_RAIL             0.0160     0.0110     1.4649     0.1430     -0.0054      0.0375
# BIKE_SHARE_BUS                  -0.0273     0.0219    -1.2427     0.2141     -0.0703      0.0157
# scooter_flag_BUS                -0.0418     0.0472    -0.8842     0.3766     -0.1343      0.0508
# BIKE_SCOOTER_RAIL                0.0228     0.0372     0.6133     0.5397     -0.0501      0.0958
# ================================================================================================
#
# F-test for Poolability: 49.843
# P-value: 0.0000
# Distribution: F(256,3763)
#
# Included effects: Entity

# %%
sns.distplot(res.resids)

# %%
sm.graphics.qqplot(res.resids,line = 'q')

# %% [markdown]
# ## Calculate FAC

# %%
# keep the relevant fields in the data set
app_data = pd.concat([df[['RAIL_FLAG', 'CLUSTER_APTA']], 
                      res.model.dependent.dataframe, 
                      res.model.exog.dataframe, 
                      res.estimated_effects, 
                      res.resids], axis=1)

# %%
app_data.head()
# Out:
#                                RAIL_FLAG  CLUSTER_APTA  UPT_ADJ_log  \
# Akron, OH Metro Area-Bus 2002          0          24.0    15.469231
#                          2003          0          24.0    15.501150
#                          2004          0          24.0    15.591676
#                          2005          0          24.0    15.609548
#                          2006          0          24.0    15.619001
#
#                                VRM_ADJ_log  FARE_per_UPT_log  POP_EMP_log  \
# Akron, OH Metro Area-Bus 2002    15.208377          0.108090    13.808216
#                          2003    15.195930          0.357460    13.823451
#                          2004    15.277699          0.326305    13.839439
#                          2005    15.214971          0.374152    13.857195
#                          2006    15.200501          0.385486    13.879496
#
#                                GasPrice_log  TOTAL_MED_INC_INDIV_2018_log  \
# Akron, OH Metro Area-Bus 2002      0.858662                     10.479210
#                          2003      0.936093                     10.446267
#                          2004      1.040277                     10.403980
#                          2005      1.178655                     10.365663
#                          2006      1.264127                     10.305856
#
#                                Tot_NonUSA_POP_pct  PCT_HH_NO_VEH  TSD_POP_PCT  \
# Akron, OH Metro Area-Bus 2002           -0.060245           8.60     0.185260
#                          2003            0.114214           8.20     0.180770
#                          2004            0.288851           7.79     0.176377
#                          2005            0.430267           7.47     0.172435
#                          2006            0.669812           6.85     0.167543
#
#                                YEARS_SINCE_TNC_BUS  YEARS_SINCE_TNC_RAIL  \
# Akron, OH Metro Area-Bus 2002                  0.0                   0.0
#                          2003                  0.0                   0.0
#                          2004                  0.0                   0.0
#                          2005                  0.0                   0.0
#                          2006                  0.0                   0.0
#
#                                BIKE_SHARE_BUS  scooter_flag_BUS  \
# Akron, OH Metro Area-Bus 2002             0.0               0.0
#                          2003             0.0               0.0
#                          2004             0.0               0.0
#                          2005             0.0               0.0
#                          2006             0.0               0.0
#
#                                BIKE_SCOOTER_RAIL   effects  residual
# Akron, OH Metro Area-Bus 2002                0.0 -1.794697 -0.192608
#                          2003                0.0 -1.794697 -0.012926
#                          2004                0.0 -1.794697 -0.036088
#                          2005                0.0 -1.794697 -0.022532
#                          2006                0.0 -1.794697 -0.060585

# %%
# calculate the fitted values
app_data['fitted'] = app_data['effects']
for var in res.params.keys(): 
    app_data['fitted'] = app_data['fitted'] + (res.params[var] * app_data[var])

# and check that we add up correctly
app_data['check_fitted'] = app_data['fitted'] + app_data['residual'] - app_data['UPT_ADJ_log']

# %%
# create the necessary columns

# dependents
app_data['UPT_ADJ']    = np.exp(app_data['UPT_ADJ_log']) - 1
app_data['fitted_exp'] = np.exp(app_data['fitted']) - 1

# linear versions of logged variables
for var in res.params.keys(): 
    if '_log' in var: 
        app_data[var.replace('_log', '')] = np.exp(app_data[var]) - 1              

# ratios and differences
for var in res.params.keys(): 
    if '_log' in var: 
        app_data[var.replace('_log', '_ratio')] = 1
    else: 
        app_data[var+'_diff'] = 0

# FAC multipliers
for var in res.params.keys(): 
    app_data[var+'_FAC_ratio'] = 1

app_data['UPT_ADJ_base'] = 0
app_data['UPT_ADJ_ratio'] = 1
app_data['fitted_exp_ratio'] = 1
app_data['UPT_ADJ_diff'] = 0
app_data['fitted_exp_diff'] = 0

# %%
# calculate the FAC relative to a specific base year
ids = app_data.index.get_level_values(0).unique()

for id in ids: 
    years = app_data.loc[id].index.get_level_values(0)

    for year in years[1:]:       
        base_year = year-1
        
        for var in res.params.keys(): 
            # ratios and differences
            if '_log' in var: 
                out_var = var.replace('_log', '_ratio')
                app_data.loc[(id,year), out_var] = (app_data.loc[(id,year), var] 
                                                 / app_data.loc[(id,base_year), var])
            else: 
                out_var = var+'_diff'                    
                app_data.loc[(id,year), out_var] = (app_data.loc[(id,year), var] 
                                                 - app_data.loc[(id,base_year), var])

            # FAC multipliers
            app_data.loc[(id,year),var+'_FAC_ratio'] = np.exp(res.params[var] * (
                                                    app_data.loc[(id,year), var] 
                                                    - app_data.loc[(id,base_year), var]))

            # estimated effects (if time effects is zero, no change)
            app_data.loc[(id,year),'effects_FAC_ratio'] = np.exp(
                                                    app_data.loc[(id,year), 'effects'] 
                                                    - app_data.loc[(id,base_year), 'effects'])

            # residual
            app_data.loc[(id,year),'residual_FAC_ratio'] = np.exp(
                                                    app_data.loc[(id,year), 'residual'] 
                                                    - app_data.loc[(id,base_year), 'residual'])

        # observed and fitted changes            
        app_data.loc[(id,year),'UPT_ADJ_base'] = app_data.loc[(id,base_year),'UPT_ADJ']
        app_data.loc[(id,year),'UPT_ADJ_ratio'] = (app_data.loc[(id,year),'UPT_ADJ'] 
                                                 / app_data.loc[(id,base_year),'UPT_ADJ'])
        app_data.loc[(id,year),'fitted_exp_ratio'] = (app_data.loc[(id,year),'fitted_exp'] 
                                                 / app_data.loc[(id,base_year),'fitted_exp'])

        app_data.loc[(id,year),'UPT_ADJ_diff'] = (app_data.loc[(id,year),'UPT_ADJ'] 
                                                 - app_data.loc[(id,base_year),'UPT_ADJ'])
        app_data.loc[(id,year),'fitted_exp_diff'] = (app_data.loc[(id,year),'fitted_exp'] 
                                                 - app_data.loc[(id,base_year),'fitted_exp'])
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:15: RuntimeWarning: divide by zero encountered in double_scalars
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:15: RuntimeWarning: invalid value encountered in double_scalars

# %%
# calculate the total change ratios

app_data['FAC_ratio'] = 1
for var in res.params.keys(): 
    app_data['FAC_ratio'] = app_data['FAC_ratio'] * app_data[var+'_FAC_ratio']
    
app_data['FAC_ratio'] = app_data['FAC_ratio'] * app_data['effects_FAC_ratio']

# %%
app_data
# Out:
#                                    RAIL_FLAG  CLUSTER_APTA  UPT_ADJ_log  \
# Akron, OH Metro Area-Bus     2002          0          24.0    15.469231
#                              2003          0          24.0    15.501150
#                              2004          0          24.0    15.591676
#                              2005          0          24.0    15.609548
#                              2006          0          24.0    15.619001
#                              2007          0          24.0    15.585152
#                              2008          0          24.0    15.630405
#                              2009          0          24.0    15.531262
#                              2010          0          24.0    15.541232
#                              2011          0          24.0    15.583482
#                              2012          0          24.0    15.606641
#                              2013          0          24.0    15.603275
#                              2014          0          24.0    15.604069
#                              2015          0          24.0    15.582683
#                              2016          0          24.0    15.520431
#                              2017          0          24.0    15.513200
#                              2018          0          24.0    15.506987
# Albany, GA Metro Area-Bus    2002          0          34.0    13.350813
#                              2003          0          34.0    13.416438
#                              2004          0          34.0    13.409539
#                              2005          0          34.0    13.390675
#                              2006          0          34.0    13.544766
#                              2007          0          34.0    13.550783
#                              2008          0          34.0    13.688660
#                              2009          0          34.0    13.677602
#                              2010          0          34.0    13.710602
#                              2011          0          34.0    13.801274
#                              2012          0          34.0    13.833006
#                              2013          0          34.0    13.832383
#                              2014          0          34.0    13.691188
# ...                                      ...           ...          ...
# Yuba City, CA Metro Area-Bus 2004          0          31.0     5.257495
#                              2005          0          31.0     5.451038
#                              2006          0          31.0    13.458463
#                              2007          0          31.0    13.609493
#                              2008          0          31.0    13.768215
#                              2012            0.739325           8.54
#                              2013            0.574760           8.07
#                              2014            0.588925           8.14
#                              2015            0.575086           8.38
#                              2016            0.778672           8.22
#                              2017            0.816910           7.79
#                              2018            0.896461           7.44
# Albany, GA Metro Area-Bus    2002            0.719558          14.66
#                              2003            0.626884          13.69
#                              2004            0.527071          12.73
#                              2005            0.481823          11.94
#                              2006            0.251421          10.69
#                              2007            0.777185          11.47
#                              2008            0.360573           9.97
#                              2009            0.516933           7.57
#                              2010            0.834875          11.19
#                              2011            0.548210          10.69
#                              2012            0.956012           9.61
#                              2013            0.503593          11.23
#                              2014            0.673674          10.98
# ...                                               ...            ...
# Yuba City, CA Metro Area-Bus 2004            2.047911           6.92
#                              2005            1.800838           6.43
#                              2006            1.590794           5.98
#                              2007            1.334243           5.53
#                              2008            1.418856           5.04
#                              2009            2.270764           6.54
#                              2010            1.294305           6.55
#                              2011            1.557043           6.44
#                              2012            1.756496           6.26
#                              2013            1.575671           7.82
#                              2014            1.406253           6.42
#                              2015            1.248282           7.97
#                              2016            1.872899           7.25
#                              2017            1.682414           7.67
#                              2018            1.694852           7.81
# Yuma, AZ Metro Area-Bus      2004                 NaN            NaN
#                              2005                 NaN            NaN
#                              2006                 NaN            NaN
#                              2007                 NaN            NaN
#                              2008                 NaN            NaN
#                              2009                 NaN            NaN
#                              2010                 NaN            NaN
#                              2011                 NaN            NaN
#                              2012                 NaN            NaN
#                              2013                 NaN            NaN
#                              2014                 NaN            NaN
#                              2015                 NaN            NaN
#                              2016                 NaN            NaN
#                              2017                 NaN            NaN
#                              2018                 NaN            NaN
#
#                                    TSD_POP_PCT  YEARS_SINCE_TNC_BUS  \
# Akron, OH Metro Area-Bus     2002     0.185260                  0.0
#                              2003     0.180770                  0.0
#                              2004     0.176377                  0.0
#                              2005     0.172435                  0.0
#                              2006     0.167543                  0.0
#                              2007     0.167084                  0.0
#                              2008     0.166435                  0.0
#                              2009     0.165268                  0.0
#                              2010     0.163724                  0.0
#                              2011     0.163236                  0.0
#                              2012     0.160892                  0.0
#                              2013     0.159320                  0.0
#                              2014     0.159639                  0.0
#                              2015     0.159340                  1.0
#                              2016     0.159134                  2.0
#                              2017     0.158745                  3.0
#                              2018     0.158403                  4.0
# Albany, GA Metro Area-Bus    2002     0.018961                  0.0
#                              2003     0.017386                  0.0
#                              2004     0.015890                  0.0
#                              2005     0.014530                  0.0
#                              2006     0.013068                  0.0
#                              2007     0.012331                  0.0
#                              2008     0.011387                  0.0
#                              2009     0.010393                  0.0
#                              2010     0.009572                  0.0
#                              2011     0.008706                  0.0
#                              2012     0.010405                  0.0
#                              2013     0.009778                  0.0
#                              2014     0.010905                  0.0
# ...                                        ...                  ...
# Yuba City, CA Metro Area-Bus 2004     0.094154                  0.0
#                              2005     0.092965                  0.0
#                              2006     0.090998                  0.0
#                              2007     0.092605                  0.0
#                              2008     0.094849                  0.0
#                              2009     0.097572                  0.0
#                              2010     0.099453                  0.0
#                              2011     0.102115                  0.0
#                              2012     0.099465                  0.0
#                              2013     0.100806                  0.0
#                              2013       1.046837          1.042147
#                              2014       1.030923          0.965818
#                              2015       0.972069          0.954047
#                              2016       0.895708          0.990012
#                              2017       0.893596          0.935392
#                              2018       0.952513          0.999273
# Yuma, AZ Metro Area-Bus      2004       1.000000          1.000000
#                              2005            NaN               NaN
#                              2006            NaN               NaN
#                              2007            NaN               NaN
#                              2008            NaN               NaN
#                              2009            NaN               NaN
#                              2010            NaN               NaN
#                              2011            NaN               NaN
#                              2012            NaN               NaN
#                              2013            NaN               NaN
#                              2014            NaN               NaN
#                              2015            NaN               NaN
#                              2016            NaN               NaN
#                              2017            NaN               NaN
#                              2018            NaN               NaN
#
#                                    UPT_ADJ_diff  fitted_exp_diff  \
# Akron, OH Metro Area-Bus     2002         0.000         0.000000
#                              2003    169516.228   -870406.202192
#                              2004    511260.393    658132.736745
#                              2005    106518.600     26482.803842
#                              2006     57116.538    299247.518555
#                              2007   -202051.341    301147.450575
#                              2008    271682.910   -261435.141998
#                              2009   -579574.924   -779692.963989
#                              2010     55713.742    153593.345802
#                              2011    242384.879    680080.241661
#                              2012    137271.784   -988896.032013
#                              2013    -20146.459      3975.727701
#                              2014      4743.689     24126.930014
#                              2015   -126546.805   -305611.969771
#                              2016   -353330.321   -320082.343061
#                              2017    -39633.043   -162981.710019
#                              2018    -33825.975    -95970.426482
# Albany, GA Metro Area-Bus    2002         0.000         0.000000
#                              2003     42617.000     62247.745360
#                              2004     -4613.000     11456.440593
#                              2005    -12452.000     50091.752099
#                              2006    108934.000     70277.753661
#                              2007      4604.000     20367.010730
#                              2008    113450.000     43827.282294
#                              2009     -9687.000    -93525.398143
#                              2010     29229.000     52661.333965
#                              2011     85457.000     58622.892241
#                              2012     31785.000    -79163.996862
#                              2013      -633.000     10854.641339
#                              2014   -133921.000    -41954.011472
# ...                                         ...              ...
# Yuba City, CA Metro Area-Bus 2004        18.000       128.667045
#                              2005        41.000       555.254411
#                              2006    699506.000    536561.294985
#                              2007    114080.000     34880.172228
#                              2008    139986.000     16184.088646
#                              2009     46831.000    -12468.923042
#                              2010     11620.000     26149.376284
#                              2011     99013.000     21931.318437
#                              2012     18249.000      7046.902344
#                              2013     52903.000     26662.870486
#                              2014     36564.000    -22535.364571
#                              2015    -34047.000    -29260.541137
#                              2016   -123580.000     -6067.529516
#                              2017   -112933.000    -38856.183099
#                              2018    -45038.000      -408.936606
# Yuma, AZ Metro Area-Bus      2004         0.000         0.000000
#                              2005           NaN              NaN
#                              2006           NaN              NaN
#                              2007           NaN              NaN
#                              2008           NaN              NaN
#                              2009           NaN              NaN
#                              2010           NaN              NaN
#                              2011           NaN              NaN
#                              2012           NaN              NaN
#                              2013           NaN              NaN
#                              2014           NaN              NaN
#                              2015           NaN              NaN
#                              2016           NaN              NaN
#                              2017           NaN              NaN
#                              2018           NaN              NaN
#
#                                    effects_FAC_ratio  residual_FAC_ratio  \
# Akron, OH Metro Area-Bus     2002                NaN                 NaN
#                              2003                1.0            1.196837
#                              2004                1.0            0.977104
#                              2005                1.0            1.013649
#                              2011         NaN
#                              2012         NaN
#                              2013         NaN
#                              2014         NaN
#                              2015         NaN
#                              2016         NaN
#                              2017         NaN
#                              2018         NaN
#
# [4535 rows x 61 columns]

# %%
# calculate the FAC
app_data['Total_FAC'] = 0
for var in res.params.keys(): 
    app_data[var+'_FAC'] = (app_data[var+'_FAC_ratio'] - 1) * app_data['UPT_ADJ_base']
    app_data['Total_FAC'] = app_data['Total_FAC'] + app_data[var+'_FAC']
app_data['effects_FAC'] = (app_data['effects_FAC_ratio'] - 1) * app_data['UPT_ADJ_base']
app_data['Total_FAC'] = app_data['Total_FAC'] + app_data['effects_FAC']

# scale the FAC
app_data['FAC_scale'] = app_data['fitted_exp_diff'] / app_data['Total_FAC']
app_data['FAC_scale'] = app_data['FAC_scale'].fillna(1)

app_data['Total_FAC_scaled'] = 0
for var in res.params.keys(): 
    app_data[var+'_FAC_scaled'] = app_data[var+'_FAC'] * app_data['FAC_scale']
    app_data['Total_FAC_scaled'] = app_data['Total_FAC_scaled'] + app_data[var+'_FAC_scaled']
app_data['effects_FAC_scaled'] = app_data[var+'_FAC_scaled'] * app_data['FAC_scale']
app_data['Total_FAC_scaled'] = app_data['Total_FAC_scaled'] + app_data['effects_FAC_scaled']

# %%
# reset the index so I get ID and year
app_data = app_data.reset_index()
app_data = app_data.rename(columns={'level_0' : 'ID', 'level_1' : 'Year'})
app_data.to_csv('FAC.csv')

# %%
# these are the fields we keep
out_fields = ['ID', 'Year', 'RAIL_FLAG', 
              'CLUSTER_APTA',  
              'UPT_ADJ_base', 'UPT_ADJ', 'UPT_ADJ_diff', 
              'fitted_exp', 'fitted_exp_diff']

# exogenous variables 
for var in res.params.keys(): 
    out_var = var.replace('_log', '')
    out_fields = out_fields + [out_var]
    
# FAC
for var in res.params.keys(): 
    out_fields = out_fields + [var+'_FAC']
out_fields = out_fields + ['Total_FAC']
    
# scaled FAC
for var in res.params.keys(): 
    out_fields = out_fields + [var+'_FAC_scaled']
out_fields = out_fields + ['Total_FAC_scaled']

# keep those fields
summary_data = app_data.reset_index()[out_fields]

# %%
# take weighted average of exogenous variables
for var in res.params.keys(): 
    out_var = var.replace('_log', '')
    summary_data[out_var] = summary_data[out_var] * summary_data['UPT_ADJ_base']

# aggregate to bus/rail totals
summary_data_apta = summary_data.groupby(by=['CLUSTER_APTA', 'RAIL_FLAG', 'Year']).agg('sum')

# divide for weighted averages
for var in res.params.keys(): 
    out_var = var.replace('_log', '')
#    summary_data_gt[out_var] = summary_data_gt[out_var] / summary_data_gt['UPT_ADJ_base']
    summary_data_apta[out_var] = summary_data_apta[out_var] / summary_data_apta['UPT_ADJ_base']
#    summary_data_apta_hml[out_var] = summary_data_apta_hml[out_var] / summary_data_apta_hml['UPT_ADJ_base']

# %%
#summary_data_gt.to_csv('FAC_totals_GT_CLUSTERS.csv')
summary_data_apta.to_csv('FAC_totals_APTA_CLUSTERS.csv')
#summary_data_apta_hml.to_csv('FAC_totals_APTA_HML_CLUSTERS.csv')

# %%
summary_data_apta.head(20)
